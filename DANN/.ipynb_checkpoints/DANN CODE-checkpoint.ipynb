# %% [markdown]
# # NEWEST

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(5112, 256),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(256, 256),
    nn.Sigmoid(),
    nn.Linear(256, 56),
    nn.Sigmoid(),
    nn.Linear(56, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(256, 128),
    nn.Sigmoid(),
    nn.Linear(128, 128), nn.Sigmoid(),              
    nn.Linear(128, 2),
    nn.Sigmoid()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 256)
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %% [markdown]
# # DATA

# %%
import pandas as pd
import numpy as np
import rowgenerators as rg

from sklearn.feature_selection import VarianceThreshold

scfp = pd.read_stata('p19i6.dta')



# SELECT only rows where there is debt and where white and black
delinquency = 'x3005'
loan_schedule ='x3004'# 1 on time, 5 sometimes late, 0 inapp.
race = 'x6809'
additional_race = 'x6810'
hispanic = 'x7004'

scfp = scfp[(scfp[race] == 1) | (scfp[race] == 2)]
scfp =  scfp[(scfp[loan_schedule] == 1) | (scfp[loan_schedule] == 5)]
scfp.shape

# Remove revealing columns
race_revealing = [additional_race, 'x7004']
race_revealing += [col.replace('x', 'j') for col in race_revealing]
sched_revealing = ['x7571', 'x7570', 'x7569', 'x7556', 'x7564', 'x7554','x7553',
                   'x7534', 'x7533', 'x7532', 'x7166', 'x7529', 'x7821', 'x7844',
                   'x7867', 'x7921', 'x7569', 'x7944', 'x7521', 'x7520', 'x7518',
                   'x7517', delinquency, 'j3005', 'j3004']
sched_revealing += [col.replace('x', 'j') for col in sched_revealing]

exclude = sched_revealing+ race_revealing
X = scfp.copy()
# Eliminate bad columns
X = scfp.loc[:, [col for col in scfp.columns if col not in exclude]]
X = X.fillna(-1)

# Remove columns with all -1

# instantiate the VarianceThreshold object with a threshold of 0
selector = VarianceThreshold(threshold=0)

# fit the selector on the DataFrame
selector.fit(X)

# get the indices of the non-constant columns
non_constant_cols = selector.get_support(indices=True)

# select the non-constant columns from the original DataFrame
X = X.iloc[:, non_constant_cols]

# print the filtered DataFrame
print(X.shape)
# Out:
# (18362, 5114)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

# split to source (white) and target (black)
# First, create a new column in X that indicates whether each person is white or black
print(len(X))
# Use groupby to split X and y into two separate dataframes, one with only white data and the other with only black data
X_white = X[X[race] == 1]
y_white = X_white[loan_schedule].replace({1: 0, 5: 1})
X_white = X_white.drop([race, loan_schedule], axis =1)
#print(y_white)
print(len(y_white))
print(len(X_white))

X_black = X[X[race]==2]
y_black = X_black[loan_schedule].replace({1: 0, 5: 1})
X_black = X_black.drop([race, loan_schedule], axis =1)
#print(y_black)
print(len(y_black))
print(len(X_black))
# Out:
# 18362
# 15615
# 15615
# 2747
# 2747

# %%
from sklearn.preprocessing import StandardScaler

X_tensor_source =  torch.from_numpy(X_white.values).type(torch.float32)
X_tensor_target =  torch.from_numpy(X_black.values).type(torch.float32)
y_tensor_source =torch.tensor(y_white.values).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_black.values).type(torch.LongTensor)


# Split the source (race) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (loan sched) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train)
num_positives = sum(target_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size, sampler=sampler)
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size, sampler = sampler)
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

print(X_train_source.shape)
print(X_train_target.shape)
# Out:
# positive weight (under represented): 0.0016835016835016834
# negative weight (over represented): 0.0006238303181534623
# positive weight (under represented): 0.0006622516556291391
# negative weight (over represented): 9.105809506465124e-05
# torch.Size([12492, 5112])
# torch.Size([2197, 5112])

# %%
combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)

y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size, sampler=sampler)



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples))
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size, sampler=sampler)
# Out:
# 2197
# tensor([0, 0, 0,  ..., 1, 1, 1])
# [12492  2197]
# [8.00512328e-05 4.55166136e-04]
# 2104
# 12585
# [7.94596742e-05 4.75285171e-04]

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch
       

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.0001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 20
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
'''lambda = 0
label trained
domain trained
feature extractor trained
Epoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133
Source Label Accuracy: 96.33%
Target Label Accuracy: 97.27%
Source Domain Accuracy: 89.32%
Target Domain Accuracy: 84.73%
domain accuracy on train data:  0.901286677105317
black predicted:  0.4585063653073729
num actually black:  0.48519300156579753
domain test accuracy:  0.906071331336782
black pred test:  0.19793084671930303
actual black =  0.14974135583991288
Credit Confusion Matrix White: 
[[2673   64]
 [  40  346]]
False positive white:  0.023383266350018268
Credit Confusion Matrix Black: 
[[376   7]
 [  8 159]]
False positive black:  0.018276762402088774

'''
# Out:
# 'lambda = 0\nlabel trained\ndomain trained\nfeature extractor trained\nEpoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133\nSource Label Accuracy: 96.33%\nTarget Label Accuracy: 97.27%\nSource Domain Accuracy: 89.32%\nTarget Domain Accuracy: 84.73%\ndomain accuracy on train data:  0.901286677105317\nblack predicted:  0.4585063653073729\nnum actually black:  0.48519300156579753\ndomain test accuracy:  0.906071331336782\nblack pred test:  0.19793084671930303\nactual black =  0.14974135583991288\nCredit Confusion Matrix White: \n[[2673   64]\n [  40  346]]\nFalse positive white:  0.023383266350018268\nCredit Confusion Matrix Black: \n[[376   7]\n [  8 159]]\nFalse positive black:  0.018276762402088774\n\n'

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall}
        return results

# %%
#write_results(0.8, model, source_test, target_test)

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5813, Domain Loss: 0.7278
# Source Label Accuracy: 73.85%
# Target Label Accuracy: 66.73%
# Source Domain Accuracy: 55.59%
# Target Domain Accuracy: 82.36%
# domain accuracy on train data:  0.7276193069643951
# black predicted:  0.5510245762134931
# num actually black:  0.49989788276941927
# domain test accuracy:  0.6904437789273074
# black pred test:  0.40647971685270895
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2470  267]
#  [ 211  175]]
# False positive white:  0.09755206430398246
# Credit Confusion Matrix Black:
# [[255 128]
#  [ 55 112]]
# False positive black:  0.3342036553524804
# Predictive parity:  0.17966931563473354
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6119, Domain Loss: 0.4150
# Source Label Accuracy: 75.57%
# Target Label Accuracy: 71.27%
# Source Domain Accuracy: 62.93%
# Target Domain Accuracy: 71.45%
# domain accuracy on train data:  0.7217645857444346
# black predicted:  0.4725304649737899
# num actually black:  0.5010552113826673
# domain test accuracy:  0.7367274707323713
# black pred test:  0.32752518377348216
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2442  295]
#  [ 181  205]]
# False positive white:  0.10778224333211546
# Credit Confusion Matrix Black:
# [[274 109]
#  [ 49 118]]
# False positive black:  0.2845953002610966
# Predictive parity:  0.13485518004249986
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5422, Domain Loss: 0.3796
# Source Label Accuracy: 76.37%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 55.20%
# Target Domain Accuracy: 79.45%
# domain accuracy on train data:  0.7226496017428007
# black predicted:  0.5577643134318198
# num actually black:  0.5007148206140649
# domain test accuracy:  0.6776476994282603
# black pred test:  0.4105635720119793
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2504  233]
#  [ 185  201]]
# False positive white:  0.08512970405553526
# Credit Confusion Matrix Black:
# [[288  95]
#  [ 43 124]]
# False positive black:  0.24804177545691905
# Predictive parity:  0.117063429685908
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5792, Domain Loss: 0.3572
# Source Label Accuracy: 78.35%
# Target Label Accuracy: 72.91%
# Source Domain Accuracy: 62.93%
# Target Domain Accuracy: 72.55%
# domain accuracy on train data:  0.7206072571311866
# black predicted:  0.4794063584995575
# num actually black:  0.4999659609231398
# domain test accuracy:  0.7250204192757963
# black pred test:  0.34249931935747346
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2438  299]
#  [ 152  234]]
# False positive white:  0.1092436974789916
# Credit Confusion Matrix Black:
# [[274 109]
#  [ 40 127]]
# False positive black:  0.2845953002610966
# Predictive parity:  0.12649666695776207
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4708, Domain Loss: 0.4259
# Source Label Accuracy: 80.36%
# Target Label Accuracy: 79.09%
# Source Domain Accuracy: 65.94%
# Target Domain Accuracy: 70.36%
# domain accuracy on train data:  0.7157737082170331
# black predicted:  0.4587105997685343
# num actually black:  0.5031656341480019
# domain test accuracy:  0.7419003539341138
# black pred test:  0.3190852164443234
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2478  259]
#  [ 152  234]]
# False positive white:  0.09462915601023018
# Credit Confusion Matrix Black:
# [[308  75]
#  [ 40 127]]
# False positive black:  0.195822454308094
# Predictive parity:  0.0774866823858178
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5042, Domain Loss: 0.4345
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 77.27%
# Source Domain Accuracy: 57.77%
# Target Domain Accuracy: 80.36%
# domain accuracy on train data:  0.726598134658588
# black predicted:  0.5412213220777452
# num actually black:  0.5026890870719586
# domain test accuracy:  0.7013340593520283
# black pred test:  0.3895997821943915
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2483  254]
#  [ 152  234]]
# False positive white:  0.092802338326635
# Credit Confusion Matrix Black:
# [[294  89]
#  [ 36 131]]
# False positive black:  0.23237597911227154
# Predictive parity:  0.0972695252234157
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5679, Domain Loss: 0.4139
# Source Label Accuracy: 82.31%
# Target Label Accuracy: 80.91%
# Source Domain Accuracy: 61.00%
# Target Domain Accuracy: 75.64%
# domain accuracy on train data:  0.7338824971066785
# black predicted:  0.5003063516917421
# num actually black:  0.49642589692967526
# domain test accuracy:  0.7247481622651784
# black pred test:  0.3520283147291043
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2531  206]
#  [ 145  241]]
# False positive white:  0.07526488856412131
# Credit Confusion Matrix Black:
# [[307  76]
#  [ 29 138]]
# False positive black:  0.19843342036553524
# Predictive parity:  0.07851716007335607
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4856, Domain Loss: 0.3801
# Source Label Accuracy: 83.89%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 58.84%
# Target Domain Accuracy: 79.27%
# domain accuracy on train data:  0.7263939001974267
# black predicted:  0.5203213288855606
# num actually black:  0.49438355231806114
# domain test accuracy:  0.709501769670569
# black pred test:  0.37816498774843454
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2449  288]
#  [ 126  260]]
# False positive white:  0.10522469857508221
# Credit Confusion Matrix Black:
# [[290  93]
#  [ 30 137]]
# False positive black:  0.24281984334203655
# Predictive parity:  0.09107152213780456
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4813, Domain Loss: 0.3433
# Source Label Accuracy: 85.51%
# Target Label Accuracy: 76.91%
# Source Domain Accuracy: 57.21%
# Target Domain Accuracy: 81.09%
# domain accuracy on train data:  0.7276873851181156
# black predicted:  0.5481652937572333
# num actually black:  0.502008305534754
# domain test accuracy:  0.6915328069697795
# black pred test:  0.40157909066158454
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2495  242]
#  [ 101  285]]
# False positive white:  0.08841797588600658
# Credit Confusion Matrix Black:
# [[280 103]
#  [ 24 143]]
# False positive black:  0.2689295039164491
# Predictive parity:  0.12107879952260359
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4896, Domain Loss: 0.3797
# Source Label Accuracy: 86.97%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 64.23%
# Target Domain Accuracy: 73.27%
# domain accuracy on train data:  0.7314316835727415
# black predicted:  0.4765470760432977
# num actually black:  0.5011232895363877
# domain test accuracy:  0.7446229240402941
# black pred test:  0.32507487067791996
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2500  237]
#  [ 105  281]]
# False positive white:  0.0865911582024114
# Credit Confusion Matrix Black:
# [[292  91]
#  [ 18 149]]
# False positive black:  0.23759791122715404
# Predictive parity:  0.08867173172648679
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5285, Domain Loss: 0.3802
# Source Label Accuracy: 85.98%
# Target Label Accuracy: 80.36%
# Source Domain Accuracy: 56.65%
# Target Domain Accuracy: 80.18%
# domain accuracy on train data:  0.7333378718769147
# black predicted:  0.5505480291374498
# num actually black:  0.5045952753761318
# domain test accuracy:  0.7018785733732643
# black pred test:  0.38851075415191944
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2543  194]
#  [ 116  270]]
# False positive white:  0.07088052612349288
# Credit Confusion Matrix Black:
# [[303  80]
#  [ 28 139]]
# False positive black:  0.20887728459530025
# Predictive parity:  0.09710010770529509
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4853, Domain Loss: 0.3651
# Source Label Accuracy: 86.65%
# Target Label Accuracy: 82.55%
# Source Domain Accuracy: 60.99%
# Target Domain Accuracy: 76.36%
# domain accuracy on train data:  0.7347675131050446
# black predicted:  0.5039825719926475
# num actually black:  0.49771938185036424
# domain test accuracy:  0.7258371903076504
# black pred test:  0.35311734277157636
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2503  234]
#  [ 105  281]]
# False positive white:  0.0854950675922543
# Credit Confusion Matrix Black:
# [[300  83]
#  [ 13 154]]
# False positive black:  0.21671018276762402
# Predictive parity:  0.06599598288359099
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4592, Domain Loss: 0.3849
# Source Label Accuracy: 88.08%
# Target Label Accuracy: 87.45%
# Source Domain Accuracy: 60.12%
# Target Domain Accuracy: 76.18%
# domain accuracy on train data:  0.7383756552522296
# black predicted:  0.5162366396623324
# num actually black:  0.5043229627612499
# domain test accuracy:  0.7233868772120882
# black pred test:  0.35502314184590256
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2554  183]
#  [  94  292]]
# False positive white:  0.06686152721958348
# Credit Confusion Matrix Black:
# [[329  54]
#  [ 15 152]]
# False positive black:  0.1409921671018277
# Predictive parity:  0.03675777952435011
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3461, Domain Loss: 0.3692
# Source Label Accuracy: 88.09%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 67.50%
# Target Domain Accuracy: 70.36%
# domain accuracy on train data:  0.7333378718769147
# black predicted:  0.44979236163115255
# num actually black:  0.5005105861529036
# domain test accuracy:  0.7658589708684999
# black pred test:  0.29512659950993736
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2560  177]
#  [  96  290]]
# False positive white:  0.06466934599926927
# Credit Confusion Matrix Black:
# [[326  57]
#  [ 14 153]]
# False positive black:  0.14882506527415143
# Predictive parity:  0.04167496288533756
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3910, Domain Loss: 0.3620
# Source Label Accuracy: 87.67%
# Target Label Accuracy: 88.91%
# Source Domain Accuracy: 62.48%
# Target Domain Accuracy: 78.18%
# domain accuracy on train data:  0.7410987814010485
# black predicted:  0.502757165225679
# num actually black:  0.5035060249166042
# domain test accuracy:  0.7353661856792812
# black pred test:  0.349033487612306
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2601  136]
#  [ 118  268]]
# False positive white:  0.049689440993788817
# Credit Confusion Matrix Black:
# [[343  40]
#  [ 21 146]]
# False positive black:  0.10443864229765012
# Predictive parity:  0.029577038395482202
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4318, Domain Loss: 0.3633
# Source Label Accuracy: 88.69%
# Target Label Accuracy: 90.36%
# Source Domain Accuracy: 67.42%
# Target Domain Accuracy: 72.55%
# domain accuracy on train data:  0.7447069235482334
# black predicted:  0.4659268840629042
# num actually black:  0.4984682415412894
# domain test accuracy:  0.7623196297304655
# black pred test:  0.30520010890280425
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2575  162]
#  [  99  287]]
# False positive white:  0.05918889294848374
# Credit Confusion Matrix Black:
# [[347  36]
#  [ 17 150]]
# False positive black:  0.09399477806788512
# Predictive parity:  0.012790149331936007
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3775, Domain Loss: 0.3720
# Source Label Accuracy: 89.82%
# Target Label Accuracy: 90.18%
# Source Domain Accuracy: 64.23%
# Target Domain Accuracy: 76.18%
# domain accuracy on train data:  0.746681190006127
# black predicted:  0.49880863230989175
# num actually black:  0.49805977261896656
# domain test accuracy:  0.7465287231146202
# black pred test:  0.33188129594337057
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2579  158]
#  [  80  306]]
# False positive white:  0.0577274388016076
# Credit Confusion Matrix Black:
# [[345  38]
#  [ 16 151]]
# False positive black:  0.09921671018276762
# Predictive parity:  0.02197304456670446
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3255, Domain Loss: 0.3303
# Source Label Accuracy: 91.88%
# Target Label Accuracy: 89.09%
# Source Domain Accuracy: 64.05%
# Target Domain Accuracy: 76.55%
# domain accuracy on train data:  0.744502689087072
# black predicted:  0.5028252433793996
# num actually black:  0.5022125399959153
# domain test accuracy:  0.7476177511570923
# black pred test:  0.33188129594337057
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2596  141]
#  [  73  313]]
# False positive white:  0.051516258677384
# Credit Confusion Matrix Black:
# [[336  47]
#  [ 13 154]]
# False positive black:  0.1227154046997389
# Predictive parity:  0.04056705382353798
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3346, Domain Loss: 0.3300
# Source Label Accuracy: 91.29%
# Target Label Accuracy: 91.27%
# Source Domain Accuracy: 65.82%
# Target Domain Accuracy: 78.18%
# domain accuracy on train data:  0.7661515419701818
# black predicted:  0.5118796378242222
# num actually black:  0.5011913676901082
# domain test accuracy:  0.756057718486251
# black pred test:  0.32834195480533623
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2610  127]
#  [  79  307]]
# False positive white:  0.0464011691633175
# Credit Confusion Matrix Black:
# [[348  35]
#  [ 13 154]]
# False positive black:  0.09138381201044386
# Predictive parity:  0.02131051145460372
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3365, Domain Loss: 0.3200
# Source Label Accuracy: 91.25%
# Target Label Accuracy: 92.36%
# Source Domain Accuracy: 68.71%
# Target Domain Accuracy: 75.64%
# domain accuracy on train data:  0.7783375314861462
# black predicted:  0.4744366532779631
# num actually black:  0.49622166246851385
# domain test accuracy:  0.7759324802613667
# black pred test:  0.3008439967329159
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2617  120]
#  [  79  307]]
# False positive white:  0.043843624406284254
# Credit Confusion Matrix Black:
# [[354  29]
#  [ 13 154]]
# False positive black:  0.07571801566579635
# Predictive parity:  0.012642855063604408
#
# Lambda: 0.0
#
# Label Classifier Accuracy (Test Data)
# Source (White): 93.6279218699968
# Target (Black): 92.36363636363636
# Overall: 93.43860604410564
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 77.93788024335575
# Target (Black): 75.63636363636364
# Overall: 77.59324802613668
#
# False Positive Rate (Test Data)
# Source (White): 4.384362440628426
# Target (Black): 7.5718015665796345
# (Black FPR) / (White FPR): 1.727001740644038
# Overall: 4.7756410256410255
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5901, Domain Loss: 0.5447
# Source Label Accuracy: 71.95%
# Target Label Accuracy: 69.64%
# Source Domain Accuracy: 59.72%
# Target Domain Accuracy: 74.00%
# domain accuracy on train data:  0.7154333174484308
# black predicted:  0.5103819184423718
# num actually black:  0.4963578187759548
# domain test accuracy:  0.697250204192758
# black pred test:  0.3746256466104002
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2509  228]
#  [ 232  154]]
# False positive white:  0.08330288637194008
# Credit Confusion Matrix Black:
# [[278 105]
#  [ 62 105]]
# False positive black:  0.2741514360313316
# Predictive parity:  0.15634209530463128
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5633, Domain Loss: 0.4807
# Source Label Accuracy: 75.82%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 58.64%
# Target Domain Accuracy: 80.91%
# domain accuracy on train data:  0.7223092109741984
# black predicted:  0.5407447750017019
# num actually black:  0.5037783375314862
# domain test accuracy:  0.7024230873945004
# black pred test:  0.3901442962156276
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2470  267]
#  [ 186  200]]
# False positive white:  0.09755206430398246
# Credit Confusion Matrix Black:
# [[287  96]
#  [ 43 124]]
# False positive black:  0.2506527415143603
# Predictive parity:  0.10767443891363193
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4334, Domain Loss: 0.4267
# Source Label Accuracy: 79.23%
# Target Label Accuracy: 76.36%
# Source Domain Accuracy: 50.79%
# Target Domain Accuracy: 82.91%
# domain accuracy on train data:  0.7169310368302811
# black predicted:  0.5863571379944176
# num actually black:  0.49676628769827763
# domain test accuracy:  0.6487884563027498
# black pred test:  0.44976858154097465
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2521  216]
#  [ 171  215]]
# False positive white:  0.07891852393131166
# Credit Confusion Matrix Black:
# [[296  87]
#  [ 43 124]]
# False positive black:  0.22715404699738903
# Predictive parity:  0.11244432800628767
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5440, Domain Loss: 0.5586
# Source Label Accuracy: 79.80%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 51.91%
# Target Domain Accuracy: 82.18%
# domain accuracy on train data:  0.7221730546667574
# black predicted:  0.5967050173599292
# num actually black:  0.5037783375314862
# domain test accuracy:  0.6564116526000544
# black pred test:  0.43996732915872583
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2515  222]
#  [ 167  219]]
# False positive white:  0.08111070515162587
# Credit Confusion Matrix Black:
# [[291  92]
#  [ 47 120]]
# False positive black:  0.2402088772845953
# Predictive parity:  0.12816755450761208
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5165, Domain Loss: 0.4972
# Source Label Accuracy: 80.60%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 55.01%
# Target Domain Accuracy: 82.73%
# domain accuracy on train data:  0.7398733746340799
# black predicted:  0.5706310844849888
# num actually black:  0.49880863230989175
# domain test accuracy:  0.6784644704601144
# black pred test:  0.4195480533623741
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2518  219]
#  [ 160  226]]
# False positive white:  0.08001461454146876
# Credit Confusion Matrix Black:
# [[293  90]
#  [ 38 129]]
# False positive black:  0.2349869451697128
# Predictive parity:  0.1113696038191716
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5705, Domain Loss: 0.5182
# Source Label Accuracy: 83.30%
# Target Label Accuracy: 77.09%
# Source Domain Accuracy: 56.73%
# Target Domain Accuracy: 80.36%
# domain accuracy on train data:  0.734971747566206
# black predicted:  0.5380897270066036
# num actually black:  0.5007148206140649
# domain test accuracy:  0.6956166621290498
# black pred test:  0.39531717941737
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2561  176]
#  [ 146  240]]
# False positive white:  0.06430398246255024
# Credit Confusion Matrix Black:
# [[297  86]
#  [ 40 127]]
# False positive black:  0.2245430809399478
# Predictive parity:  0.12598492125869654
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4889, Domain Loss: 0.4485
# Source Label Accuracy: 84.18%
# Target Label Accuracy: 80.55%
# Source Domain Accuracy: 51.76%
# Target Domain Accuracy: 82.73%
# domain accuracy on train data:  0.7072639390019743
# black predicted:  0.5986792838178229
# num actually black:  0.4984682415412894
# domain test accuracy:  0.6534168254832562
# black pred test:  0.44459569833923224
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2561  176]
#  [ 144  242]]
# False positive white:  0.06430398246255024
# Credit Confusion Matrix Black:
# [[312  71]
#  [ 36 131]]
# False positive black:  0.185378590078329
# Predictive parity:  0.09207987657555383
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4406, Domain Loss: 0.4584
# Source Label Accuracy: 84.61%
# Target Label Accuracy: 80.55%
# Source Domain Accuracy: 54.13%
# Target Domain Accuracy: 81.45%
# domain accuracy on train data:  0.7253727278916196
# black predicted:  0.5744434610933351
# num actually black:  0.5011913676901082
# domain test accuracy:  0.6830928396406207
# black pred test:  0.41110808603321536
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2567  170]
#  [ 132  254]]
# False positive white:  0.062111801242236024
# Credit Confusion Matrix Black:
# [[308  75]
#  [ 32 135]]
# False positive black:  0.195822454308094
# Predictive parity:  0.09784356533636074
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4133, Domain Loss: 0.4731
# Source Label Accuracy: 86.38%
# Target Label Accuracy: 81.64%
# Source Domain Accuracy: 56.14%
# Target Domain Accuracy: 79.45%
# domain accuracy on train data:  0.7335421063380761
# black predicted:  0.5493226223704814
# num actually black:  0.4992171012322146
# domain test accuracy:  0.6836373536618567
# black pred test:  0.4045739177783828
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2539  198]
#  [ 116  270]]
# False positive white:  0.07234198027036902
# Credit Confusion Matrix Black:
# [[309  74]
#  [ 27 140]]
# False positive black:  0.19321148825065274
# Predictive parity:  0.08309201525339849
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4334, Domain Loss: 0.4427
# Source Label Accuracy: 87.31%
# Target Label Accuracy: 84.73%
# Source Domain Accuracy: 56.68%
# Target Domain Accuracy: 78.91%
# domain accuracy on train data:  0.7289127918850841
# black predicted:  0.5580366260467016
# num actually black:  0.5037102593777657
# domain test accuracy:  0.6885379798529813
# black pred test:  0.39803974952355026
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2585  152]
#  [ 107  279]]
# False positive white:  0.055535257581293386
# Credit Confusion Matrix Black:
# [[324  59]
#  [ 25 142]]
# False positive black:  0.15404699738903394
# Predictive parity:  0.06979419555788435
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3887, Domain Loss: 0.4120
# Source Label Accuracy: 87.92%
# Target Label Accuracy: 86.91%
# Source Domain Accuracy: 56.08%
# Target Domain Accuracy: 81.09%
# domain accuracy on train data:  0.7346994349513242
# black predicted:  0.5542242494383552
# num actually black:  0.5043229627612499
# domain test accuracy:  0.6915328069697795
# black pred test:  0.40157909066158454
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2542  195]
#  [ 103  283]]
# False positive white:  0.0712458896602119
# Credit Confusion Matrix Black:
# [[336  47]
#  [ 25 142]]
# False positive black:  0.1227154046997389
# Predictive parity:  0.03548802142462082
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3716, Domain Loss: 0.4845
# Source Label Accuracy: 89.42%
# Target Label Accuracy: 88.73%
# Source Domain Accuracy: 59.65%
# Target Domain Accuracy: 76.18%
# domain accuracy on train data:  0.725576962352781
# black predicted:  0.5165089522772143
# num actually black:  0.5022806181496358
# domain test accuracy:  0.7059624285325347
# black pred test:  0.372447590525456
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2571  166]
#  [  96  290]]
# False positive white:  0.06065034709535988
# Credit Confusion Matrix Black:
# [[346  37]
#  [ 25 142]]
# False positive black:  0.09660574412532637
# Predictive parity:  0.028833580764416444
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4198, Domain Loss: 0.4270
# Source Label Accuracy: 90.37%
# Target Label Accuracy: 89.82%
# Source Domain Accuracy: 54.34%
# Target Domain Accuracy: 85.09%
# domain accuracy on train data:  0.7393968275580366
# black predicted:  0.6011300973517598
# num actually black:  0.5099053713663285
# domain test accuracy:  0.6781922134494963
# black pred test:  0.4268989926490607
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2594  143]
#  [  84  302]]
# False positive white:  0.05224698575082207
# Credit Confusion Matrix Black:
# [[350  33]
#  [ 23 144]]
# False positive black:  0.08616187989556136
# Predictive parity:  0.02913166244578347
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3505, Domain Loss: 0.4627
# Source Label Accuracy: 89.64%
# Target Label Accuracy: 90.91%
# Source Domain Accuracy: 59.35%
# Target Domain Accuracy: 80.73%
# domain accuracy on train data:  0.7337463407992375
# black predicted:  0.5470079651439853
# num actually black:  0.5025529307645177
# domain test accuracy:  0.7075959705962429
# black pred test:  0.38442689899264904
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2608  129]
#  [  99  287]]
# False positive white:  0.04713189623675557
# Credit Confusion Matrix Black:
# [[354  29]
#  [ 21 146]]
# False positive black:  0.07571801566579635
# Predictive parity:  0.01790236660553668
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3681, Domain Loss: 0.5770
# Source Label Accuracy: 90.67%
# Target Label Accuracy: 93.09%
# Source Domain Accuracy: 59.52%
# Target Domain Accuracy: 77.82%
# domain accuracy on train data:  0.7284362448090408
# black predicted:  0.5187555313499898
# num actually black:  0.4990809449247736
# domain test accuracy:  0.7130411108086033
# black pred test:  0.37026953444051186
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2630  107]
#  [  95  291]]
# False positive white:  0.03909389842893679
# Credit Confusion Matrix Black:
# [[366  17]
#  [ 21 146]]
# False positive black:  0.044386422976501305
# Predictive parity:  0.004409512997409215
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3692, Domain Loss: 0.5811
# Source Label Accuracy: 91.64%
# Target Label Accuracy: 92.73%
# Source Domain Accuracy: 55.66%
# Target Domain Accuracy: 79.64%
# domain accuracy on train data:  0.7227176798965212
# black predicted:  0.5604874395806386
# num actually black:  0.4991490230784941
# domain test accuracy:  0.6877212088211272
# black pred test:  0.4010345766403485
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2602  135]
#  [  78  308]]
# False positive white:  0.049324077457069786
# Credit Confusion Matrix Black:
# [[358  25]
#  [ 15 152]]
# False positive black:  0.06527415143603134
# Predictive parity:  0.004523622391057525
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3189, Domain Loss: 0.4813
# Source Label Accuracy: 92.21%
# Target Label Accuracy: 92.91%
# Source Domain Accuracy: 53.19%
# Target Domain Accuracy: 84.18%
# domain accuracy on train data:  0.7231261488188441
# black predicted:  0.5762134930900674
# num actually black:  0.4943154741643407
# domain test accuracy:  0.6784644704601144
# black pred test:  0.42390416553226246
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2626  111]
#  [  72  314]]
# False positive white:  0.040555352575812935
# Credit Confusion Matrix Black:
# [[359  24]
#  [ 15 152]]
# False positive black:  0.06266318537859007
# Predictive parity:  0.012311588507553983
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3422, Domain Loss: 0.6040
# Source Label Accuracy: 93.24%
# Target Label Accuracy: 94.55%
# Source Domain Accuracy: 53.65%
# Target Domain Accuracy: 82.36%
# domain accuracy on train data:  0.7309551364966982
# black predicted:  0.5711076315610321
# num actually black:  0.4969024440057186
# domain test accuracy:  0.6751973863326981
# black pred test:  0.42172610944731825
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2638   99]
#  [  58  328]]
# False positive white:  0.03617099013518451
# Credit Confusion Matrix Black:
# [[372  11]
#  [ 19 148]]
# False positive black:  0.028720626631853787
# Predictive parity:  0.004273280353972009
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3599, Domain Loss: 0.3549
# Source Label Accuracy: 94.11%
# Target Label Accuracy: 94.91%
# Source Domain Accuracy: 48.90%
# Target Domain Accuracy: 86.55%
# domain accuracy on train data:  0.7175437402137654
# black predicted:  0.6291102185308735
# num actually black:  0.49710667846688
# domain test accuracy:  0.6245575823577457
# black pred test:  0.4848897359106997
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2639   98]
#  [  53  333]]
# False positive white:  0.03580562659846547
# Credit Confusion Matrix Black:
# [[369  14]
#  [ 14 153]]
# False positive black:  0.03655352480417755
# Predictive parity:  0.0025581463045439845
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3186, Domain Loss: 0.3961
# Source Label Accuracy: 94.65%
# Target Label Accuracy: 94.73%
# Source Domain Accuracy: 47.84%
# Target Domain Accuracy: 87.09%
# domain accuracy on train data:  0.7133228946830962
# black predicted:  0.6411600517393968
# num actually black:  0.5012594458438288
# domain test accuracy:  0.6139395589436428
# black pred test:  0.49714130138851076
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2647   90]
#  [  54  332]]
# False positive white:  0.03288271830471319
# Credit Confusion Matrix Black:
# [[367  16]
#  [ 13 154]]
# False positive black:  0.04177545691906005
# Predictive parity:  0.006617762640817371
#
# Lambda: 0.1
#
# Label Classifier Accuracy (Test Data)
# Source (White): 95.38904899135447
# Target (Black): 94.72727272727273
# Overall: 95.28995371630819
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.86839577329491
# Target (Black): 87.0909090909091
# Overall: 61.39395589436428
#
# False Positive Rate (Test Data)
# Source (White): 3.2882718304713188
# Target (Black): 4.177545691906006
# (Black FPR) / (White FPR): 1.270438062082971
# Overall: 3.3974358974358974
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5755, Domain Loss: 0.4435
# Source Label Accuracy: 72.17%
# Target Label Accuracy: 68.36%
# Source Domain Accuracy: 42.75%
# Target Domain Accuracy: 88.91%
# domain accuracy on train data:  0.7055619851589625
# black predicted:  0.6777180202872898
# num actually black:  0.5045952753761318
# domain test accuracy:  0.5856248298393684
# black pred test:  0.5309011707051456
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2489  248]
#  [ 224  162]]
# False positive white:  0.0906101571063208
# Credit Confusion Matrix Black:
# [[275 108]
#  [ 66 101]]
# False positive black:  0.2819843342036554
# Predictive parity:  0.16522690885803282
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4732, Domain Loss: 0.4678
# Source Label Accuracy: 75.01%
# Target Label Accuracy: 72.00%
# Source Domain Accuracy: 46.86%
# Target Domain Accuracy: 86.18%
# domain accuracy on train data:  0.722104976513037
# black predicted:  0.6286336714548302
# num actually black:  0.4972428347743209
# domain test accuracy:  0.6218350122515655
# black pred test:  0.48652327797440786
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2481  256]
#  [ 214  172]]
# False positive white:  0.09353306540007307
# Credit Confusion Matrix Black:
# [[283 100]
#  [ 54 113]]
# False positive black:  0.26109660574412535
# Predictive parity:  0.12950368235670828
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6061, Domain Loss: 0.4186
# Source Label Accuracy: 77.27%
# Target Label Accuracy: 75.82%
# Source Domain Accuracy: 51.99%
# Target Domain Accuracy: 82.91%
# domain accuracy on train data:  0.7224453672816393
# black predicted:  0.5999727687385118
# num actually black:  0.4987405541561713
# domain test accuracy:  0.6594064797168527
# black pred test:  0.43915055812687176
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2479  258]
#  [ 173  213]]
# False positive white:  0.09426379247351115
# Credit Confusion Matrix Black:
# [[280 103]
#  [ 30 137]]
# False positive black:  0.2689295039164491
# Predictive parity:  0.10380985648997176
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5381, Domain Loss: 0.4209
# Source Label Accuracy: 78.98%
# Target Label Accuracy: 73.09%
# Source Domain Accuracy: 51.71%
# Target Domain Accuracy: 84.73%
# domain accuracy on train data:  0.7206753352849071
# black predicted:  0.597113486282252
# num actually black:  0.5062291510654231
# domain test accuracy:  0.6604955077593248
# black pred test:  0.44350667029676016
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2415  322]
#  [ 142  244]]
# False positive white:  0.11764705882352941
# Credit Confusion Matrix Black:
# [[269 114]
#  [ 34 133]]
# False positive black:  0.29765013054830286
# Predictive parity:  0.12051582103455294
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5325, Domain Loss: 0.5182
# Source Label Accuracy: 79.32%
# Target Label Accuracy: 77.82%
# Source Domain Accuracy: 52.38%
# Target Domain Accuracy: 81.45%
# domain accuracy on train data:  0.7180883654435292
# black predicted:  0.5872421539927837
# num actually black:  0.495949349853632
# domain test accuracy:  0.6640348488973591
# black pred test:  0.430166076776477
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2486  251]
#  [ 163  223]]
# False positive white:  0.0917062477164779
# Credit Confusion Matrix Black:
# [[287  96]
#  [ 26 141]]
# False positive black:  0.2506527415143603
# Predictive parity:  0.08925334031962273
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.6567, Domain Loss: 0.3953
# Source Label Accuracy: 79.21%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 49.27%
# Target Domain Accuracy: 83.27%
# domain accuracy on train data:  0.7182925999046906
# black predicted:  0.6140649465586493
# num actually black:  0.49805977261896656
# domain test accuracy:  0.639259460931119
# black pred test:  0.4603866049550776
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2499  238]
#  [ 173  213]]
# False positive white:  0.08695652173913043
# Credit Confusion Matrix Black:
# [[299  84]
#  [ 39 128]]
# False positive black:  0.2193211488250653
# Predictive parity:  0.09203213693127232
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4630, Domain Loss: 0.5930
# Source Label Accuracy: 80.98%
# Target Label Accuracy: 75.64%
# Source Domain Accuracy: 52.92%
# Target Domain Accuracy: 81.09%
# domain accuracy on train data:  0.7204711008237457
# black predicted:  0.5805704949281776
# num actually black:  0.5036421812240452
# domain test accuracy:  0.6787367274707323
# black pred test:  0.41437517016063163
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2493  244]
#  [ 152  234]]
# False positive white:  0.08914870295944465
# Credit Confusion Matrix Black:
# [[291  92]
#  [ 42 125]]
# False positive black:  0.2402088772845953
# Predictive parity:  0.11683521089861149
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4814, Domain Loss: 0.4760
# Source Label Accuracy: 80.79%
# Target Label Accuracy: 77.09%
# Source Domain Accuracy: 53.03%
# Target Domain Accuracy: 83.27%
# domain accuracy on train data:  0.7223092109741984
# black predicted:  0.5789366192388863
# num actually black:  0.5008509769215059
# domain test accuracy:  0.6673019330247754
# black pred test:  0.4323441328614212
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2558  179]
#  [ 158  228]]
# False positive white:  0.06540007307270734
# Credit Confusion Matrix Black:
# [[305  78]
#  [ 48 119]]
# False positive black:  0.20365535248041775
# Predictive parity:  0.12118184729135739
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4930, Domain Loss: 0.4945
# Source Label Accuracy: 83.64%
# Target Label Accuracy: 75.09%
# Source Domain Accuracy: 51.66%
# Target Domain Accuracy: 84.55%
# domain accuracy on train data:  0.7203349445163048
# black predicted:  0.5903056709102049
# num actually black:  0.4918646606304037
# domain test accuracy:  0.663218077865505
# black pred test:  0.4402395861693439
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2447  290]
#  [ 121  265]]
# False positive white:  0.10595542564852027
# Credit Confusion Matrix Black:
# [[283 100]
#  [ 37 130]]
# False positive black:  0.26109660574412535
# Predictive parity:  0.11748668238581783
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4898, Domain Loss: 0.4893
# Source Label Accuracy: 82.98%
# Target Label Accuracy: 80.91%
# Source Domain Accuracy: 49.27%
# Target Domain Accuracy: 85.82%
# domain accuracy on train data:  0.7223772891279189
# black predicted:  0.6103206481040234
# num actually black:  0.49663013139083667
# domain test accuracy:  0.6351756057718486
# black pred test:  0.4720936564116526
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2565  172]
#  [ 146  240]]
# False positive white:  0.06284252831567409
# Credit Confusion Matrix Black:
# [[317  66]
#  [ 39 128]]
# False positive black:  0.17232375979112272
# Predictive parity:  0.08908392280150201
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4471, Domain Loss: 0.5290
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 82.91%
# Source Domain Accuracy: 55.83%
# Target Domain Accuracy: 81.82%
# domain accuracy on train data:  0.7298658860371706
# black predicted:  0.567771802028729
# num actually black:  0.5013275239975492
# domain test accuracy:  0.6847263817043289
# black pred test:  0.4105635720119793
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2560  177]
#  [ 136  250]]
# False positive white:  0.06466934599926927
# Credit Confusion Matrix Black:
# [[324  59]
#  [ 35 132]]
# False positive black:  0.15404699738903394
# Predictive parity:  0.07068494745728171
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4654, Domain Loss: 0.4342
# Source Label Accuracy: 85.19%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 52.19%
# Target Domain Accuracy: 84.00%
# domain accuracy on train data:  0.7289127918850841
# black predicted:  0.5877867792225475
# num actually black:  0.5022806181496358
# domain test accuracy:  0.6678464470460115
# black pred test:  0.43397767492512934
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2594  143]
#  [ 122  264]]
# False positive white:  0.05224698575082207
# Credit Confusion Matrix Black:
# [[318  65]
#  [ 30 137]]
# False positive black:  0.16971279373368145
# Predictive parity:  0.08787296597094874
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3830, Domain Loss: 0.4406
# Source Label Accuracy: 86.95%
# Target Label Accuracy: 84.36%
# Source Domain Accuracy: 59.83%
# Target Domain Accuracy: 77.27%
# domain accuracy on train data:  0.7287766355776432
# black predicted:  0.5114030907481789
# num actually black:  0.4966982095445572
# domain test accuracy:  0.7231146202014702
# black pred test:  0.35856248298393684
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2535  202]
#  [ 102  284]]
# False positive white:  0.07380343441724516
# Credit Confusion Matrix Black:
# [[328  55]
#  [ 31 136]]
# False positive black:  0.14360313315926893
# Predictive parity:  0.05902133729223069
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4315, Domain Loss: 0.5919
# Source Label Accuracy: 87.74%
# Target Label Accuracy: 85.09%
# Source Domain Accuracy: 53.99%
# Target Domain Accuracy: 80.73%
# domain accuracy on train data:  0.7146844577575057
# black predicted:  0.5692014432568588
# num actually black:  0.4988767104636122
# domain test accuracy:  0.6773754424176422
# black pred test:  0.41464742717124964
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2555  182]
#  [ 107  279]]
# False positive white:  0.06649616368286446
# Credit Confusion Matrix Black:
# [[325  58]
#  [ 24 143]]
# False positive black:  0.1514360313315927
# Predictive parity:  0.056551683986842405
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4055, Domain Loss: 0.5153
# Source Label Accuracy: 90.08%
# Target Label Accuracy: 88.55%
# Source Domain Accuracy: 60.24%
# Target Domain Accuracy: 75.82%
# domain accuracy on train data:  0.7347675131050446
# black predicted:  0.5035741030703247
# num actually black:  0.49812785077268706
# domain test accuracy:  0.7236591342227062
# black pred test:  0.3536618567928124
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2566  171]
#  [  85  301]]
# False positive white:  0.06247716477895506
# Credit Confusion Matrix Black:
# [[337  46]
#  [ 17 150]]
# False positive black:  0.12010443864229765
# Predictive parity:  0.03257299216953391
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4922, Domain Loss: 0.4859
# Source Label Accuracy: 88.90%
# Target Label Accuracy: 90.00%
# Source Domain Accuracy: 53.46%
# Target Domain Accuracy: 80.55%
# domain accuracy on train data:  0.7105316903805569
# black predicted:  0.5611682211178433
# num actually black:  0.49363469262713594
# domain test accuracy:  0.6621290498230329
# black pred test:  0.42934930574462293
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2597  140]
#  [ 104  282]]
# False positive white:  0.05115089514066496
# Credit Confusion Matrix Black:
# [[347  36]
#  [ 19 148]]
# False positive black:  0.09399477806788512
# Predictive parity:  0.021869996797950653
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3917, Domain Loss: 0.4307
# Source Label Accuracy: 90.18%
# Target Label Accuracy: 86.91%
# Source Domain Accuracy: 47.49%
# Target Domain Accuracy: 85.64%
# domain accuracy on train data:  0.7167948805228402
# black predicted:  0.6402750357410307
# num actually black:  0.5009871332289468
# domain test accuracy:  0.6180234141029132
# black pred test:  0.488701334059352
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2563  174]
#  [  86  300]]
# False positive white:  0.06357325538911217
# Credit Confusion Matrix Black:
# [[324  59]
#  [ 13 154]]
# False positive black:  0.15404699738903394
# Predictive parity:  0.047655808808546474
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3304, Domain Loss: 0.4397
# Source Label Accuracy: 91.37%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 48.93%
# Target Domain Accuracy: 86.36%
# domain accuracy on train data:  0.7224453672816393
# black predicted:  0.6236639662332357
# num actually black:  0.5011913676901082
# domain test accuracy:  0.6354478627824667
# black pred test:  0.4734549414647427
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2625  112]
#  [  83  303]]
# False positive white:  0.04092071611253197
# Credit Confusion Matrix Black:
# [[357  26]
#  [ 19 148]]
# False positive black:  0.06788511749347259
# Predictive parity:  0.01937822024277358
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3685, Domain Loss: 0.4814
# Source Label Accuracy: 91.99%
# Target Label Accuracy: 89.27%
# Source Domain Accuracy: 48.22%
# Target Domain Accuracy: 85.09%
# domain accuracy on train data:  0.7050173599291987
# black predicted:  0.6062359588807952
# num actually black:  0.49574511539247057
# domain test accuracy:  0.6327252926762864
# black pred test:  0.47236591342227063
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2607  130]
#  [  63  323]]
# False positive white:  0.047497259773474604
# Credit Confusion Matrix Black:
# [[339  44]
#  [ 15 152]]
# False positive black:  0.11488250652741515
# Predictive parity:  0.04547317555963093
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3746, Domain Loss: 0.3981
# Source Label Accuracy: 91.97%
# Target Label Accuracy: 91.45%
# Source Domain Accuracy: 48.06%
# Target Domain Accuracy: 86.55%
# domain accuracy on train data:  0.7146844577575057
# black predicted:  0.6285655933011097
# num actually black:  0.5054122132207775
# domain test accuracy:  0.6316362646338143
# black pred test:  0.4778110536346311
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2616  121]
#  [  73  313]]
# False positive white:  0.04420898794300329
# Credit Confusion Matrix Black:
# [[352  31]
#  [ 16 151]]
# False positive black:  0.08093994778067885
# Predictive parity:  0.02333478881029316
#
# Lambda: 0.2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 93.78802433557476
# Target (Black): 91.45454545454545
# Overall: 93.43860604410564
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.0457893051553
# Target (Black): 86.54545454545455
# Overall: 63.16362646338143
#
# False Positive Rate (Test Data)
# Source (White): 4.420898794300329
# Target (Black): 8.093994778067884
# (Black FPR) / (White FPR): 1.83084824029519
# Overall: 4.871794871794871
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5971, Domain Loss: 0.4396
# Source Label Accuracy: 74.65%
# Target Label Accuracy: 67.82%
# Source Domain Accuracy: 39.19%
# Target Domain Accuracy: 92.18%
# domain accuracy on train data:  0.6931717611818368
# black predicted:  0.7051535162366397
# num actually black:  0.49976172646197836
# domain test accuracy:  0.5513204465014974
# black pred test:  0.5750068064252655
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2456  281]
#  [ 209  177]]
# False positive white:  0.10266715381804896
# Credit Confusion Matrix Black:
# [[265 118]
#  [ 59 108]]
# False positive black:  0.30809399477806787
# Predictive parity:  0.1649177655517713
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4567, Domain Loss: 0.3580
# Source Label Accuracy: 76.71%
# Target Label Accuracy: 71.45%
# Source Domain Accuracy: 38.88%
# Target Domain Accuracy: 92.91%
# domain accuracy on train data:  0.6889509156511675
# black predicted:  0.7195860848253796
# num actually black:  0.5062972292191436
# domain test accuracy:  0.5494146474271713
# black pred test:  0.5790906615845358
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2472  265]
#  [ 175  211]]
# False positive white:  0.0968213372305444
# Credit Confusion Matrix Black:
# [[275 108]
#  [ 49 118]]
# False positive black:  0.2819843342036554
# Predictive parity:  0.14456437574593184
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6046, Domain Loss: 0.4716
# Source Label Accuracy: 76.29%
# Target Label Accuracy: 74.36%
# Source Domain Accuracy: 43.90%
# Target Domain Accuracy: 89.27%
# domain accuracy on train data:  0.7082170331540608
# black predicted:  0.6706378923003609
# num actually black:  0.49976172646197836
# domain test accuracy:  0.5946093111897631
# black pred test:  0.523005717397223
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2535  202]
#  [ 191  195]]
# False positive white:  0.07380343441724516
# Credit Confusion Matrix Black:
# [[298  85]
#  [ 56 111]]
# False positive black:  0.22193211488250653
# Predictive parity:  0.13052309841935206
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4696, Domain Loss: 0.3968
# Source Label Accuracy: 78.96%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 49.02%
# Target Domain Accuracy: 85.64%
# domain accuracy on train data:  0.7193818503642181
# black predicted:  0.6163115256314249
# num actually black:  0.5042548846075294
# domain test accuracy:  0.6270078954533079
# black pred test:  0.47971685270895725
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2509  228]
#  [ 166  220]]
# False positive white:  0.08330288637194008
# Credit Confusion Matrix Black:
# [[281 102]
#  [ 37 130]]
# False positive black:  0.26631853785900783
# Predictive parity:  0.12656652985183237
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4514, Domain Loss: 0.4217
# Source Label Accuracy: 80.44%
# Target Label Accuracy: 74.36%
# Source Domain Accuracy: 52.94%
# Target Domain Accuracy: 80.00%
# domain accuracy on train data:  0.7180202872898087
# black predicted:  0.566614473415481
# num actually black:  0.5033017904554429
# domain test accuracy:  0.6648516199292132
# black pred test:  0.42499319357473453
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2550  187]
#  [ 168  218]]
# False positive white:  0.06832298136645963
# Credit Confusion Matrix Black:
# [[288  95]
#  [ 46 121]]
# False positive black:  0.24804177545691905
# Predictive parity:  0.1426908858032777
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4462, Domain Loss: 0.4320
# ...
# Predictive parity:  0.005793380490786815
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4186, Domain Loss: 0.3482
# Source Label Accuracy: 91.60%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 33.47%
# Target Domain Accuracy: 92.73%
# domain accuracy on train data:  0.6665532030771325
# black predicted:  0.7595479610592961
# num actually black:  0.5117434815167813
# domain test accuracy:  0.4906071331336782
# black pred test:  0.6373536618567928
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2644   93]
#  [  76  310]]
# False positive white:  0.0339788089148703
# Credit Confusion Matrix Black:
# [[357  26]
#  [ 19 148]]
# False positive black:  0.06788511749347259
# Predictive parity:  0.027703548452827964
#
# Lambda: 0.8
#
# Label Classifier Accuracy (Test Data)
# Source (White): 94.58853666346462
# Target (Black): 91.81818181818181
# Overall: 94.1736999727743
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 41.37047710534742
# Target (Black): 92.72727272727273
# Overall: 49.06071331336782
#
# False Positive Rate (Test Data)
# Source (White): 3.3978808914870298
# Target (Black): 6.788511749347259
# (Black FPR) / (White FPR): 1.9978663073078975
# Overall: 3.8141025641025643
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5938, Domain Loss: 0.3736
# Source Label Accuracy: 71.45%
# Target Label Accuracy: 67.64%
# Source Domain Accuracy: 29.72%
# Target Domain Accuracy: 94.55%
# domain accuracy on train data:  0.6457212880386684
# black predicted:  0.7837157056300633
# num actually black:  0.5029613996868405
# domain test accuracy:  0.4579362918595154
# black pred test:  0.675469643343316
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2470  267]
#  [ 222  164]]
# False positive white:  0.09755206430398246
# Credit Confusion Matrix Black:
# [[269 114]
#  [ 64 103]]
# False positive black:  0.29765013054830286
# Predictive parity:  0.16705615230110904
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6805, Domain Loss: 0.4378
# Source Label Accuracy: 76.16%
# Target Label Accuracy: 70.91%
# Source Domain Accuracy: 36.05%
# Target Domain Accuracy: 92.00%
# domain accuracy on train data:  0.6754033630607937
# black predicted:  0.7330655592620328
# num actually black:  0.5011913676901082
# domain test accuracy:  0.5159270351211543
# black pred test:  0.6098557037843725
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2449  288]
#  [ 190  196]]
# False positive white:  0.10522469857508221
# Credit Confusion Matrix Black:
# [[267 116]
#  [ 44 123]]
# False positive black:  0.3028720626631854
# Predictive parity:  0.13785113381655167
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5783, Domain Loss: 0.4321
# Source Label Accuracy: 77.38%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 33.85%
# Target Domain Accuracy: 92.18%
# domain accuracy on train data:  0.6581115120157941
# black predicted:  0.7393968275580366
# num actually black:  0.4928177547824903
# domain test accuracy:  0.49795807242036483
# black pred test:  0.628369180506398
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2484  253]
#  [ 183  203]]
# False positive white:  0.09243697478991597
# Credit Confusion Matrix Black:
# [[296  87]
#  [ 52 115]]
# False positive black:  0.22715404699738903
# Predictive parity:  0.11311792274328292
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5161, Domain Loss: 0.4730
# Source Label Accuracy: 78.58%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 40.28%
# Target Domain Accuracy: 90.18%
# domain accuracy on train data:  0.6873170399618762
# black predicted:  0.6946014024099666
# num actually black:  0.5029613996868405
# domain test accuracy:  0.55785461475633
# black pred test:  0.5624829839368364
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2561  176]
#  [ 189  197]]
# False positive white:  0.06430398246255024
# Credit Confusion Matrix Black:
# [[299  84]
#  [ 44 123]]
# False positive black:  0.2193211488250653
# Predictive parity:  0.11585247285535472
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4574, Domain Loss: 0.3239
# Source Label Accuracy: 79.17%
# Target Label Accuracy: 78.91%
# Source Domain Accuracy: 35.34%
# Target Domain Accuracy: 92.36%
# domain accuracy on train data:  0.676016066444278
# black predicted:  0.733814418952958
# num actually black:  0.5018721492273129
# domain test accuracy:  0.5148380070786823
# black pred test:  0.6120337598693166
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2517  220]
#  [ 173  213]]
# False positive white:  0.0803799780781878
# Credit Confusion Matrix Black:
# [[299  84]
#  [ 32 135]]
# False positive black:  0.2193211488250653
# Predictive parity:  0.08506855296480664
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4148, Domain Loss: 0.4044
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 77.09%
# Source Domain Accuracy: 37.97%
# Target Domain Accuracy: 91.09%
# domain accuracy on train data:  0.6775818639798489
# black predicted:  0.710395534073116
# num actually black:  0.49676628769827763
# domain test accuracy:  0.5303566566839096
# black pred test:  0.5927035121154369
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2443  294]
#  [ 139  247]]
# False positive white:  0.10741687979539642
# Credit Confusion Matrix Black:
# [[280 103]
#  [ 23 144]]
# False positive black:  0.2689295039164491
# Predictive parity:  0.09044217390038722
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4422, Domain Loss: 0.4346
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 78.91%
# Source Domain Accuracy: 42.52%
# Target Domain Accuracy: 88.36%
# domain accuracy on train data:  0.6918782762611478
# black predicted:  0.6710463612226837
# num actually black:  0.5018040710735925
# domain test accuracy:  0.5731010073509393
# black pred test:  0.5417914511298666
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2535  202]
#  [ 142  244]]
# False positive white:  0.07380343441724516
# Credit Confusion Matrix Black:
# [[298  85]
#  [ 31 136]]
# False positive black:  0.22193211488250653
# Predictive parity:  0.10075859459144765
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.3953, Domain Loss: 0.4311
# Source Label Accuracy: 84.20%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 41.45%
# Target Domain Accuracy: 90.73%
# domain accuracy on train data:  0.7012049833208523
# black predicted:  0.6912655728776635
# num actually black:  0.5019402273810334
# domain test accuracy:  0.5709229512659951
# black pred test:  0.5510481894908794
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2499  238]
#  [ 124  262]]
# False positive white:  0.08695652173913043
# Credit Confusion Matrix Black:
# [[300  83]
#  [ 26 141]]
# False positive black:  0.21671018276762402
# Predictive parity:  0.08226763310336804
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4761, Domain Loss: 0.4991
# Source Label Accuracy: 84.41%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 40.90%
# Target Domain Accuracy: 91.09%
# domain accuracy on train data:  0.6938525427190415
# black predicted:  0.6957587310232146
# num actually black:  0.5035741030703247
# domain test accuracy:  0.5671113531173427
# black pred test:  0.5559488156820038
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2530  207]
#  [ 128  258]]
# False positive white:  0.07563025210084033
# Credit Confusion Matrix Black:
# [[298  85]
#  [ 24 143]]
# False positive black:  0.22193211488250653
# Predictive parity:  0.09091316624457846
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4414, Domain Loss: 0.4110
# Source Label Accuracy: 85.74%
# Target Label Accuracy: 81.64%
# Source Domain Accuracy: 40.79%
# Target Domain Accuracy: 90.73%
# domain accuracy on train data:  0.6922186670297501
# black predicted:  0.6867724147321125
# num actually black:  0.5012594458438288
# domain test accuracy:  0.5676558671385789
# black pred test:  0.5543152736182957
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2491  246]
#  [ 103  283]]
# False positive white:  0.08987943003288272
# Credit Confusion Matrix Black:
# [[300  83]
#  [ 18 149]]
# False positive black:  0.21671018276762402
# Predictive parity:  0.0718848426629406
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5017, Domain Loss: 0.4534
# Source Label Accuracy: 85.39%
# Target Label Accuracy: 80.91%
# Source Domain Accuracy: 35.46%
# Target Domain Accuracy: 92.18%
# domain accuracy on train data:  0.6720675335284907
# black predicted:  0.7308189801892573
# num actually black:  0.5026890870719586
# domain test accuracy:  0.5167438061530084
# black pred test:  0.6095834467737544
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2525  212]
#  [ 106  280]]
# False positive white:  0.07745706978443552
# Credit Confusion Matrix Black:
# [[307  76]
#  [ 29 138]]
# False positive black:  0.19843342036553524
# Predictive parity:  0.08908392280150201
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2606  131]
#  [  84  302]]
# False positive white:  0.04786262331019364
# Credit Confusion Matrix Black:
# [[341  42]
#  [ 17 150]]
# False positive black:  0.10966057441253264
# Predictive parity:  0.03842866707420023
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3327, Domain Loss: 0.4746
# Source Label Accuracy: 90.85%
# Target Label Accuracy: 90.55%
# Source Domain Accuracy: 33.09%
# Target Domain Accuracy: 94.00%
# domain accuracy on train data:  0.6649874055415617
# black predicted:  0.7591394921369733
# num actually black:  0.4972428347743209
# domain test accuracy:  0.4911516471549142
# black pred test:  0.640620745984209
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2564  173]
#  [  71  315]]
# False positive white:  0.06320789185239313
# Credit Confusion Matrix Black:
# [[341  42]
#  [ 10 157]]
# False positive black:  0.10966057441253264
# Predictive parity:  0.016415451343405274
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3306, Domain Loss: 0.3259
# Source Label Accuracy: 92.16%
# Target Label Accuracy: 90.55%
# Source Domain Accuracy: 30.20%
# Target Domain Accuracy: 94.18%
# domain accuracy on train data:  0.6515760092586289
# black predicted:  0.773844373340595
# num actually black:  0.49840016338756893
# domain test accuracy:  0.46447046011434795
# black pred test:  0.6678464470460115
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2590  147]
#  [  68  318]]
# False positive white:  0.05370843989769821
# Credit Confusion Matrix Black:
# [[347  36]
#  [ 16 151]]
# False positive black:  0.09399477806788512
# Predictive parity:  0.02570139434692753
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3232, Domain Loss: 0.3836
# Source Label Accuracy: 91.69%
# Target Label Accuracy: 91.64%
# Source Domain Accuracy: 33.29%
# Target Domain Accuracy: 93.82%
# domain accuracy on train data:  0.666485124923412
# black predicted:  0.7492681598475049
# num actually black:  0.49091156647831713
# domain test accuracy:  0.5053090117070514
# black pred test:  0.6259188674108358
# actual black =  0.14974135583991288
# Credit Confusion Matrix White:
# [[2595  142]
#  [  73  313]]
# False positive white:  0.05188162221410303
# Credit Confusion Matrix Black:
# [[354  29]
#  [ 17 150]]
# False positive black:  0.07571801566579635
# Predictive parity:  0.014792303437836551
#
# Lambda: 0.9
#
# Label Classifier Accuracy (Test Data)
# Source (White): 93.1155939801473
# Target (Black): 91.63636363636364
# Overall: 92.89409202286959
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 42.90746077489593
# Target (Black): 93.81818181818181
# Overall: 50.53090117070514
#
# False Positive Rate (Test Data)
# Source (White): 5.188162221410304
# Target (Black): 7.5718015665796345
# (Black FPR) / (White FPR): 1.4594380906851028
# Overall: 5.480769230769231

# %%
# Out:
# Dann(
#   (f): Sequential(
#     (0): Linear(in_features=5112, out_features=256, bias=True)
#     (1): ReLU()
#   )
#   (lc): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=256, out_features=56, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=56, out_features=2, bias=True)
#     (5): Sigmoid()
#   )
#   (dc): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=128, out_features=2, bias=True)
#     (5): Sigmoid()
#   )
# )

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results_conf_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(15):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5115, Domain Loss: 0.7859
# Source Label Accuracy: 72.79%
# Target Label Accuracy: 70.00%
# Source Domain Accuracy: 63.14%
# Target Domain Accuracy: 73.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6115, Domain Loss: 0.7207
# Source Label Accuracy: 76.13%
# Target Label Accuracy: 71.45%
# Source Domain Accuracy: 62.58%
# Target Domain Accuracy: 76.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4482, Domain Loss: 0.5327
# Source Label Accuracy: 78.05%
# Target Label Accuracy: 71.27%
# Source Domain Accuracy: 54.52%
# Target Domain Accuracy: 82.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4373, Domain Loss: 0.4094
# Source Label Accuracy: 79.80%
# Target Label Accuracy: 72.73%
# Source Domain Accuracy: 66.77%
# Target Domain Accuracy: 70.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5300, Domain Loss: 0.3570
# Source Label Accuracy: 80.12%
# Target Label Accuracy: 71.45%
# Source Domain Accuracy: 65.34%
# Target Domain Accuracy: 72.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5465, Domain Loss: 0.3740
# Source Label Accuracy: 82.63%
# Target Label Accuracy: 76.00%
# Source Domain Accuracy: 62.58%
# Target Domain Accuracy: 76.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4164, Domain Loss: 0.3464
# Source Label Accuracy: 82.75%
# Target Label Accuracy: 76.91%
# Source Domain Accuracy: 64.28%
# Target Domain Accuracy: 71.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5385, Domain Loss: 0.4149
# Source Label Accuracy: 84.93%
# Target Label Accuracy: 75.45%
# Source Domain Accuracy: 65.07%
# Target Domain Accuracy: 73.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4345, Domain Loss: 0.3726
# Source Label Accuracy: 85.49%
# Target Label Accuracy: 79.82%
# Source Domain Accuracy: 62.93%
# Target Domain Accuracy: 76.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4189, Domain Loss: 0.3875
# Source Label Accuracy: 86.76%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 67.60%
# Target Domain Accuracy: 72.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4443, Domain Loss: 0.4031
# Source Label Accuracy: 87.30%
# Target Label Accuracy: 83.45%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 73.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4349, Domain Loss: 0.4192
# Source Label Accuracy: 88.81%
# Target Label Accuracy: 86.00%
# Source Domain Accuracy: 59.56%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4584, Domain Loss: 0.3493
# Source Label Accuracy: 87.13%
# Target Label Accuracy: 86.55%
# Source Domain Accuracy: 66.48%
# Target Domain Accuracy: 70.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3823, Domain Loss: 0.3516
# Source Label Accuracy: 89.58%
# Target Label Accuracy: 87.82%
# Source Domain Accuracy: 66.04%
# Target Domain Accuracy: 73.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3841, Domain Loss: 0.3265
# Source Label Accuracy: 89.06%
# Target Label Accuracy: 89.09%
# Source Domain Accuracy: 62.45%
# Target Domain Accuracy: 76.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3317, Domain Loss: 0.3180
# Source Label Accuracy: 92.41%
# Target Label Accuracy: 92.00%
# Source Domain Accuracy: 68.27%
# Target Domain Accuracy: 72.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 46.52577649695805
# Target (Black): 92.36363636363636
# Overall: 53.38959978219439
#
# False Positive Rate (Test Data)
# Source (White): 5.516989404457435
# Target (Black): 10.182767624020888
# (Black FPR) / (White FPR): 1.8457109262877596
# Overall: 6.089743589743589
#
# run: 15/15
# Label Classifier Accuracy (Test Data)
# Source (White): 92.41114313160422
# Target (Black): 90.18181818181819
# Overall: 92.07732099101551
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 50.400256163944924
# Target (Black): 90.9090909090909
# Overall: 56.46610400217806
#
# False Positive Rate (Test Data)
# Source (White): 5.224698575082207
# Target (Black): 10.443864229765014
# (Black FPR) / (White FPR): 1.998941006773905
# Overall: 5.865384615384615

# %%
# Get true positive and negative rates for test data !!!!!

# %%
true_pos_black = sum(y_test_target)
print('1s in y_test_target', true_pos_black)
true_pos_white = sum(y_test_source)
print('1s in y_test_source', true_pos_white)

length_white = len(y_test_source)
length_black = len(y_test_target)

true_neg_black = len(y_test_target) - true_pos_black
print('zeros in test black ', true_neg_black)
true_neg_white = len(y_test_source) - true_pos_white
print('zeros in test white ', true_neg_white)
# Out:
# 1s in y_test_target tensor(167)
# 1s in y_test_source tensor(386)
# zeros in test black  tensor(383)
# zeros in test white  tensor(2737)

# %%
l = 1
write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5937, Domain Loss: 0.3429
# Source Label Accuracy: 72.19%
# Target Label Accuracy: 67.27%
# Source Domain Accuracy: 31.98%
# Target Domain Accuracy: 95.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5073, Domain Loss: 0.4200
# Source Label Accuracy: 76.32%
# Target Label Accuracy: 72.55%
# Source Domain Accuracy: 31.48%
# Target Domain Accuracy: 95.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4708, Domain Loss: 0.3484
# Source Label Accuracy: 76.52%
# Target Label Accuracy: 74.55%
# Source Domain Accuracy: 32.72%
# Target Domain Accuracy: 94.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4172, Domain Loss: 0.3806
# Source Label Accuracy: 79.96%
# Target Label Accuracy: 72.73%
# Source Domain Accuracy: 38.57%
# Target Domain Accuracy: 91.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5350, Domain Loss: 0.4345
# Source Label Accuracy: 80.61%
# Target Label Accuracy: 77.82%
# Source Domain Accuracy: 35.41%
# Target Domain Accuracy: 92.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4259, Domain Loss: 0.3485
# Source Label Accuracy: 82.78%
# Target Label Accuracy: 77.82%
# Source Domain Accuracy: 38.28%
# Target Domain Accuracy: 90.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4631, Domain Loss: 0.3521
# Source Label Accuracy: 83.89%
# Target Label Accuracy: 78.18%
# Source Domain Accuracy: 36.30%
# Target Domain Accuracy: 92.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.3992, Domain Loss: 0.3806
# Source Label Accuracy: 84.40%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 42.01%
# Target Domain Accuracy: 90.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4588, Domain Loss: 0.3605
# Source Label Accuracy: 85.98%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 35.18%
# Target Domain Accuracy: 94.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4371, Domain Loss: 0.4673
# Source Label Accuracy: 85.78%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 44.69%
# Target Domain Accuracy: 88.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4208, Domain Loss: 0.3702
# Source Label Accuracy: 87.03%
# Target Label Accuracy: 85.27%
# Source Domain Accuracy: 37.07%
# Target Domain Accuracy: 91.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4584, Domain Loss: 0.3497
# Source Label Accuracy: 86.75%
# Target Label Accuracy: 86.91%
# Source Domain Accuracy: 38.95%
# Target Domain Accuracy: 92.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 47.13416586615434
# Target (Black): 92.54545454545455
# Overall: 53.934113803430435
#
# False Positive Rate (Test Data)
# Source (White): 3.9093898428936793
# Target (Black): 4.960835509138382
# (Black FPR) / (White FPR): 1.2689539054683878
# Overall: 4.038461538461538
#
# run: 8/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.27569644572526
# Target (Black): 91.27272727272727
# Overall: 92.975769126055
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 35.92699327569645
# Target (Black): 95.45454545454545
# Overall: 44.840729648788454
#
# False Positive Rate (Test Data)
# Source (White): 4.786262331019365
# Target (Black): 8.355091383812011
# (Black FPR) / (White FPR): 1.7456400853048453
# Overall: 5.2243589743589745
#
# run: 9/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.75600384245918
# Target (Black): 92.18181818181819
# Overall: 93.52028314729104
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 45.50112071725905
# Target (Black): 91.63636363636364
# Overall: 52.40947454396951
#
# False Positive Rate (Test Data)
# Source (White): 4.01899890390939
# Target (Black): 6.788511749347259
# (Black FPR) / (White FPR): 1.6891051507239496
# Overall: 4.358974358974359
#
# run: 10/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.55651617034903
# Target (Black): 92.9090909090909
# Overall: 94.3098284780833
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 43.707973102785786
# Target (Black): 93.63636363636364
# Overall: 51.184317996188405
#
# False Positive Rate (Test Data)
# Source (White): 4.311289733284618
# Target (Black): 6.788511749347259
# (Black FPR) / (White FPR): 1.5745895472850377
# Overall: 4.615384615384615
#
# run: 11/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.30035222542428
# Target (Black): 94.18181818181819
# Overall: 94.28260277702151
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 27.28146013448607
# Target (Black): 97.27272727272727
# Overall: 37.76204737271985
#
# False Positive Rate (Test Data)
# Source (White): 4.092071611253197
# Target (Black): 4.699738903394256
# (Black FPR) / (White FPR): 1.1484986945169713
# Overall: 4.166666666666667
#
# run: 12/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.88408581492155
# Target (Black): 91.45454545454545
# Overall: 93.52028314729104
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 42.23503041946846
# Target (Black): 93.81818181818181
# Overall: 49.95916144840729
#
# False Positive Rate (Test Data)
# Source (White): 4.311289733284618
# Target (Black): 8.877284595300262
# (Black FPR) / (White FPR): 2.059078638757357
# Overall: 4.871794871794871
#
# run: 13/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.74863912904259
# Target (Black): 94.0
# Overall: 94.63653689082494
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 33.97374319564521
# Target (Black): 96.0
# Overall: 43.26163898720392
#
# False Positive Rate (Test Data)
# Source (White): 3.3978808914870298
# Target (Black): 3.6553524804177546
# (Black FPR) / (White FPR): 1.0757741654734831
# Overall: 3.4294871794871793
#
# run: 14/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.36439321165545
# Target (Black): 92.18181818181819
# Overall: 94.03757146746528
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 34.454050592379126
# Target (Black): 95.27272727272727
# Overall: 43.561121698883746
#
# False Positive Rate (Test Data)
# Source (White): 3.982462550237486
# Target (Black): 8.093994778067884
# (Black FPR) / (White FPR): 2.0324095144561283
# Overall: 4.487179487179487
#
# run: 15/15
# Label Classifier Accuracy (Test Data)
# Source (White): 92.82740954210695
# Target (Black): 93.45454545454545
# Overall: 92.9213177239314
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 38.93691962856228
# Target (Black): 93.27272727272727
# Overall: 47.073237135856246
#
# False Positive Rate (Test Data)
# Source (White): 5.882352941176471
# Target (Black): 6.788511749347259
# (Black FPR) / (White FPR): 1.154046997389034
# Overall: 5.993589743589744
