# %% [markdown]
# # NEWEST

# %%
# IW CODE: https://github.com/sarahmbock/COS-IW-BOCK/blob/main/DANN%20CODE.ipynb

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init
import pandas as pd
import sklearn.preprocessing as preprocessing

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
# Can adjust NN Sizes
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(85, 64),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(64, 32),
    nn.Sigmoid(),
    nn.Linear(32, 32),
    nn.Sigmoid(),
    nn.Linear(32, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(64, 36),
    nn.Sigmoid(),
    nn.Linear(36, 36), nn.Sigmoid(),              
    nn.Linear(36, 2),
    nn.Sigmoid()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 64) # must be same dimension as output size from init()
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %% [markdown]
# # DATA

# %%
# Adult data code
# Change these to local file if available
train_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
test_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'

features = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"] 


# This will download 3.8M
original_train = pd.read_csv(train_url, names=features, sep=r'\s*,\s*', 
                             engine='python', na_values="?")
# This will download 1.9M
original_test = pd.read_csv(test_url, names=features, sep=r'\s*,\s*', 
                            engine='python', na_values="?", skiprows=1)



num_train = len(original_train)
original = pd.concat([original_train, original_test])
roc_original = original
labels = original['Target']
labels = labels.replace('<=50K', 0).replace('>50K', 1)
labels = labels.replace('<=50K.', 0).replace('>50K.', 1)


# Preprocess
# Redundant column
del original["Education"]
# Remove target variable
del original["Target"]


def data_transform(df):
    """Normalize features."""
    binary_data = pd.get_dummies(df)
    feature_cols = binary_data[binary_data.columns[:-2]]
    scaler = preprocessing.StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(feature_cols), columns=feature_cols.columns)
    return data

data = data_transform(original)

# %%
# Adult code, seperate sensitive and non sensitive
# get array of sensitive characteristics
sensitive = original.Sex.map({'Male': 0, 'Female': 1})
y = np.array(labels).flatten()
data = data.drop(['Sex_Male', 'Sex_Female'], axis=1) # Drop sensitive info from data
data_np = np.array(data)
# split to source (non-sensitive) and target (sensitive)
sensitive_idx = np.array(np.where(sensitive==1))[0].flatten()
nonsensitive_idx = np.array(np.where(sensitive!=1))[0].flatten()
data_sensitive = data_np[sensitive_idx,:]
data_nonsensitive = data_np[nonsensitive_idx,:]
y_sensitive = y[sensitive_idx]
y_nonsensitive = y[nonsensitive_idx]
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

X_tensor_source =  torch.from_numpy(data_nonsensitive).type(torch.float32)
X_tensor_target =  torch.from_numpy(data_sensitive).type(torch.float32)
y_tensor_source =torch.tensor(y_nonsensitive).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_sensitive).type(torch.LongTensor)


# Split the source (white) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (black) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train) # number of black samples
num_positives = sum(target_train[i][1] for i in range(num_samples)) # Number black with positive label
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives]) 


weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size, sampler=sampler) # remove sampler
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size, sampler=sampler) # remove sampler
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)
# Weight with respect to sensitive feature itself
y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size) # Removed sensitive characteristic data loader



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples)) # Number of positives for label predictor
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size) # Remove sampler
# Out:
# Index(['Age', 'fnlwgt', 'Education-Num', 'Capital Gain', 'Capital Loss',
#        'Hours per week', 'Workclass_Federal-gov', 'Workclass_Local-gov',
#        'Workclass_Never-worked', 'Workclass_Private', 'Workclass_Self-emp-inc',
#        'Workclass_Self-emp-not-inc', 'Workclass_State-gov',
#        'Workclass_Without-pay', 'Martial Status_Divorced',
#        'Martial Status_Married-AF-spouse', 'Martial Status_Married-civ-spouse',
#        'Martial Status_Married-spouse-absent', 'Martial Status_Never-married',
#        'Martial Status_Separated', 'Martial Status_Widowed',
#        'Occupation_Adm-clerical', 'Occupation_Armed-Forces',
#        'Occupation_Craft-repair', 'Occupation_Exec-managerial',
#        'Occupation_Farming-fishing', 'Occupation_Handlers-cleaners',
#        'Occupation_Machine-op-inspct', 'Occupation_Other-service',
#        'Occupation_Priv-house-serv', 'Occupation_Prof-specialty',
#        'Occupation_Protective-serv', 'Occupation_Sales',
#        'Occupation_Tech-support', 'Occupation_Transport-moving',
#        'Relationship_Husband', 'Relationship_Not-in-family',
#        'Relationship_Other-relative', 'Relationship_Own-child',
#        'Relationship_Unmarried', 'Relationship_Wife',
#        'Race_Amer-Indian-Eskimo', 'Race_Asian-Pac-Islander', 'Race_Black',
#        'Race_Other', 'Race_White', 'Sex_Female', 'Sex_Male',
#        'Country_Cambodia', 'Country_Canada', 'Country_China',
#        'Country_Columbia', 'Country_Cuba', 'Country_Dominican-Republic',
#        'Country_Ecuador', 'Country_El-Salvador', 'Country_England',
#        'Country_France', 'Country_Germany', 'Country_Greece',
#        'Country_Guatemala', 'Country_Haiti', 'Country_Holand-Netherlands',
#        'Country_Honduras', 'Country_Hong', 'Country_Hungary', 'Country_India',
#        'Country_Iran', 'Country_Ireland', 'Country_Italy', 'Country_Jamaica',
#        'Country_Japan', 'Country_Laos', 'Country_Mexico', 'Country_Nicaragua',
#        'Country_Outlying-US(Guam-USVI-etc)', 'Country_Peru',
#        'Country_Philippines', 'Country_Poland', 'Country_Portugal',
#        'Country_Puerto-Rico', 'Country_Scotland', 'Country_South',
#        'Country_Taiwan', 'Country_Thailand', 'Country_Trinadad&Tobago',
#        'Country_United-States'],
#       dtype='object')

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.00001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 20
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
'''lambda = 0
label trained
domain trained
feature extractor trained
Epoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133
Source Label Accuracy: 96.33%
Target Label Accuracy: 97.27%
Source Domain Accuracy: 89.32%
Target Domain Accuracy: 84.73%
domain accuracy on train data:  0.901286677105317
black predicted:  0.4585063653073729
num actually black:  0.48519300156579753
domain test accuracy:  0.906071331336782
black pred test:  0.19793084671930303
actual black =  0.14974135583991288
Credit Confusion Matrix White: 
[[2673   64]
 [  40  346]]
False positive white:  0.023383266350018268
Credit Confusion Matrix Black: 
[[376   7]
 [  8 159]]
False positive black:  0.018276762402088774

'''
# Out:
# 'lambda = 0\nlabel trained\ndomain trained\nfeature extractor trained\nEpoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133\nSource Label Accuracy: 96.33%\nTarget Label Accuracy: 97.27%\nSource Domain Accuracy: 89.32%\nTarget Domain Accuracy: 84.73%\ndomain accuracy on train data:  0.901286677105317\nblack predicted:  0.4585063653073729\nnum actually black:  0.48519300156579753\ndomain test accuracy:  0.906071331336782\nblack pred test:  0.19793084671930303\nactual black =  0.14974135583991288\nCredit Confusion Matrix White: \n[[2673   64]\n [  40  346]]\nFalse positive white:  0.023383266350018268\nCredit Confusion Matrix Black: \n[[376   7]\n [  8 159]]\nFalse positive black:  0.018276762402088774\n\n'

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_adult'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        source_label_positive_rate = (sum(source_label_predictions)/len(source_label_predictions)).item()

        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        target_label_positive_rate = (sum(target_label_predictions)/len(target_label_predictions)).item()

        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_label_positive_rate = ((sum(source_label_predictions) + sum(target_label_predictions))/(len(target_label_predictions)+len(source_label_predictions))).item()

        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall,
                     'source_label_positive_rate': source_label_positive_rate, 'target_label_positive_rate': target_label_positive_rate,
                   'overall_label_positive_rate': overall_label_positive_rate}
        return results

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results/results_conf_Adult'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(10):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        model_file_name = 'model_results/adult_original_'+str(lam)+'_'+str(i)+'.pt'
        torch.save(model.state_dict(), model_file_name)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        my_str += 'Source Label Positive Rate: ' + str(results['source_label_positive_rate']) + '\n'
        my_str += 'Target Label Positive Rate: ' + str(results['target_label_positive_rate']) + '\n'
        my_str += 'Overall Label Positive Rate: ' + str(results['overall_label_positive_rate']) + '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7877, Domain Loss: 0.9752
# Source Label Accuracy: 53.95%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 73.96%
# Target Domain Accuracy: 73.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6888, Domain Loss: 0.9432
# Source Label Accuracy: 69.58%
# Target Label Accuracy: 91.08%
# Source Domain Accuracy: 70.60%
# Target Domain Accuracy: 82.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6085, Domain Loss: 0.8967
# Source Label Accuracy: 77.75%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 66.71%
# Target Domain Accuracy: 97.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5546, Domain Loss: 0.8764
# Source Label Accuracy: 78.47%
# Target Label Accuracy: 91.76%
# Source Domain Accuracy: 66.40%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5913, Domain Loss: 0.8844
# Source Label Accuracy: 79.01%
# Target Label Accuracy: 91.91%
# Source Domain Accuracy: 65.64%
# Target Domain Accuracy: 98.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4913, Domain Loss: 0.8948
# Source Label Accuracy: 79.36%
# Target Label Accuracy: 91.91%
# Source Domain Accuracy: 65.13%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5709, Domain Loss: 0.9027
# Source Label Accuracy: 78.94%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 65.30%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5207, Domain Loss: 0.9117
# Source Label Accuracy: 79.20%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 64.46%
# Target Domain Accuracy: 98.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3805, Domain Loss: 0.9175
# Source Label Accuracy: 79.51%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.28%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5070, Domain Loss: 0.9208
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 63.97%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5076, Domain Loss: 0.9240
# Source Label Accuracy: 79.72%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 63.27%
# Target Domain Accuracy: 98.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5449, Domain Loss: 0.9262
# Source Label Accuracy: 79.39%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 63.33%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6121, Domain Loss: 0.9280
# Source Label Accuracy: 79.91%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 63.19%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5169, Domain Loss: 0.9293
# Source Label Accuracy: 79.28%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 62.56%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.6445, Domain Loss: 0.9293
# Source Label Accuracy: 79.41%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 62.75%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4231, Domain Loss: 0.9287
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5578, Domain Loss: 0.9290
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 62.31%
# Target Domain Accuracy: 98.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4815, Domain Loss: 0.9276
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 62.60%
# Target Domain Accuracy: 98.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3966, Domain Loss: 0.9249
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 62.47%
# Target Domain Accuracy: 98.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5196, Domain Loss: 0.9231
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 62.36%
# Target Domain Accuracy: 98.27%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6703, Domain Loss: 0.9732
# Source Label Accuracy: 53.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 70.19%
# Target Domain Accuracy: 85.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5656, Domain Loss: 0.8421
# Source Label Accuracy: 76.63%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 69.05%
# Target Domain Accuracy: 96.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6436, Domain Loss: 0.7851
# Source Label Accuracy: 78.09%
# Target Label Accuracy: 91.91%
# Source Domain Accuracy: 67.44%
# Target Domain Accuracy: 97.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4657, Domain Loss: 0.7757
# Source Label Accuracy: 78.73%
# Target Label Accuracy: 91.60%
# Source Domain Accuracy: 66.40%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4893, Domain Loss: 0.7855
# Source Label Accuracy: 79.12%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 65.77%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4888, Domain Loss: 0.8074
# Source Label Accuracy: 79.08%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 66.09%
# Target Domain Accuracy: 97.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5225, Domain Loss: 0.8305
# Source Label Accuracy: 79.29%
# Target Label Accuracy: 92.00%
# Source Domain Accuracy: 65.70%
# Target Domain Accuracy: 98.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4709, Domain Loss: 0.8575
# Source Label Accuracy: 79.51%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 65.34%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4819, Domain Loss: 0.8844
# Source Label Accuracy: 79.45%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 65.51%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.6660, Domain Loss: 0.9035
# Source Label Accuracy: 79.71%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.91%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4603, Domain Loss: 0.9160
# Source Label Accuracy: 79.53%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.80%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5407, Domain Loss: 0.9240
# Source Label Accuracy: 79.65%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 64.33%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5041, Domain Loss: 0.9299
# Source Label Accuracy: 79.79%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 64.75%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4200, Domain Loss: 0.9321
# Source Label Accuracy: 79.87%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 64.84%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4129, Domain Loss: 0.9339
# Source Label Accuracy: 79.60%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 65.11%
# Target Domain Accuracy: 97.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4540, Domain Loss: 0.9370
# Source Label Accuracy: 79.64%
# Target Label Accuracy: 92.50%
# Source Domain Accuracy: 64.87%
# Target Domain Accuracy: 97.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5183, Domain Loss: 0.9405
# Source Label Accuracy: 79.98%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 64.73%
# Target Domain Accuracy: 97.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4242, Domain Loss: 0.9424
# Source Label Accuracy: 79.85%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 64.55%
# Target Domain Accuracy: 97.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5257, Domain Loss: 0.9446
# Source Label Accuracy: 79.90%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 65.07%
# Target Domain Accuracy: 97.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5007, Domain Loss: 0.9441
# Source Label Accuracy: 79.69%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 64.52%
# Target Domain Accuracy: 97.62%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6501, Domain Loss: 1.0238
# Source Label Accuracy: 53.95%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 73.72%
# Target Domain Accuracy: 76.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4751, Domain Loss: 0.9170
# Source Label Accuracy: 76.57%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 70.35%
# Target Domain Accuracy: 88.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5004, Domain Loss: 0.8655
# Source Label Accuracy: 77.71%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 68.75%
# Target Domain Accuracy: 97.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5674, Domain Loss: 0.8517
# Source Label Accuracy: 78.39%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 68.19%
# Target Domain Accuracy: 97.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4114, Domain Loss: 0.8404
# Source Label Accuracy: 79.34%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 66.57%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4831, Domain Loss: 0.8295
# Source Label Accuracy: 79.04%
# Target Label Accuracy: 91.88%
# Source Domain Accuracy: 65.41%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5169, Domain Loss: 0.8252
# Source Label Accuracy: 79.09%
# Target Label Accuracy: 92.00%
# Source Domain Accuracy: 64.57%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5428, Domain Loss: 0.8248
# Source Label Accuracy: 79.29%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 64.38%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5125, Domain Loss: 0.8205
# Source Label Accuracy: 79.52%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 63.72%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4141, Domain Loss: 0.8195
# Source Label Accuracy: 79.27%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 63.80%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4596, Domain Loss: 0.8196
# Source Label Accuracy: 79.55%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4422, Domain Loss: 0.8184
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 63.12%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6434, Domain Loss: 0.8205
# Source Label Accuracy: 79.36%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 63.06%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4613, Domain Loss: 0.8233
# Source Label Accuracy: 79.45%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 63.31%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4276, Domain Loss: 0.8229
# Source Label Accuracy: 79.50%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 63.37%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5994, Domain Loss: 0.8211
# Source Label Accuracy: 79.54%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 63.97%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5833, Domain Loss: 0.8223
# Source Label Accuracy: 79.82%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 63.72%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4553, Domain Loss: 0.8247
# Source Label Accuracy: 79.56%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 63.65%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4616, Domain Loss: 0.8283
# Source Label Accuracy: 79.95%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 63.80%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5103, Domain Loss: 0.8318
# Source Label Accuracy: 79.78%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 63.72%
# Target Domain Accuracy: 97.99%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.67840735068913
# Target (Black): 92.40506329113924
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.085758039816234
# Target (Black): 97.99320778017906
# Overall: 71.31743269526052
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.581742450538008
# (Black FPR) / (White FPR): 0.2344804292231615
# Overall: 13.752350255170562
#
# Source Label Positive Rate: 0.37090352177619934
# Target Label Positive Rate: 0.11608520895242691
# Overall Label Positive Rate: 0.2864162027835846
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7209, Domain Loss: 1.0093
# Source Label Accuracy: 53.74%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 72.02%
# Target Domain Accuracy: 80.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6054, Domain Loss: 0.8846
# Source Label Accuracy: 76.58%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 69.58%
# Target Domain Accuracy: 96.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5171, Domain Loss: 0.8010
# Source Label Accuracy: 78.26%
# Target Label Accuracy: 91.69%
# Source Domain Accuracy: 68.87%
# Target Domain Accuracy: 97.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4810, Domain Loss: 0.7691
# Source Label Accuracy: 78.71%
# Target Label Accuracy: 91.73%
# Source Domain Accuracy: 68.32%
# Target Domain Accuracy: 97.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6505, Domain Loss: 0.7606
# Source Label Accuracy: 79.36%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 67.54%
# Target Domain Accuracy: 97.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4965, Domain Loss: 0.7681
# Source Label Accuracy: 79.23%
# Target Label Accuracy: 91.91%
# Source Domain Accuracy: 66.85%
# Target Domain Accuracy: 97.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4804, Domain Loss: 0.7804
# Source Label Accuracy: 79.30%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 66.51%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4994, Domain Loss: 0.7950
# Source Label Accuracy: 79.24%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 66.15%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5257, Domain Loss: 0.8114
# Source Label Accuracy: 79.74%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 66.21%
# Target Domain Accuracy: 98.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4608, Domain Loss: 0.8229
# Source Label Accuracy: 78.96%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 66.36%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4639, Domain Loss: 0.8326
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 65.50%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5560, Domain Loss: 0.8437
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 65.47%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3917, Domain Loss: 0.8550
# Source Label Accuracy: 79.34%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 65.32%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4394, Domain Loss: 0.8658
# Source Label Accuracy: 79.33%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 64.97%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4638, Domain Loss: 0.8728
# Source Label Accuracy: 79.65%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 65.16%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4539, Domain Loss: 0.8804
# Source Label Accuracy: 79.46%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 64.74%
# Target Domain Accuracy: 97.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4428, Domain Loss: 0.8845
# Source Label Accuracy: 79.64%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.50%
# Target Domain Accuracy: 97.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5233, Domain Loss: 0.8896
# Source Label Accuracy: 79.80%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.24%
# Target Domain Accuracy: 97.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5520, Domain Loss: 0.8943
# Source Label Accuracy: 79.70%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 64.05%
# Target Domain Accuracy: 97.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.6734, Domain Loss: 0.8977
# Source Label Accuracy: 79.60%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 64.51%
# Target Domain Accuracy: 97.65%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.67840735068913
# Target (Black): 92.40506329113924
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.085758039816234
# Target (Black): 97.99320778017906
# Overall: 71.31743269526052
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.581742450538008
# (Black FPR) / (White FPR): 0.2344804292231615
# Overall: 13.752350255170562
#
# Source Label Positive Rate: 0.37090352177619934
# Target Label Positive Rate: 0.11608520895242691
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.21982093238654
# Overall: 83.8468625243116
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.52986217457887
# Target (Black): 97.65359678913245
# Overall: 71.50168901627598
#
# False Positive Rate (Test Data)
# Source (White): 19.518072289156628
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.2418570369513329
# Overall: 13.792640343808756
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6611, Domain Loss: 0.9409
# Source Label Accuracy: 53.96%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 71.80%
# Target Domain Accuracy: 85.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5462, Domain Loss: 0.9373
# Source Label Accuracy: 75.33%
# Target Label Accuracy: 91.97%
# Source Domain Accuracy: 68.74%
# Target Domain Accuracy: 96.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5883, Domain Loss: 0.9082
# Source Label Accuracy: 78.26%
# Target Label Accuracy: 91.57%
# Source Domain Accuracy: 67.76%
# Target Domain Accuracy: 97.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4173, Domain Loss: 0.8856
# Source Label Accuracy: 78.28%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 66.39%
# Target Domain Accuracy: 97.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5605, Domain Loss: 0.8710
# Source Label Accuracy: 79.30%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 65.44%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5633, Domain Loss: 0.8651
# Source Label Accuracy: 79.37%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 65.55%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5089, Domain Loss: 0.8692
# Source Label Accuracy: 79.21%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 65.39%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5489, Domain Loss: 0.8777
# Source Label Accuracy: 79.45%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 64.61%
# Target Domain Accuracy: 98.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4279, Domain Loss: 0.8871
# Source Label Accuracy: 79.30%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 64.89%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4778, Domain Loss: 0.8980
# Source Label Accuracy: 79.58%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 64.70%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3774, Domain Loss: 0.9104
# Source Label Accuracy: 79.31%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 64.43%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3899, Domain Loss: 0.9248
# Source Label Accuracy: 79.37%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 64.31%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5698, Domain Loss: 0.9367
# Source Label Accuracy: 79.36%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 63.95%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4914, Domain Loss: 0.9470
# Source Label Accuracy: 79.56%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 64.45%
# Target Domain Accuracy: 98.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4019, Domain Loss: 0.9550
# Source Label Accuracy: 79.37%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.99%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3970, Domain Loss: 0.9585
# Source Label Accuracy: 79.47%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 64.36%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5024, Domain Loss: 0.9639
# Source Label Accuracy: 79.61%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 64.88%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5860, Domain Loss: 0.9669
# Source Label Accuracy: 79.73%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 64.81%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4231, Domain Loss: 0.9690
# Source Label Accuracy: 79.81%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.40%
# Target Domain Accuracy: 97.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3930, Domain Loss: 0.9686
# Source Label Accuracy: 79.92%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 63.60%
# Target Domain Accuracy: 97.81%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.67840735068913
# Target (Black): 92.40506329113924
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.085758039816234
# Target (Black): 97.99320778017906
# Overall: 71.31743269526052
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.581742450538008
# (Black FPR) / (White FPR): 0.2344804292231615
# Overall: 13.752350255170562
#
# Source Label Positive Rate: 0.37090352177619934
# Target Label Positive Rate: 0.11608520895242691
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.21982093238654
# Overall: 83.8468625243116
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.52986217457887
# Target (Black): 97.65359678913245
# Overall: 71.50168901627598
#
# False Positive Rate (Test Data)
# Source (White): 19.518072289156628
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.2418570369513329
# Overall: 13.792640343808756
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.66309341500765
# Target (Black): 92.15807347946897
# Overall: 83.80591667519705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.83614088820827
# Target (Black): 97.80796542142636
# Overall: 71.75760057324189
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.755293300937175
# (Black FPR) / (White FPR): 0.24336226366343278
# Overall: 13.819500402900886
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7447, Domain Loss: 0.9890
# Source Label Accuracy: 53.89%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 73.19%
# Target Domain Accuracy: 78.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5624, Domain Loss: 0.9187
# Source Label Accuracy: 77.13%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 71.65%
# Target Domain Accuracy: 94.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5587, Domain Loss: 0.8436
# Source Label Accuracy: 78.33%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 70.03%
# Target Domain Accuracy: 96.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4138, Domain Loss: 0.7980
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 68.38%
# Target Domain Accuracy: 97.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6770, Domain Loss: 0.7725
# Source Label Accuracy: 79.17%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 67.91%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4786, Domain Loss: 0.7639
# Source Label Accuracy: 79.53%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 67.46%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4643, Domain Loss: 0.7647
# Source Label Accuracy: 78.97%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 67.30%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4834, Domain Loss: 0.7685
# Source Label Accuracy: 79.21%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 66.60%
# Target Domain Accuracy: 98.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4661, Domain Loss: 0.7720
# Source Label Accuracy: 79.52%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 66.45%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5393, Domain Loss: 0.7807
# Source Label Accuracy: 79.62%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 66.65%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4790, Domain Loss: 0.7902
# Source Label Accuracy: 79.54%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 66.50%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5442, Domain Loss: 0.7996
# Source Label Accuracy: 79.51%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 65.75%
# Target Domain Accuracy: 97.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4724, Domain Loss: 0.8081
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 66.23%
# Target Domain Accuracy: 97.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4727, Domain Loss: 0.8196
# Source Label Accuracy: 79.47%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 66.47%
# Target Domain Accuracy: 97.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4952, Domain Loss: 0.8345
# Source Label Accuracy: 79.60%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 65.90%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4974, Domain Loss: 0.8475
# Source Label Accuracy: 79.30%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 66.58%
# Target Domain Accuracy: 97.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4464, Domain Loss: 0.8569
# Source Label Accuracy: 79.96%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 65.81%
# Target Domain Accuracy: 97.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5218, Domain Loss: 0.8643
# Source Label Accuracy: 79.99%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 65.91%
# Target Domain Accuracy: 97.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4776, Domain Loss: 0.8724
# Source Label Accuracy: 79.76%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 66.08%
# Target Domain Accuracy: 97.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5063, Domain Loss: 0.8788
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 65.66%
# Target Domain Accuracy: 97.68%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.67840735068913
# Target (Black): 92.40506329113924
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.085758039816234
# Target (Black): 97.99320778017906
# Overall: 71.31743269526052
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.581742450538008
# (Black FPR) / (White FPR): 0.2344804292231615
# Overall: 13.752350255170562
#
# Source Label Positive Rate: 0.37090352177619934
# Target Label Positive Rate: 0.11608520895242691
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.21982093238654
# Overall: 83.8468625243116
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.52986217457887
# Target (Black): 97.65359678913245
# Overall: 71.50168901627598
#
# False Positive Rate (Test Data)
# Source (White): 19.518072289156628
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.2418570369513329
# Overall: 13.792640343808756
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.66309341500765
# Target (Black): 92.15807347946897
# Overall: 83.80591667519705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.83614088820827
# Target (Black): 97.80796542142636
# Overall: 71.75760057324189
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.755293300937175
# (Black FPR) / (White FPR): 0.24336226366343278
# Overall: 13.819500402900886
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.8009188361409
# Target (Black): 92.37418956468046
# Overall: 83.96970007165524
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.03062787136294
# Target (Black): 97.68447051559123
# Overall: 72.51509878186098
#
# False Positive Rate (Test Data)
# Source (White): 19.40854326396495
# Target (Black): 4.547032280458175
# (Black FPR) / (White FPR): 0.23427993634640595
# Overall: 13.658340048348107
#
# Source Label Positive Rate: 0.37029096484184265
# Target Label Positive Rate: 0.11515899747610092
# Overall Label Positive Rate: 0.28569966554641724
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7519, Domain Loss: 1.0219
# Source Label Accuracy: 53.86%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 72.17%
# Target Domain Accuracy: 81.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5976, Domain Loss: 0.9493
# Source Label Accuracy: 76.50%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 70.17%
# Target Domain Accuracy: 94.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4858, Domain Loss: 0.8721
# Source Label Accuracy: 77.69%
# Target Label Accuracy: 91.73%
# Source Domain Accuracy: 68.45%
# Target Domain Accuracy: 95.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4801, Domain Loss: 0.8298
# Source Label Accuracy: 78.51%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 67.40%
# Target Domain Accuracy: 96.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4947, Domain Loss: 0.8181
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 91.88%
# Source Domain Accuracy: 66.25%
# Target Domain Accuracy: 96.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5889, Domain Loss: 0.8216
# Source Label Accuracy: 79.19%
# Target Label Accuracy: 91.88%
# Source Domain Accuracy: 65.57%
# Target Domain Accuracy: 96.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.3988, Domain Loss: 0.8322
# Source Label Accuracy: 79.48%
# Target Label Accuracy: 91.97%
# Source Domain Accuracy: 65.35%
# Target Domain Accuracy: 96.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4638, Domain Loss: 0.8446
# Source Label Accuracy: 79.58%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 64.66%
# Target Domain Accuracy: 96.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5581, Domain Loss: 0.8549
# Source Label Accuracy: 79.38%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 64.65%
# Target Domain Accuracy: 96.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4691, Domain Loss: 0.8588
# Source Label Accuracy: 78.98%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 64.50%
# Target Domain Accuracy: 96.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4116, Domain Loss: 0.8622
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 64.52%
# Target Domain Accuracy: 96.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4115, Domain Loss: 0.8622
# Source Label Accuracy: 79.63%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 64.18%
# Target Domain Accuracy: 96.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5425, Domain Loss: 0.8607
# Source Label Accuracy: 79.75%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 64.21%
# Target Domain Accuracy: 96.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5658, Domain Loss: 0.8609
# Source Label Accuracy: 79.72%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 64.14%
# Target Domain Accuracy: 96.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5276, Domain Loss: 0.8633
# Source Label Accuracy: 79.57%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 64.16%
# Target Domain Accuracy: 96.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3768, Domain Loss: 0.8709
# Source Label Accuracy: 79.35%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 64.17%
# Target Domain Accuracy: 96.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4385, Domain Loss: 0.8790
# Source Label Accuracy: 79.48%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 64.24%
# Target Domain Accuracy: 96.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4318, Domain Loss: 0.8860
# Source Label Accuracy: 79.43%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 63.80%
# Target Domain Accuracy: 96.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5060, Domain Loss: 0.8919
# Source Label Accuracy: 79.63%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 63.97%
# Target Domain Accuracy: 96.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3948, Domain Loss: 0.8965
# Source Label Accuracy: 79.72%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 63.64%
# Target Domain Accuracy: 96.54%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.40506329113924
# Overall: 83.92875422254069
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.64624808575804
# Target (Black): 98.27107131830812
# Overall: 70.44733340157642
#
# False Positive Rate (Test Data)
# Source (White): 19.605695509309967
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23015363613270529
# Overall: 13.765780284716627
#
# Source Label Positive Rate: 0.3722817897796631
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2869280278682709
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.83154670750383
# Target (Black): 92.4668107440568
# Overall: 84.02088238304842
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.01990811638591
# Target (Black): 97.62272306267367
# Overall: 71.8190193469137
#
# False Positive Rate (Test Data)
# Source (White): 19.45235487404162
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23196791029140906
# Overall: 13.671770077894172
#
# Source Label Positive Rate: 0.3712098002433777
# Target Label Positive Rate: 0.11546773463487625
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.67840735068913
# Target (Black): 92.40506329113924
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.085758039816234
# Target (Black): 97.99320778017906
# Overall: 71.31743269526052
#
# False Positive Rate (Test Data)
# Source (White): 19.53997809419496
# Target (Black): 4.581742450538008
# (Black FPR) / (White FPR): 0.2344804292231615
# Overall: 13.752350255170562
#
# Source Label Positive Rate: 0.37090352177619934
# Target Label Positive Rate: 0.11608520895242691
# Overall Label Positive Rate: 0.2864162027835846
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.21982093238654
# Overall: 83.8468625243116
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.52986217457887
# Target (Black): 97.65359678913245
# Overall: 71.50168901627598
#
# False Positive Rate (Test Data)
# Source (White): 19.518072289156628
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.2418570369513329
# Overall: 13.792640343808756
#
# Source Label Positive Rate: 0.37075039744377136
# Target Label Positive Rate: 0.11670268326997757
# Overall Label Positive Rate: 0.28651857376098633
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.66309341500765
# Target (Black): 92.15807347946897
# Overall: 83.80591667519705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.83614088820827
# Target (Black): 97.80796542142636
# Overall: 71.75760057324189
#
# ...
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4831, Domain Loss: 0.7599
# Source Label Accuracy: 79.02%
# Target Label Accuracy: 91.69%
# Source Domain Accuracy: 67.09%
# Target Domain Accuracy: 98.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5661, Domain Loss: 0.7445
# Source Label Accuracy: 79.31%
# Target Label Accuracy: 91.73%
# Source Domain Accuracy: 65.62%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5289, Domain Loss: 0.7441
# Source Label Accuracy: 79.20%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 64.11%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4111, Domain Loss: 0.7475
# Source Label Accuracy: 79.63%
# Target Label Accuracy: 91.97%
# Source Domain Accuracy: 62.96%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5466, Domain Loss: 0.7607
# Source Label Accuracy: 79.25%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 62.71%
# Target Domain Accuracy: 98.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5552, Domain Loss: 0.7824
# Source Label Accuracy: 79.35%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 62.82%
# Target Domain Accuracy: 98.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4433, Domain Loss: 0.7974
# Source Label Accuracy: 79.32%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 62.73%
# Target Domain Accuracy: 98.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4552, Domain Loss: 0.8122
# Source Label Accuracy: 78.83%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 62.44%
# Target Domain Accuracy: 98.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4933, Domain Loss: 0.8217
# Source Label Accuracy: 79.77%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 62.97%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4348, Domain Loss: 0.8370
# Source Label Accuracy: 79.38%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 62.65%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5288, Domain Loss: 0.8397
# Source Label Accuracy: 79.88%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 63.48%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4765, Domain Loss: 0.8418
# Source Label Accuracy: 79.45%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 63.83%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4528, Domain Loss: 0.8577
# Source Label Accuracy: 79.74%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 63.81%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5398, Domain Loss: 0.8624
# Source Label Accuracy: 79.66%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.34%
# Target Domain Accuracy: 97.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5028, Domain Loss: 0.8737
# Source Label Accuracy: 79.45%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 64.61%
# Target Domain Accuracy: 97.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.6546, Domain Loss: 0.8746
# Source Label Accuracy: 79.59%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 64.65%
# Target Domain Accuracy: 97.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5260, Domain Loss: 0.8804
# Source Label Accuracy: 79.89%
# Target Label Accuracy: 92.31%
# Source Domain Accuracy: 65.09%
# Target Domain Accuracy: 96.26%
#
# Lambda: 0.05
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.70903522205207
# Target (Black): 92.4668107440568
# Overall: 83.93899068481933
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.13169984686064
# Target (Black): 95.89379438098179
# Overall: 70.65206264714915
#
# False Positive Rate (Test Data)
# Source (White): 19.189485213581598
# Target (Black): 4.477611940298507
# (Black FPR) / (White FPR): 0.23333674095277038
# Overall: 13.497179693795326
#
# Source Label Positive Rate: 0.36630934476852417
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.28293582797050476
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.86217457886677
# Target (Black): 92.59030564989195
# Overall: 84.08230115672023
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.97856049004594
# Target (Black): 96.66563754245138
# Overall: 70.8056095813287
#
# False Positive Rate (Test Data)
# Source (White): 18.97042716319825
# Target (Black): 4.30406108989934
# (Black FPR) / (White FPR): 0.2268826659975807
# Overall: 13.295729250604351
#
# Source Label Positive Rate: 0.36477795243263245
# Target Label Positive Rate: 0.11299783736467361
# Overall Label Positive Rate: 0.2812979817390442
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.34331583822167
# Overall: 83.90828129798342
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.76416539050536
# Target (Black): 97.65359678913245
# Overall: 70.98986590234415
#
# False Positive Rate (Test Data)
# Source (White): 19.211391018619935
# Target (Black): 4.547032280458175
# (Black FPR) / (White FPR): 0.23668417742635767
# Overall: 13.537469782433522
#
# Source Label Positive Rate: 0.3667687475681305
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2832429111003876
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.37418956468046
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.248085758039814
# Target (Black): 97.22136461870947
# Overall: 69.83314566485822
#
# False Positive Rate (Test Data)
# Source (White): 19.474260679079958
# Target (Black): 4.547032280458175
# (Black FPR) / (White FPR): 0.2334893403857319
# Overall: 13.698630136986301
#
# Source Label Positive Rate: 0.3701378107070923
# Target Label Positive Rate: 0.11515899747610092
# Overall Label Positive Rate: 0.2855972945690155
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.86217457886677
# Target (Black): 92.59030564989195
# Overall: 84.08230115672023
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.266462480857584
# Target (Black): 86.44643408459402
# Overall: 70.28355000511823
#
# False Positive Rate (Test Data)
# Source (White): 19.03614457831325
# Target (Black): 4.30406108989934
# (Black FPR) / (White FPR): 0.2260994116845856
# Overall: 13.336019339242545
#
# Source Label Positive Rate: 0.3656967878341675
# Target Label Positive Rate: 0.11299783736467361
# Overall Label Positive Rate: 0.2819121778011322
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.75497702909648
# Target (Black): 92.4976844705156
# Overall: 83.97993653393387
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.18836140888208
# Target (Black): 95.862920654523
# Overall: 71.34814208209643
#
# False Positive Rate (Test Data)
# Source (White): 19.211391018619935
# Target (Black): 4.40819160013884
# (Black FPR) / (White FPR): 0.22945717964234671
# Overall: 13.483749664249261
#
# Source Label Positive Rate: 0.36707502603530884
# Target Label Positive Rate: 0.1139240488409996
# Overall Label Positive Rate: 0.28314054012298584
#
# run: 7/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.66309341500765
# Target (Black): 92.40506329113924
# Overall: 83.88780837342614
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.437978560490045
# Target (Black): 97.49922815683853
# Overall: 71.38908793121098
#
# False Positive Rate (Test Data)
# Source (White): 19.430449069003284
# Target (Black): 4.477611940298507
# (Black FPR) / (White FPR): 0.23044304968954551
# Overall: 13.644910018802042
#
# Source Label Positive Rate: 0.36921897530555725
# Target Label Positive Rate: 0.11423278599977493
# Overall Label Positive Rate: 0.2846760153770447
#
# run: 8/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.739663093415
# Target (Black): 92.40506329113924
# Overall: 83.93899068481933
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.91271056661562
# Target (Black): 96.07903673973449
# Overall: 71.23554099703142
#
# False Positive Rate (Test Data)
# Source (White): 19.430449069003284
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23222942991969703
# Overall: 13.658340048348107
#
# Source Label Positive Rate: 0.3699846863746643
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2853925824165344
#
# run: 9/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.77029096477794
# Target (Black): 92.43593701759802
# Overall: 83.96970007165524
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.02450229709035
# Target (Black): 96.29515282494597
# Overall: 70.71348142082097
#
# False Positive Rate (Test Data)
# Source (White): 19.299014238773275
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.2338110151404895
# Overall: 13.577759871071716
#
# Source Label Positive Rate: 0.3684532940387726
# Target Label Positive Rate: 0.11515899747610092
# Overall Label Positive Rate: 0.2844712734222412
#
# run: 10/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.55589586523736
# Target (Black): 92.31244211176289
# Overall: 83.78544375063979
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.72894333843798
# Target (Black): 96.2642790984872
# Overall: 71.1741222233596
#
# False Positive Rate (Test Data)
# Source (White): 19.890470974808323
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.23732887656788287
# Overall: 14.02095084609186
#
# Source Label Positive Rate: 0.3745788633823395
# Target Label Positive Rate: 0.11762889474630356
# Overall Label Positive Rate: 0.28938478231430054
#
#
# Lambda: 0.05
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.70903522205207
# Target (Black): 92.4668107440568
# Overall: 83.93899068481933
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.13169984686064
# Target (Black): 95.89379438098179
# Overall: 70.65206264714915
#
# False Positive Rate (Test Data)
# Source (White): 19.189485213581598
# Target (Black): 4.477611940298507
# (Black FPR) / (White FPR): 0.23333674095277038
# Overall: 13.497179693795326
#
# Source Label Positive Rate: 0.36630934476852417
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.28293582797050476
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.86217457886677
# Target (Black): 92.59030564989195
# Overall: 84.08230115672023
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.97856049004594
# Target (Black): 96.66563754245138
# Overall: 70.8056095813287
#
# False Positive Rate (Test Data)
# Source (White): 18.97042716319825
# Target (Black): 4.30406108989934
# (Black FPR) / (White FPR): 0.2268826659975807
# Overall: 13.295729250604351
#
# Source Label Positive Rate: 0.36477795243263245
# Target Label Positive Rate: 0.11299783736467361
# Overall Label Positive Rate: 0.2812979817390442
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.72434915773354
# Target (Black): 92.34331583822167
# Overall: 83.90828129798342
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.76416539050536
# Target (Black): 97.65359678913245
# Overall: 70.98986590234415
#
# False Positive Rate (Test Data)
# Source (White): 19.211391018619935
# Target (Black): 4.547032280458175
# (Black FPR) / (White FPR): 0.23668417742635767
# Overall: 13.537469782433522
#
# Source Label Positive Rate: 0.3667687475681305
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2832429111003876
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.6937212863706
# Target (Black): 92.37418956468046
# Overall: 83.89804483570478
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.248085758039814
# Target (Black): 97.22136461870947
# Overall: 69.83314566485822
#
# False Positive Rate (Test Data)
# Source (White): 19.474260679079958
# Target (Black): 4.547032280458175
# (Black FPR) / (White FPR): 0.2334893403857319
# Overall: 13.698630136986301
#
# Source Label Positive Rate: 0.3701378107070923
# Target Label Positive Rate: 0.11515899747610092
# Overall Label Positive Rate: 0.2855972945690155
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.86217457886677
# Target (Black): 92.59030564989195
# Overall: 84.08230115672023
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.266462480857584
# Target (Black): 86.44643408459402
# Overall: 70.28355000511823
#
# False Positive Rate (Test Data)
# Source (White): 19.03614457831325
# Target (Black): 4.30406108989934
# (Black FPR) / (White FPR): 0.2260994116845856
# Overall: 13.336019339242545
#
# Source Label Positive Rate: 0.3656967878341675
# Target Label Positive Rate: 0.11299783736467361
# Overall Label Positive Rate: 0.2819121778011322
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.75497702909648
# Target (Black): 92.4976844705156
# Overall: 83.97993653393387
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.18836140888208
# Target (Black): 95.862920654523
# Overall: 71.34814208209643
#
# False Positive Rate (Test Data)
# Source (White): 19.211391018619935
# Target (Black): 4.40819160013884
# (Black FPR) / (White FPR): 0.22945717964234671
# Overall: 13.483749664249261
#
# Source Label Positive Rate: 0.36707502603530884
# Target Label Positive Rate: 0.1139240488409996
# Overall Label Positive Rate: 0.28314054012298584
#
# run: 7/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.66309341500765
# Target (Black): 92.40506329113924
# Overall: 83.88780837342614
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.437978560490045
# Target (Black): 97.49922815683853
# Overall: 71.38908793121098
#
# False Positive Rate (Test Data)
# Source (White): 19.430449069003284
# Target (Black): 4.477611940298507
# (Black FPR) / (White FPR): 0.23044304968954551
# Overall: 13.644910018802042
#
# Source Label Positive Rate: 0.36921897530555725
# Target Label Positive Rate: 0.11423278599977493
# Overall Label Positive Rate: 0.2846760153770447
#
# run: 8/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.739663093415
# Target (Black): 92.40506329113924
# Overall: 83.93899068481933
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.91271056661562
# Target (Black): 96.07903673973449
# Overall: 71.23554099703142
#
# False Positive Rate (Test Data)
# Source (White): 19.430449069003284
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.23222942991969703
# Overall: 13.658340048348107
#
# Source Label Positive Rate: 0.3699846863746643
# Target Label Positive Rate: 0.11485026031732559
# Overall Label Positive Rate: 0.2853925824165344
#
# run: 9/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.77029096477794
# Target (Black): 92.43593701759802
# Overall: 83.96970007165524
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.02450229709035
# Target (Black): 96.29515282494597
# Overall: 70.71348142082097
#
# False Positive Rate (Test Data)
# Source (White): 19.299014238773275
# Target (Black): 4.51232211037834
# (Black FPR) / (White FPR): 0.2338110151404895
# Overall: 13.577759871071716
#
# Source Label Positive Rate: 0.3684532940387726
# Target Label Positive Rate: 0.11515899747610092
# Overall Label Positive Rate: 0.2844712734222412
#
# run: 10/15
# Label Classifier Accuracy (Test Data)
# Source (White): 79.55589586523736
# Target (Black): 92.31244211176289
# Overall: 83.78544375063979
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.72894333843798
# Target (Black): 96.2642790984872
# Overall: 71.1741222233596
#
# False Positive Rate (Test Data)
# Source (White): 19.890470974808323
# Target (Black): 4.720583130857341
# (Black FPR) / (White FPR): 0.23732887656788287
# Overall: 14.02095084609186
#
# Source Label Positive Rate: 0.3745788633823395
# Target Label Positive Rate: 0.11762889474630356
# Overall Label Positive Rate: 0.28938478231430054
