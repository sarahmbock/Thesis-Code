# %% [markdown]
# # NEWEST

# %%
# IW CODE: https://github.com/sarahmbock/COS-IW-BOCK/blob/main/DANN%20CODE.ipynb

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(5112, 256),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(256, 256),
    nn.Sigmoid(),
    nn.Linear(256, 56),
    nn.Sigmoid(),
    nn.Linear(56, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(256, 128),
    nn.Sigmoid(),
    nn.Linear(128, 128), nn.Sigmoid(),              
    nn.Linear(128, 2),
    nn.Sigmoid()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 256)
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %% [markdown]
# # DATA

# %%
import pandas as pd
import numpy as np
#import rowgenerators as rg ****commented out for thesis****

from sklearn.feature_selection import VarianceThreshold

scfp = pd.read_stata('p19i6.dta')



# SELECT only rows where there is debt and where white and black
delinquency = 'x3005'
loan_schedule ='x3004'# 1 on time, 5 sometimes late, 0 inapp.
race = 'x6809'
additional_race = 'x6810'
hispanic = 'x7004'

scfp = scfp[(scfp[race] == 1) | (scfp[race] == 2)]
scfp =  scfp[(scfp[loan_schedule] == 1) | (scfp[loan_schedule] == 5)]
scfp.shape

# Remove revealing columns
race_revealing = [additional_race, 'x7004']
race_revealing += [col.replace('x', 'j') for col in race_revealing]
sched_revealing = ['x7571', 'x7570', 'x7569', 'x7556', 'x7564', 'x7554','x7553',
                   'x7534', 'x7533', 'x7532', 'x7166', 'x7529', 'x7821', 'x7844',
                   'x7867', 'x7921', 'x7569', 'x7944', 'x7521', 'x7520', 'x7518',
                   'x7517', delinquency, 'j3005', 'j3004']
sched_revealing += [col.replace('x', 'j') for col in sched_revealing]

exclude = sched_revealing+ race_revealing
X = scfp.copy()
# Eliminate bad columns
X = scfp.loc[:, [col for col in scfp.columns if col not in exclude]]
X = X.fillna(-1)

# Remove columns with all -1

# instantiate the VarianceThreshold object with a threshold of 0
selector = VarianceThreshold(threshold=0)

# fit the selector on the DataFrame
selector.fit(X)

# get the indices of the non-constant columns
non_constant_cols = selector.get_support(indices=True)

# select the non-constant columns from the original DataFrame
X = X.iloc[:, non_constant_cols]

# print the filtered DataFrame
print(X.shape)
# Out:
# (18362, 5114)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

# split to source (white) and target (black)
# First, create a new column in X that indicates whether each person is white or black
print(len(X))
# Use groupby to split X and y into two separate dataframes, one with only white data and the other with only black data
X_white = X[X[race] == 1]
y_white = X_white[loan_schedule].replace({1: 0, 5: 1})
X_white = X_white.drop([race, loan_schedule], axis =1)
#print(y_white)
print(len(y_white))
print(len(X_white))

X_black = X[X[race]==2]
y_black = X_black[loan_schedule].replace({1: 0, 5: 1})
X_black = X_black.drop([race, loan_schedule], axis =1)
#print(y_black)
print(len(y_black))
print(len(X_black))
# Out:
# 18362
# 15615
# 15615
# 2747
# 2747

# %%
from sklearn.preprocessing import StandardScaler

X_tensor_source =  torch.from_numpy(X_white.values).type(torch.float32)
X_tensor_target =  torch.from_numpy(X_black.values).type(torch.float32)
y_tensor_source =torch.tensor(y_white.values).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_black.values).type(torch.LongTensor)


# Split the source (race) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (loan sched) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train)
num_positives = sum(target_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size, sampler=sampler)
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size, sampler = sampler)
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

print(X_train_source.shape)
print(X_train_target.shape)
# Out:
# positive weight (under represented): 0.0016835016835016834
# negative weight (over represented): 0.0006238303181534623
# positive weight (under represented): 0.0006622516556291391
# negative weight (over represented): 9.105809506465124e-05
# torch.Size([12492, 5112])
# torch.Size([2197, 5112])

# %%
combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)


# ****** what am i weighting based off of
y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size, sampler=sampler)



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples))
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size, sampler=sampler)
# Out:
# 2197
# tensor([0, 0, 0,  ..., 1, 1, 1])
# [12492  2197]
# [8.00512328e-05 4.55166136e-04]
# 2104
# 12585
# [7.94596742e-05 4.75285171e-04]

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch
       

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.0001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 20
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
'''lambda = 0
label trained
domain trained
feature extractor trained
Epoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133
Source Label Accuracy: 96.33%
Target Label Accuracy: 97.27%
Source Domain Accuracy: 89.32%
Target Domain Accuracy: 84.73%
domain accuracy on train data:  0.901286677105317
black predicted:  0.4585063653073729
num actually black:  0.48519300156579753
domain test accuracy:  0.906071331336782
black pred test:  0.19793084671930303
actual black =  0.14974135583991288
Credit Confusion Matrix White: 
[[2673   64]
 [  40  346]]
False positive white:  0.023383266350018268
Credit Confusion Matrix Black: 
[[376   7]
 [  8 159]]
False positive black:  0.018276762402088774

'''
# Out:
# 'lambda = 0\nlabel trained\ndomain trained\nfeature extractor trained\nEpoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133\nSource Label Accuracy: 96.33%\nTarget Label Accuracy: 97.27%\nSource Domain Accuracy: 89.32%\nTarget Domain Accuracy: 84.73%\ndomain accuracy on train data:  0.901286677105317\nblack predicted:  0.4585063653073729\nnum actually black:  0.48519300156579753\ndomain test accuracy:  0.906071331336782\nblack pred test:  0.19793084671930303\nactual black =  0.14974135583991288\nCredit Confusion Matrix White: \n[[2673   64]\n [  40  346]]\nFalse positive white:  0.023383266350018268\nCredit Confusion Matrix Black: \n[[376   7]\n [  8 159]]\nFalse positive black:  0.018276762402088774\n\n'

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        source_label_positive_rate = (sum(source_label_predictions)/len(source_label_predictions)).item()
        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        target_label_positive_rate = (sum(target_label_predictions)/len(target_label_predictions)).item()
        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_label_positive_rate = ((sum(source_label_predictions) + sum(target_label_predictions))/(len(target_label_predictions)+len(source_label_predictions))).item()
        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall,
                   'source_label_positive_rate': source_label_positive_rate, 'target_label_positive_rate': target_label_positive_rate,
                   'overall_label_positive_rate': overall_label_positive_rate}
        return results

# %%
#write_results(0.8, model, source_test, target_test)

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 4
#       2 for lam in range(10):
#       3     lam = 0.1*lam
# ----> 4     model = train_for_lambda(lam)
#       5     models[lam] = model
#       6     write_results(lam, model, source_test, target_test)
#
# Cell In[42], line 32, in train_for_lambda(lambda_)
#      30 # Training loop
#      31 num_epochs = 1
# ---> 32 train(model, num_epochs, optimizer_lc, 20, domain_epochs =30,
#      33       source_loader=source_train, target_loader= target_train,
#      34       label_criterion =criterion_lc, domain_criterion=criterion_dc,
#      35      label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
#      36 return model
#
# Cell In[33], line 19, in train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion, label_optimizer, domain_optimizer, lambda_)
#      17         label_preds = dann.lc(feature_embed)
#      18         label_loss = label_criterion(label_preds, source_labels)
# ---> 19         label_loss.backward()
#      20         label_optimizer.step()
#      21 print('label trained')
#
# File ~/.pyenv/versions/3.10.8/envs/iw/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/.pyenv/versions/3.10.8/envs/iw/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results_conf_SCF_Race_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(10):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        # parity
        my_str += 'Source Label Positive Rate: ' + str(results['source_label_positive_rate']) + '\n'
        my_str += 'Target Label Positive Rate: ' + str(results['target_label_positive_rate']) + '\n'
        my_str += 'Overall Label Positive Rate: ' + str(results['overall_label_positive_rate']) + '\n\n'

        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
# To get parity, changed get_results() and write_conf_results() to include positive rate
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5754, Domain Loss: 0.5681
# Source Label Accuracy: 74.07%
# Target Label Accuracy: 70.00%
# Source Domain Accuracy: 57.78%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5653, Domain Loss: 0.3895
# Source Label Accuracy: 77.23%
# Target Label Accuracy: 74.00%
# Source Domain Accuracy: 63.45%
# Target Domain Accuracy: 76.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5393, Domain Loss: 0.3766
# Source Label Accuracy: 79.98%
# Target Label Accuracy: 73.27%
# Source Domain Accuracy: 64.15%
# Target Domain Accuracy: 75.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5252, Domain Loss: 0.3426
# Source Label Accuracy: 80.92%
# Target Label Accuracy: 78.00%
# Source Domain Accuracy: 64.97%
# Target Domain Accuracy: 74.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4908, Domain Loss: 0.3258
# Source Label Accuracy: 82.82%
# Target Label Accuracy: 79.64%
# Source Domain Accuracy: 64.12%
# Target Domain Accuracy: 73.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4975, Domain Loss: 0.3232
# Source Label Accuracy: 84.33%
# Target Label Accuracy: 80.00%
# Source Domain Accuracy: 66.22%
# Target Domain Accuracy: 75.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4351, Domain Loss: 0.3402
# Source Label Accuracy: 85.35%
# Target Label Accuracy: 80.36%
# Source Domain Accuracy: 64.78%
# Target Domain Accuracy: 73.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4453, Domain Loss: 0.3396
# Source Label Accuracy: 85.55%
# Target Label Accuracy: 82.55%
# Source Domain Accuracy: 65.90%
# Target Domain Accuracy: 73.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3449, Domain Loss: 0.3406
# Source Label Accuracy: 87.49%
# Target Label Accuracy: 84.36%
# Source Domain Accuracy: 64.51%
# Target Domain Accuracy: 72.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.3428, Domain Loss: 0.3313
# Source Label Accuracy: 88.52%
# Target Label Accuracy: 86.36%
# Source Domain Accuracy: 61.50%
# Target Domain Accuracy: 74.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4278, Domain Loss: 0.3407
# Source Label Accuracy: 89.23%
# Target Label Accuracy: 88.36%
# Source Domain Accuracy: 63.00%
# Target Domain Accuracy: 75.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3431, Domain Loss: 0.3554
# Source Label Accuracy: 89.54%
# Target Label Accuracy: 89.27%
# Source Domain Accuracy: 66.18%
# Target Domain Accuracy: 77.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4108, Domain Loss: 0.3506
# Source Label Accuracy: 90.55%
# Target Label Accuracy: 90.18%
# Source Domain Accuracy: 72.74%
# Target Domain Accuracy: 73.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4092, Domain Loss: 0.3236
# Source Label Accuracy: 90.57%
# Target Label Accuracy: 90.18%
# Source Domain Accuracy: 71.99%
# Target Domain Accuracy: 69.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3281, Domain Loss: 0.3208
# Source Label Accuracy: 90.89%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 71.34%
# Target Domain Accuracy: 75.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3293, Domain Loss: 0.3219
# Source Label Accuracy: 91.90%
# Target Label Accuracy: 92.55%
# Source Domain Accuracy: 70.30%
# Target Domain Accuracy: 75.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3591, Domain Loss: 0.3170
# Source Label Accuracy: 93.71%
# Target Label Accuracy: 93.09%
# Source Domain Accuracy: 76.32%
# Target Domain Accuracy: 71.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3462, Domain Loss: 0.3155
# Source Label Accuracy: 93.48%
# Target Label Accuracy: 93.64%
# Source Domain Accuracy: 73.34%
# Target Domain Accuracy: 77.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3229, Domain Loss: 0.3139
# Source Label Accuracy: 94.57%
# Target Label Accuracy: 94.55%
# Source Domain Accuracy: 73.54%
# Target Domain Accuracy: 82.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4017, Domain Loss: 0.3135
# Source Label Accuracy: 94.44%
# Target Label Accuracy: 94.00%
# Source Domain Accuracy: 76.46%
# Target Domain Accuracy: 80.00%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.97278258085174
# Target (Black): 94.0
# Overall: 94.82711679825755
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 82.06852385526737
# Target (Black): 80.0
# Overall: 81.75878028859243
#
# False Positive Rate (Test Data)
# Source (White): 3.945926196565583
# Target (Black): 4.960835509138382
# (Black FPR) / (White FPR): 1.2572043322696065
# Overall: 4.07051282051282
#
# Source Label Positive Rate: 0.1424911916255951
# Target Label Positive Rate: 0.31272727251052856
# Overall Label Positive Rate: 0.1679825782775879
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5965, Domain Loss: 0.4710
# Source Label Accuracy: 73.75%
# Target Label Accuracy: 68.55%
# Source Domain Accuracy: 59.22%
# Target Domain Accuracy: 77.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4999, Domain Loss: 0.4596
# Source Label Accuracy: 77.07%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 62.70%
# Target Domain Accuracy: 74.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4383, Domain Loss: 0.4079
# Source Label Accuracy: 78.16%
# Target Label Accuracy: 74.18%
# Source Domain Accuracy: 64.00%
# Target Domain Accuracy: 76.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4921, Domain Loss: 0.3738
# Source Label Accuracy: 80.25%
# Target Label Accuracy: 77.27%
# Source Domain Accuracy: 64.84%
# Target Domain Accuracy: 71.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6067, Domain Loss: 0.3923
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 55.57%
# Target Domain Accuracy: 82.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4496, Domain Loss: 0.4407
# Source Label Accuracy: 82.57%
# Target Label Accuracy: 76.00%
# Source Domain Accuracy: 65.17%
# Target Domain Accuracy: 70.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.3492, Domain Loss: 0.4267
# Source Label Accuracy: 82.52%
# Target Label Accuracy: 78.73%
# Source Domain Accuracy: 59.62%
# Target Domain Accuracy: 78.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4197, Domain Loss: 0.4084
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 54.04%
# Target Domain Accuracy: 82.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4510, Domain Loss: 0.3576
# Source Label Accuracy: 83.09%
# Target Label Accuracy: 80.55%
# Source Domain Accuracy: 59.45%
# Target Domain Accuracy: 75.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5392, Domain Loss: 0.4246
# Source Label Accuracy: 85.60%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 60.68%
# Target Domain Accuracy: 74.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4121, Domain Loss: 0.4288
# Source Label Accuracy: 84.84%
# Target Label Accuracy: 80.55%
# Source Domain Accuracy: 67.71%
# Target Domain Accuracy: 67.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3438, Domain Loss: 0.4484
# Source Label Accuracy: 86.60%
# Target Label Accuracy: 85.09%
# Source Domain Accuracy: 59.88%
# Target Domain Accuracy: 76.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4350, Domain Loss: 0.3962
# Source Label Accuracy: 87.92%
# Target Label Accuracy: 84.00%
# Source Domain Accuracy: 60.12%
# Target Domain Accuracy: 75.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4245, Domain Loss: 0.4027
# Source Label Accuracy: 87.55%
# Target Label Accuracy: 86.73%
# Source Domain Accuracy: 63.08%
# Target Domain Accuracy: 75.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3390, Domain Loss: 0.3804
# Source Label Accuracy: 87.01%
# Target Label Accuracy: 87.27%
# Source Domain Accuracy: 61.58%
# Target Domain Accuracy: 77.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4175, Domain Loss: 0.3556
# Source Label Accuracy: 89.07%
# Target Label Accuracy: 87.64%
# Source Domain Accuracy: 65.15%
# Target Domain Accuracy: 71.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3655, Domain Loss: 0.3412
# Source Label Accuracy: 90.05%
# Target Label Accuracy: 90.91%
# Source Domain Accuracy: 62.93%
# Target Domain Accuracy: 72.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3691, Domain Loss: 0.3477
# Source Label Accuracy: 91.68%
# Target Label Accuracy: 90.36%
# Source Domain Accuracy: 57.37%
# Target Domain Accuracy: 81.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3286, Domain Loss: 0.3280
# Source Label Accuracy: 92.17%
# Target Label Accuracy: 93.09%
# Source Domain Accuracy: 62.88%
# Target Domain Accuracy: 78.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3175, Domain Loss: 0.3266
# Source Label Accuracy: 92.33%
# Target Label Accuracy: 93.09%
# Source Domain Accuracy: 67.17%
# Target Domain Accuracy: 74.36%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.97278258085174
# Target (Black): 94.0
# Overall: 94.82711679825755
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 82.06852385526737
# Target (Black): 80.0
# Overall: 81.75878028859243
#
# False Positive Rate (Test Data)
# Source (White): 3.945926196565583
# Target (Black): 4.960835509138382
# (Black FPR) / (White FPR): 1.2572043322696065
# Overall: 4.07051282051282
#
# Source Label Positive Rate: 0.1424911916255951
# Target Label Positive Rate: 0.31272727251052856
# Overall Label Positive Rate: 0.1679825782775879
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.43579891130324
# Target (Black): 93.0909090909091
# Overall: 93.38415464198204
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 76.94524495677233
# Target (Black): 74.36363636363636
# Overall: 76.55867138578819
#
# False Positive Rate (Test Data)
# Source (White): 4.676653270003654
# Target (Black): 7.310704960835509
# (Black FPR) / (White FPR): 1.5632343342036552
# Overall: 5.0
#
# Source Label Positive Rate: 0.13992954790592194
# Target Label Positive Rate: 0.33636364340782166
# Overall Label Positive Rate: 0.16934385895729065
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6275, Domain Loss: 0.6938
# Source Label Accuracy: 73.31%
# Target Label Accuracy: 70.18%
# Source Domain Accuracy: 64.24%
# Target Domain Accuracy: 71.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6387, Domain Loss: 0.5925
# Source Label Accuracy: 74.62%
# Target Label Accuracy: 73.64%
# Source Domain Accuracy: 64.36%
# Target Domain Accuracy: 71.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4376, Domain Loss: 0.4904
# Source Label Accuracy: 77.27%
# Target Label Accuracy: 71.64%
# Source Domain Accuracy: 57.50%
# Target Domain Accuracy: 80.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4566, Domain Loss: 0.5252
# Source Label Accuracy: 79.05%
# Target Label Accuracy: 72.91%
# Source Domain Accuracy: 60.42%
# Target Domain Accuracy: 73.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.3841, Domain Loss: 0.4314
# Source Label Accuracy: 79.33%
# Target Label Accuracy: 77.45%
# Source Domain Accuracy: 64.85%
# Target Domain Accuracy: 69.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4162, Domain Loss: 0.4509
# Source Label Accuracy: 82.29%
# Target Label Accuracy: 75.82%
# Source Domain Accuracy: 56.45%
# Target Domain Accuracy: 79.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.6172, Domain Loss: 0.4302
# Source Label Accuracy: 83.52%
# Target Label Accuracy: 80.00%
# Source Domain Accuracy: 57.48%
# Target Domain Accuracy: 76.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5094, Domain Loss: 0.4091
# Source Label Accuracy: 82.41%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 60.24%
# Target Domain Accuracy: 75.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3928, Domain Loss: 0.3971
# Source Label Accuracy: 83.11%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 61.37%
# Target Domain Accuracy: 73.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.3948, Domain Loss: 0.5055
# Source Label Accuracy: 83.65%
# Target Label Accuracy: 83.64%
# Source Domain Accuracy: 60.90%
# Target Domain Accuracy: 73.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4766, Domain Loss: 0.4284
# Source Label Accuracy: 85.99%
# Target Label Accuracy: 82.91%
# Source Domain Accuracy: 62.93%
# Target Domain Accuracy: 73.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3674, Domain Loss: 0.3969
# Source Label Accuracy: 87.45%
# Target Label Accuracy: 84.73%
# Source Domain Accuracy: 65.62%
# Target Domain Accuracy: 70.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3672, Domain Loss: 0.3785
# Source Label Accuracy: 87.61%
# Target Label Accuracy: 85.82%
# Source Domain Accuracy: 61.04%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4506, Domain Loss: 0.3717
# Source Label Accuracy: 87.28%
# Target Label Accuracy: 85.64%
# Source Domain Accuracy: 66.19%
# Target Domain Accuracy: 67.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5119, Domain Loss: 0.3581
# Source Label Accuracy: 88.41%
# Target Label Accuracy: 84.55%
# Source Domain Accuracy: 62.41%
# Target Domain Accuracy: 74.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3777, Domain Loss: 0.3319
# Source Label Accuracy: 89.13%
# Target Label Accuracy: 86.73%
# Source Domain Accuracy: 60.75%
# Target Domain Accuracy: 77.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3333, Domain Loss: 0.3973
# Source Label Accuracy: 89.37%
# Target Label Accuracy: 89.45%
# Source Domain Accuracy: 63.70%
# Target Domain Accuracy: 75.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3963, Domain Loss: 0.3859
# Source Label Accuracy: 90.53%
# Target Label Accuracy: 90.00%
# Source Domain Accuracy: 61.67%
# Target Domain Accuracy: 77.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3698, Domain Loss: 0.3596
# Source Label Accuracy: 89.70%
# Target Label Accuracy: 90.73%
# Source Domain Accuracy: 59.09%
# Target Domain Accuracy: 81.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3447, Domain Loss: 0.3319
# Source Label Accuracy: 90.50%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 63.46%
# Target Domain Accuracy: 74.91%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 94.97278258085174
# Target (Black): 94.0
# Overall: 94.82711679825755
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 82.06852385526737
# Target (Black): 80.0
# Overall: 81.75878028859243
#
# False Positive Rate (Test Data)
# Source (White): 3.945926196565583
# Target (Black): 4.960835509138382
# (Black FPR) / (White FPR): 1.2572043322696065
# Overall: 4.07051282051282
#
# Source Label Positive Rate: 0.1424911916255951
# Target Label Positive Rate: 0.31272727251052856
# Overall Label Positive Rate: 0.1679825782775879
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.43579891130324
# Target (Black): 93.0909090909091
# Overall: 93.38415464198204
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 76.94524495677233
# Target (Black): 74.36363636363636
# Overall: 76.55867138578819
#
# False Positive Rate (Test Data)
# Source (White): 4.676653270003654
# Target (Black): 7.310704960835509
# (Black FPR) / (White FPR): 1.5632343342036552
# Overall: 5.0
#
# Source Label Positive Rate: 0.13992954790592194
# Target Label Positive Rate: 0.33636364340782166
# Overall Label Positive Rate: 0.16934385895729065
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 93.30771693884085
# Target (Black): 91.81818181818181
# Overall: 93.0846719303022
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 74.35158501440922
# Target (Black): 74.9090909090909
# Overall: 74.4350667029676
#
# False Positive Rate (Test Data)
# Source (White): 4.201680672268908
# Target (Black): 7.310704960835509
# (Black FPR) / (White FPR): 1.739947780678851
# Overall: 4.583333333333333
#
# Source Label Positive Rate: 0.1303234100341797
# Target Label Positive Rate: 0.32363635301589966
# Overall Label Positive Rate: 0.15927034616470337
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6538, Domain Loss: 0.6197
# Source Label Accuracy: 73.65%
# Target Label Accuracy: 70.73%
# Source Domain Accuracy: 63.57%
# Target Domain Accuracy: 75.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6056, Domain Loss: 0.4027
# Source Label Accuracy: 76.00%
# Target Label Accuracy: 72.18%
# Source Domain Accuracy: 56.44%
# Target Domain Accuracy: 77.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4688, Domain Loss: 0.3618
# Source Label Accuracy: 79.55%
# Target Label Accuracy: 73.64%
# Source Domain Accuracy: 64.33%
# Target Domain Accuracy: 72.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4932, Domain Loss: 0.3258
# Source Label Accuracy: 78.48%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 63.08%
# Target Domain Accuracy: 74.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4572, Domain Loss: 0.3662
# Source Label Accuracy: 81.20%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 60.50%
# Target Domain Accuracy: 79.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4332, Domain Loss: 0.3255
# Source Label Accuracy: 83.62%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 65.81%
# Target Domain Accuracy: 72.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5213, Domain Loss: 0.3254
# Source Label Accuracy: 83.32%
# Target Label Accuracy: 80.36%
# Source Domain Accuracy: 61.55%
# Target Domain Accuracy: 76.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.3653, Domain Loss: 0.3237
# Source Label Accuracy: 85.19%
# Target Label Accuracy: 80.36%
# Source Domain Accuracy: 63.50%
# Target Domain Accuracy: 73.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4026, Domain Loss: 0.3218
# Source Label Accuracy: 84.39%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 66.98%
# Target Domain Accuracy: 72.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4367, Domain Loss: 0.3215
# Source Label Accuracy: 86.37%
# Target Label Accuracy: 81.45%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 76.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3782, Domain Loss: 0.3288
# Source Label Accuracy: 87.49%
# Target Label Accuracy: 84.91%
# Source Domain Accuracy: 68.72%
# Target Domain Accuracy: 66.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3748, Domain Loss: 0.3244
# Source Label Accuracy: 87.00%
# Target Label Accuracy: 85.09%
# Source Domain Accuracy: 64.95%
# Target Domain Accuracy: 70.18%
#
# label trained

# %%
# Get true positive and negative rates for test data !!!!!

# %%
true_pos_black = sum(y_test_target)
print('1s in y_test_target', true_pos_black)
true_pos_white = sum(y_test_source)
print('1s in y_test_source', true_pos_white)

length_white = len(y_test_source)
length_black = len(y_test_target)

true_neg_black = len(y_test_target) - true_pos_black
print('zeros in test black ', true_neg_black)
true_neg_white = len(y_test_source) - true_pos_white
print('zeros in test white ', true_neg_white)

# %%
l = 1
write_conf_results(l, source_test, target_test)

# %%
l = 2
model = train_for_lambda(l)
write_results(l, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5859, Domain Loss: 0.3430
# Source Label Accuracy: 71.46%
# Target Label Accuracy: 70.73%
# Source Domain Accuracy: 20.67%
# Target Domain Accuracy: 96.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5739, Domain Loss: 0.3845
# Source Label Accuracy: 74.51%
# Target Label Accuracy: 70.36%
# Source Domain Accuracy: 27.13%
# Target Domain Accuracy: 95.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5463, Domain Loss: 0.3792
# Source Label Accuracy: 75.03%
# Target Label Accuracy: 70.73%
# Source Domain Accuracy: 29.23%
# Target Domain Accuracy: 93.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5192, Domain Loss: 0.3457
# Source Label Accuracy: 77.41%
# Target Label Accuracy: 73.09%
# Source Domain Accuracy: 30.11%
# Target Domain Accuracy: 94.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4534, Domain Loss: 0.3362
# Source Label Accuracy: 77.64%
# Target Label Accuracy: 73.82%
# Source Domain Accuracy: 35.54%
# Target Domain Accuracy: 92.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5790, Domain Loss: 0.4170
# Source Label Accuracy: 78.29%
# Target Label Accuracy: 73.45%
# Source Domain Accuracy: 30.45%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4897, Domain Loss: 0.4152
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 78.73%
# Source Domain Accuracy: 34.06%
# Target Domain Accuracy: 92.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.6269, Domain Loss: 0.3802
# Source Label Accuracy: 81.50%
# Target Label Accuracy: 77.09%
# Source Domain Accuracy: 32.86%
# Target Domain Accuracy: 92.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3829, Domain Loss: 0.4569
# Source Label Accuracy: 79.88%
# Target Label Accuracy: 78.91%
# Source Domain Accuracy: 38.41%
# Target Domain Accuracy: 89.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4208, Domain Loss: 0.4472
# Source Label Accuracy: 83.15%
# Target Label Accuracy: 79.64%
# Source Domain Accuracy: 34.11%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4792, Domain Loss: 0.3756
# Source Label Accuracy: 83.70%
# Target Label Accuracy: 78.18%
# Source Domain Accuracy: 38.74%
# Target Domain Accuracy: 90.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4332, Domain Loss: 0.4678
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 78.73%
# Source Domain Accuracy: 37.90%
# Target Domain Accuracy: 90.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5887, Domain Loss: 0.4297
# Source Label Accuracy: 85.13%
# Target Label Accuracy: 81.82%
# Source Domain Accuracy: 36.87%
# Target Domain Accuracy: 92.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4972, Domain Loss: 0.4574
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 84.00%
# Source Domain Accuracy: 42.93%
# Target Domain Accuracy: 89.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4238, Domain Loss: 0.5282
# Source Label Accuracy: 85.32%
# Target Label Accuracy: 84.36%
# Source Domain Accuracy: 46.13%
# Target Domain Accuracy: 85.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5050, Domain Loss: 0.3882
# Source Label Accuracy: 86.50%
# Target Label Accuracy: 84.00%
# Source Domain Accuracy: 32.16%
# Target Domain Accuracy: 94.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3697, Domain Loss: 0.3730
# Source Label Accuracy: 87.17%
# Target Label Accuracy: 86.00%
# Source Domain Accuracy: 40.08%
# Target Domain Accuracy: 90.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3393, Domain Loss: 0.4226
# Source Label Accuracy: 87.67%
# Target Label Accuracy: 84.36%
# Source Domain Accuracy: 35.52%
# Target Domain Accuracy: 92.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4053, Domain Loss: 0.4018
# Source Label Accuracy: 87.99%
# Target Label Accuracy: 88.91%
# Source Domain Accuracy: 43.84%
# Target Domain Accuracy: 87.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4107, Domain Loss: 0.3663
# Source Label Accuracy: 88.57%
# Target Label Accuracy: 87.64%
# Source Domain Accuracy: 32.77%
# Target Domain Accuracy: 93.64%
#
# Lambda: 2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 91.5465898174832
# Target (Black): 87.63636363636364
# Overall: 90.96106724748162
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 40.76208773615114
# Target (Black): 93.63636363636364
# Overall: 48.679553498502585
#
# False Positive Rate (Test Data)
# Source (White): 5.9554256485202774
# Target (Black): 11.22715404699739
# (Black FPR) / (White FPR): 1.885197584455942
# Overall: 6.602564102564102

# %%
l = 3
model = train_for_lambda(l)
write_results(l, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7445, Domain Loss: 0.3240
# Source Label Accuracy: 72.58%
# Target Label Accuracy: 70.55%
# Source Domain Accuracy: 25.30%
# Target Domain Accuracy: 97.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5684, Domain Loss: 0.4190
# Source Label Accuracy: 75.66%
# Target Label Accuracy: 69.09%
# Source Domain Accuracy: 26.42%
# Target Domain Accuracy: 97.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5019, Domain Loss: 0.3351
# Source Label Accuracy: 76.46%
# Target Label Accuracy: 71.27%
# Source Domain Accuracy: 31.71%
# Target Domain Accuracy: 93.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5673, Domain Loss: 0.3859
# Source Label Accuracy: 75.94%
# Target Label Accuracy: 73.27%
# Source Domain Accuracy: 34.78%
# Target Domain Accuracy: 92.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5872, Domain Loss: 0.3602
# Source Label Accuracy: 75.70%
# Target Label Accuracy: 75.64%
# Source Domain Accuracy: 34.83%
# Target Domain Accuracy: 92.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5784, Domain Loss: 0.3865
# Source Label Accuracy: 80.13%
# Target Label Accuracy: 76.36%
# Source Domain Accuracy: 34.82%
# Target Domain Accuracy: 90.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5512, Domain Loss: 0.3850
# Source Label Accuracy: 80.97%
# Target Label Accuracy: 75.45%
# Source Domain Accuracy: 32.58%
# Target Domain Accuracy: 94.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.6068, Domain Loss: 0.4381
# Source Label Accuracy: 80.08%
# Target Label Accuracy: 77.27%
# Source Domain Accuracy: 37.62%
# Target Domain Accuracy: 90.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4642, Domain Loss: 0.4612
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 77.09%
# Source Domain Accuracy: 31.98%
# Target Domain Accuracy: 92.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4798, Domain Loss: 0.4223
# Source Label Accuracy: 83.57%
# Target Label Accuracy: 74.73%
# Source Domain Accuracy: 30.28%
# Target Domain Accuracy: 94.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4822, Domain Loss: 0.4203
# Source Label Accuracy: 84.43%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 33.28%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4626, Domain Loss: 0.3995
# Source Label Accuracy: 85.14%
# Target Label Accuracy: 79.82%
# Source Domain Accuracy: 36.22%
# Target Domain Accuracy: 92.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5019, Domain Loss: 0.4031
# Source Label Accuracy: 85.24%
# Target Label Accuracy: 83.09%
# Source Domain Accuracy: 39.51%
# Target Domain Accuracy: 89.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3576, Domain Loss: 0.5426
# Source Label Accuracy: 86.14%
# Target Label Accuracy: 83.82%
# Source Domain Accuracy: 35.94%
# Target Domain Accuracy: 92.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3721, Domain Loss: 0.4301
# Source Label Accuracy: 86.44%
# Target Label Accuracy: 86.55%
# Source Domain Accuracy: 46.59%
# Target Domain Accuracy: 83.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3717, Domain Loss: 0.3791
# Source Label Accuracy: 86.76%
# Target Label Accuracy: 81.82%
# Source Domain Accuracy: 34.51%
# Target Domain Accuracy: 93.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3887, Domain Loss: 0.5021
# Source Label Accuracy: 88.61%
# Target Label Accuracy: 87.45%
# Source Domain Accuracy: 40.84%
# Target Domain Accuracy: 88.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3432, Domain Loss: 0.4312
# Source Label Accuracy: 89.34%
# Target Label Accuracy: 87.45%
# Source Domain Accuracy: 38.14%
# Target Domain Accuracy: 91.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4669, Domain Loss: 0.3369
# Source Label Accuracy: 89.60%
# Target Label Accuracy: 88.00%
# Source Domain Accuracy: 33.72%
# Target Domain Accuracy: 93.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4592, Domain Loss: 0.4627
# Source Label Accuracy: 90.61%
# Target Label Accuracy: 87.82%
# Source Domain Accuracy: 39.94%
# Target Domain Accuracy: 91.45%
#
# Lambda: 3
#
# Label Classifier Accuracy (Test Data)
# Source (White): 91.57861031059878
# Target (Black): 87.81818181818181
# Overall: 91.01551864960523
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.40762087736151
# Target (Black): 91.45454545454545
# Overall: 55.70378437244759
#
# False Positive Rate (Test Data)
# Source (White): 6.941907197661673
# Target (Black): 12.532637075718016
# (Black FPR) / (White FPR): 1.8053593513810637
# Overall: 7.628205128205129

# %%
l = 15
model = train_for_lambda(l)
write_results(l, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5827, Domain Loss: 0.4845
# Source Label Accuracy: 73.33%
# Target Label Accuracy: 69.45%
# Source Domain Accuracy: 32.11%
# Target Domain Accuracy: 93.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5977, Domain Loss: 0.4063
# Source Label Accuracy: 74.03%
# Target Label Accuracy: 71.64%
# Source Domain Accuracy: 29.76%
# Target Domain Accuracy: 94.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5201, Domain Loss: 0.3545
# Source Label Accuracy: 76.98%
# Target Label Accuracy: 74.36%
# Source Domain Accuracy: 34.38%
# Target Domain Accuracy: 94.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5432, Domain Loss: 0.4377
# Source Label Accuracy: 79.30%
# Target Label Accuracy: 71.27%
# Source Domain Accuracy: 32.41%
# Target Domain Accuracy: 92.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5489, Domain Loss: 0.4588
# Source Label Accuracy: 77.53%
# Target Label Accuracy: 76.00%
# Source Domain Accuracy: 38.23%
# Target Domain Accuracy: 92.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5059, Domain Loss: 0.3939
# Source Label Accuracy: 81.15%
# Target Label Accuracy: 76.36%
# Source Domain Accuracy: 38.31%
# Target Domain Accuracy: 91.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.6305, Domain Loss: 0.4141
# Source Label Accuracy: 78.74%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 34.01%
# Target Domain Accuracy: 92.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.3854, Domain Loss: 0.5385
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 38.64%
# Target Domain Accuracy: 89.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4626, Domain Loss: 0.4603
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 43.04%
# Target Domain Accuracy: 87.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4458, Domain Loss: 0.5343
# Source Label Accuracy: 82.62%
# Target Label Accuracy: 79.64%
# Source Domain Accuracy: 47.61%
# Target Domain Accuracy: 84.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4585, Domain Loss: 0.3631
# Source Label Accuracy: 82.93%
# Target Label Accuracy: 80.73%
# Source Domain Accuracy: 38.03%
# Target Domain Accuracy: 90.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4185, Domain Loss: 0.4999
# Source Label Accuracy: 83.42%
# Target Label Accuracy: 83.64%
# Source Domain Accuracy: 45.33%
# Target Domain Accuracy: 86.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5792, Domain Loss: 0.4345
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 82.18%
# Source Domain Accuracy: 36.94%
# Target Domain Accuracy: 90.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5215, Domain Loss: 0.4799
# Source Label Accuracy: 82.55%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 38.00%
# Target Domain Accuracy: 90.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5561, Domain Loss: 0.4848
# Source Label Accuracy: 82.98%
# Target Label Accuracy: 80.18%
# Source Domain Accuracy: 46.10%
# Target Domain Accuracy: 85.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4373, Domain Loss: 0.4121
# Source Label Accuracy: 84.26%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 41.50%
# Target Domain Accuracy: 90.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4463, Domain Loss: 0.4315
# Source Label Accuracy: 85.71%
# Target Label Accuracy: 83.45%
# Source Domain Accuracy: 43.93%
# Target Domain Accuracy: 87.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4300, Domain Loss: 0.5081
# Source Label Accuracy: 86.31%
# Target Label Accuracy: 83.45%
# Source Domain Accuracy: 57.50%
# Target Domain Accuracy: 73.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4916, Domain Loss: 0.3648
# Source Label Accuracy: 84.16%
# Target Label Accuracy: 81.09%
# Source Domain Accuracy: 34.46%
# Target Domain Accuracy: 92.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4024, Domain Loss: 0.4253
# Source Label Accuracy: 86.24%
# Target Label Accuracy: 82.73%
# Source Domain Accuracy: 46.94%
# Target Domain Accuracy: 84.18%
#
# Lambda: 15
#
# Label Classifier Accuracy (Test Data)
# Source (White): 90.26577009285943
# Target (Black): 82.72727272727273
# Overall: 89.13694527634087
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.92507204610951
# Target (Black): 84.18181818181819
# Overall: 61.856792812414916
#
# False Positive Rate (Test Data)
# Source (White): 6.7957617829740595
# Target (Black): 19.321148825065276
# (Black FPR) / (White FPR): 2.8431174373227774
# Overall: 8.333333333333334
