# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init
import pandas as pd
import sklearn.preprocessing as preprocessing

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
# Can adjust NN Sizes
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(86, 64),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(64, 32),
    nn.Sigmoid(),
    nn.Linear(32, 32),
    nn.Sigmoid(),
    nn.Linear(32, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(64, 36),
    nn.ReLU(),
    nn.Linear(36, 36), nn.ReLU(),              
    nn.Linear(36, 2),
    nn.ReLU()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 64) # must be same dimension as output size from init()
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %%
# Adult data code
# Change these to local file if available
train_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
test_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'

features = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"] 


# This will download 3.8M
original_train = pd.read_csv(train_url, names=features, sep=r'\s*,\s*', 
                             engine='python', na_values="?")
# This will download 1.9M
original_test = pd.read_csv(test_url, names=features, sep=r'\s*,\s*', 
                            engine='python', na_values="?", skiprows=1)



num_train = len(original_train)
original = pd.concat([original_train, original_test])
roc_original = original
labels = original['Target']
labels = labels.replace('<=50K', 0).replace('>50K', 1)
labels = labels.replace('<=50K.', 0).replace('>50K.', 1)


# Preprocess
# Redundant column
del original["Education"]
# Remove target variable
del original["Target"]


def data_transform(df):
    """Normalize features."""
    binary_data = pd.get_dummies(df)
    feature_cols = binary_data[binary_data.columns[:-2]]
    scaler = preprocessing.StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(feature_cols), columns=feature_cols.columns)
    return data

data = data_transform(original)

# %%
# Adult code, seperate sensitive and non sensitive
# get array of sensitive characteristics
sensitive = (original['Age'] > 37)
y = np.array(labels).flatten()
print(data.columns)
data = data.drop(['Age'], axis=1) # Drop sensitive info from data
data_np = np.array(data)
# Out:
# Index(['Age', 'fnlwgt', 'Education-Num', 'Capital Gain', 'Capital Loss',
#        'Hours per week', 'Workclass_Federal-gov', 'Workclass_Local-gov',
#        'Workclass_Never-worked', 'Workclass_Private', 'Workclass_Self-emp-inc',
#        'Workclass_Self-emp-not-inc', 'Workclass_State-gov',
#        'Workclass_Without-pay', 'Martial Status_Divorced',
#        'Martial Status_Married-AF-spouse', 'Martial Status_Married-civ-spouse',
#        'Martial Status_Married-spouse-absent', 'Martial Status_Never-married',
#        'Martial Status_Separated', 'Martial Status_Widowed',
#        'Occupation_Adm-clerical', 'Occupation_Armed-Forces',
#        'Occupation_Craft-repair', 'Occupation_Exec-managerial',
#        'Occupation_Farming-fishing', 'Occupation_Handlers-cleaners',
#        'Occupation_Machine-op-inspct', 'Occupation_Other-service',
#        'Occupation_Priv-house-serv', 'Occupation_Prof-specialty',
#        'Occupation_Protective-serv', 'Occupation_Sales',
#        'Occupation_Tech-support', 'Occupation_Transport-moving',
#        'Relationship_Husband', 'Relationship_Not-in-family',
#        'Relationship_Other-relative', 'Relationship_Own-child',
#        'Relationship_Unmarried', 'Relationship_Wife',
#        'Race_Amer-Indian-Eskimo', 'Race_Asian-Pac-Islander', 'Race_Black',
#        'Race_Other', 'Race_White', 'Sex_Female', 'Sex_Male',
#        'Country_Cambodia', 'Country_Canada', 'Country_China',
#        'Country_Columbia', 'Country_Cuba', 'Country_Dominican-Republic',
#        'Country_Ecuador', 'Country_El-Salvador', 'Country_England',
#        'Country_France', 'Country_Germany', 'Country_Greece',
#        'Country_Guatemala', 'Country_Haiti', 'Country_Holand-Netherlands',
#        'Country_Honduras', 'Country_Hong', 'Country_Hungary', 'Country_India',
#        'Country_Iran', 'Country_Ireland', 'Country_Italy', 'Country_Jamaica',
#        'Country_Japan', 'Country_Laos', 'Country_Mexico', 'Country_Nicaragua',
#        'Country_Outlying-US(Guam-USVI-etc)', 'Country_Peru',
#        'Country_Philippines', 'Country_Poland', 'Country_Portugal',
#        'Country_Puerto-Rico', 'Country_Scotland', 'Country_South',
#        'Country_Taiwan', 'Country_Thailand', 'Country_Trinadad&Tobago',
#        'Country_United-States'],
#       dtype='object')

# %%
# split to source (non-sensitive) and target (sensitive)
sensitive_idx = np.array(np.where(sensitive==1))[0].flatten()
nonsensitive_idx = np.array(np.where(sensitive!=1))[0].flatten()
data_sensitive = data_np[sensitive_idx,:]
data_nonsensitive = data_np[nonsensitive_idx,:]
y_sensitive = y[sensitive_idx]
y_nonsensitive = y[nonsensitive_idx]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

X_tensor_source =  torch.from_numpy(data_nonsensitive).type(torch.float32)
X_tensor_target =  torch.from_numpy(data_sensitive).type(torch.float32)
y_tensor_source =torch.tensor(y_nonsensitive).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_sensitive).type(torch.LongTensor)


# Split the source (race) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (loan sched) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train)
num_positives = sum(target_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size, sampler=sampler)
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size, sampler = sampler)
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

print(X_train_source.shape)
print(X_train_target.shape)
# Out:
# positive weight (under represented): 0.00014903129657228018
# negative weight (over represented): 8.074935400516796e-05
# positive weight (under represented): 0.00037650602409638556
# negative weight (over represented): 5.7726721699474687e-05
# torch.Size([19979, 86])
# torch.Size([19094, 86])

# %%
combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)

y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size)



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples))
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size)
# Out:
# 19094
# tensor([0, 0, 0,  ..., 1, 1, 1])
# [19979 19094]
# [5.00525552e-05 5.23724730e-05]
# 9366
# 29707
# [3.36620998e-05 1.06769165e-04]

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.00001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 20
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_age_unweighted'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        source_label_positive_rate = (sum(source_label_predictions)/len(source_label_predictions)).item()

        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        target_label_positive_rate = (sum(target_label_predictions)/len(target_label_predictions)).item()
        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_label_positive_rate = ((sum(source_label_predictions) + sum(target_label_predictions))/(len(target_label_predictions)+len(source_label_predictions))).item()

        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall,  'source_label_positive_rate': source_label_positive_rate, 'target_label_positive_rate': target_label_positive_rate,
                   'overall_label_positive_rate': overall_label_positive_rate}
        return results

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)

lams = [2, 3, 5, 10, 15, 100]
for lam in lams:
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7042, Domain Loss: 0.6782
# Source Label Accuracy: 56.50%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 37.80%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5555, Domain Loss: 0.6372
# Source Label Accuracy: 78.43%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 32.64%
# Target Domain Accuracy: 92.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5024, Domain Loss: 0.5907
# Source Label Accuracy: 80.45%
# Target Label Accuracy: 78.23%
# Source Domain Accuracy: 30.49%
# Target Domain Accuracy: 93.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5234, Domain Loss: 0.5694
# Source Label Accuracy: 81.43%
# Target Label Accuracy: 78.68%
# Source Domain Accuracy: 29.10%
# Target Domain Accuracy: 94.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5995, Domain Loss: 0.5576
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 28.28%
# Target Domain Accuracy: 94.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5065, Domain Loss: 0.5501
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 28.31%
# Target Domain Accuracy: 94.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4739, Domain Loss: 0.5440
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 26.88%
# Target Domain Accuracy: 95.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5004, Domain Loss: 0.5390
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 26.56%
# Target Domain Accuracy: 95.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5262, Domain Loss: 0.5341
# Source Label Accuracy: 82.18%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 25.81%
# Target Domain Accuracy: 95.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5340, Domain Loss: 0.5293
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 25.79%
# Target Domain Accuracy: 95.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4597, Domain Loss: 0.5249
# Source Label Accuracy: 82.23%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 24.88%
# Target Domain Accuracy: 95.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5531, Domain Loss: 0.5218
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 24.39%
# Target Domain Accuracy: 95.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5474, Domain Loss: 0.5183
# Source Label Accuracy: 82.31%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 24.21%
# Target Domain Accuracy: 95.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4953, Domain Loss: 0.5153
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 24.33%
# Target Domain Accuracy: 94.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5656, Domain Loss: 0.5123
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 24.11%
# Target Domain Accuracy: 94.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5035, Domain Loss: 0.5098
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 23.95%
# Target Domain Accuracy: 94.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4402, Domain Loss: 0.5074
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 78.93%
# Source Domain Accuracy: 23.93%
# Target Domain Accuracy: 94.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5217, Domain Loss: 0.5056
# Source Label Accuracy: 82.45%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 24.11%
# Target Domain Accuracy: 94.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5349, Domain Loss: 0.5041
# Source Label Accuracy: 82.27%
# Target Label Accuracy: 78.98%
# Source Domain Accuracy: 23.87%
# Target Domain Accuracy: 94.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.6339, Domain Loss: 0.5028
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 24.11%
# Target Domain Accuracy: 93.77%
#
# Lambda: 0.0
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.83429369652524
# Target (Black): 79.00074202325006
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 34.01431814213375
# Target (Black): 93.76700469948058
# Overall: 58.7410440122825
#
# False Positive Rate (Test Data)
# Source (White): 10.390968011708132
# Target (Black): 17.03422053231939
# (Black FPR) / (White FPR): 1.6393295132008785
# Overall: 12.747875354107649
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6802, Domain Loss: 0.6292
# Source Label Accuracy: 56.29%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 37.03%
# Target Domain Accuracy: 83.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6398, Domain Loss: 0.5921
# Source Label Accuracy: 75.65%
# Target Label Accuracy: 77.34%
# Source Domain Accuracy: 38.73%
# Target Domain Accuracy: 77.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5318, Domain Loss: 0.5649
# Source Label Accuracy: 80.96%
# Target Label Accuracy: 78.09%
# Source Domain Accuracy: 38.42%
# Target Domain Accuracy: 77.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5835, Domain Loss: 0.5611
# Source Label Accuracy: 81.54%
# Target Label Accuracy: 78.41%
# Source Domain Accuracy: 37.74%
# Target Domain Accuracy: 77.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4945, Domain Loss: 0.5617
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 78.95%
# Source Domain Accuracy: 38.15%
# Target Domain Accuracy: 77.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5411, Domain Loss: 0.5550
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 37.84%
# Target Domain Accuracy: 78.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5373, Domain Loss: 0.5443
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 37.77%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5197, Domain Loss: 0.5467
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 36.88%
# Target Domain Accuracy: 79.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5183, Domain Loss: 0.5473
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 36.69%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4348, Domain Loss: 0.5420
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 36.36%
# Target Domain Accuracy: 81.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4904, Domain Loss: 0.5395
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 35.44%
# Target Domain Accuracy: 82.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5497, Domain Loss: 0.5289
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 35.35%
# Target Domain Accuracy: 83.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5113, Domain Loss: 0.5205
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 35.00%
# Target Domain Accuracy: 83.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5732, Domain Loss: 0.5280
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 34.16%
# Target Domain Accuracy: 83.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.6237, Domain Loss: 0.5207
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 33.84%
# Target Domain Accuracy: 84.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4552, Domain Loss: 0.5239
# Source Label Accuracy: 82.60%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 33.26%
# Target Domain Accuracy: 84.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4992, Domain Loss: 0.5124
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 33.10%
# Target Domain Accuracy: 84.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4646, Domain Loss: 0.5055
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 78.95%
# Source Domain Accuracy: 32.67%
# Target Domain Accuracy: 84.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5507, Domain Loss: 0.5082
# Source Label Accuracy: 82.23%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 32.20%
# Target Domain Accuracy: 85.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5035, Domain Loss: 0.5042
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 79.07%
# Source Domain Accuracy: 31.45%
# Target Domain Accuracy: 85.85%
#
# Lambda: 0.1
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.07494434825624
# Overall: 83.54145342886387
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 44.12432338047844
# Target (Black): 85.85209003215434
# Overall: 61.39201637666326
#
# False Positive Rate (Test Data)
# Source (White): 10.558227054150114
# Target (Black): 16.99619771863118
# (Black FPR) / (White FPR): 1.6097586868953058
# Overall: 12.842304060434373
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6889, Domain Loss: 0.6106
# Source Label Accuracy: 56.87%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 33.95%
# Target Domain Accuracy: 92.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6263, Domain Loss: 0.5753
# Source Label Accuracy: 78.08%
# Target Label Accuracy: 77.29%
# Source Domain Accuracy: 32.03%
# Target Domain Accuracy: 93.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4838, Domain Loss: 0.5472
# Source Label Accuracy: 80.51%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 29.20%
# Target Domain Accuracy: 93.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5094, Domain Loss: 0.5260
# Source Label Accuracy: 80.61%
# Target Label Accuracy: 78.58%
# Source Domain Accuracy: 26.71%
# Target Domain Accuracy: 94.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5196, Domain Loss: 0.5089
# Source Label Accuracy: 81.39%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 24.19%
# Target Domain Accuracy: 95.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5259, Domain Loss: 0.5030
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 22.35%
# Target Domain Accuracy: 95.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5066, Domain Loss: 0.4858
# Source Label Accuracy: 81.41%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 22.36%
# Target Domain Accuracy: 95.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4936, Domain Loss: 0.4921
# Source Label Accuracy: 81.23%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 23.03%
# Target Domain Accuracy: 94.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5718, Domain Loss: 0.5015
# Source Label Accuracy: 81.50%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 25.14%
# Target Domain Accuracy: 92.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5170, Domain Loss: 0.5019
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 26.91%
# Target Domain Accuracy: 90.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5240, Domain Loss: 0.5146
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 28.87%
# Target Domain Accuracy: 89.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4697, Domain Loss: 0.4988
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 29.72%
# Target Domain Accuracy: 87.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5508, Domain Loss: 0.4891
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 79.40%
# Source Domain Accuracy: 31.14%
# Target Domain Accuracy: 85.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5335, Domain Loss: 0.4951
# Source Label Accuracy: 82.32%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 31.85%
# Target Domain Accuracy: 84.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5002, Domain Loss: 0.5052
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.47%
# Source Domain Accuracy: 31.95%
# Target Domain Accuracy: 82.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5473, Domain Loss: 0.5037
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 32.55%
# Target Domain Accuracy: 82.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5098, Domain Loss: 0.5009
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 32.50%
# Target Domain Accuracy: 82.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5557, Domain Loss: 0.5066
# Source Label Accuracy: 82.22%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 32.68%
# Target Domain Accuracy: 81.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5312, Domain Loss: 0.5090
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 33.11%
# Target Domain Accuracy: 80.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4792, Domain Loss: 0.5056
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 32.77%
# Target Domain Accuracy: 80.58%
#
# Lambda: 0.2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.09621093067923
# Target (Black): 79.22334899826862
# Overall: 83.83828045035824
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 46.324428147372096
# Target (Black): 80.58372495671532
# Overall: 60.501535312180145
#
# False Positive Rate (Test Data)
# Source (White): 9.972820405603178
# Target (Black): 16.425855513307983
# (Black FPR) / (White FPR): 1.647062199583901
# Overall: 12.2622420072845
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7282, Domain Loss: 0.6620
# Source Label Accuracy: 56.98%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 35.61%
# Target Domain Accuracy: 91.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6009, Domain Loss: 0.6141
# Source Label Accuracy: 78.09%
# Target Label Accuracy: 77.94%
# Source Domain Accuracy: 31.49%
# Target Domain Accuracy: 94.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5735, Domain Loss: 0.5581
# Source Label Accuracy: 80.88%
# Target Label Accuracy: 78.21%
# Source Domain Accuracy: 27.74%
# Target Domain Accuracy: 95.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5138, Domain Loss: 0.5425
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 24.57%
# Target Domain Accuracy: 94.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4953, Domain Loss: 0.5283
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 26.39%
# Target Domain Accuracy: 90.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5511, Domain Loss: 0.5280
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 31.49%
# Target Domain Accuracy: 84.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4857, Domain Loss: 0.5207
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 36.56%
# Target Domain Accuracy: 76.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5888, Domain Loss: 0.5088
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 38.24%
# Target Domain Accuracy: 73.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5144, Domain Loss: 0.5400
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.11%
# Target Domain Accuracy: 71.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5570, Domain Loss: 0.5132
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.55%
# Target Domain Accuracy: 70.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5451, Domain Loss: 0.5378
# Source Label Accuracy: 82.44%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.16%
# Target Domain Accuracy: 70.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5209, Domain Loss: 0.5250
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 40.19%
# Target Domain Accuracy: 70.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5379, Domain Loss: 0.5299
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.81%
# Target Domain Accuracy: 70.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5119, Domain Loss: 0.5308
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.67%
# Target Domain Accuracy: 70.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4821, Domain Loss: 0.5315
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.39%
# Target Domain Accuracy: 70.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5414, Domain Loss: 0.5217
# Source Label Accuracy: 82.24%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.81%
# Target Domain Accuracy: 70.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5256, Domain Loss: 0.5297
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.79%
# Target Domain Accuracy: 70.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4096, Domain Loss: 0.5214
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.10%
# Target Domain Accuracy: 70.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5986, Domain Loss: 0.5342
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 38.84%
# Target Domain Accuracy: 71.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4462, Domain Loss: 0.5310
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 38.82%
# Target Domain Accuracy: 71.23%
#
# Lambda: 0.30000000000000004
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.02636633490484
# Target (Black): 79.19861488993322
# Overall: 83.78710337768679
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 54.408940108259124
# Target (Black): 71.23423200593619
# Overall: 61.37154554759468
#
# False Positive Rate (Test Data)
# Source (White): 10.056449926824168
# Target (Black): 16.539923954372625
# (Black FPR) / (White FPR): 1.6447080306395898
# Overall: 12.356670713611223
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6423, Domain Loss: 0.6027
# Source Label Accuracy: 56.89%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 33.61%
# Target Domain Accuracy: 90.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6307, Domain Loss: 0.5372
# Source Label Accuracy: 77.83%
# Target Label Accuracy: 77.62%
# Source Domain Accuracy: 25.41%
# Target Domain Accuracy: 94.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5789, Domain Loss: 0.5225
# Source Label Accuracy: 80.48%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 21.49%
# Target Domain Accuracy: 94.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4320, Domain Loss: 0.5147
# Source Label Accuracy: 80.83%
# Target Label Accuracy: 78.58%
# Source Domain Accuracy: 27.08%
# Target Domain Accuracy: 87.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4718, Domain Loss: 0.5484
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 37.31%
# Target Domain Accuracy: 73.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5168, Domain Loss: 0.5376
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.79%
# Target Domain Accuracy: 69.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4806, Domain Loss: 0.5534
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 41.22%
# Target Domain Accuracy: 69.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5021, Domain Loss: 0.5555
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 41.00%
# Target Domain Accuracy: 69.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5435, Domain Loss: 0.5392
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 40.68%
# Target Domain Accuracy: 69.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4470, Domain Loss: 0.5416
# Source Label Accuracy: 82.27%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 40.24%
# Target Domain Accuracy: 69.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4420, Domain Loss: 0.5423
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 40.26%
# Target Domain Accuracy: 69.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4952, Domain Loss: 0.5391
# Source Label Accuracy: 82.25%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.61%
# Target Domain Accuracy: 69.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5093, Domain Loss: 0.5468
# Source Label Accuracy: 82.40%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.44%
# Target Domain Accuracy: 69.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4801, Domain Loss: 0.5419
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.88%
# Target Domain Accuracy: 69.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.6106, Domain Loss: 0.5487
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.64%
# Target Domain Accuracy: 69.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4899, Domain Loss: 0.5625
# Source Label Accuracy: 82.30%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 40.14%
# Target Domain Accuracy: 69.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4829, Domain Loss: 0.5572
# Source Label Accuracy: 82.42%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.83%
# Target Domain Accuracy: 69.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5127, Domain Loss: 0.5352
# Source Label Accuracy: 82.44%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 39.79%
# Target Domain Accuracy: 69.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5438, Domain Loss: 0.5380
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.63%
# Target Domain Accuracy: 69.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5423, Domain Loss: 0.5273
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 78.98%
# Source Domain Accuracy: 39.28%
# Target Domain Accuracy: 69.90%
#
# Lambda: 0.4
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.72952680286363
# Target (Black): 78.97600791491466
# Overall: 83.52098259979529
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.229614108608345
# Target (Black): 69.89859015582488
# Overall: 61.29989764585466
#
# False Positive Rate (Test Data)
# Source (White): 10.453690152623876
# Target (Black): 16.958174904942965
# (Black FPR) / (White FPR): 1.622219011406844
# Overall: 12.76136516929718
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7968, Domain Loss: 0.5375
# Source Label Accuracy: 56.51%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 30.29%
# Target Domain Accuracy: 93.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6083, Domain Loss: 0.5362
# Source Label Accuracy: 76.10%
# Target Label Accuracy: 77.20%
# Source Domain Accuracy: 23.62%
# Target Domain Accuracy: 94.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5923, Domain Loss: 0.5019
# Source Label Accuracy: 80.00%
# Target Label Accuracy: 78.48%
# Source Domain Accuracy: 24.09%
# Target Domain Accuracy: 91.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5534, Domain Loss: 0.5119
# Source Label Accuracy: 80.73%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 31.95%
# Target Domain Accuracy: 81.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5544, Domain Loss: 0.5101
# Source Label Accuracy: 81.41%
# Target Label Accuracy: 78.95%
# Source Domain Accuracy: 38.31%
# Target Domain Accuracy: 71.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4956, Domain Loss: 0.4963
# Source Label Accuracy: 81.54%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 39.78%
# Target Domain Accuracy: 69.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4745, Domain Loss: 0.5636
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.13%
# Target Domain Accuracy: 69.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5575, Domain Loss: 0.5378
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 40.21%
# Target Domain Accuracy: 69.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4933, Domain Loss: 0.5295
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.24%
# Target Domain Accuracy: 69.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5104, Domain Loss: 0.5401
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 39.62%
# Target Domain Accuracy: 69.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5645, Domain Loss: 0.5453
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 69.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4903, Domain Loss: 0.5720
# Source Label Accuracy: 81.60%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 39.67%
# Target Domain Accuracy: 69.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4840, Domain Loss: 0.5560
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.44%
# Target Domain Accuracy: 69.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4710, Domain Loss: 0.5513
# Source Label Accuracy: 82.54%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.98%
# Target Domain Accuracy: 69.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5737, Domain Loss: 0.5443
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 39.63%
# Target Domain Accuracy: 69.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5828, Domain Loss: 0.5442
# Source Label Accuracy: 81.50%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.16%
# Target Domain Accuracy: 69.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5319, Domain Loss: 0.5586
# Source Label Accuracy: 82.49%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 40.03%
# Target Domain Accuracy: 69.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4515, Domain Loss: 0.5527
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.30%
# Target Domain Accuracy: 69.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5989, Domain Loss: 0.5611
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.86%
# Target Domain Accuracy: 69.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5433, Domain Loss: 0.5562
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 39.64%
# Target Domain Accuracy: 69.33%
#
# Lambda: 0.5
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.83429369652524
# Target (Black): 79.14914667326242
# Overall: 83.65404298874104
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.73598742797276
# Target (Black): 69.3297056641108
# Overall: 61.361310133060385
#
# False Positive Rate (Test Data)
# Source (White): 10.286431110181894
# Target (Black): 16.577946768060837
# (Black FPR) / (White FPR): 1.6116325079600606
# Overall: 12.518548495885607
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6904, Domain Loss: 0.5652
# Source Label Accuracy: 56.72%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 34.65%
# Target Domain Accuracy: 88.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5921, Domain Loss: 0.5249
# Source Label Accuracy: 73.46%
# Target Label Accuracy: 76.97%
# Source Domain Accuracy: 30.23%
# Target Domain Accuracy: 91.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6095, Domain Loss: 0.5184
# Source Label Accuracy: 80.27%
# Target Label Accuracy: 78.41%
# Source Domain Accuracy: 28.67%
# Target Domain Accuracy: 90.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5092, Domain Loss: 0.5324
# Source Label Accuracy: 80.78%
# Target Label Accuracy: 78.56%
# Source Domain Accuracy: 30.95%
# Target Domain Accuracy: 83.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4276, Domain Loss: 0.5089
# Source Label Accuracy: 81.11%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 35.32%
# Target Domain Accuracy: 74.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4864, Domain Loss: 0.5232
# Source Label Accuracy: 81.49%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 39.12%
# Target Domain Accuracy: 70.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5323, Domain Loss: 0.5517
# Source Label Accuracy: 81.28%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.64%
# Target Domain Accuracy: 69.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5835, Domain Loss: 0.5604
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.95%
# Target Domain Accuracy: 68.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5001, Domain Loss: 0.5516
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 40.46%
# Target Domain Accuracy: 68.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4939, Domain Loss: 0.5464
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.39%
# Target Domain Accuracy: 68.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5114, Domain Loss: 0.5582
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 40.77%
# Target Domain Accuracy: 68.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5679, Domain Loss: 0.5403
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 39.78%
# Target Domain Accuracy: 68.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5160, Domain Loss: 0.5274
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.18%
# Target Domain Accuracy: 68.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5839, Domain Loss: 0.5870
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.71%
# Target Domain Accuracy: 68.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5661, Domain Loss: 0.5809
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.37%
# Target Domain Accuracy: 68.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5609, Domain Loss: 0.5690
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.71%
# Target Domain Accuracy: 68.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4595, Domain Loss: 0.5416
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.31%
# Target Domain Accuracy: 68.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4985, Domain Loss: 0.5789
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.53%
# Target Domain Accuracy: 68.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5401, Domain Loss: 0.5502
# Source Label Accuracy: 82.49%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.68%
# Target Domain Accuracy: 68.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5455, Domain Loss: 0.5615
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 40.17%
# Target Domain Accuracy: 67.85%
#
# Lambda: 0.6000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.88667714335604
# Target (Black): 79.12441256492703
# Overall: 83.67451381780963
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.92334555613759
# Target (Black): 67.84565916398714
# Overall: 61.4431934493347
#
# False Positive Rate (Test Data)
# Source (White): 10.181894208655656
# Target (Black): 16.577946768060837
# (Black FPR) / (White FPR): 1.6281790429493836
# Overall: 12.451099419937947
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7226, Domain Loss: 0.5215
# Source Label Accuracy: 56.55%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 29.80%
# Target Domain Accuracy: 93.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5625, Domain Loss: 0.5140
# Source Label Accuracy: 76.46%
# Target Label Accuracy: 77.32%
# Source Domain Accuracy: 24.97%
# Target Domain Accuracy: 94.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5849, Domain Loss: 0.4864
# Source Label Accuracy: 80.58%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 18.50%
# Target Domain Accuracy: 94.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5946, Domain Loss: 0.4832
# Source Label Accuracy: 81.22%
# Target Label Accuracy: 78.46%
# Source Domain Accuracy: 19.88%
# Target Domain Accuracy: 89.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5222, Domain Loss: 0.4963
# Source Label Accuracy: 81.38%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 31.34%
# Target Domain Accuracy: 80.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5633, Domain Loss: 0.5519
# Source Label Accuracy: 81.67%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 38.97%
# Target Domain Accuracy: 70.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5399, Domain Loss: 0.5552
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.55%
# Target Domain Accuracy: 69.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5321, Domain Loss: 0.5787
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.93%
# Target Domain Accuracy: 68.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5375, Domain Loss: 0.5721
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 40.27%
# Target Domain Accuracy: 68.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5103, Domain Loss: 0.5710
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 40.07%
# Target Domain Accuracy: 68.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4984, Domain Loss: 0.5590
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 39.67%
# Target Domain Accuracy: 69.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4934, Domain Loss: 0.5554
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.79%
# Target Domain Accuracy: 69.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6030, Domain Loss: 0.5548
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 39.48%
# Target Domain Accuracy: 69.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4552, Domain Loss: 0.5594
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 39.59%
# Target Domain Accuracy: 69.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3938, Domain Loss: 0.5993
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.07%
# Target Domain Accuracy: 69.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4962, Domain Loss: 0.5855
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.72%
# Target Domain Accuracy: 69.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5348, Domain Loss: 0.5759
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.68%
# Target Domain Accuracy: 69.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5237, Domain Loss: 0.5796
# Source Label Accuracy: 82.38%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.42%
# Target Domain Accuracy: 68.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5275, Domain Loss: 0.5452
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.59%
# Target Domain Accuracy: 68.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.6240, Domain Loss: 0.5893
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 39.96%
# Target Domain Accuracy: 68.71%
#
# Lambda: 0.7000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.81683254758163
# Target (Black): 79.3222854316102
# Overall: 83.71545547594678
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.962982364239565
# Target (Black): 68.71135295572594
# Overall: 61.23848515864893
#
# False Positive Rate (Test Data)
# Source (White): 10.244616349571398
# Target (Black): 16.34980988593156
# (Black FPR) / (White FPR): 1.5959416466206255
# Overall: 12.410629974369352
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7419, Domain Loss: 0.5301
# Source Label Accuracy: 56.72%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 35.52%
# Target Domain Accuracy: 85.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6133, Domain Loss: 0.5138
# Source Label Accuracy: 76.13%
# Target Label Accuracy: 77.24%
# Source Domain Accuracy: 32.56%
# Target Domain Accuracy: 86.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5710, Domain Loss: 0.5418
# Source Label Accuracy: 80.63%
# Target Label Accuracy: 78.31%
# Source Domain Accuracy: 33.42%
# Target Domain Accuracy: 83.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5543, Domain Loss: 0.4932
# Source Label Accuracy: 80.98%
# Target Label Accuracy: 78.41%
# Source Domain Accuracy: 37.37%
# Target Domain Accuracy: 74.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5566, Domain Loss: 0.5479
# Source Label Accuracy: 81.22%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.66%
# Target Domain Accuracy: 69.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5331, Domain Loss: 0.5575
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 41.28%
# Target Domain Accuracy: 68.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5108, Domain Loss: 0.5605
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.93%
# Target Domain Accuracy: 67.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5674, Domain Loss: 0.5252
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.97%
# Target Domain Accuracy: 67.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4720, Domain Loss: 0.5892
# Source Label Accuracy: 82.24%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 41.17%
# Target Domain Accuracy: 67.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5753, Domain Loss: 0.5860
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.38%
# Target Domain Accuracy: 67.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4606, Domain Loss: 0.5672
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 40.67%
# Target Domain Accuracy: 67.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5464, Domain Loss: 0.5727
# Source Label Accuracy: 82.43%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.81%
# Target Domain Accuracy: 67.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4873, Domain Loss: 0.5309
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 40.57%
# Target Domain Accuracy: 67.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5426, Domain Loss: 0.5374
# Source Label Accuracy: 82.57%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 41.00%
# Target Domain Accuracy: 67.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4572, Domain Loss: 0.5658
# Source Label Accuracy: 82.19%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.62%
# Target Domain Accuracy: 67.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5151, Domain Loss: 0.5841
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 41.38%
# Target Domain Accuracy: 66.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5299, Domain Loss: 0.6067
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 41.49%
# Target Domain Accuracy: 66.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4566, Domain Loss: 0.5280
# Source Label Accuracy: 82.36%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 40.87%
# Target Domain Accuracy: 66.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4635, Domain Loss: 0.5608
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 41.33%
# Target Domain Accuracy: 65.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4868, Domain Loss: 0.5590
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 41.52%
# Target Domain Accuracy: 65.82%
#
# Lambda: 0.8
#
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.24808310660401
# Overall: 83.61310133060388
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.936092194866426
# Target (Black): 65.81746228048479
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5863110281338464
# Overall: 12.653446647780925
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7561, Domain Loss: 0.5511
# Source Label Accuracy: 56.89%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 34.46%
# Target Domain Accuracy: 91.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6123, Domain Loss: 0.4955
# Source Label Accuracy: 71.00%
# Target Label Accuracy: 76.03%
# Source Domain Accuracy: 28.10%
# Target Domain Accuracy: 93.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6861, Domain Loss: 0.4890
# Source Label Accuracy: 80.42%
# Target Label Accuracy: 78.21%
# Source Domain Accuracy: 26.89%
# Target Domain Accuracy: 93.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5876, Domain Loss: 0.4834
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 31.57%
# Target Domain Accuracy: 84.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6018, Domain Loss: 0.5309
# Source Label Accuracy: 81.49%
# Target Label Accuracy: 78.90%
# Source Domain Accuracy: 37.62%
# Target Domain Accuracy: 73.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5444, Domain Loss: 0.4917
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 40.04%
# Target Domain Accuracy: 70.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4466, Domain Loss: 0.5627
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.73%
# Target Domain Accuracy: 68.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4851, Domain Loss: 0.5256
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 40.98%
# Target Domain Accuracy: 68.14%
#
# label trained
# domain trained
# feature extractor trained
# ...
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4918, Domain Loss: 0.5676
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 38.75%
# Target Domain Accuracy: 66.53%
#
# Lambda: 5
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.16605552645365
# Target (Black): 79.27281721493941
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 54.32163436354112
# Target (Black): 66.53475142221123
# Overall: 59.37563971340839
#
# False Positive Rate (Test Data)
# Source (White): 9.868283504076938
# Target (Black): 15.893536121673003
# (Black FPR) / (White FPR): 1.6105674421602114
# Overall: 12.005935518683394
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7385, Domain Loss: 0.4717
# Source Label Accuracy: 57.10%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 29.53%
# Target Domain Accuracy: 91.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5025, Domain Loss: 0.3904
# Source Label Accuracy: 77.26%
# Target Label Accuracy: 77.37%
# Source Domain Accuracy: 24.53%
# Target Domain Accuracy: 95.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4668, Domain Loss: 0.4734
# Source Label Accuracy: 79.83%
# Target Label Accuracy: 78.16%
# Source Domain Accuracy: 22.82%
# Target Domain Accuracy: 94.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4968, Domain Loss: 0.3904
# Source Label Accuracy: 80.41%
# Target Label Accuracy: 78.65%
# Source Domain Accuracy: 22.61%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5067, Domain Loss: 0.4298
# Source Label Accuracy: 81.10%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 22.93%
# Target Domain Accuracy: 90.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5440, Domain Loss: 0.4989
# Source Label Accuracy: 81.11%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 24.57%
# Target Domain Accuracy: 88.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5219, Domain Loss: 0.5476
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 26.50%
# Target Domain Accuracy: 85.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4639, Domain Loss: 0.5738
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 27.97%
# Target Domain Accuracy: 82.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4570, Domain Loss: 0.4964
# Source Label Accuracy: 81.46%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 30.54%
# Target Domain Accuracy: 79.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5152, Domain Loss: 0.5975
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 32.93%
# Target Domain Accuracy: 76.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4840, Domain Loss: 0.5848
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 33.94%
# Target Domain Accuracy: 74.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4795, Domain Loss: 0.7259
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 34.81%
# Target Domain Accuracy: 73.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6020, Domain Loss: 0.6121
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 36.03%
# Target Domain Accuracy: 72.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.6130, Domain Loss: 0.6212
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 35.45%
# Target Domain Accuracy: 71.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4708, Domain Loss: 0.6148
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 36.44%
# Target Domain Accuracy: 71.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4954, Domain Loss: 0.5921
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 36.95%
# Target Domain Accuracy: 71.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5328, Domain Loss: 0.6522
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 36.65%
# Target Domain Accuracy: 70.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5739, Domain Loss: 0.5102
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 36.83%
# Target Domain Accuracy: 70.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4780, Domain Loss: 0.6042
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 37.16%
# Target Domain Accuracy: 70.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5161, Domain Loss: 0.6853
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 36.53%
# Target Domain Accuracy: 70.62%
#
# Lambda: 10
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.21843897328444
# Target (Black): 79.17388078159783
# Overall: 83.88945752302968
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 51.68500087305745
# Target (Black): 70.61587929755132
# Overall: 59.51893551688843
#
# False Positive Rate (Test Data)
# Source (White): 9.784653982855948
# Target (Black): 15.513307984790874
# (Black FPR) / (White FPR): 1.585473335283221
# Overall: 11.817078106029948
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7481, Domain Loss: 0.4754
# Source Label Accuracy: 56.90%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 31.47%
# Target Domain Accuracy: 87.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5807, Domain Loss: 0.4175
# Source Label Accuracy: 57.30%
# Target Label Accuracy: 65.92%
# Source Domain Accuracy: 28.09%
# Target Domain Accuracy: 91.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5663, Domain Loss: 0.5198
# Source Label Accuracy: 78.96%
# Target Label Accuracy: 78.11%
# Source Domain Accuracy: 27.17%
# Target Domain Accuracy: 91.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4850, Domain Loss: 0.4034
# Source Label Accuracy: 80.22%
# Target Label Accuracy: 78.56%
# Source Domain Accuracy: 26.61%
# Target Domain Accuracy: 90.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5312, Domain Loss: 0.4994
# Source Label Accuracy: 80.89%
# Target Label Accuracy: 78.85%
# Source Domain Accuracy: 27.34%
# Target Domain Accuracy: 88.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5050, Domain Loss: 0.4815
# Source Label Accuracy: 80.92%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 28.07%
# Target Domain Accuracy: 86.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5324, Domain Loss: 0.5219
# Source Label Accuracy: 81.43%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 28.33%
# Target Domain Accuracy: 85.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5194, Domain Loss: 0.4985
# Source Label Accuracy: 81.37%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 29.09%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5257, Domain Loss: 0.5936
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 30.02%
# Target Domain Accuracy: 83.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5444, Domain Loss: 0.4288
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 30.40%
# Target Domain Accuracy: 83.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.6381, Domain Loss: 0.6118
# Source Label Accuracy: 81.26%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 31.04%
# Target Domain Accuracy: 82.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4589, Domain Loss: 0.5485
# Source Label Accuracy: 81.51%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 31.73%
# Target Domain Accuracy: 81.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5119, Domain Loss: 0.6489
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 31.62%
# Target Domain Accuracy: 79.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4652, Domain Loss: 0.6193
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 31.80%
# Target Domain Accuracy: 78.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5410, Domain Loss: 0.6121
# Source Label Accuracy: 81.59%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 32.71%
# Target Domain Accuracy: 77.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.6100, Domain Loss: 0.5654
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 33.24%
# Target Domain Accuracy: 76.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5230, Domain Loss: 0.5472
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 33.18%
# Target Domain Accuracy: 75.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5034, Domain Loss: 0.7444
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 33.81%
# Target Domain Accuracy: 74.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4355, Domain Loss: 0.6291
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 34.46%
# Target Domain Accuracy: 73.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5589, Domain Loss: 0.6734
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 35.61%
# Target Domain Accuracy: 72.27%
#
# Lambda: 15
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.35812816483325
# Target (Black): 79.44595597328717
# Overall: 84.08393039918117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.921424829753796
# Target (Black): 72.27306455602276
# Overall: 59.17093142272262
#
# False Positive Rate (Test Data)
# Source (White): 9.429228517666736
# Target (Black): 15.095057034220533
# (Black FPR) / (White FPR): 1.6008793302589093
# Overall: 11.439363280723054
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7188, Domain Loss: 0.4921
# Source Label Accuracy: 56.93%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 30.49%
# Target Domain Accuracy: 93.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6155, Domain Loss: 0.3888
# Source Label Accuracy: 66.51%
# Target Label Accuracy: 74.23%
# Source Domain Accuracy: 26.26%
# Target Domain Accuracy: 94.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5679, Domain Loss: 0.3811
# Source Label Accuracy: 78.32%
# Target Label Accuracy: 77.86%
# Source Domain Accuracy: 23.94%
# Target Domain Accuracy: 95.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5730, Domain Loss: 0.3610
# Source Label Accuracy: 79.54%
# Target Label Accuracy: 78.41%
# Source Domain Accuracy: 21.63%
# Target Domain Accuracy: 95.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4884, Domain Loss: 0.3884
# Source Label Accuracy: 80.41%
# Target Label Accuracy: 78.60%
# Source Domain Accuracy: 20.53%
# Target Domain Accuracy: 94.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5246, Domain Loss: 0.3828
# Source Label Accuracy: 80.28%
# Target Label Accuracy: 78.88%
# Source Domain Accuracy: 19.74%
# Target Domain Accuracy: 94.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5246, Domain Loss: 0.4002
# Source Label Accuracy: 80.71%
# Target Label Accuracy: 78.93%
# Source Domain Accuracy: 19.80%
# Target Domain Accuracy: 94.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5518, Domain Loss: 0.4360
# Source Label Accuracy: 80.64%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 19.91%
# Target Domain Accuracy: 93.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5309, Domain Loss: 0.4932
# Source Label Accuracy: 80.86%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 20.08%
# Target Domain Accuracy: 92.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5415, Domain Loss: 0.4988
# Source Label Accuracy: 80.55%
# Target Label Accuracy: 79.52%
# Source Domain Accuracy: 20.90%
# Target Domain Accuracy: 89.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5444, Domain Loss: 0.4790
# Source Label Accuracy: 81.29%
# Target Label Accuracy: 79.62%
# Source Domain Accuracy: 23.17%
# Target Domain Accuracy: 85.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.6161, Domain Loss: 0.5420
# Source Label Accuracy: 81.02%
# Target Label Accuracy: 79.52%
# Source Domain Accuracy: 25.88%
# Target Domain Accuracy: 81.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4530, Domain Loss: 0.6409
# Source Label Accuracy: 81.57%
# Target Label Accuracy: 79.54%
# Source Domain Accuracy: 29.41%
# Target Domain Accuracy: 77.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5166, Domain Loss: 0.5738
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 79.50%
# Source Domain Accuracy: 30.61%
# Target Domain Accuracy: 75.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5540, Domain Loss: 0.6077
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 79.40%
# Source Domain Accuracy: 32.68%
# Target Domain Accuracy: 72.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5083, Domain Loss: 0.6140
# Source Label Accuracy: 81.34%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 34.33%
# Target Domain Accuracy: 70.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5358, Domain Loss: 0.5796
# Source Label Accuracy: 81.33%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 34.83%
# Target Domain Accuracy: 69.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5362, Domain Loss: 0.5682
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 36.56%
# Target Domain Accuracy: 68.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5721, Domain Loss: 0.5346
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 36.98%
# Target Domain Accuracy: 66.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5902, Domain Loss: 0.5348
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 36.42%
# Target Domain Accuracy: 67.08%
#
# Lambda: 100
#
# Label Classifier Accuracy (Test Data)
# Source (White): 87.13113322856644
# Target (Black): 79.37175364828099
# Overall: 83.92016376663256
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 51.89453466038065
# Target (Black): 67.07890180558991
# Overall: 58.17809621289662
#
# False Positive Rate (Test Data)
# Source (White): 9.554672799498222
# Target (Black): 14.904942965779467
# (Black FPR) / (White FPR): 1.5599637244053215
# Overall: 11.452853095912586

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results_conf_age_37_unweighted'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(5):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        model_file_name = 'model_results/adult_age_37_unweight_'+str(lam)+'_'+str(i)+'.pt'
        torch.save(model.state_dict(), model_file_name)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'

        my_str += 'Source Label Positive Rate: ' + str(results['source_label_positive_rate']) + '\n'
        my_str += 'Target Label Positive Rate: ' + str(results['target_label_positive_rate']) + '\n'
        my_str += 'Overall Label Positive Rate: ' + str(results['overall_label_positive_rate']) + '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7398, Domain Loss: 0.4746
# Source Label Accuracy: 56.82%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 14.92%
# Target Domain Accuracy: 98.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6555, Domain Loss: 0.4054
# Source Label Accuracy: 57.57%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 12.11%
# Target Domain Accuracy: 99.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6591, Domain Loss: 0.3675
# Source Label Accuracy: 77.97%
# Target Label Accuracy: 77.82%
# Source Domain Accuracy: 11.30%
# Target Domain Accuracy: 99.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5861, Domain Loss: 0.3689
# Source Label Accuracy: 80.36%
# Target Label Accuracy: 78.09%
# Source Domain Accuracy: 10.01%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5577, Domain Loss: 0.3946
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 78.22%
# Source Domain Accuracy: 8.18%
# Target Domain Accuracy: 99.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5715, Domain Loss: 0.4054
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 78.30%
# Source Domain Accuracy: 7.61%
# Target Domain Accuracy: 99.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4536, Domain Loss: 0.3931
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 7.32%
# Target Domain Accuracy: 99.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5092, Domain Loss: 0.4142
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 6.29%
# Target Domain Accuracy: 99.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4426, Domain Loss: 0.4158
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 6.35%
# Target Domain Accuracy: 99.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4747, Domain Loss: 0.3940
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 5.92%
# Target Domain Accuracy: 99.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5146, Domain Loss: 0.3570
# Source Label Accuracy: 82.53%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 6.69%
# Target Domain Accuracy: 99.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5531, Domain Loss: 0.3589
# Source Label Accuracy: 82.22%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 6.86%
# Target Domain Accuracy: 99.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4836, Domain Loss: 0.3424
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 7.43%
# Target Domain Accuracy: 99.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4887, Domain Loss: 0.3652
# Source Label Accuracy: 82.40%
# Target Label Accuracy: 78.57%
# Source Domain Accuracy: 3.25%
# Target Domain Accuracy: 99.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4940, Domain Loss: 0.3465
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 4.23%
# Target Domain Accuracy: 99.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.6045, Domain Loss: 0.3319
# Source Label Accuracy: 82.75%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 6.70%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.6745, Domain Loss: 0.3189
# Source Label Accuracy: 82.99%
# Target Label Accuracy: 78.42%
# Source Domain Accuracy: 2.91%
# Target Domain Accuracy: 99.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5336, Domain Loss: 0.3488
# Source Label Accuracy: 82.61%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 5.26%
# Target Domain Accuracy: 99.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5386, Domain Loss: 0.3472
# Source Label Accuracy: 82.53%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 4.75%
# Target Domain Accuracy: 99.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5411, Domain Loss: 0.3416
# Source Label Accuracy: 82.65%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 0.19%
# Target Domain Accuracy: 99.96%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6122, Domain Loss: 0.5263
# Source Label Accuracy: 57.34%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 15.10%
# Target Domain Accuracy: 98.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6100, Domain Loss: 0.5110
# Source Label Accuracy: 77.10%
# Target Label Accuracy: 77.06%
# Source Domain Accuracy: 9.53%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5288, Domain Loss: 0.5027
# Source Label Accuracy: 81.02%
# Target Label Accuracy: 77.69%
# Source Domain Accuracy: 8.16%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4901, Domain Loss: 0.4838
# Source Label Accuracy: 81.29%
# Target Label Accuracy: 77.94%
# Source Domain Accuracy: 7.00%
# Target Domain Accuracy: 99.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5261, Domain Loss: 0.4946
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 78.26%
# Source Domain Accuracy: 7.63%
# Target Domain Accuracy: 99.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4704, Domain Loss: 0.5062
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 78.26%
# Source Domain Accuracy: 9.50%
# Target Domain Accuracy: 98.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5825, Domain Loss: 0.5254
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 78.26%
# Source Domain Accuracy: 12.32%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4798, Domain Loss: 0.5603
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 78.32%
# Source Domain Accuracy: 11.32%
# Target Domain Accuracy: 98.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4427, Domain Loss: 0.5894
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 78.26%
# Source Domain Accuracy: 11.56%
# Target Domain Accuracy: 98.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4473, Domain Loss: 0.5841
# Source Label Accuracy: 82.42%
# Target Label Accuracy: 78.22%
# Source Domain Accuracy: 13.33%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4491, Domain Loss: 0.5445
# Source Label Accuracy: 82.48%
# Target Label Accuracy: 78.30%
# Source Domain Accuracy: 11.91%
# Target Domain Accuracy: 98.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4986, Domain Loss: 0.5518
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 78.42%
# Source Domain Accuracy: 10.93%
# Target Domain Accuracy: 98.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6640, Domain Loss: 0.5362
# Source Label Accuracy: 82.19%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 15.59%
# Target Domain Accuracy: 97.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4902, Domain Loss: 0.5179
# Source Label Accuracy: 82.39%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 12.43%
# Target Domain Accuracy: 98.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4282, Domain Loss: 0.4881
# Source Label Accuracy: 82.78%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 13.06%
# Target Domain Accuracy: 97.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4684, Domain Loss: 0.4892
# Source Label Accuracy: 82.48%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 15.56%
# Target Domain Accuracy: 97.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5231, Domain Loss: 0.4849
# Source Label Accuracy: 82.88%
# Target Label Accuracy: 78.32%
# Source Domain Accuracy: 10.61%
# Target Domain Accuracy: 98.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5334, Domain Loss: 0.4554
# Source Label Accuracy: 82.62%
# Target Label Accuracy: 78.59%
# Source Domain Accuracy: 10.91%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4690, Domain Loss: 0.4256
# Source Label Accuracy: 82.70%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 12.52%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4333, Domain Loss: 0.4306
# Source Label Accuracy: 82.67%
# Target Label Accuracy: 78.32%
# Source Domain Accuracy: 17.61%
# Target Domain Accuracy: 96.75%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.08808808808809
# Target (Black): 78.32006702974445
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 24.924924924924923
# Target (Black): 96.75324675324676
# Overall: 60.02661480192445
#
# False Positive Rate (Test Data)
# Source (White): 9.250175192711984
# Target (Black): 17.745500473634355
# (Black FPR) / (White FPR): 1.9183961496875925
# Overall: 12.8625134264232
#
# Source Label Positive Rate: 0.18238237500190735
# Target Label Positive Rate: 0.35525766015052795
# Overall Label Positive Rate: 0.2668645679950714
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7695, Domain Loss: 0.4098
# Source Label Accuracy: 57.40%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 15.27%
# Target Domain Accuracy: 98.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6543, Domain Loss: 0.2901
# Source Label Accuracy: 58.16%
# Target Label Accuracy: 67.62%
# Source Domain Accuracy: 9.01%
# Target Domain Accuracy: 99.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6176, Domain Loss: 0.2786
# Source Label Accuracy: 81.13%
# Target Label Accuracy: 77.78%
# Source Domain Accuracy: 8.43%
# Target Domain Accuracy: 99.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5068, Domain Loss: 0.2721
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 77.92%
# Source Domain Accuracy: 7.24%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5479, Domain Loss: 0.2687
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 78.34%
# Source Domain Accuracy: 10.80%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4065, Domain Loss: 0.2781
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 10.79%
# Target Domain Accuracy: 98.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4397, Domain Loss: 0.3159
# Source Label Accuracy: 82.33%
# Target Label Accuracy: 78.34%
# Source Domain Accuracy: 9.33%
# Target Domain Accuracy: 98.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4361, Domain Loss: 0.3284
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 78.34%
# Source Domain Accuracy: 9.19%
# Target Domain Accuracy: 98.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.6206, Domain Loss: 0.3244
# Source Label Accuracy: 82.54%
# Target Label Accuracy: 78.49%
# Source Domain Accuracy: 13.52%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.6158, Domain Loss: 0.3182
# Source Label Accuracy: 82.88%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 14.58%
# Target Domain Accuracy: 98.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.6750, Domain Loss: 0.3708
# Source Label Accuracy: 82.39%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 14.31%
# Target Domain Accuracy: 98.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4919, Domain Loss: 0.4227
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 12.76%
# Target Domain Accuracy: 98.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5136, Domain Loss: 0.4524
# Source Label Accuracy: 82.51%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 14.90%
# Target Domain Accuracy: 98.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4975, Domain Loss: 0.4787
# Source Label Accuracy: 82.59%
# Target Label Accuracy: 78.55%
# Source Domain Accuracy: 8.18%
# Target Domain Accuracy: 99.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4241, Domain Loss: 0.4995
# Source Label Accuracy: 82.58%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 6.30%
# Target Domain Accuracy: 99.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4699, Domain Loss: 0.5101
# Source Label Accuracy: 83.03%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 14.56%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5130, Domain Loss: 0.5014
# Source Label Accuracy: 82.64%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 13.03%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5164, Domain Loss: 0.5258
# Source Label Accuracy: 82.33%
# Target Label Accuracy: 78.34%
# Source Domain Accuracy: 14.68%
# Target Domain Accuracy: 97.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4205, Domain Loss: 0.4956
# Source Label Accuracy: 82.67%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 6.14%
# Target Domain Accuracy: 99.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5399, Domain Loss: 0.4956
# Source Label Accuracy: 82.72%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 9.82%
# Target Domain Accuracy: 98.83%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.08808808808809
# Target (Black): 78.32006702974445
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 24.924924924924923
# Target (Black): 96.75324675324676
# Overall: 60.02661480192445
#
# False Positive Rate (Test Data)
# Source (White): 9.250175192711984
# Target (Black): 17.745500473634355
# (Black FPR) / (White FPR): 1.9183961496875925
# Overall: 12.8625134264232
#
# Source Label Positive Rate: 0.18238237500190735
# Target Label Positive Rate: 0.35525766015052795
# Overall Label Positive Rate: 0.2668645679950714
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.40385421030582
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 14.114114114114114
# Target (Black): 98.82697947214076
# Overall: 55.51233493704576
#
# False Positive Rate (Test Data)
# Source (White): 9.34361130576968
# Target (Black): 17.87180296810862
# (Black FPR) / (White FPR): 1.912729712661825
# Overall: 12.969924812030076
#
# Source Label Positive Rate: 0.18318317830562592
# Target Label Positive Rate: 0.35777124762535095
# Overall Label Positive Rate: 0.268502414226532
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7029, Domain Loss: 0.4087
# Source Label Accuracy: 57.29%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 14.89%
# Target Domain Accuracy: 98.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6368, Domain Loss: 0.3856
# Source Label Accuracy: 57.38%
# Target Label Accuracy: 66.36%
# Source Domain Accuracy: 9.49%
# Target Domain Accuracy: 99.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6234, Domain Loss: 0.3759
# Source Label Accuracy: 78.63%
# Target Label Accuracy: 77.82%
# Source Domain Accuracy: 8.51%
# Target Domain Accuracy: 99.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4837, Domain Loss: 0.3738
# Source Label Accuracy: 81.39%
# Target Label Accuracy: 78.09%
# Source Domain Accuracy: 2.86%
# Target Domain Accuracy: 99.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6763, Domain Loss: 0.3901
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 5.65%
# Target Domain Accuracy: 99.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5299, Domain Loss: 0.3711
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 6.03%
# Target Domain Accuracy: 99.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5728, Domain Loss: 0.4002
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 5.75%
# Target Domain Accuracy: 99.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4326, Domain Loss: 0.4011
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 4.83%
# Target Domain Accuracy: 99.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5261, Domain Loss: 0.4299
# Source Label Accuracy: 82.29%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 5.74%
# Target Domain Accuracy: 99.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4806, Domain Loss: 0.4454
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 1.51%
# Target Domain Accuracy: 99.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4708, Domain Loss: 0.4713
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 6.42%
# Target Domain Accuracy: 99.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5398, Domain Loss: 0.4632
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 7.24%
# Target Domain Accuracy: 98.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3516, Domain Loss: 0.4836
# Source Label Accuracy: 82.45%
# Target Label Accuracy: 78.45%
# Source Domain Accuracy: 4.64%
# Target Domain Accuracy: 99.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4544, Domain Loss: 0.4696
# Source Label Accuracy: 82.76%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 5.45%
# Target Domain Accuracy: 99.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.6717, Domain Loss: 0.4702
# Source Label Accuracy: 82.42%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 7.82%
# Target Domain Accuracy: 98.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.6106, Domain Loss: 0.4405
# Source Label Accuracy: 82.57%
# Target Label Accuracy: 78.59%
# Source Domain Accuracy: 5.23%
# Target Domain Accuracy: 99.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4600, Domain Loss: 0.4375
# Source Label Accuracy: 82.49%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 5.77%
# Target Domain Accuracy: 99.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5324, Domain Loss: 0.4459
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 5.85%
# Target Domain Accuracy: 99.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4090, Domain Loss: 0.4272
# Source Label Accuracy: 82.47%
# Target Label Accuracy: 78.55%
# Source Domain Accuracy: 6.81%
# Target Domain Accuracy: 99.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4678, Domain Loss: 0.4139
# Source Label Accuracy: 82.53%
# Target Label Accuracy: 78.49%
# Source Domain Accuracy: 1.93%
# Target Domain Accuracy: 99.66%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.08808808808809
# Target (Black): 78.32006702974445
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 24.924924924924923
# Target (Black): 96.75324675324676
# Overall: 60.02661480192445
#
# False Positive Rate (Test Data)
# Source (White): 9.250175192711984
# Target (Black): 17.745500473634355
# (Black FPR) / (White FPR): 1.9183961496875925
# Overall: 12.8625134264232
#
# Source Label Positive Rate: 0.18238237500190735
# Target Label Positive Rate: 0.35525766015052795
# Overall Label Positive Rate: 0.2668645679950714
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.40385421030582
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 14.114114114114114
# Target (Black): 98.82697947214076
# Overall: 55.51233493704576
#
# False Positive Rate (Test Data)
# Source (White): 9.34361130576968
# Target (Black): 17.87180296810862
# (Black FPR) / (White FPR): 1.912729712661825
# Overall: 12.969924812030076
#
# Source Label Positive Rate: 0.18318317830562592
# Target Label Positive Rate: 0.35777124762535095
# Overall Label Positive Rate: 0.268502414226532
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.10810810810811
# Target (Black): 78.4876413908672
# Overall: 83.40669464633022
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 2.8228228228228227
# Target (Black): 99.66485127775451
# Overall: 50.14842870304023
#
# False Positive Rate (Test Data)
# Source (White): 9.06330296659659
# Target (Black): 17.145563624881593
# (Black FPR) / (White FPR): 1.89175664634325
# Overall: 12.5
#
# Source Label Positive Rate: 0.17937937378883362
# Target Label Positive Rate: 0.3489736020565033
# Overall Label Positive Rate: 0.2622581720352173
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6962, Domain Loss: 0.5030
# Source Label Accuracy: 57.22%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 16.45%
# Target Domain Accuracy: 97.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5905, Domain Loss: 0.3471
# Source Label Accuracy: 73.45%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 14.74%
# Target Domain Accuracy: 98.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4824, Domain Loss: 0.3214
# Source Label Accuracy: 80.58%
# Target Label Accuracy: 77.69%
# Source Domain Accuracy: 12.34%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5213, Domain Loss: 0.3144
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 77.92%
# Source Domain Accuracy: 11.60%
# Target Domain Accuracy: 98.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4550, Domain Loss: 0.3364
# Source Label Accuracy: 81.60%
# Target Label Accuracy: 78.13%
# Source Domain Accuracy: 10.11%
# Target Domain Accuracy: 98.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5346, Domain Loss: 0.3311
# Source Label Accuracy: 82.24%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 10.32%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5313, Domain Loss: 0.3079
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 8.26%
# Target Domain Accuracy: 98.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5860, Domain Loss: 0.3125
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 8.62%
# Target Domain Accuracy: 98.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5091, Domain Loss: 0.3322
# Source Label Accuracy: 82.43%
# Target Label Accuracy: 78.15%
# Source Domain Accuracy: 9.32%
# Target Domain Accuracy: 98.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5165, Domain Loss: 0.3236
# Source Label Accuracy: 82.53%
# Target Label Accuracy: 78.42%
# Source Domain Accuracy: 8.99%
# Target Domain Accuracy: 98.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4986, Domain Loss: 0.3442
# Source Label Accuracy: 82.62%
# Target Label Accuracy: 78.30%
# Source Domain Accuracy: 8.89%
# Target Domain Accuracy: 98.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.6404, Domain Loss: 0.3468
# Source Label Accuracy: 82.83%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 10.90%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5370, Domain Loss: 0.3461
# Source Label Accuracy: 82.76%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 10.68%
# Target Domain Accuracy: 98.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5537, Domain Loss: 0.3438
# Source Label Accuracy: 82.45%
# Target Label Accuracy: 78.42%
# Source Domain Accuracy: 9.92%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4928, Domain Loss: 0.3881
# Source Label Accuracy: 83.10%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 9.11%
# Target Domain Accuracy: 98.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5483, Domain Loss: 0.3899
# Source Label Accuracy: 82.51%
# Target Label Accuracy: 78.26%
# Source Domain Accuracy: 9.62%
# Target Domain Accuracy: 98.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5638, Domain Loss: 0.3661
# Source Label Accuracy: 82.61%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 8.87%
# Target Domain Accuracy: 98.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5298, Domain Loss: 0.3338
# Source Label Accuracy: 82.92%
# Target Label Accuracy: 78.34%
# Source Domain Accuracy: 9.63%
# Target Domain Accuracy: 98.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.6609, Domain Loss: 0.3919
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 78.24%
# Source Domain Accuracy: 9.50%
# Target Domain Accuracy: 98.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3890, Domain Loss: 0.3779
# Source Label Accuracy: 82.94%
# Target Label Accuracy: 78.19%
# Source Domain Accuracy: 4.86%
# Target Domain Accuracy: 99.16%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.08808808808809
# Target (Black): 78.32006702974445
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 24.924924924924923
# Target (Black): 96.75324675324676
# Overall: 60.02661480192445
#
# False Positive Rate (Test Data)
# Source (White): 9.250175192711984
# Target (Black): 17.745500473634355
# (Black FPR) / (White FPR): 1.9183961496875925
# Overall: 12.8625134264232
#
# Source Label Positive Rate: 0.18238237500190735
# Target Label Positive Rate: 0.35525766015052795
# Overall Label Positive Rate: 0.2668645679950714
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.40385421030582
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 14.114114114114114
# Target (Black): 98.82697947214076
# Overall: 55.51233493704576
#
# False Positive Rate (Test Data)
# Source (White): 9.34361130576968
# Target (Black): 17.87180296810862
# (Black FPR) / (White FPR): 1.912729712661825
# Overall: 12.969924812030076
#
# Source Label Positive Rate: 0.18318317830562592
# Target Label Positive Rate: 0.35777124762535095
# Overall Label Positive Rate: 0.268502414226532
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.10810810810811
# Target (Black): 78.4876413908672
# Overall: 83.40669464633022
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 2.8228228228228227
# Target (Black): 99.66485127775451
# Overall: 50.14842870304023
#
# False Positive Rate (Test Data)
# Source (White): 9.06330296659659
# Target (Black): 17.145563624881593
# (Black FPR) / (White FPR): 1.89175664634325
# Overall: 12.5
#
# Source Label Positive Rate: 0.17937937378883362
# Target Label Positive Rate: 0.3489736020565033
# Overall Label Positive Rate: 0.2622581720352173
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.19438625890238
# Overall: 83.21220186303613
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 6.986986986986987
# Target (Black): 99.16212819438626
# Overall: 52.03193776230935
#
# False Positive Rate (Test Data)
# Source (White): 9.366970334034104
# Target (Black): 18.061256709820018
# (Black FPR) / (White FPR): 1.9281855355296633
# Overall: 13.063909774436091
#
# Source Label Positive Rate: 0.1835835874080658
# Target Label Positive Rate: 0.3581902086734772
# Overall Label Positive Rate: 0.26891186833381653
#
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.06806806806807
# Target (Black): 78.40385421030582
# Overall: 83.3452758726584
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 0.34034034034034033
# Target (Black): 99.9581064097193
# Overall: 49.02241785239021
#
# False Positive Rate (Test Data)
# Source (White): 9.203457136183134
# Target (Black): 17.398168613830123
# (Black FPR) / (White FPR): 1.890394919690527
# Overall: 12.68796992481203
#
# Source Label Positive Rate: 0.18138137459754944
# Target Label Positive Rate: 0.3514872193336487
# Overall Label Positive Rate: 0.2645101845264435
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.08808808808809
# Target (Black): 78.32006702974445
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 24.924924924924923
# Target (Black): 96.75324675324676
# Overall: 60.02661480192445
#
# False Positive Rate (Test Data)
# Source (White): 9.250175192711984
# Target (Black): 17.745500473634355
# (Black FPR) / (White FPR): 1.9183961496875925
# Overall: 12.8625134264232
#
# Source Label Positive Rate: 0.18238237500190735
# Target Label Positive Rate: 0.35525766015052795
# Overall Label Positive Rate: 0.2668645679950714
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.40385421030582
# Overall: 83.3145664858225
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 14.114114114114114
# Target (Black): 98.82697947214076
# Overall: 55.51233493704576
#
# False Positive Rate (Test Data)
# Source (White): 9.34361130576968
# Target (Black): 17.87180296810862
# (Black FPR) / (White FPR): 1.912729712661825
# Overall: 12.969924812030076
#
# Source Label Positive Rate: 0.18318317830562592
# Target Label Positive Rate: 0.35777124762535095
# Overall Label Positive Rate: 0.268502414226532
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.10810810810811
# Target (Black): 78.4876413908672
# Overall: 83.40669464633022
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 2.8228228228228227
# Target (Black): 99.66485127775451
# Overall: 50.14842870304023
#
# False Positive Rate (Test Data)
# Source (White): 9.06330296659659
# Target (Black): 17.145563624881593
# (Black FPR) / (White FPR): 1.89175664634325
# Overall: 12.5
#
# Source Label Positive Rate: 0.17937937378883362
# Target Label Positive Rate: 0.3489736020565033
# Overall Label Positive Rate: 0.2622581720352173
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 88.008008008008
# Target (Black): 78.19438625890238
# Overall: 83.21220186303613
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 6.986986986986987
# Target (Black): 99.16212819438626
# Overall: 52.03193776230935
#
# False Positive Rate (Test Data)
# Source (White): 9.366970334034104
# Target (Black): 18.061256709820018
# (Black FPR) / (White FPR): 1.9281855355296633
# Overall: 13.063909774436091
#
# Source Label Positive Rate: 0.1835835874080658
# Target Label Positive Rate: 0.3581902086734772
# Overall Label Positive Rate: 0.26891186833381653
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6205, Domain Loss: 0.4170
# Source Label Accuracy: 57.08%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 15.38%
# Target Domain Accuracy: 98.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5827, Domain Loss: 0.3689
# Source Label Accuracy: 77.68%
# Target Label Accuracy: 77.31%
# Source Domain Accuracy: 8.95%
# Target Domain Accuracy: 99.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5696, Domain Loss: 0.3529
# Source Label Accuracy: 80.87%
# Target Label Accuracy: 77.84%
# Source Domain Accuracy: 7.15%
# Target Domain Accuracy: 99.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.6130, Domain Loss: 0.3894
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 78.11%
# Source Domain Accuracy: 6.79%
# Target Domain Accuracy: 99.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5981, Domain Loss: 0.3822
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 6.19%
# Target Domain Accuracy: 99.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5289, Domain Loss: 0.3689
# Source Label Accuracy: 82.25%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 3.13%
# Target Domain Accuracy: 99.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5352, Domain Loss: 0.3894
# Source Label Accuracy: 81.97%
# Target Label Accuracy: 78.49%
# Source Domain Accuracy: 4.80%
# Target Domain Accuracy: 99.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4422, Domain Loss: 0.3593
# Source Label Accuracy: 82.70%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 4.18%
# Target Domain Accuracy: 99.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.6812, Domain Loss: 0.4090
# Source Label Accuracy: 82.27%
# Target Label Accuracy: 78.28%
# Source Domain Accuracy: 3.91%
# Target Domain Accuracy: 99.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4947, Domain Loss: 0.4032
# Source Label Accuracy: 82.57%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 3.56%
# Target Domain Accuracy: 99.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5437, Domain Loss: 0.3961
# Source Label Accuracy: 82.69%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 3.80%
# Target Domain Accuracy: 99.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4906, Domain Loss: 0.4031
# Source Label Accuracy: 82.74%
# Target Label Accuracy: 78.40%
# Source Domain Accuracy: 2.85%
# Target Domain Accuracy: 99.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4717, Domain Loss: 0.3813
# Source Label Accuracy: 82.49%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 3.58%
# Target Domain Accuracy: 98.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.6106, Domain Loss: 0.3635
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 78.42%
# Source Domain Accuracy: 2.75%
# Target Domain Accuracy: 99.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.6758, Domain Loss: 0.3987
# Source Label Accuracy: 82.52%
# Target Label Accuracy: 78.30%
# Source Domain Accuracy: 4.73%
# Target Domain Accuracy: 98.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.6005, Domain Loss: 0.3907
# Source Label Accuracy: 82.44%
# Target Label Accuracy: 78.47%
# Source Domain Accuracy: 2.41%
# Target Domain Accuracy: 99.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.6319, Domain Loss: 0.4104
# Source Label Accuracy: 82.62%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 2.45%
# Target Domain Accuracy: 98.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5177, Domain Loss: 0.3851
# Source Label Accuracy: 82.44%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 1.50%
# Target Domain Accuracy: 99.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4420, Domain Loss: 0.3791
# Source Label Accuracy: 83.22%
# Target Label Accuracy: 78.30%
# Source Domain Accuracy: 3.48%
# Target Domain Accuracy: 98.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5211, Domain Loss: 0.4057
# Source Label Accuracy: 82.61%
# Target Label Accuracy: 78.22%
# Source Domain Accuracy: 3.81%
# Target Domain Accuracy: 98.53%
#
# Lambda: 0.1
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.92792792792793
# Target (Black): 78.21533305404273
# Overall: 83.18149247620022
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 5.305305305305305
# Target (Black): 98.53372434017595
# Overall: 50.864981062544786
#
# False Positive Rate (Test Data)
# Source (White): 9.483765475356225
# Target (Black): 18.15598358067572
# (Black FPR) / (White FPR): 1.914427726819526
# Overall: 13.171321160042964
#
# Source Label Positive Rate: 0.18478478491306305
# Target Label Positive Rate: 0.3596564829349518
# Overall Label Positive Rate: 0.2702426016330719
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6509, Domain Loss: 0.4356
# Source Label Accuracy: 56.98%
# Target Label Accuracy: 66.34%
# Source Domain Accuracy: 16.41%
# Target Domain Accuracy: 98.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5943, Domain Loss: 0.3998
# Source Label Accuracy: 79.41%
# Target Label Accuracy: 77.29%
# Source Domain Accuracy: 12.65%
# Target Domain Accuracy: 98.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6412, Domain Loss: 0.3970
# Source Label Accuracy: 80.84%
# Target Label Accuracy: 77.69%
# Source Domain Accuracy: 10.34%
# Target Domain Accuracy: 98.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4961, Domain Loss: 0.3589
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 77.92%
# Source Domain Accuracy: 8.07%
# Target Domain Accuracy: 99.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5540, Domain Loss: 0.3544
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 78.15%
# Source Domain Accuracy: 6.69%
# Target Domain Accuracy: 99.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5254, Domain Loss: 0.3730
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 78.19%
# Source Domain Accuracy: 5.69%
# Target Domain Accuracy: 99.37%

# %%
# More lambdas
lams = [2, 3, 5, 10, 15, 100]
for l in lams:
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7529, Domain Loss: 0.4667
# Source Label Accuracy: 56.44%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 32.20%
# Target Domain Accuracy: 90.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5926, Domain Loss: 0.4381
# Source Label Accuracy: 78.61%
# Target Label Accuracy: 77.69%
# Source Domain Accuracy: 23.22%
# Target Domain Accuracy: 93.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5254, Domain Loss: 0.4487
# Source Label Accuracy: 80.90%
# Target Label Accuracy: 78.18%
# Source Domain Accuracy: 20.38%
# Target Domain Accuracy: 90.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5369, Domain Loss: 0.5697
# Source Label Accuracy: 81.15%
# Target Label Accuracy: 78.53%
# Source Domain Accuracy: 24.97%
# Target Domain Accuracy: 83.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5841, Domain Loss: 0.5384
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 32.66%
# Target Domain Accuracy: 76.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4711, Domain Loss: 0.5552
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 37.12%
# Target Domain Accuracy: 70.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5482, Domain Loss: 0.5690
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 38.76%
# Target Domain Accuracy: 68.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4296, Domain Loss: 0.5652
# Source Label Accuracy: 81.97%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 68.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4692, Domain Loss: 0.5082
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.27%
# Target Domain Accuracy: 68.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4649, Domain Loss: 0.5805
# Source Label Accuracy: 82.30%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.96%
# Target Domain Accuracy: 67.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5098, Domain Loss: 0.6197
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 40.13%
# Target Domain Accuracy: 67.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5701, Domain Loss: 0.5235
# Source Label Accuracy: 82.43%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 40.32%
# Target Domain Accuracy: 66.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4798, Domain Loss: 0.5550
# Source Label Accuracy: 82.57%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 40.71%
# Target Domain Accuracy: 65.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5751, Domain Loss: 0.5285
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 41.09%
# Target Domain Accuracy: 64.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4053, Domain Loss: 0.6413
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 41.33%
# Target Domain Accuracy: 64.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4219, Domain Loss: 0.5766
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 40.88%
# Target Domain Accuracy: 64.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.6000, Domain Loss: 0.5317
# Source Label Accuracy: 82.39%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 41.52%
# Target Domain Accuracy: 63.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5774, Domain Loss: 0.5716
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 42.56%
# Target Domain Accuracy: 63.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5500, Domain Loss: 0.5749
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 41.99%
# Target Domain Accuracy: 63.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4633, Domain Loss: 0.6364
# Source Label Accuracy: 82.33%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 42.31%
# Target Domain Accuracy: 62.82%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6901, Domain Loss: 0.4919
# Source Label Accuracy: 56.61%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 25.91%
# Target Domain Accuracy: 94.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6290, Domain Loss: 0.4651
# Source Label Accuracy: 56.95%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 20.71%
# Target Domain Accuracy: 96.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5789, Domain Loss: 0.4118
# Source Label Accuracy: 78.93%
# Target Label Accuracy: 77.84%
# Source Domain Accuracy: 15.87%
# Target Domain Accuracy: 96.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5428, Domain Loss: 0.4464
# Source Label Accuracy: 80.51%
# Target Label Accuracy: 77.99%
# Source Domain Accuracy: 15.52%
# Target Domain Accuracy: 93.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5787, Domain Loss: 0.5754
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 28.24%
# Target Domain Accuracy: 80.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5404, Domain Loss: 0.5473
# Source Label Accuracy: 81.17%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 36.99%
# Target Domain Accuracy: 70.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5244, Domain Loss: 0.5660
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 37.76%
# Target Domain Accuracy: 70.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5198, Domain Loss: 0.5506
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 38.35%
# Target Domain Accuracy: 69.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5892, Domain Loss: 0.5240
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 38.32%
# Target Domain Accuracy: 69.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4677, Domain Loss: 0.4855
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.20%
# Target Domain Accuracy: 69.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4734, Domain Loss: 0.6154
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 39.13%
# Target Domain Accuracy: 68.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5298, Domain Loss: 0.5917
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 39.14%
# Target Domain Accuracy: 68.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4984, Domain Loss: 0.6604
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 38.95%
# Target Domain Accuracy: 68.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4403, Domain Loss: 0.5599
# Source Label Accuracy: 82.32%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.34%
# Target Domain Accuracy: 68.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5463, Domain Loss: 0.5849
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.80%
# Target Domain Accuracy: 67.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5015, Domain Loss: 0.5447
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 39.84%
# Target Domain Accuracy: 67.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5094, Domain Loss: 0.5774
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 65.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5496, Domain Loss: 0.5708
# Source Label Accuracy: 82.24%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 40.82%
# Target Domain Accuracy: 64.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4772, Domain Loss: 0.6192
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 41.27%
# Target Domain Accuracy: 65.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5532, Domain Loss: 0.5072
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 41.04%
# Target Domain Accuracy: 64.46%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.17388078159783
# Overall: 83.58239508700102
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.88370874803562
# Target (Black): 64.4570863220381
# Overall: 60.60388945752303
#
# False Positive Rate (Test Data)
# Source (White): 10.60004181476061
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5675381165582978
# Overall: 12.734385538918117
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6937, Domain Loss: 0.4886
# Source Label Accuracy: 56.84%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 29.86%
# Target Domain Accuracy: 92.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5702, Domain Loss: 0.4300
# Source Label Accuracy: 75.73%
# Target Label Accuracy: 76.21%
# Source Domain Accuracy: 23.79%
# Target Domain Accuracy: 94.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6206, Domain Loss: 0.4656
# Source Label Accuracy: 79.48%
# Target Label Accuracy: 77.84%
# Source Domain Accuracy: 21.33%
# Target Domain Accuracy: 93.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5488, Domain Loss: 0.4766
# Source Label Accuracy: 80.14%
# Target Label Accuracy: 78.51%
# Source Domain Accuracy: 22.25%
# Target Domain Accuracy: 90.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6364, Domain Loss: 0.4610
# Source Label Accuracy: 80.65%
# Target Label Accuracy: 78.73%
# Source Domain Accuracy: 24.83%
# Target Domain Accuracy: 86.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5204, Domain Loss: 0.5248
# Source Label Accuracy: 81.12%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 27.64%
# Target Domain Accuracy: 81.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4912, Domain Loss: 0.4949
# Source Label Accuracy: 81.51%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 32.85%
# Target Domain Accuracy: 78.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5116, Domain Loss: 0.5841
# Source Label Accuracy: 82.18%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 33.88%
# Target Domain Accuracy: 75.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4754, Domain Loss: 0.5291
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 34.74%
# Target Domain Accuracy: 73.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4882, Domain Loss: 0.5263
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 35.58%
# Target Domain Accuracy: 71.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5135, Domain Loss: 0.6222
# Source Label Accuracy: 81.57%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 36.08%
# Target Domain Accuracy: 70.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4708, Domain Loss: 0.5234
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 36.88%
# Target Domain Accuracy: 70.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5495, Domain Loss: 0.5849
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 38.21%
# Target Domain Accuracy: 69.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4364, Domain Loss: 0.6135
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 38.33%
# Target Domain Accuracy: 68.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5449, Domain Loss: 0.5799
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 79.47%
# Source Domain Accuracy: 38.52%
# Target Domain Accuracy: 67.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.6002, Domain Loss: 0.5196
# Source Label Accuracy: 82.26%
# Target Label Accuracy: 79.54%
# Source Domain Accuracy: 39.19%
# Target Domain Accuracy: 66.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5550, Domain Loss: 0.5561
# Source Label Accuracy: 82.46%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 39.80%
# Target Domain Accuracy: 66.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5018, Domain Loss: 0.6258
# Source Label Accuracy: 82.41%
# Target Label Accuracy: 79.42%
# Source Domain Accuracy: 40.41%
# Target Domain Accuracy: 65.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5177, Domain Loss: 0.5715
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 79.52%
# Source Domain Accuracy: 40.31%
# Target Domain Accuracy: 65.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4548, Domain Loss: 0.5493
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.50%
# Source Domain Accuracy: 41.62%
# Target Domain Accuracy: 64.93%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.17388078159783
# Overall: 83.58239508700102
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.88370874803562
# Target (Black): 64.4570863220381
# Overall: 60.60388945752303
#
# False Positive Rate (Test Data)
# Source (White): 10.60004181476061
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5675381165582978
# Overall: 12.734385538918117
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.00890518596124
# Target (Black): 79.49542418995796
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.429718875502004
# Target (Black): 64.92703438041059
# Overall: 60.53224155578301
#
# False Positive Rate (Test Data)
# Source (White): 10.056449926824168
# Target (Black): 15.96958174904943
# (Black FPR) / (White FPR): 1.5879939606175348
# Overall: 12.154323485768245
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7161, Domain Loss: 0.5062
# Source Label Accuracy: 56.83%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 35.37%
# Target Domain Accuracy: 83.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5830, Domain Loss: 0.4907
# Source Label Accuracy: 79.17%
# Target Label Accuracy: 78.04%
# Source Domain Accuracy: 28.33%
# Target Domain Accuracy: 92.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5960, Domain Loss: 0.5001
# Source Label Accuracy: 81.00%
# Target Label Accuracy: 78.36%
# Source Domain Accuracy: 27.76%
# Target Domain Accuracy: 91.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.6066, Domain Loss: 0.4942
# Source Label Accuracy: 81.22%
# Target Label Accuracy: 78.65%
# Source Domain Accuracy: 28.12%
# Target Domain Accuracy: 88.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4805, Domain Loss: 0.5148
# Source Label Accuracy: 81.48%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 30.91%
# Target Domain Accuracy: 83.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5346, Domain Loss: 0.4988
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 34.41%
# Target Domain Accuracy: 75.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5514, Domain Loss: 0.5488
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 78.98%
# Source Domain Accuracy: 36.73%
# Target Domain Accuracy: 72.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4981, Domain Loss: 0.5266
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 38.41%
# Target Domain Accuracy: 70.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4655, Domain Loss: 0.6165
# Source Label Accuracy: 82.50%
# Target Label Accuracy: 79.07%
# Source Domain Accuracy: 39.01%
# Target Domain Accuracy: 69.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4952, Domain Loss: 0.5960
# Source Label Accuracy: 82.32%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 68.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5702, Domain Loss: 0.5761
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.06%
# Target Domain Accuracy: 68.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5089, Domain Loss: 0.5554
# Source Label Accuracy: 82.56%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 38.88%
# Target Domain Accuracy: 68.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5921, Domain Loss: 0.5814
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 39.70%
# Target Domain Accuracy: 68.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4446, Domain Loss: 0.5655
# Source Label Accuracy: 82.40%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 39.90%
# Target Domain Accuracy: 68.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5277, Domain Loss: 0.5911
# Source Label Accuracy: 82.51%
# Target Label Accuracy: 79.03%
# Source Domain Accuracy: 39.46%
# Target Domain Accuracy: 67.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4652, Domain Loss: 0.5877
# Source Label Accuracy: 82.30%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.93%
# Target Domain Accuracy: 67.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4855, Domain Loss: 0.5985
# Source Label Accuracy: 82.29%
# Target Label Accuracy: 79.00%
# Source Domain Accuracy: 40.06%
# Target Domain Accuracy: 67.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4842, Domain Loss: 0.4948
# Source Label Accuracy: 82.61%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 39.96%
# Target Domain Accuracy: 66.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4618, Domain Loss: 0.6198
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 78.98%
# Source Domain Accuracy: 40.00%
# Target Domain Accuracy: 65.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4370, Domain Loss: 0.6018
# Source Label Accuracy: 82.27%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 40.46%
# Target Domain Accuracy: 65.05%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.17388078159783
# Overall: 83.58239508700102
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.88370874803562
# Target (Black): 64.4570863220381
# Overall: 60.60388945752303
#
# False Positive Rate (Test Data)
# Source (White): 10.60004181476061
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5675381165582978
# Overall: 12.734385538918117
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.00890518596124
# Target (Black): 79.49542418995796
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.429718875502004
# Target (Black): 64.92703438041059
# Overall: 60.53224155578301
#
# False Positive Rate (Test Data)
# Source (White): 10.056449926824168
# Target (Black): 15.96958174904943
# (Black FPR) / (White FPR): 1.5879939606175348
# Overall: 12.154323485768245
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.53745416448402
# Target (Black): 79.05021023992084
# Overall: 83.43909928352099
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.49956347127641
# Target (Black): 65.05070492208756
# Overall: 60.62436028659161
#
# False Positive Rate (Test Data)
# Source (White): 10.871837758728832
# Target (Black): 16.99619771863118
# (Black FPR) / (White FPR): 1.563323340157941
# Overall: 13.04465128827735
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7742, Domain Loss: 0.4853
# Source Label Accuracy: 56.60%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 34.06%
# Target Domain Accuracy: 89.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6488, Domain Loss: 0.4179
# Source Label Accuracy: 69.93%
# Target Label Accuracy: 75.36%
# Source Domain Accuracy: 26.69%
# Target Domain Accuracy: 92.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5604, Domain Loss: 0.4498
# Source Label Accuracy: 79.71%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 23.95%
# Target Domain Accuracy: 88.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5942, Domain Loss: 0.4673
# Source Label Accuracy: 80.65%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 29.28%
# Target Domain Accuracy: 84.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5114, Domain Loss: 0.5537
# Source Label Accuracy: 81.07%
# Target Label Accuracy: 78.80%
# Source Domain Accuracy: 35.48%
# Target Domain Accuracy: 74.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5041, Domain Loss: 0.4985
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 38.15%
# Target Domain Accuracy: 71.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5220, Domain Loss: 0.5614
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 38.97%
# Target Domain Accuracy: 69.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5048, Domain Loss: 0.5308
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 39.68%
# Target Domain Accuracy: 68.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5037, Domain Loss: 0.5953
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.52%
# Target Domain Accuracy: 68.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5350, Domain Loss: 0.5396
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.32%
# Target Domain Accuracy: 68.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4338, Domain Loss: 0.6188
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 39.28%
# Target Domain Accuracy: 68.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5154, Domain Loss: 0.6023
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.40%
# Source Domain Accuracy: 39.40%
# Target Domain Accuracy: 68.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4003, Domain Loss: 0.6279
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 79.40%
# Source Domain Accuracy: 39.59%
# Target Domain Accuracy: 68.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4307, Domain Loss: 0.5837
# Source Label Accuracy: 82.35%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.61%
# Target Domain Accuracy: 68.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5053, Domain Loss: 0.5559
# Source Label Accuracy: 82.37%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 39.28%
# Target Domain Accuracy: 67.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5022, Domain Loss: 0.5449
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 39.67%
# Target Domain Accuracy: 66.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5315, Domain Loss: 0.5713
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 40.16%
# Target Domain Accuracy: 65.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5214, Domain Loss: 0.6036
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 40.59%
# Target Domain Accuracy: 65.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4755, Domain Loss: 0.6152
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 41.39%
# Target Domain Accuracy: 64.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5321, Domain Loss: 0.5979
# Source Label Accuracy: 82.61%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 41.56%
# Target Domain Accuracy: 64.95%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.17388078159783
# Overall: 83.58239508700102
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.88370874803562
# Target (Black): 64.4570863220381
# Overall: 60.60388945752303
#
# False Positive Rate (Test Data)
# Source (White): 10.60004181476061
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5675381165582978
# Overall: 12.734385538918117
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.00890518596124
# Target (Black): 79.49542418995796
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.429718875502004
# Target (Black): 64.92703438041059
# Overall: 60.53224155578301
#
# False Positive Rate (Test Data)
# Source (White): 10.056449926824168
# Target (Black): 15.96958174904943
# (Black FPR) / (White FPR): 1.5879939606175348
# Overall: 12.154323485768245
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.53745416448402
# Target (Black): 79.05021023992084
# Overall: 83.43909928352099
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.49956347127641
# Target (Black): 65.05070492208756
# Overall: 60.62436028659161
#
# False Positive Rate (Test Data)
# Source (White): 10.871837758728832
# Target (Black): 16.99619771863118
# (Black FPR) / (White FPR): 1.563323340157941
# Overall: 13.04465128827735
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.76444910075082
# Target (Black): 79.27281721493941
# Overall: 83.66427840327533
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.86624759909202
# Target (Black): 64.95176848874598
# Overall: 60.79836233367451
#
# False Positive Rate (Test Data)
# Source (White): 10.51641229353962
# Target (Black): 16.4638783269962
# (Black FPR) / (White FPR): 1.5655413526445887
# Overall: 12.626467017401861
#
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.74698795180723
# Target (Black): 79.12441256492703
# Overall: 83.59263050153531
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.00122228042605
# Target (Black): 62.82463517190205
# Overall: 60.58341862845445
#
# False Positive Rate (Test Data)
# Source (White): 10.474597532929124
# Target (Black): 16.653992395437264
# (Black FPR) / (White FPR): 1.5899410304865556
# Overall: 12.666936462970458
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.69460450497643
# Target (Black): 79.17388078159783
# Overall: 83.58239508700102
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.88370874803562
# Target (Black): 64.4570863220381
# Overall: 60.60388945752303
#
# False Positive Rate (Test Data)
# Source (White): 10.60004181476061
# Target (Black): 16.61596958174905
# (Black FPR) / (White FPR): 1.5675381165582978
# Overall: 12.734385538918117
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.00890518596124
# Target (Black): 79.49542418995796
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.429718875502004
# Target (Black): 64.92703438041059
# Overall: 60.53224155578301
#
# False Positive Rate (Test Data)
# Source (White): 10.056449926824168
# Target (Black): 15.96958174904943
# (Black FPR) / (White FPR): 1.5879939606175348
# Overall: 12.154323485768245
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.53745416448402
# Target (Black): 79.05021023992084
# Overall: 83.43909928352099
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.49956347127641
# Target (Black): 65.05070492208756
# Overall: 60.62436028659161
#
# False Positive Rate (Test Data)
# Source (White): 10.871837758728832
# Target (Black): 16.99619771863118
# (Black FPR) / (White FPR): 1.563323340157941
# Overall: 13.04465128827735
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.76444910075082
# Target (Black): 79.27281721493941
# Overall: 83.66427840327533
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.86624759909202
# Target (Black): 64.95176848874598
# Overall: 60.79836233367451
#
# False Positive Rate (Test Data)
# Source (White): 10.51641229353962
# Target (Black): 16.4638783269962
# (Black FPR) / (White FPR): 1.5655413526445887
# Overall: 12.626467017401861
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.8020, Domain Loss: 0.4879
# Source Label Accuracy: 56.88%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 32.77%
# Target Domain Accuracy: 91.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6129, Domain Loss: 0.4235
# Source Label Accuracy: 56.42%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 25.63%
# Target Domain Accuracy: 92.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6493, Domain Loss: 0.4246
# Source Label Accuracy: 76.79%
# Target Label Accuracy: 77.69%
# Source Domain Accuracy: 21.78%
# Target Domain Accuracy: 91.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5407, Domain Loss: 0.4198
# Source Label Accuracy: 79.70%
# Target Label Accuracy: 78.80%
# Source Domain Accuracy: 20.25%
# Target Domain Accuracy: 90.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5314, Domain Loss: 0.5462
# Source Label Accuracy: 80.56%
# Target Label Accuracy: 78.80%
# Source Domain Accuracy: 21.74%
# Target Domain Accuracy: 87.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5252, Domain Loss: 0.5751
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 26.61%
# Target Domain Accuracy: 83.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4547, Domain Loss: 0.5959
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 79.40%
# Source Domain Accuracy: 31.40%
# Target Domain Accuracy: 79.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4389, Domain Loss: 0.5574
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 36.63%
# Target Domain Accuracy: 72.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5296, Domain Loss: 0.6314
# Source Label Accuracy: 81.18%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 37.81%
# Target Domain Accuracy: 69.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5377, Domain Loss: 0.5645
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 38.15%
# Target Domain Accuracy: 69.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5434, Domain Loss: 0.5334
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 68.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5375, Domain Loss: 0.6092
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 38.67%
# Target Domain Accuracy: 68.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5751, Domain Loss: 0.5797
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 38.57%
# Target Domain Accuracy: 68.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4768, Domain Loss: 0.6536
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 39.27%
# Target Domain Accuracy: 67.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5531, Domain Loss: 0.5632
# Source Label Accuracy: 82.18%
# Target Label Accuracy: 79.35%
# Source Domain Accuracy: 40.47%
# Target Domain Accuracy: 65.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5135, Domain Loss: 0.5555
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 40.73%
# Target Domain Accuracy: 65.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4803, Domain Loss: 0.6224
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 40.97%
# Target Domain Accuracy: 64.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5275, Domain Loss: 0.6107
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 40.90%
# Target Domain Accuracy: 64.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5000, Domain Loss: 0.5782
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 41.07%
# Target Domain Accuracy: 63.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5175, Domain Loss: 0.6104
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 41.45%
# Target Domain Accuracy: 63.37%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.83132530120482
# Target (Black): 63.36878555528073
# Overall: 60.122824974411465
#
# False Positive Rate (Test Data)
# Source (White): 9.95191302529793
# Target (Black): 16.007604562737644
# (Black FPR) / (White FPR): 1.6084952231843308
# Overall: 12.100364225010118
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7566, Domain Loss: 0.4484
# Source Label Accuracy: 56.54%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 30.12%
# Target Domain Accuracy: 93.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6185, Domain Loss: 0.3816
# Source Label Accuracy: 66.12%
# Target Label Accuracy: 74.13%
# Source Domain Accuracy: 23.52%
# Target Domain Accuracy: 94.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5961, Domain Loss: 0.4199
# Source Label Accuracy: 79.60%
# Target Label Accuracy: 78.58%
# Source Domain Accuracy: 20.47%
# Target Domain Accuracy: 94.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5722, Domain Loss: 0.3688
# Source Label Accuracy: 80.64%
# Target Label Accuracy: 78.56%
# Source Domain Accuracy: 19.41%
# Target Domain Accuracy: 93.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5930, Domain Loss: 0.4699
# Source Label Accuracy: 81.30%
# Target Label Accuracy: 78.93%
# Source Domain Accuracy: 20.55%
# Target Domain Accuracy: 91.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4901, Domain Loss: 0.5460
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 24.28%
# Target Domain Accuracy: 87.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5041, Domain Loss: 0.4713
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.32%
# Source Domain Accuracy: 29.08%
# Target Domain Accuracy: 81.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5181, Domain Loss: 0.4699
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 33.08%
# Target Domain Accuracy: 77.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5248, Domain Loss: 0.5958
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 35.60%
# Target Domain Accuracy: 73.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5263, Domain Loss: 0.5202
# Source Label Accuracy: 82.31%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 37.11%
# Target Domain Accuracy: 72.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4502, Domain Loss: 0.6113
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 37.19%
# Target Domain Accuracy: 70.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5409, Domain Loss: 0.5741
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 37.55%
# Target Domain Accuracy: 70.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4671, Domain Loss: 0.6315
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 37.36%
# Target Domain Accuracy: 70.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5996, Domain Loss: 0.6327
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 37.19%
# Target Domain Accuracy: 70.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5174, Domain Loss: 0.6512
# Source Label Accuracy: 82.39%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 37.73%
# Target Domain Accuracy: 69.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5240, Domain Loss: 0.5617
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 37.86%
# Target Domain Accuracy: 69.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5256, Domain Loss: 0.6462
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 38.12%
# Target Domain Accuracy: 68.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4586, Domain Loss: 0.5566
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 38.52%
# Target Domain Accuracy: 67.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5783, Domain Loss: 0.5081
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.27%
# Source Domain Accuracy: 38.76%
# Target Domain Accuracy: 67.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4809, Domain Loss: 0.6333
# Source Label Accuracy: 82.28%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 39.50%
# Target Domain Accuracy: 67.18%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.83132530120482
# Target (Black): 63.36878555528073
# Overall: 60.122824974411465
#
# False Positive Rate (Test Data)
# Source (White): 9.95191302529793
# Target (Black): 16.007604562737644
# (Black FPR) / (White FPR): 1.6084952231843308
# Overall: 12.100364225010118
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.95652173913044
# Target (Black): 79.24808310660401
# Overall: 83.76663254861822
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.02008032128514
# Target (Black): 67.17783823893149
# Overall: 60.05117707267144
#
# False Positive Rate (Test Data)
# Source (White): 10.181894208655656
# Target (Black): 16.273764258555133
# (Black FPR) / (White FPR): 1.5983041981246242
# Overall: 12.343180898421691
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7064, Domain Loss: 0.4734
# Source Label Accuracy: 56.69%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 28.45%
# Target Domain Accuracy: 93.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5835, Domain Loss: 0.4318
# Source Label Accuracy: 75.93%
# Target Label Accuracy: 77.22%
# Source Domain Accuracy: 24.74%
# Target Domain Accuracy: 93.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4912, Domain Loss: 0.3977
# Source Label Accuracy: 80.03%
# Target Label Accuracy: 78.31%
# Source Domain Accuracy: 23.00%
# Target Domain Accuracy: 93.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.6305, Domain Loss: 0.4341
# Source Label Accuracy: 80.86%
# Target Label Accuracy: 78.48%
# Source Domain Accuracy: 22.96%
# Target Domain Accuracy: 92.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5388, Domain Loss: 0.4942
# Source Label Accuracy: 81.15%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 23.81%
# Target Domain Accuracy: 89.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5203, Domain Loss: 0.4360
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 26.63%
# Target Domain Accuracy: 85.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5487, Domain Loss: 0.4603
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 79.20%
# Source Domain Accuracy: 30.39%
# Target Domain Accuracy: 80.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5737, Domain Loss: 0.5981
# Source Label Accuracy: 82.32%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 33.72%
# Target Domain Accuracy: 76.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4835, Domain Loss: 0.6035
# Source Label Accuracy: 82.22%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 34.44%
# Target Domain Accuracy: 73.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4785, Domain Loss: 0.5545
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 79.15%
# Source Domain Accuracy: 35.13%
# Target Domain Accuracy: 72.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5121, Domain Loss: 0.5581
# Source Label Accuracy: 82.56%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 35.10%
# Target Domain Accuracy: 71.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5607, Domain Loss: 0.5974
# Source Label Accuracy: 82.34%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 35.95%
# Target Domain Accuracy: 71.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5679, Domain Loss: 0.5218
# Source Label Accuracy: 82.25%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 35.93%
# Target Domain Accuracy: 71.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4988, Domain Loss: 0.6069
# Source Label Accuracy: 82.31%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 36.77%
# Target Domain Accuracy: 70.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5092, Domain Loss: 0.5733
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 37.07%
# Target Domain Accuracy: 69.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4977, Domain Loss: 0.6535
# Source Label Accuracy: 81.81%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 36.64%
# Target Domain Accuracy: 69.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.6056, Domain Loss: 0.6375
# Source Label Accuracy: 82.38%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 38.19%
# Target Domain Accuracy: 68.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4895, Domain Loss: 0.6230
# Source Label Accuracy: 82.30%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 38.20%
# Target Domain Accuracy: 67.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5033, Domain Loss: 0.6077
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 38.70%
# Target Domain Accuracy: 66.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5674, Domain Loss: 0.5796
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 39.09%
# Target Domain Accuracy: 65.55%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# ...
# Target (Black): 75.06801879792233
# Overall: 58.32139201637666
#
# False Positive Rate (Test Data)
# Source (White): 9.784653982855948
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.5388417665984206
# Overall: 11.655200323755565
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7672, Domain Loss: 0.5233
# Source Label Accuracy: 57.13%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 33.83%
# Target Domain Accuracy: 91.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5969, Domain Loss: 0.3742
# Source Label Accuracy: 70.25%
# Target Label Accuracy: 75.54%
# Source Domain Accuracy: 29.95%
# Target Domain Accuracy: 93.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5919, Domain Loss: 0.3614
# Source Label Accuracy: 78.73%
# Target Label Accuracy: 77.47%
# Source Domain Accuracy: 26.93%
# Target Domain Accuracy: 94.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.6049, Domain Loss: 0.4239
# Source Label Accuracy: 79.47%
# Target Label Accuracy: 78.06%
# Source Domain Accuracy: 23.83%
# Target Domain Accuracy: 94.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5768, Domain Loss: 0.3938
# Source Label Accuracy: 79.92%
# Target Label Accuracy: 78.38%
# Source Domain Accuracy: 24.23%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5695, Domain Loss: 0.4839
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 78.43%
# Source Domain Accuracy: 23.89%
# Target Domain Accuracy: 92.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5872, Domain Loss: 0.5064
# Source Label Accuracy: 80.67%
# Target Label Accuracy: 78.93%
# Source Domain Accuracy: 24.32%
# Target Domain Accuracy: 90.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4689, Domain Loss: 0.4469
# Source Label Accuracy: 80.69%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 25.45%
# Target Domain Accuracy: 87.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5266, Domain Loss: 0.5659
# Source Label Accuracy: 81.05%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 26.49%
# Target Domain Accuracy: 85.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5718, Domain Loss: 0.4786
# Source Label Accuracy: 81.38%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 27.27%
# Target Domain Accuracy: 84.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5567, Domain Loss: 0.6210
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 79.05%
# Source Domain Accuracy: 27.98%
# Target Domain Accuracy: 83.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5104, Domain Loss: 0.5447
# Source Label Accuracy: 81.41%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 28.90%
# Target Domain Accuracy: 81.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5495, Domain Loss: 0.5126
# Source Label Accuracy: 81.60%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 29.54%
# Target Domain Accuracy: 79.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5330, Domain Loss: 0.5986
# Source Label Accuracy: 81.47%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 30.17%
# Target Domain Accuracy: 77.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4686, Domain Loss: 0.5653
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 79.25%
# Source Domain Accuracy: 31.67%
# Target Domain Accuracy: 76.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5230, Domain Loss: 0.5435
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 32.72%
# Target Domain Accuracy: 75.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4931, Domain Loss: 0.6464
# Source Label Accuracy: 81.24%
# Target Label Accuracy: 79.17%
# Source Domain Accuracy: 34.03%
# Target Domain Accuracy: 73.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5976, Domain Loss: 0.6497
# Source Label Accuracy: 81.47%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 34.34%
# Target Domain Accuracy: 72.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5385, Domain Loss: 0.6006
# Source Label Accuracy: 81.46%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 34.50%
# Target Domain Accuracy: 72.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4851, Domain Loss: 0.6268
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 79.10%
# Source Domain Accuracy: 34.86%
# Target Domain Accuracy: 71.70%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.95652173913044
# Target (Black): 79.14914667326242
# Overall: 83.72569089048106
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.83743670333508
# Target (Black): 65.99060103883255
# Overall: 58.280450358239506
#
# False Positive Rate (Test Data)
# Source (White): 9.701024461634956
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.552107643896683
# Overall: 11.601241062997437
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.93906059018684
# Target (Black): 79.12441256492703
# Overall: 83.70522006141249
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.20551772306618
# Target (Black): 69.47811031412317
# Overall: 57.59467758444217
#
# False Positive Rate (Test Data)
# Source (White): 9.889190884382186
# Target (Black): 15.171102661596958
# (Black FPR) / (White FPR): 1.5341095989517601
# Overall: 11.76311884527182
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 46.4990396368081
# Target (Black): 75.06801879792233
# Overall: 58.32139201637666
#
# False Positive Rate (Test Data)
# Source (White): 9.784653982855948
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.5388417665984206
# Overall: 11.655200323755565
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.90413829229963
# Target (Black): 79.09967845659163
# Overall: 83.67451381780963
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.04836738257377
# Target (Black): 71.70418006430869
# Overall: 58.42374616171955
#
# False Positive Rate (Test Data)
# Source (White): 9.931005644992682
# Target (Black): 15.361216730038024
# (Black FPR) / (White FPR): 1.5467936762057235
# Overall: 11.857547551598543
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.7480, Domain Loss: 0.4495
# Source Label Accuracy: 56.97%
# Target Label Accuracy: 65.05%
# Source Domain Accuracy: 33.83%
# Target Domain Accuracy: 91.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6582, Domain Loss: 0.3571
# Source Label Accuracy: 60.53%
# Target Label Accuracy: 69.63%
# Source Domain Accuracy: 28.09%
# Target Domain Accuracy: 94.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6114, Domain Loss: 0.4246
# Source Label Accuracy: 78.05%
# Target Label Accuracy: 77.64%
# Source Domain Accuracy: 25.33%
# Target Domain Accuracy: 94.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5174, Domain Loss: 0.3314
# Source Label Accuracy: 78.54%
# Target Label Accuracy: 78.21%
# Source Domain Accuracy: 23.31%
# Target Domain Accuracy: 94.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5093, Domain Loss: 0.4735
# Source Label Accuracy: 79.87%
# Target Label Accuracy: 78.56%
# Source Domain Accuracy: 21.81%
# Target Domain Accuracy: 94.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5576, Domain Loss: 0.3528
# Source Label Accuracy: 79.71%
# Target Label Accuracy: 78.70%
# Source Domain Accuracy: 20.92%
# Target Domain Accuracy: 93.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4729, Domain Loss: 0.4823
# Source Label Accuracy: 80.44%
# Target Label Accuracy: 78.93%
# Source Domain Accuracy: 21.10%
# Target Domain Accuracy: 91.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4757, Domain Loss: 0.4054
# Source Label Accuracy: 80.39%
# Target Label Accuracy: 79.07%
# Source Domain Accuracy: 20.94%
# Target Domain Accuracy: 88.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5912, Domain Loss: 0.5014
# Source Label Accuracy: 80.76%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 21.76%
# Target Domain Accuracy: 87.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5150, Domain Loss: 0.5481
# Source Label Accuracy: 81.18%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 23.46%
# Target Domain Accuracy: 83.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4963, Domain Loss: 0.6573
# Source Label Accuracy: 80.71%
# Target Label Accuracy: 79.22%
# Source Domain Accuracy: 29.09%
# Target Domain Accuracy: 78.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5693, Domain Loss: 0.5196
# Source Label Accuracy: 81.15%
# Target Label Accuracy: 79.47%
# Source Domain Accuracy: 32.11%
# Target Domain Accuracy: 74.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4920, Domain Loss: 0.5493
# Source Label Accuracy: 81.29%
# Target Label Accuracy: 79.50%
# Source Domain Accuracy: 34.24%
# Target Domain Accuracy: 71.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5235, Domain Loss: 0.6628
# Source Label Accuracy: 81.51%
# Target Label Accuracy: 79.37%
# Source Domain Accuracy: 35.79%
# Target Domain Accuracy: 70.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5157, Domain Loss: 0.6167
# Source Label Accuracy: 81.20%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 35.59%
# Target Domain Accuracy: 69.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5750, Domain Loss: 0.5341
# Source Label Accuracy: 81.29%
# Target Label Accuracy: 79.45%
# Source Domain Accuracy: 35.88%
# Target Domain Accuracy: 68.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4764, Domain Loss: 0.6645
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 35.90%
# Target Domain Accuracy: 68.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4832, Domain Loss: 0.5297
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 36.35%
# Target Domain Accuracy: 67.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4979, Domain Loss: 0.5153
# Source Label Accuracy: 80.97%
# Target Label Accuracy: 79.12%
# Source Domain Accuracy: 36.72%
# Target Domain Accuracy: 67.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5014, Domain Loss: 0.6243
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 79.30%
# Source Domain Accuracy: 37.23%
# Target Domain Accuracy: 66.34%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.95652173913044
# Target (Black): 79.14914667326242
# Overall: 83.72569089048106
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.83743670333508
# Target (Black): 65.99060103883255
# Overall: 58.280450358239506
#
# False Positive Rate (Test Data)
# Source (White): 9.701024461634956
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.552107643896683
# Overall: 11.601241062997437
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.93906059018684
# Target (Black): 79.12441256492703
# Overall: 83.70522006141249
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.20551772306618
# Target (Black): 69.47811031412317
# Overall: 57.59467758444217
#
# False Positive Rate (Test Data)
# Source (White): 9.889190884382186
# Target (Black): 15.171102661596958
# (Black FPR) / (White FPR): 1.5341095989517601
# Overall: 11.76311884527182
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 46.4990396368081
# Target (Black): 75.06801879792233
# Overall: 58.32139201637666
#
# False Positive Rate (Test Data)
# Source (White): 9.784653982855948
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.5388417665984206
# Overall: 11.655200323755565
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.90413829229963
# Target (Black): 79.09967845659163
# Overall: 83.67451381780963
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.04836738257377
# Target (Black): 71.70418006430869
# Overall: 58.42374616171955
#
# False Positive Rate (Test Data)
# Source (White): 9.931005644992682
# Target (Black): 15.361216730038024
# (Black FPR) / (White FPR): 1.5467936762057235
# Overall: 11.857547551598543
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.14859437751004
# Target (Black): 79.2975513232748
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.38344683080147
# Target (Black): 66.33687855552807
# Overall: 58.15762538382805
#
# False Positive Rate (Test Data)
# Source (White): 9.366506376750992
# Target (Black): 14.714828897338403
# (Black FPR) / (White FPR): 1.5710050583921784
# Overall: 11.26399568325914
#
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.95652173913044
# Target (Black): 79.14914667326242
# Overall: 83.72569089048106
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.83743670333508
# Target (Black): 65.99060103883255
# Overall: 58.280450358239506
#
# False Positive Rate (Test Data)
# Source (White): 9.701024461634956
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.552107643896683
# Overall: 11.601241062997437
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.93906059018684
# Target (Black): 79.12441256492703
# Overall: 83.70522006141249
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.20551772306618
# Target (Black): 69.47811031412317
# Overall: 57.59467758444217
#
# False Positive Rate (Test Data)
# Source (White): 9.889190884382186
# Target (Black): 15.171102661596958
# (Black FPR) / (White FPR): 1.5341095989517601
# Overall: 11.76311884527182
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.99144403701763
# Target (Black): 79.27281721493941
# Overall: 83.79733879222108
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 46.4990396368081
# Target (Black): 75.06801879792233
# Overall: 58.32139201637666
#
# False Positive Rate (Test Data)
# Source (White): 9.784653982855948
# Target (Black): 15.05703422053232
# (Black FPR) / (White FPR): 1.5388417665984206
# Overall: 11.655200323755565
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 86.90413829229963
# Target (Black): 79.09967845659163
# Overall: 83.67451381780963
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 49.04836738257377
# Target (Black): 71.70418006430869
# Overall: 58.42374616171955
#
# False Positive Rate (Test Data)
# Source (White): 9.931005644992682
# Target (Black): 15.361216730038024
# (Black FPR) / (White FPR): 1.5467936762057235
# Overall: 11.857547551598543
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 87.14859437751004
# Target (Black): 79.2975513232748
# Overall: 83.89969293756397
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.38344683080147
# Target (Black): 66.33687855552807
# Overall: 58.15762538382805
#
# False Positive Rate (Test Data)
# Source (White): 9.366506376750992
# Target (Black): 14.714828897338403
# (Black FPR) / (White FPR): 1.5710050583921784
# Overall: 11.26399568325914
