# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init
import pandas as pd
import sklearn.preprocessing as preprocessing

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
# Can adjust NN Sizes
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(85, 64),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(64, 32),
    nn.Sigmoid(),
    nn.Linear(32, 32),
    nn.Sigmoid(),
    nn.Linear(32, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(64, 36),
    nn.Sigmoid(),
    nn.Linear(36, 36), nn.Sigmoid(),              
    nn.Linear(36, 2),
    nn.Sigmoid()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 64) # must be same dimension as output size from init()
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %%
# Adult data code
# Change these to local file if available
train_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
test_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'

features = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"] 


# This will download 3.8M
original_train = pd.read_csv(train_url, names=features, sep=r'\s*,\s*', 
                             engine='python', na_values="?")
# This will download 1.9M
original_test = pd.read_csv(test_url, names=features, sep=r'\s*,\s*', 
                            engine='python', na_values="?", skiprows=1)



num_train = len(original_train)
original = pd.concat([original_train, original_test])
roc_original = original
labels = original['Target']
labels = labels.replace('<=50K', 0).replace('>50K', 1)
labels = labels.replace('<=50K.', 0).replace('>50K.', 1)


# Preprocess
# Redundant column
del original["Education"]
# Remove target variable
del original["Target"]


def data_transform(df):
    """Normalize features."""
    binary_data = pd.get_dummies(df)
    feature_cols = binary_data[binary_data.columns[:-2]]
    scaler = preprocessing.StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(feature_cols), columns=feature_cols.columns)
    return data

data = data_transform(original)

# %%
# Adult code, seperate sensitive and non sensitive
# get array of sensitive characteristics
sensitive = original.Sex.map({'Male': 0, 'Female': 1})
y = np.array(labels).flatten()
print(data.columns)
data = data.drop(['Sex_Male', 'Sex_Female'], axis=1) # Drop sensitive info from data
data_np = np.array(data)
# Out:
# Index(['Age', 'fnlwgt', 'Education-Num', 'Capital Gain', 'Capital Loss',
#        'Hours per week', 'Workclass_Federal-gov', 'Workclass_Local-gov',
#        'Workclass_Never-worked', 'Workclass_Private', 'Workclass_Self-emp-inc',
#        'Workclass_Self-emp-not-inc', 'Workclass_State-gov',
#        'Workclass_Without-pay', 'Martial Status_Divorced',
#        'Martial Status_Married-AF-spouse', 'Martial Status_Married-civ-spouse',
#        'Martial Status_Married-spouse-absent', 'Martial Status_Never-married',
#        'Martial Status_Separated', 'Martial Status_Widowed',
#        'Occupation_Adm-clerical', 'Occupation_Armed-Forces',
#        'Occupation_Craft-repair', 'Occupation_Exec-managerial',
#        'Occupation_Farming-fishing', 'Occupation_Handlers-cleaners',
#        'Occupation_Machine-op-inspct', 'Occupation_Other-service',
#        'Occupation_Priv-house-serv', 'Occupation_Prof-specialty',
#        'Occupation_Protective-serv', 'Occupation_Sales',
#        'Occupation_Tech-support', 'Occupation_Transport-moving',
#        'Relationship_Husband', 'Relationship_Not-in-family',
#        'Relationship_Other-relative', 'Relationship_Own-child',
#        'Relationship_Unmarried', 'Relationship_Wife',
#        'Race_Amer-Indian-Eskimo', 'Race_Asian-Pac-Islander', 'Race_Black',
#        'Race_Other', 'Race_White', 'Sex_Female', 'Sex_Male',
#        'Country_Cambodia', 'Country_Canada', 'Country_China',
#        'Country_Columbia', 'Country_Cuba', 'Country_Dominican-Republic',
#        'Country_Ecuador', 'Country_El-Salvador', 'Country_England',
#        'Country_France', 'Country_Germany', 'Country_Greece',
#        'Country_Guatemala', 'Country_Haiti', 'Country_Holand-Netherlands',
#        'Country_Honduras', 'Country_Hong', 'Country_Hungary', 'Country_India',
#        'Country_Iran', 'Country_Ireland', 'Country_Italy', 'Country_Jamaica',
#        'Country_Japan', 'Country_Laos', 'Country_Mexico', 'Country_Nicaragua',
#        'Country_Outlying-US(Guam-USVI-etc)', 'Country_Peru',
#        'Country_Philippines', 'Country_Poland', 'Country_Portugal',
#        'Country_Puerto-Rico', 'Country_Scotland', 'Country_South',
#        'Country_Taiwan', 'Country_Thailand', 'Country_Trinadad&Tobago',
#        'Country_United-States'],
#       dtype='object')

# %%
# split to source (non-sensitive) and target (sensitive)
sensitive_idx = np.array(np.where(sensitive==1))[0].flatten()
nonsensitive_idx = np.array(np.where(sensitive!=1))[0].flatten()
data_sensitive = data_np[sensitive_idx,:]
data_nonsensitive = data_np[nonsensitive_idx,:]
y_sensitive = y[sensitive_idx]
y_nonsensitive = y[nonsensitive_idx]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

X_tensor_source =  torch.from_numpy(data_nonsensitive).type(torch.float32)
X_tensor_target =  torch.from_numpy(data_sensitive).type(torch.float32)
y_tensor_source =torch.tensor(y_nonsensitive).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_sensitive).type(torch.LongTensor)


# Split the source (white) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (black) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train) # number of black samples
num_positives = sum(target_train[i][1] for i in range(num_samples)) # Number black with positive label
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives]) 


weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size) # remove sampler
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size) # remove sampler
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

print(X_train_source.shape)
print(X_train_target.shape)
# Out:
# positive weight (under represented): 0.0007087172218284905
# negative weight (over represented): 8.664009703690868e-05
# positive weight (under represented): 0.0001257387149503332
# negative weight (over represented): 5.504486156217317e-05
# torch.Size([26120, 85])
# torch.Size([12953, 85])

# %%
combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)
# Weight with respect to sensitive feature itself
y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size) # Removed sensitive characteristic data loader



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples)) # Number of positives for label predictor
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size) # Remove sampler
# Out:
# 12953
# tensor([0, 0, 0,  ..., 1, 1, 1])
# [26120 12953]
# [3.82848392e-05 7.72021925e-05]
# 9364
# 29709
# [3.36598337e-05 1.06791969e-04]

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.00001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 20
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_adult_unweight'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall}
        return results

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5152, Domain Loss: 1.0365
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 65.65%
# Target Domain Accuracy: 82.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4573, Domain Loss: 0.8393
# Source Label Accuracy: 75.72%
# Target Label Accuracy: 90.46%
# Source Domain Accuracy: 64.11%
# Target Domain Accuracy: 84.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4304, Domain Loss: 0.7771
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 63.40%
# Target Domain Accuracy: 88.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4207, Domain Loss: 0.7673
# Source Label Accuracy: 81.08%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 62.37%
# Target Domain Accuracy: 94.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4155, Domain Loss: 0.7769
# Source Label Accuracy: 81.31%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 61.45%
# Target Domain Accuracy: 96.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4122, Domain Loss: 0.7930
# Source Label Accuracy: 81.48%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 60.37%
# Target Domain Accuracy: 97.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4102, Domain Loss: 0.8107
# Source Label Accuracy: 81.57%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.48%
# Target Domain Accuracy: 98.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4089, Domain Loss: 0.8281
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 58.82%
# Target Domain Accuracy: 98.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4079, Domain Loss: 0.8453
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.46%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4072, Domain Loss: 0.8635
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 58.28%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4067, Domain Loss: 0.8842
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.15%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4063, Domain Loss: 0.9013
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 58.03%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4059, Domain Loss: 0.9136
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 58.00%
# Target Domain Accuracy: 98.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4056, Domain Loss: 0.9215
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 57.92%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4054, Domain Loss: 0.9253
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 57.84%
# Target Domain Accuracy: 98.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4051, Domain Loss: 0.9274
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 57.68%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4049, Domain Loss: 0.9297
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 57.55%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4047, Domain Loss: 0.9336
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 57.40%
# Target Domain Accuracy: 97.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4046, Domain Loss: 0.9376
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 57.17%
# Target Domain Accuracy: 98.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4045, Domain Loss: 0.9414
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 56.94%
# Target Domain Accuracy: 98.15%
#
# Lambda: 0.0
#
# Label Classifier Accuracy (Test Data)
# Source (White): 80.94946401225116
# Target (Black): 93.17690645260883
# Overall: 85.00358276179752
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.10566615620215
# Target (Black): 98.14757641247299
# Overall: 70.71348142082097
#
# False Positive Rate (Test Data)
# Source (White): 11.303395399780943
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1566094621538064
# Overall: 7.614826752618856
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5097, Domain Loss: 0.9297
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.73%
# Target Domain Accuracy: 87.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4579, Domain Loss: 0.8207
# Source Label Accuracy: 71.96%
# Target Label Accuracy: 89.29%
# Source Domain Accuracy: 60.77%
# Target Domain Accuracy: 96.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4350, Domain Loss: 0.7780
# Source Label Accuracy: 80.63%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 58.84%
# Target Domain Accuracy: 97.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4230, Domain Loss: 0.7758
# Source Label Accuracy: 81.05%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 57.68%
# Target Domain Accuracy: 97.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4166, Domain Loss: 0.7910
# Source Label Accuracy: 81.31%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 57.15%
# Target Domain Accuracy: 97.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4129, Domain Loss: 0.8106
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 56.98%
# Target Domain Accuracy: 97.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4107, Domain Loss: 0.8275
# Source Label Accuracy: 81.57%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 56.98%
# Target Domain Accuracy: 97.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4091, Domain Loss: 0.8437
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 57.21%
# Target Domain Accuracy: 97.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4079, Domain Loss: 0.8593
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 57.63%
# Target Domain Accuracy: 96.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4070, Domain Loss: 0.8738
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.14%
# Target Domain Accuracy: 96.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4062, Domain Loss: 0.8906
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 58.75%
# Target Domain Accuracy: 95.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4056, Domain Loss: 0.9063
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 59.39%
# Target Domain Accuracy: 93.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4051, Domain Loss: 0.9210
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 59.84%
# Target Domain Accuracy: 92.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4046, Domain Loss: 0.9331
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 60.13%
# Target Domain Accuracy: 90.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4042, Domain Loss: 0.9416
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.30%
# Target Domain Accuracy: 88.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4038, Domain Loss: 0.9450
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.46%
# Target Domain Accuracy: 87.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4034, Domain Loss: 0.9456
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.62%
# Target Domain Accuracy: 86.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4031, Domain Loss: 0.9464
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.73%
# Target Domain Accuracy: 85.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4027, Domain Loss: 0.9464
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.79%
# Target Domain Accuracy: 85.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4024, Domain Loss: 0.9460
# Source Label Accuracy: 82.20%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.84%
# Target Domain Accuracy: 85.12%
#
# Lambda: 0.1
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.11515899969126
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.19448698315467
# Target (Black): 85.11886384686632
# Overall: 69.1268297676323
#
# False Positive Rate (Test Data)
# Source (White): 11.171960569550931
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.15845192641443942
# Overall: 7.534246575342466
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5052, Domain Loss: 0.7980
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 62.78%
# Target Domain Accuracy: 87.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4539, Domain Loss: 0.7013
# Source Label Accuracy: 79.65%
# Target Label Accuracy: 91.26%
# Source Domain Accuracy: 62.13%
# Target Domain Accuracy: 95.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4313, Domain Loss: 0.6736
# Source Label Accuracy: 80.54%
# Target Label Accuracy: 92.00%
# Source Domain Accuracy: 57.98%
# Target Domain Accuracy: 96.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4209, Domain Loss: 0.6742
# Source Label Accuracy: 81.04%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 55.02%
# Target Domain Accuracy: 96.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4147, Domain Loss: 0.6938
# Source Label Accuracy: 81.38%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 55.42%
# Target Domain Accuracy: 95.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4108, Domain Loss: 0.7316
# Source Label Accuracy: 81.49%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 58.83%
# Target Domain Accuracy: 91.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4084, Domain Loss: 0.7716
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 61.18%
# Target Domain Accuracy: 85.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4066, Domain Loss: 0.8024
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 61.75%
# Target Domain Accuracy: 83.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4053, Domain Loss: 0.8244
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 61.95%
# Target Domain Accuracy: 82.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4042, Domain Loss: 0.8412
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.97%
# Target Domain Accuracy: 82.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4034, Domain Loss: 0.8555
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 61.94%
# Target Domain Accuracy: 81.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4026, Domain Loss: 0.8682
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.86%
# Target Domain Accuracy: 81.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4019, Domain Loss: 0.8798
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.71%
# Target Domain Accuracy: 81.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4012, Domain Loss: 0.8891
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.50%
# Target Domain Accuracy: 80.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4005, Domain Loss: 0.8971
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.31%
# Target Domain Accuracy: 80.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3999, Domain Loss: 0.9037
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.14%
# Target Domain Accuracy: 80.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3992, Domain Loss: 0.9091
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.06%
# Target Domain Accuracy: 80.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3986, Domain Loss: 0.9129
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.93%
# Target Domain Accuracy: 80.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3980, Domain Loss: 0.9162
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.85%
# Target Domain Accuracy: 80.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3970, Domain Loss: 0.9185
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.76%
# Target Domain Accuracy: 80.40%
#
# Lambda: 0.2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 80.94946401225116
# Target (Black): 93.14603272615004
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.37825421133231
# Target (Black): 80.39518369867243
# Overall: 67.68348858634457
#
# False Positive Rate (Test Data)
# Source (White): 11.215772179627601
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.15783297357688303
# Overall: 7.561106634434596
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5115, Domain Loss: 0.8761
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.68%
# Target Domain Accuracy: 81.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4559, Domain Loss: 0.7593
# Source Label Accuracy: 79.04%
# Target Label Accuracy: 91.14%
# Source Domain Accuracy: 62.17%
# Target Domain Accuracy: 85.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4285, Domain Loss: 0.7228
# Source Label Accuracy: 80.71%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 61.53%
# Target Domain Accuracy: 85.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4193, Domain Loss: 0.7480
# Source Label Accuracy: 81.15%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 61.61%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4144, Domain Loss: 0.7934
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 62.02%
# Target Domain Accuracy: 83.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4114, Domain Loss: 0.8313
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.46%
# Target Domain Accuracy: 82.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4095, Domain Loss: 0.8536
# Source Label Accuracy: 81.57%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 62.70%
# Target Domain Accuracy: 81.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4081, Domain Loss: 0.8651
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.82%
# Target Domain Accuracy: 81.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4070, Domain Loss: 0.8721
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 62.81%
# Target Domain Accuracy: 81.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4061, Domain Loss: 0.8778
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 62.78%
# Target Domain Accuracy: 80.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4055, Domain Loss: 0.8798
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 62.67%
# Target Domain Accuracy: 80.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4048, Domain Loss: 0.8746
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.40%
# Target Domain Accuracy: 81.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4042, Domain Loss: 0.8639
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.05%
# Target Domain Accuracy: 81.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4037, Domain Loss: 0.8530
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.78%
# Target Domain Accuracy: 82.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4031, Domain Loss: 0.8445
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.50%
# Target Domain Accuracy: 82.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4027, Domain Loss: 0.8383
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.25%
# Target Domain Accuracy: 82.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4023, Domain Loss: 0.8339
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.03%
# Target Domain Accuracy: 82.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4020, Domain Loss: 0.8309
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.79%
# Target Domain Accuracy: 82.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4016, Domain Loss: 0.8294
# Source Label Accuracy: 82.19%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.58%
# Target Domain Accuracy: 82.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4013, Domain Loss: 0.8292
# Source Label Accuracy: 82.23%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.43%
# Target Domain Accuracy: 82.49%
#
# Lambda: 0.30000000000000004
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.11791730474732
# Target (Black): 93.08428527323248
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.85758039816233
# Target (Black): 82.49459709786971
# Overall: 68.0315283038182
#
# False Positive Rate (Test Data)
# Source (White): 10.99671412924425
# Target (Black): 1.8396390142311698
# (Black FPR) / (White FPR): 0.16728988246942808
# Overall: 7.453666398066075
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5103, Domain Loss: 0.7679
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 59.96%
# Target Domain Accuracy: 86.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4617, Domain Loss: 0.7271
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 59.73%
# Target Domain Accuracy: 89.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4335, Domain Loss: 0.7676
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 60.96%
# Target Domain Accuracy: 85.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4217, Domain Loss: 0.8245
# Source Label Accuracy: 81.07%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 62.05%
# Target Domain Accuracy: 82.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4155, Domain Loss: 0.8455
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 62.83%
# Target Domain Accuracy: 80.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4120, Domain Loss: 0.8502
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 63.16%
# Target Domain Accuracy: 79.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4098, Domain Loss: 0.8463
# Source Label Accuracy: 81.54%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 63.23%
# Target Domain Accuracy: 79.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4085, Domain Loss: 0.8425
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 63.24%
# Target Domain Accuracy: 79.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4075, Domain Loss: 0.8410
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 63.16%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4068, Domain Loss: 0.8404
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 63.10%
# Target Domain Accuracy: 79.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4062, Domain Loss: 0.8398
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 63.03%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4058, Domain Loss: 0.8385
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.97%
# Target Domain Accuracy: 79.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4055, Domain Loss: 0.8366
# Source Label Accuracy: 81.81%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 79.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4050, Domain Loss: 0.8338
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.63%
# Target Domain Accuracy: 79.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4046, Domain Loss: 0.8301
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.43%
# Target Domain Accuracy: 80.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4043, Domain Loss: 0.8265
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 62.22%
# Target Domain Accuracy: 80.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4039, Domain Loss: 0.8228
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.00%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4036, Domain Loss: 0.8194
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.79%
# Target Domain Accuracy: 80.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4033, Domain Loss: 0.8164
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.62%
# Target Domain Accuracy: 80.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4030, Domain Loss: 0.8139
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.48%
# Target Domain Accuracy: 80.83%
#
# Lambda: 0.4
#
# Label Classifier Accuracy (Test Data)
# Source (White): 80.9800918836141
# Target (Black): 93.0534115467737
# Overall: 84.98310983724025
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.669218989280246
# Target (Black): 80.8274158690954
# Overall: 68.02129184153956
#
# False Positive Rate (Test Data)
# Source (White): 10.99671412924425
# Target (Black): 1.8049288441513363
# (Black FPR) / (White FPR): 0.1641334695926464
# Overall: 7.440236368520011
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5206, Domain Loss: 0.7830
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 65.13%
# Target Domain Accuracy: 77.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4874, Domain Loss: 0.7578
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 65.22%
# Target Domain Accuracy: 76.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4544, Domain Loss: 0.7766
# Source Label Accuracy: 76.73%
# Target Label Accuracy: 90.58%
# Source Domain Accuracy: 65.03%
# Target Domain Accuracy: 76.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4334, Domain Loss: 0.8013
# Source Label Accuracy: 80.75%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 64.48%
# Target Domain Accuracy: 76.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4228, Domain Loss: 0.8039
# Source Label Accuracy: 81.03%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 64.01%
# Target Domain Accuracy: 77.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4169, Domain Loss: 0.8001
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 63.77%
# Target Domain Accuracy: 77.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4134, Domain Loss: 0.7940
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 63.55%
# Target Domain Accuracy: 77.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4113, Domain Loss: 0.7891
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 63.30%
# Target Domain Accuracy: 78.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4098, Domain Loss: 0.7853
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 63.17%
# Target Domain Accuracy: 78.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4087, Domain Loss: 0.7836
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 63.08%
# Target Domain Accuracy: 78.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4079, Domain Loss: 0.7830
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 63.03%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4073, Domain Loss: 0.7823
# Source Label Accuracy: 81.67%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.95%
# Target Domain Accuracy: 78.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4067, Domain Loss: 0.7817
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.86%
# Target Domain Accuracy: 79.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4063, Domain Loss: 0.7813
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.78%
# Target Domain Accuracy: 79.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4059, Domain Loss: 0.7810
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.73%
# Target Domain Accuracy: 79.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4055, Domain Loss: 0.7802
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.66%
# Target Domain Accuracy: 79.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4052, Domain Loss: 0.7786
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.60%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4049, Domain Loss: 0.7770
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.50%
# Target Domain Accuracy: 79.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4046, Domain Loss: 0.7758
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.40%
# Target Domain Accuracy: 79.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4043, Domain Loss: 0.7752
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 62.31%
# Target Domain Accuracy: 79.78%
#
# Lambda: 0.5
#
# Label Classifier Accuracy (Test Data)
# Source (White): 80.84226646248086
# Target (Black): 93.0534115467737
# Overall: 84.89098167673252
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.45022970903522
# Target (Black): 79.77770916949676
# Overall: 68.19531170027638
#
# False Positive Rate (Test Data)
# Source (White): 10.909090909090908
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.1590882795325697
# Overall: 7.359656191243621
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5135, Domain Loss: 0.6903
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 61.88%
# Target Domain Accuracy: 82.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4570, Domain Loss: 0.6235
# Source Label Accuracy: 78.70%
# Target Label Accuracy: 91.05%
# Source Domain Accuracy: 60.94%
# Target Domain Accuracy: 83.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4289, Domain Loss: 0.6640
# Source Label Accuracy: 80.61%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 80.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4185, Domain Loss: 0.7059
# Source Label Accuracy: 81.10%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 62.94%
# Target Domain Accuracy: 79.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4131, Domain Loss: 0.7349
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 63.41%
# Target Domain Accuracy: 78.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4099, Domain Loss: 0.7510
# Source Label Accuracy: 81.50%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 63.47%
# Target Domain Accuracy: 77.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4078, Domain Loss: 0.7582
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 63.44%
# Target Domain Accuracy: 77.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4064, Domain Loss: 0.7627
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 63.39%
# Target Domain Accuracy: 77.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4053, Domain Loss: 0.7661
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 63.38%
# Target Domain Accuracy: 76.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4045, Domain Loss: 0.7685
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 63.37%
# Target Domain Accuracy: 76.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4038, Domain Loss: 0.7693
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 63.34%
# Target Domain Accuracy: 77.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4031, Domain Loss: 0.7694
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 63.23%
# Target Domain Accuracy: 77.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4025, Domain Loss: 0.7683
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 63.08%
# Target Domain Accuracy: 77.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4019, Domain Loss: 0.7669
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.90%
# Target Domain Accuracy: 78.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4012, Domain Loss: 0.7650
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.73%
# Target Domain Accuracy: 78.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4007, Domain Loss: 0.7630
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 62.52%
# Target Domain Accuracy: 78.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4001, Domain Loss: 0.7611
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 62.31%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3995, Domain Loss: 0.7591
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 62.08%
# Target Domain Accuracy: 79.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3990, Domain Loss: 0.7570
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 61.85%
# Target Domain Accuracy: 79.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3985, Domain Loss: 0.7551
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 61.65%
# Target Domain Accuracy: 79.13%
#
# Lambda: 0.6000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.08728943338438
# Target (Black): 93.17690645260883
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.00612557427259
# Target (Black): 79.1293609138623
# Overall: 67.68348858634457
#
# False Positive Rate (Test Data)
# Source (White): 10.558598028477547
# Target (Black): 1.8743491843110032
# (Black FPR) / (White FPR): 0.17751875573401926
# Overall: 7.1984958366908405
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5161, Domain Loss: 0.6814
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.04%
# Target Domain Accuracy: 80.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4743, Domain Loss: 0.6660
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 81.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4395, Domain Loss: 0.6786
# Source Label Accuracy: 80.41%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 62.55%
# Target Domain Accuracy: 81.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4243, Domain Loss: 0.7033
# Source Label Accuracy: 80.88%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 62.83%
# Target Domain Accuracy: 79.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4167, Domain Loss: 0.7191
# Source Label Accuracy: 81.19%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 63.06%
# Target Domain Accuracy: 78.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4126, Domain Loss: 0.7227
# Source Label Accuracy: 81.38%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 63.01%
# Target Domain Accuracy: 78.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4100, Domain Loss: 0.7238
# Source Label Accuracy: 81.49%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 63.00%
# Target Domain Accuracy: 78.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4084, Domain Loss: 0.7243
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 62.91%
# Target Domain Accuracy: 79.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4072, Domain Loss: 0.7245
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.83%
# Target Domain Accuracy: 79.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4064, Domain Loss: 0.7252
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.73%
# Target Domain Accuracy: 79.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4058, Domain Loss: 0.7253
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.66%
# Target Domain Accuracy: 79.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4052, Domain Loss: 0.7245
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.62%
# Target Domain Accuracy: 79.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4047, Domain Loss: 0.7228
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.55%
# Target Domain Accuracy: 80.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4043, Domain Loss: 0.7210
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.44%
# Target Domain Accuracy: 80.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4040, Domain Loss: 0.7189
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 62.38%
# Target Domain Accuracy: 80.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4037, Domain Loss: 0.7164
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.29%
# Target Domain Accuracy: 81.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4034, Domain Loss: 0.7133
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 62.19%
# Target Domain Accuracy: 81.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4031, Domain Loss: 0.7104
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.10%
# Target Domain Accuracy: 81.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4028, Domain Loss: 0.7078
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.98%
# Target Domain Accuracy: 81.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4026, Domain Loss: 0.7049
# Source Label Accuracy: 81.97%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.86%
# Target Domain Accuracy: 81.60%
#
# Lambda: 0.7000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.0534115467737
# Overall: 84.97287337496161
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.97549770290965
# Target (Black): 81.599259030565
# Overall: 68.48193264407821
#
# False Positive Rate (Test Data)
# Source (White): 10.711938663745892
# Target (Black): 1.8396390142311698
# (Black FPR) / (White FPR): 0.1717372617579814
# Overall: 7.279076013967231
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5155, Domain Loss: 0.6897
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.75%
# Target Domain Accuracy: 79.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4678, Domain Loss: 0.6789
# Source Label Accuracy: 70.12%
# Target Label Accuracy: 88.98%
# Source Domain Accuracy: 63.20%
# Target Domain Accuracy: 79.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4365, Domain Loss: 0.6989
# Source Label Accuracy: 80.48%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 63.34%
# Target Domain Accuracy: 78.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4237, Domain Loss: 0.7166
# Source Label Accuracy: 80.94%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 63.51%
# Target Domain Accuracy: 77.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4170, Domain Loss: 0.7232
# Source Label Accuracy: 81.21%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 63.40%
# Target Domain Accuracy: 77.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4130, Domain Loss: 0.7258
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 63.29%
# Target Domain Accuracy: 77.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4104, Domain Loss: 0.7282
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 63.23%
# Target Domain Accuracy: 77.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4087, Domain Loss: 0.7300
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 63.20%
# Target Domain Accuracy: 77.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4075, Domain Loss: 0.7306
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 63.12%
# Target Domain Accuracy: 77.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4066, Domain Loss: 0.7314
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 63.02%
# Target Domain Accuracy: 77.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4059, Domain Loss: 0.7318
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.92%
# Target Domain Accuracy: 77.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4052, Domain Loss: 0.7311
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 62.83%
# Target Domain Accuracy: 78.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4046, Domain Loss: 0.7290
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 62.66%
# Target Domain Accuracy: 78.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4040, Domain Loss: 0.7254
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 62.54%
# Target Domain Accuracy: 79.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4035, Domain Loss: 0.7213
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 62.39%
# Target Domain Accuracy: 79.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4030, Domain Loss: 0.7170
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 62.24%
# Target Domain Accuracy: 80.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4025, Domain Loss: 0.7137
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 62.07%
# Target Domain Accuracy: 80.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4020, Domain Loss: 0.7111
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.94%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4015, Domain Loss: 0.7089
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 61.82%
# Target Domain Accuracy: 80.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4011, Domain Loss: 0.7067
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.70%
# Target Domain Accuracy: 80.98%
#
# Lambda: 0.8
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.01071975497703
# Target (Black): 93.08428527323248
# Overall: 85.01381922407616
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.96018376722818
# Target (Black): 80.98178450138931
# Overall: 68.26696693622684
#
# False Positive Rate (Test Data)
# Source (White): 10.53669222343921
# Target (Black): 1.8049288441513363
# (Black FPR) / (White FPR): 0.1712993799075021
# Overall: 7.158205748052645
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5163, Domain Loss: 0.6505
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.73%
# Target Domain Accuracy: 76.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4666, Domain Loss: 0.5812
# Source Label Accuracy: 70.28%
# Target Label Accuracy: 88.98%
# Source Domain Accuracy: 61.65%
# Target Domain Accuracy: 80.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4317, Domain Loss: 0.5857
# Source Label Accuracy: 80.46%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 60.65%
# Target Domain Accuracy: 79.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4196, Domain Loss: 0.6446
# Source Label Accuracy: 80.91%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 75.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4135, Domain Loss: 0.6733
# Source Label Accuracy: 81.24%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 62.83%
# Target Domain Accuracy: 74.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4098, Domain Loss: 0.6818
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 62.56%
# Target Domain Accuracy: 76.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4076, Domain Loss: 0.6789
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 77.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4061, Domain Loss: 0.6731
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 61.84%
# Target Domain Accuracy: 78.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4050, Domain Loss: 0.6652
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 61.51%
# Target Domain Accuracy: 80.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4041, Domain Loss: 0.6614
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.26%
# Target Domain Accuracy: 81.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4033, Domain Loss: 0.6569
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 61.09%
# Target Domain Accuracy: 81.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4025, Domain Loss: 0.6564
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.04%
# Target Domain Accuracy: 81.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4018, Domain Loss: 0.6533
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 60.93%
# Target Domain Accuracy: 82.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4012, Domain Loss: 0.6530
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 60.89%
# Target Domain Accuracy: 82.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4006, Domain Loss: 0.6511
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 60.77%
# Target Domain Accuracy: 82.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4000, Domain Loss: 0.6520
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.76%
# Target Domain Accuracy: 82.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3995, Domain Loss: 0.6513
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.64%
# Target Domain Accuracy: 82.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3991, Domain Loss: 0.6521
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.62%
# Target Domain Accuracy: 82.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3987, Domain Loss: 0.6515
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.50%
# Target Domain Accuracy: 82.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3983, Domain Loss: 0.6532
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.49%
# Target Domain Accuracy: 82.34%
#
# Lambda: 0.9
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.01071975497703
# Target (Black): 93.11515899969126
# Overall: 85.0240556863548
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.658499234303214
# Target (Black): 82.34022846557579
# Overall: 67.84727198280274
#
# False Positive Rate (Test Data)
# Source (White): 10.470974808324206
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.18894894990843195
# Overall: 7.185065807144776

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results_conf_Adult_unweighted'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(5):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5075, Domain Loss: 0.9153
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.91%
# Target Domain Accuracy: 85.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4564, Domain Loss: 0.7826
# Source Label Accuracy: 78.91%
# Target Label Accuracy: 91.23%
# Source Domain Accuracy: 64.15%
# Target Domain Accuracy: 96.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4340, Domain Loss: 0.7134
# Source Label Accuracy: 80.55%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 61.99%
# Target Domain Accuracy: 97.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4240, Domain Loss: 0.6899
# Source Label Accuracy: 81.05%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 60.03%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4182, Domain Loss: 0.6839
# Source Label Accuracy: 81.35%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 59.08%
# Target Domain Accuracy: 98.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4147, Domain Loss: 0.6853
# Source Label Accuracy: 81.41%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 58.52%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4126, Domain Loss: 0.6946
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 57.81%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4112, Domain Loss: 0.7105
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 57.26%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4103, Domain Loss: 0.7313
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 56.77%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4096, Domain Loss: 0.7540
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 56.52%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4090, Domain Loss: 0.7788
# Source Label Accuracy: 81.81%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 56.41%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4086, Domain Loss: 0.8045
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 56.18%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4082, Domain Loss: 0.8268
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 56.06%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4079, Domain Loss: 0.8465
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 55.97%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4076, Domain Loss: 0.8656
# Source Label Accuracy: 81.93%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 55.93%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4073, Domain Loss: 0.8808
# Source Label Accuracy: 81.97%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 55.90%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4070, Domain Loss: 0.8933
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 55.86%
# Target Domain Accuracy: 98.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4067, Domain Loss: 0.9031
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 55.83%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4065, Domain Loss: 0.9105
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 55.80%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4063, Domain Loss: 0.9164
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 55.82%
# Target Domain Accuracy: 98.36%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5131, Domain Loss: 0.8824
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.12%
# Target Domain Accuracy: 91.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4567, Domain Loss: 0.7443
# Source Label Accuracy: 79.85%
# Target Label Accuracy: 91.26%
# Source Domain Accuracy: 62.90%
# Target Domain Accuracy: 97.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4330, Domain Loss: 0.7312
# Source Label Accuracy: 80.61%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 61.92%
# Target Domain Accuracy: 98.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4232, Domain Loss: 0.7458
# Source Label Accuracy: 81.03%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 60.95%
# Target Domain Accuracy: 98.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4174, Domain Loss: 0.7655
# Source Label Accuracy: 81.34%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 60.25%
# Target Domain Accuracy: 98.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4137, Domain Loss: 0.7801
# Source Label Accuracy: 81.47%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 59.68%
# Target Domain Accuracy: 98.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4113, Domain Loss: 0.7899
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.06%
# Target Domain Accuracy: 98.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4097, Domain Loss: 0.8006
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.59%
# Target Domain Accuracy: 98.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4084, Domain Loss: 0.8119
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.18%
# Target Domain Accuracy: 98.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4075, Domain Loss: 0.8185
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 57.75%
# Target Domain Accuracy: 98.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4068, Domain Loss: 0.8201
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 57.45%
# Target Domain Accuracy: 98.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4062, Domain Loss: 0.8228
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 57.17%
# Target Domain Accuracy: 98.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4057, Domain Loss: 0.8252
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 57.01%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4051, Domain Loss: 0.8283
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 56.84%
# Target Domain Accuracy: 98.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4045, Domain Loss: 0.8330
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 56.71%
# Target Domain Accuracy: 98.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4040, Domain Loss: 0.8382
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 56.63%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4034, Domain Loss: 0.8442
# Source Label Accuracy: 82.08%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 56.55%
# Target Domain Accuracy: 98.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4029, Domain Loss: 0.8491
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 56.51%
# Target Domain Accuracy: 98.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4025, Domain Loss: 0.8548
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 56.43%
# Target Domain Accuracy: 98.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4021, Domain Loss: 0.8591
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 56.37%
# Target Domain Accuracy: 98.43%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.07197549770291
# Target (Black): 93.11515899969126
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.70750382848392
# Target (Black): 98.42543995060204
# Overall: 70.53946156208414
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5342, Domain Loss: 1.0357
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 65.42%
# Target Domain Accuracy: 84.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4792, Domain Loss: 0.8220
# Source Label Accuracy: 71.59%
# Target Label Accuracy: 89.07%
# Source Domain Accuracy: 65.24%
# Target Domain Accuracy: 84.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4372, Domain Loss: 0.6661
# Source Label Accuracy: 80.39%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 64.66%
# Target Domain Accuracy: 87.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4252, Domain Loss: 0.6018
# Source Label Accuracy: 80.95%
# Target Label Accuracy: 92.37%
# Source Domain Accuracy: 63.28%
# Target Domain Accuracy: 88.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4194, Domain Loss: 0.5748
# Source Label Accuracy: 81.29%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 62.19%
# Target Domain Accuracy: 90.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4157, Domain Loss: 0.5675
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 61.53%
# Target Domain Accuracy: 91.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4131, Domain Loss: 0.5702
# Source Label Accuracy: 81.60%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.04%
# Target Domain Accuracy: 91.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4114, Domain Loss: 0.5795
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 60.77%
# Target Domain Accuracy: 91.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4101, Domain Loss: 0.5967
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 60.62%
# Target Domain Accuracy: 91.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4092, Domain Loss: 0.6172
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.61%
# Target Domain Accuracy: 91.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4085, Domain Loss: 0.6400
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.55%
# Target Domain Accuracy: 91.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4079, Domain Loss: 0.6616
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.46%
# Target Domain Accuracy: 91.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4073, Domain Loss: 0.6822
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.38%
# Target Domain Accuracy: 91.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4069, Domain Loss: 0.7013
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.34%
# Target Domain Accuracy: 90.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4065, Domain Loss: 0.7182
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.31%
# Target Domain Accuracy: 90.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4062, Domain Loss: 0.7346
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.31%
# Target Domain Accuracy: 90.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4058, Domain Loss: 0.7485
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.30%
# Target Domain Accuracy: 90.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4055, Domain Loss: 0.7626
# Source Label Accuracy: 82.17%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.28%
# Target Domain Accuracy: 90.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4053, Domain Loss: 0.7759
# Source Label Accuracy: 82.18%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.28%
# Target Domain Accuracy: 90.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4050, Domain Loss: 0.7885
# Source Label Accuracy: 82.21%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.27%
# Target Domain Accuracy: 90.40%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.07197549770291
# Target (Black): 93.11515899969126
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.70750382848392
# Target (Black): 98.42543995060204
# Overall: 70.53946156208414
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.17690645260883
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.61255742725881
# Target (Black): 90.3982710713183
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.193866374589266
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.155041023888884
# Overall: 7.534246575342466
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5180, Domain Loss: 1.0373
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.99%
# Target Domain Accuracy: 79.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4640, Domain Loss: 0.9249
# Source Label Accuracy: 73.43%
# Target Label Accuracy: 89.63%
# Source Domain Accuracy: 63.22%
# Target Domain Accuracy: 84.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4340, Domain Loss: 0.8644
# Source Label Accuracy: 80.45%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 61.96%
# Target Domain Accuracy: 96.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4217, Domain Loss: 0.8456
# Source Label Accuracy: 80.92%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 60.49%
# Target Domain Accuracy: 98.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4154, Domain Loss: 0.8405
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 59.61%
# Target Domain Accuracy: 98.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4116, Domain Loss: 0.8454
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.15%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4090, Domain Loss: 0.8573
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.89%
# Target Domain Accuracy: 98.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4072, Domain Loss: 0.8732
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 58.66%
# Target Domain Accuracy: 98.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4058, Domain Loss: 0.8865
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.40%
# Target Domain Accuracy: 98.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4048, Domain Loss: 0.8928
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.18%
# Target Domain Accuracy: 98.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4040, Domain Loss: 0.8980
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 58.00%
# Target Domain Accuracy: 98.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4032, Domain Loss: 0.9039
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 57.89%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4027, Domain Loss: 0.9104
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 57.91%
# Target Domain Accuracy: 98.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4021, Domain Loss: 0.9186
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 57.91%
# Target Domain Accuracy: 98.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4016, Domain Loss: 0.9274
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 57.92%
# Target Domain Accuracy: 98.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4011, Domain Loss: 0.9366
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 58.00%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4008, Domain Loss: 0.9436
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 58.09%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4005, Domain Loss: 0.9484
# Source Label Accuracy: 82.07%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 58.19%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4001, Domain Loss: 0.9525
# Source Label Accuracy: 82.11%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.22%
# Target Domain Accuracy: 98.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3996, Domain Loss: 0.9545
# Source Label Accuracy: 82.14%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 58.32%
# Target Domain Accuracy: 98.30%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.07197549770291
# Target (Black): 93.11515899969126
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.70750382848392
# Target (Black): 98.42543995060204
# Overall: 70.53946156208414
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.17690645260883
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.61255742725881
# Target (Black): 90.3982710713183
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.193866374589266
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.155041023888884
# Overall: 7.534246575342466
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.93415007656968
# Target (Black): 93.11515899969126
# Overall: 84.97287337496161
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.62174578866769
# Target (Black): 98.30194504476691
# Overall: 71.77807349779916
#
# False Positive Rate (Test Data)
# Source (White): 11.281489594742606
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.1538368217615917
# Overall: 7.587966693526726
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5114, Domain Loss: 1.0347
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.91%
# Target Domain Accuracy: 80.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4528, Domain Loss: 0.9501
# Source Label Accuracy: 77.44%
# Target Label Accuracy: 90.77%
# Source Domain Accuracy: 60.77%
# Target Domain Accuracy: 92.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4295, Domain Loss: 0.8850
# Source Label Accuracy: 80.52%
# Target Label Accuracy: 92.28%
# Source Domain Accuracy: 60.05%
# Target Domain Accuracy: 98.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4210, Domain Loss: 0.8669
# Source Label Accuracy: 81.07%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 59.63%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4157, Domain Loss: 0.8697
# Source Label Accuracy: 81.35%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 59.26%
# Target Domain Accuracy: 98.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4123, Domain Loss: 0.8791
# Source Label Accuracy: 81.48%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 59.04%
# Target Domain Accuracy: 98.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4100, Domain Loss: 0.8871
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 58.88%
# Target Domain Accuracy: 98.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4084, Domain Loss: 0.8957
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.80%
# Target Domain Accuracy: 98.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4073, Domain Loss: 0.9062
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.79%
# Target Domain Accuracy: 98.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4064, Domain Loss: 0.9145
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 58.80%
# Target Domain Accuracy: 98.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4058, Domain Loss: 0.9209
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 58.76%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4053, Domain Loss: 0.9261
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.69%
# Target Domain Accuracy: 98.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4048, Domain Loss: 0.9308
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 58.68%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4045, Domain Loss: 0.9366
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 58.69%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4042, Domain Loss: 0.9404
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.69%
# Target Domain Accuracy: 98.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4040, Domain Loss: 0.9445
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.54%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4037, Domain Loss: 0.9491
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.48%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4035, Domain Loss: 0.9522
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.42%
# Target Domain Accuracy: 98.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4033, Domain Loss: 0.9557
# Source Label Accuracy: 82.15%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 58.34%
# Target Domain Accuracy: 98.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4032, Domain Loss: 0.9587
# Source Label Accuracy: 82.18%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 58.32%
# Target Domain Accuracy: 98.58%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.07197549770291
# Target (Black): 93.11515899969126
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.70750382848392
# Target (Black): 98.42543995060204
# Overall: 70.53946156208414
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.17690645260883
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.61255742725881
# Target (Black): 90.3982710713183
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.193866374589266
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.155041023888884
# Overall: 7.534246575342466
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.93415007656968
# Target (Black): 93.11515899969126
# Overall: 84.97287337496161
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.62174578866769
# Target (Black): 98.30194504476691
# Overall: 71.77807349779916
#
# False Positive Rate (Test Data)
# Source (White): 11.281489594742606
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.1538368217615917
# Overall: 7.587966693526726
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.20778017906761
# Overall: 85.11618384686253
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.65237366003063
# Target (Black): 98.57980858289595
# Overall: 71.89067458286416
#
# False Positive Rate (Test Data)
# Source (White): 11.106243154435926
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.15626422723317496
# Overall: 7.480526457158206
#
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.96477794793262
# Target (Black): 93.11515899969126
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 55.91117917304747
# Target (Black): 98.36369249768447
# Overall: 69.98669259903777
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.6660881638320029
# (Black FPR) / (White FPR): 0.14825911243456322
# Overall: 7.534246575342466
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.07197549770291
# Target (Black): 93.11515899969126
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.70750382848392
# Target (Black): 98.42543995060204
# Overall: 70.53946156208414
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.17690645260883
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.61255742725881
# Target (Black): 90.3982710713183
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.193866374589266
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.155041023888884
# Overall: 7.534246575342466
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.93415007656968
# Target (Black): 93.11515899969126
# Overall: 84.97287337496161
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.62174578866769
# Target (Black): 98.30194504476691
# Overall: 71.77807349779916
#
# False Positive Rate (Test Data)
# Source (White): 11.281489594742606
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.1538368217615917
# Overall: 7.587966693526726
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.20778017906761
# Overall: 85.11618384686253
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.65237366003063
# Target (Black): 98.57980858289595
# Overall: 71.89067458286416
#
# False Positive Rate (Test Data)
# Source (White): 11.106243154435926
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.15626422723317496
# Overall: 7.480526457158206
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5133, Domain Loss: 0.9852
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.66%
# Target Domain Accuracy: 79.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4577, Domain Loss: 0.9043
# Source Label Accuracy: 78.28%
# Target Label Accuracy: 90.71%
# Source Domain Accuracy: 62.05%
# Target Domain Accuracy: 93.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4304, Domain Loss: 0.8313
# Source Label Accuracy: 80.46%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 61.60%
# Target Domain Accuracy: 97.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4217, Domain Loss: 0.8017
# Source Label Accuracy: 80.95%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 60.97%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4167, Domain Loss: 0.7946
# Source Label Accuracy: 81.30%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 60.44%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4135, Domain Loss: 0.8007
# Source Label Accuracy: 81.44%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 60.13%
# Target Domain Accuracy: 97.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4114, Domain Loss: 0.8179
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.89%
# Target Domain Accuracy: 97.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4101, Domain Loss: 0.8354
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.60%
# Target Domain Accuracy: 97.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4091, Domain Loss: 0.8514
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 59.21%
# Target Domain Accuracy: 97.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4085, Domain Loss: 0.8646
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 58.87%
# Target Domain Accuracy: 97.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4080, Domain Loss: 0.8765
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.63%
# Target Domain Accuracy: 97.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4076, Domain Loss: 0.8846
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.39%
# Target Domain Accuracy: 96.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4073, Domain Loss: 0.8913
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.26%
# Target Domain Accuracy: 96.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4071, Domain Loss: 0.8969
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 58.16%
# Target Domain Accuracy: 96.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4069, Domain Loss: 0.9027
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 58.06%
# Target Domain Accuracy: 96.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4067, Domain Loss: 0.9076
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 57.91%
# Target Domain Accuracy: 96.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4065, Domain Loss: 0.9107
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 57.81%
# Target Domain Accuracy: 96.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4063, Domain Loss: 0.9150
# Source Label Accuracy: 82.05%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 57.64%
# Target Domain Accuracy: 96.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4062, Domain Loss: 0.9189
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 57.43%
# Target Domain Accuracy: 96.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4061, Domain Loss: 0.9210
# Source Label Accuracy: 82.10%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 57.17%
# Target Domain Accuracy: 96.30%
#
# Lambda: 0.1
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.9800918836141
# Target (Black): 93.08428527323248
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.68759571209801
# Target (Black): 96.29515282494597
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5124, Domain Loss: 0.8839
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.26%
# Target Domain Accuracy: 88.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4696, Domain Loss: 0.8336
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 60.57%
# Target Domain Accuracy: 97.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4390, Domain Loss: 0.8033
# Source Label Accuracy: 80.45%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 59.16%
# Target Domain Accuracy: 98.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4258, Domain Loss: 0.8093
# Source Label Accuracy: 80.89%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 57.84%
# Target Domain Accuracy: 98.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4188, Domain Loss: 0.8307
# Source Label Accuracy: 81.23%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 57.03%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4145, Domain Loss: 0.8578
# Source Label Accuracy: 81.33%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 56.71%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4118, Domain Loss: 0.8864
# Source Label Accuracy: 81.46%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 57.12%
# Target Domain Accuracy: 97.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4101, Domain Loss: 0.9101
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 57.97%
# Target Domain Accuracy: 97.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4088, Domain Loss: 0.9289
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 58.89%
# Target Domain Accuracy: 97.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4079, Domain Loss: 0.9460
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 59.58%
# Target Domain Accuracy: 96.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4071, Domain Loss: 0.9601
# Source Label Accuracy: 81.66%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 60.08%
# Target Domain Accuracy: 95.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4064, Domain Loss: 0.9698
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.47%
# Target Domain Accuracy: 91.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4056, Domain Loss: 0.9777
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.74%
# Target Domain Accuracy: 87.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4050, Domain Loss: 0.9856
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 60.92%
# Target Domain Accuracy: 86.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4044, Domain Loss: 0.9917
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.17%
# Target Domain Accuracy: 85.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4038, Domain Loss: 0.9956
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.33%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4032, Domain Loss: 0.9974
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.48%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4028, Domain Loss: 0.9976
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.59%
# Target Domain Accuracy: 83.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4023, Domain Loss: 0.9969
# Source Label Accuracy: 81.96%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.65%
# Target Domain Accuracy: 83.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4019, Domain Loss: 0.9954
# Source Label Accuracy: 82.01%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.69%
# Target Domain Accuracy: 83.64%
#
# Lambda: 0.1
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.9800918836141
# Target (Black): 93.08428527323248
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.68759571209801
# Target (Black): 96.29515282494597
# Overall: 70.48827925069097
#
# False Positive Rate (Test Data)
# Source (White): 11.237677984665936
# Target (Black): 1.770218674071503
# (Black FPR) / (White FPR): 0.1575253069617234
# Overall: 7.574536663980661
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.94946401225116
# Target (Black): 93.0534115467737
# Overall: 84.96263691268298
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.929555895865235
# Target (Black): 83.63692497684471
# Overall: 69.1268297676323
#
# False Positive Rate (Test Data)
# Source (White): 11.281489594742606
# Target (Black): 1.7355085039916696
# (Black FPR) / (White FPR): 0.1538368217615917
# Overall: 7.587966693526726
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5136, Domain Loss: 0.9695
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.82%
# Target Domain Accuracy: 84.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4564, Domain Loss: 0.8792
# Source Label Accuracy: 79.05%
# Target Label Accuracy: 91.17%
# Source Domain Accuracy: 63.72%
# Target Domain Accuracy: 95.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4314, Domain Loss: 0.8602
# Source Label Accuracy: 80.47%
# Target Label Accuracy: 92.07%
# Source Domain Accuracy: 61.83%
# Target Domain Accuracy: 96.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4212, Domain Loss: 0.8728
# Source Label Accuracy: 81.02%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 59.52%
# Target Domain Accuracy: 97.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4153, Domain Loss: 0.8922
# Source Label Accuracy: 81.26%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 57.79%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4117, Domain Loss: 0.9099
# Source Label Accuracy: 81.43%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 56.92%
# Target Domain Accuracy: 98.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4095, Domain Loss: 0.9267
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 56.43%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4080, Domain Loss: 0.9388
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 56.86%
# Target Domain Accuracy: 98.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4068, Domain Loss: 0.9430
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 57.17%
# Target Domain Accuracy: 98.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4060, Domain Loss: 0.9462
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 57.66%
# Target Domain Accuracy: 97.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4053, Domain Loss: 0.9507
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 58.29%
# Target Domain Accuracy: 97.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4047, Domain Loss: 0.9569
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 58.90%
# Target Domain Accuracy: 96.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4042, Domain Loss: 0.9616
# Source Label Accuracy: 81.92%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 59.22%
# Target Domain Accuracy: 94.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4037, Domain Loss: 0.9677
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 59.48%
# Target Domain Accuracy: 92.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4034, Domain Loss: 0.9749
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 59.71%
# Target Domain Accuracy: 90.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4032, Domain Loss: 0.9798
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 59.79%
# Target Domain Accuracy: 89.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4030, Domain Loss: 0.9811
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 59.92%
# Target Domain Accuracy: 88.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4027, Domain Loss: 0.9803
# Source Label Accuracy: 82.09%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.02%
# Target Domain Accuracy: 87.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4024, Domain Loss: 0.9803
# Source Label Accuracy: 82.13%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.19%
# Target Domain Accuracy: 86.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4022, Domain Loss: 0.9803
# Source Label Accuracy: 82.16%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.34%
# Target Domain Accuracy: 85.49%
#
# Lambda: 0.1
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.9800918836141
# Target (Black): 93.08428527323248
# Overall: 84.99334629951889
# ...
# Overall: 68.26696693622684
#
# False Positive Rate (Test Data)
# Source (White): 10.251916757940855
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.19298632063297108
# Overall: 7.0507655116841255
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5073, Domain Loss: 0.6480
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 62.78%
# Target Domain Accuracy: 78.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4518, Domain Loss: 0.5954
# Source Label Accuracy: 73.54%
# Target Label Accuracy: 89.84%
# Source Domain Accuracy: 61.51%
# Target Domain Accuracy: 82.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4273, Domain Loss: 0.5983
# Source Label Accuracy: 80.64%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 61.32%
# Target Domain Accuracy: 82.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4181, Domain Loss: 0.6271
# Source Label Accuracy: 81.12%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 61.79%
# Target Domain Accuracy: 80.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4126, Domain Loss: 0.6454
# Source Label Accuracy: 81.35%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 62.04%
# Target Domain Accuracy: 80.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4090, Domain Loss: 0.6595
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.28%
# Target Domain Accuracy: 79.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4064, Domain Loss: 0.6707
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.35%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4046, Domain Loss: 0.6750
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 62.45%
# Target Domain Accuracy: 79.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4030, Domain Loss: 0.6747
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.30%
# Target Domain Accuracy: 80.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4019, Domain Loss: 0.6726
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.13%
# Target Domain Accuracy: 81.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4008, Domain Loss: 0.6699
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 61.94%
# Target Domain Accuracy: 81.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4000, Domain Loss: 0.6685
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.81%
# Target Domain Accuracy: 82.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3991, Domain Loss: 0.6673
# Source Label Accuracy: 81.95%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.67%
# Target Domain Accuracy: 82.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3982, Domain Loss: 0.6667
# Source Label Accuracy: 81.98%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.55%
# Target Domain Accuracy: 82.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3972, Domain Loss: 0.6657
# Source Label Accuracy: 82.00%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.44%
# Target Domain Accuracy: 83.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3961, Domain Loss: 0.6643
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 61.35%
# Target Domain Accuracy: 83.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3949, Domain Loss: 0.6628
# Source Label Accuracy: 82.02%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 61.25%
# Target Domain Accuracy: 83.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3939, Domain Loss: 0.6614
# Source Label Accuracy: 82.04%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 61.16%
# Target Domain Accuracy: 83.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3929, Domain Loss: 0.6601
# Source Label Accuracy: 82.03%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.11%
# Target Domain Accuracy: 83.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3919, Domain Loss: 0.6592
# Source Label Accuracy: 82.06%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 61.05%
# Target Domain Accuracy: 83.30%
#
# Lambda: 0.9
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.08728943338438
# Target (Black): 93.08428527323248
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.316998468606435
# Target (Black): 82.8959555418339
# Overall: 68.47169618179957
#
# False Positive Rate (Test Data)
# Source (White): 10.427163198247536
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18308520909231446
# Overall: 7.131345688960516
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.01071975497703
# Target (Black): 93.23865390552639
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.32771822358346
# Target (Black): 79.43809817845013
# Overall: 68.0008189169823
#
# False Positive Rate (Test Data)
# Source (White): 10.339539978094194
# Target (Black): 1.8049288441513363
# (Black FPR) / (White FPR): 0.1745656816430265
# Overall: 7.037335482138061
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.13323124042878
# Target (Black): 93.11515899969126
# Overall: 85.10594738458389
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.11791730474732
# Target (Black): 82.67983945662242
# Overall: 68.26696693622684
#
# False Positive Rate (Test Data)
# Source (White): 10.251916757940855
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.19298632063297108
# Overall: 7.0507655116841255
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.05666156202145
# Target (Black): 93.20778017906761
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.19448698315467
# Target (Black): 83.29731398579808
# Overall: 68.52287849319275
#
# False Positive Rate (Test Data)
# Source (White): 10.405257393209201
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18347065163777196
# Overall: 7.117915659414451
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5098, Domain Loss: 0.6399
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.10%
# Target Domain Accuracy: 77.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4582, Domain Loss: 0.6464
# Source Label Accuracy: 75.94%
# Target Label Accuracy: 90.37%
# Source Domain Accuracy: 63.66%
# Target Domain Accuracy: 78.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4311, Domain Loss: 0.6609
# Source Label Accuracy: 80.63%
# Target Label Accuracy: 92.10%
# Source Domain Accuracy: 63.59%
# Target Domain Accuracy: 77.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4203, Domain Loss: 0.6708
# Source Label Accuracy: 80.99%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 63.19%
# Target Domain Accuracy: 77.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4144, Domain Loss: 0.6750
# Source Label Accuracy: 81.26%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 78.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4109, Domain Loss: 0.6743
# Source Label Accuracy: 81.43%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 62.51%
# Target Domain Accuracy: 78.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4086, Domain Loss: 0.6724
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4070, Domain Loss: 0.6692
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 61.93%
# Target Domain Accuracy: 80.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4059, Domain Loss: 0.6669
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 61.76%
# Target Domain Accuracy: 80.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4049, Domain Loss: 0.6642
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 61.63%
# Target Domain Accuracy: 81.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4043, Domain Loss: 0.6629
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 61.51%
# Target Domain Accuracy: 81.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4037, Domain Loss: 0.6623
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.40%
# Target Domain Accuracy: 81.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4031, Domain Loss: 0.6625
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.31%
# Target Domain Accuracy: 81.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4025, Domain Loss: 0.6622
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.22%
# Target Domain Accuracy: 82.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4019, Domain Loss: 0.6627
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.11%
# Target Domain Accuracy: 82.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4013, Domain Loss: 0.6640
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.04%
# Target Domain Accuracy: 81.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4006, Domain Loss: 0.6658
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.97%
# Target Domain Accuracy: 81.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3999, Domain Loss: 0.6673
# Source Label Accuracy: 81.94%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.94%
# Target Domain Accuracy: 81.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3994, Domain Loss: 0.6688
# Source Label Accuracy: 81.97%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 60.94%
# Target Domain Accuracy: 81.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3989, Domain Loss: 0.6703
# Source Label Accuracy: 81.99%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 60.92%
# Target Domain Accuracy: 81.44%
#
# Lambda: 0.9
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.08728943338438
# Target (Black): 93.08428527323248
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.316998468606435
# Target (Black): 82.8959555418339
# Overall: 68.47169618179957
#
# False Positive Rate (Test Data)
# Source (White): 10.427163198247536
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18308520909231446
# Overall: 7.131345688960516
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.01071975497703
# Target (Black): 93.23865390552639
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.32771822358346
# Target (Black): 79.43809817845013
# Overall: 68.0008189169823
#
# False Positive Rate (Test Data)
# Source (White): 10.339539978094194
# Target (Black): 1.8049288441513363
# (Black FPR) / (White FPR): 0.1745656816430265
# Overall: 7.037335482138061
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.13323124042878
# Target (Black): 93.11515899969126
# Overall: 85.10594738458389
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.11791730474732
# Target (Black): 82.67983945662242
# Overall: 68.26696693622684
#
# False Positive Rate (Test Data)
# Source (White): 10.251916757940855
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.19298632063297108
# Overall: 7.0507655116841255
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.05666156202145
# Target (Black): 93.20778017906761
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.19448698315467
# Target (Black): 83.29731398579808
# Overall: 68.52287849319275
#
# False Positive Rate (Test Data)
# Source (White): 10.405257393209201
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18347065163777196
# Overall: 7.117915659414451
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.99540581929556
# Target (Black): 93.0534115467737
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.27105666156202
# Target (Black): 81.44489039827107
# Overall: 67.95987306786775
#
# False Positive Rate (Test Data)
# Source (White): 10.339539978094194
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18463677866089342
# Overall: 7.077625570776256
#
#
# Lambda: 0.9
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.08728943338438
# Target (Black): 93.08428527323248
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.316998468606435
# Target (Black): 82.8959555418339
# Overall: 68.47169618179957
#
# False Positive Rate (Test Data)
# Source (White): 10.427163198247536
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18308520909231446
# Overall: 7.131345688960516
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.01071975497703
# Target (Black): 93.23865390552639
# Overall: 85.06500153546934
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.32771822358346
# Target (Black): 79.43809817845013
# Overall: 68.0008189169823
#
# False Positive Rate (Test Data)
# Source (White): 10.339539978094194
# Target (Black): 1.8049288441513363
# (Black FPR) / (White FPR): 0.1745656816430265
# Overall: 7.037335482138061
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.13323124042878
# Target (Black): 93.11515899969126
# Overall: 85.10594738458389
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.11791730474732
# Target (Black): 82.67983945662242
# Overall: 68.26696693622684
#
# False Positive Rate (Test Data)
# Source (White): 10.251916757940855
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.19298632063297108
# Overall: 7.0507655116841255
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.05666156202145
# Target (Black): 93.20778017906761
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.19448698315467
# Target (Black): 83.29731398579808
# Overall: 68.52287849319275
#
# False Positive Rate (Test Data)
# Source (White): 10.405257393209201
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18347065163777196
# Overall: 7.117915659414451
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.99540581929556
# Target (Black): 93.0534115467737
# Overall: 84.99334629951889
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.27105666156202
# Target (Black): 81.44489039827107
# Overall: 67.95987306786775
#
# False Positive Rate (Test Data)
# Source (White): 10.339539978094194
# Target (Black): 1.9090593543908365
# (Black FPR) / (White FPR): 0.18463677866089342
# Overall: 7.077625570776256

# %%
# More lambdas
lams = [2, 3, 5, 10, 15, 100]
for l in lams:
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5148, Domain Loss: 0.4997
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 61.06%
# Target Domain Accuracy: 83.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4686, Domain Loss: 0.5183
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 61.98%
# Target Domain Accuracy: 83.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4324, Domain Loss: 0.5362
# Source Label Accuracy: 80.49%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 62.10%
# Target Domain Accuracy: 82.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4205, Domain Loss: 0.5371
# Source Label Accuracy: 80.91%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 62.15%
# Target Domain Accuracy: 82.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4142, Domain Loss: 0.5418
# Source Label Accuracy: 81.27%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 62.12%
# Target Domain Accuracy: 82.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4102, Domain Loss: 0.5447
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.09%
# Target Domain Accuracy: 82.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4077, Domain Loss: 0.5485
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 62.04%
# Target Domain Accuracy: 83.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4058, Domain Loss: 0.5428
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.94%
# Target Domain Accuracy: 83.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4045, Domain Loss: 0.5463
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.90%
# Target Domain Accuracy: 83.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4034, Domain Loss: 0.5454
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.86%
# Target Domain Accuracy: 83.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4028, Domain Loss: 0.5480
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 61.88%
# Target Domain Accuracy: 83.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4021, Domain Loss: 0.5456
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 61.88%
# Target Domain Accuracy: 83.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4017, Domain Loss: 0.5480
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 61.89%
# Target Domain Accuracy: 83.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4012, Domain Loss: 0.5481
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.90%
# Target Domain Accuracy: 83.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4008, Domain Loss: 0.5473
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 61.87%
# Target Domain Accuracy: 83.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4004, Domain Loss: 0.5475
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 61.87%
# Target Domain Accuracy: 83.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3999, Domain Loss: 0.5483
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.88%
# Target Domain Accuracy: 83.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3994, Domain Loss: 0.5473
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.84%
# Target Domain Accuracy: 83.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3990, Domain Loss: 0.5486
# Source Label Accuracy: 81.81%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.86%
# Target Domain Accuracy: 83.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3983, Domain Loss: 0.5485
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.85%
# Target Domain Accuracy: 83.48%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5117, Domain Loss: 0.5125
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.89%
# Target Domain Accuracy: 78.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4613, Domain Loss: 0.5045
# Source Label Accuracy: 73.01%
# Target Label Accuracy: 89.84%
# Source Domain Accuracy: 61.80%
# Target Domain Accuracy: 80.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4321, Domain Loss: 0.5309
# Source Label Accuracy: 80.47%
# Target Label Accuracy: 92.19%
# Source Domain Accuracy: 62.21%
# Target Domain Accuracy: 79.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4209, Domain Loss: 0.5502
# Source Label Accuracy: 80.96%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 76.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4152, Domain Loss: 0.5375
# Source Label Accuracy: 81.18%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 62.68%
# Target Domain Accuracy: 74.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4115, Domain Loss: 0.5394
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 62.84%
# Target Domain Accuracy: 76.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4088, Domain Loss: 0.5456
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 62.43%
# Target Domain Accuracy: 76.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4068, Domain Loss: 0.5394
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 61.80%
# Target Domain Accuracy: 78.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4052, Domain Loss: 0.5440
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.58%
# Target Domain Accuracy: 78.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4039, Domain Loss: 0.5546
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 61.64%
# Target Domain Accuracy: 78.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4027, Domain Loss: 0.5454
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.80%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4019, Domain Loss: 0.5426
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.49%
# Target Domain Accuracy: 80.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4009, Domain Loss: 0.5563
# Source Label Accuracy: 81.67%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 60.88%
# Target Domain Accuracy: 79.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4005, Domain Loss: 0.5464
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.12%
# Target Domain Accuracy: 80.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3998, Domain Loss: 0.5449
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.01%
# Target Domain Accuracy: 81.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3990, Domain Loss: 0.5561
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.37%
# Target Domain Accuracy: 80.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3985, Domain Loss: 0.5587
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.21%
# Target Domain Accuracy: 81.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3979, Domain Loss: 0.5570
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.09%
# Target Domain Accuracy: 81.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3972, Domain Loss: 0.5631
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.28%
# Target Domain Accuracy: 81.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3970, Domain Loss: 0.5650
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 60.15%
# Target Domain Accuracy: 81.48%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.23865390552639
# Overall: 85.12642030914117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.398162327718225
# Target (Black): 81.47576412472985
# Overall: 67.3866311802641
#
# False Positive Rate (Test Data)
# Source (White): 9.112814895947427
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.21330067017328383
# Overall: 6.338973945742681
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5099, Domain Loss: 0.5239
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.54%
# Target Domain Accuracy: 80.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4484, Domain Loss: 0.5011
# Source Label Accuracy: 77.95%
# Target Label Accuracy: 91.20%
# Source Domain Accuracy: 61.65%
# Target Domain Accuracy: 83.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4246, Domain Loss: 0.4947
# Source Label Accuracy: 80.46%
# Target Label Accuracy: 92.13%
# Source Domain Accuracy: 60.75%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4178, Domain Loss: 0.5020
# Source Label Accuracy: 80.95%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 60.79%
# Target Domain Accuracy: 82.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4125, Domain Loss: 0.4773
# Source Label Accuracy: 81.20%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 60.80%
# Target Domain Accuracy: 81.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4078, Domain Loss: 0.4653
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 60.22%
# Target Domain Accuracy: 81.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4047, Domain Loss: 0.4818
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 60.70%
# Target Domain Accuracy: 81.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4026, Domain Loss: 0.4948
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.01%
# Target Domain Accuracy: 81.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4010, Domain Loss: 0.4866
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 60.06%
# Target Domain Accuracy: 82.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.3993, Domain Loss: 0.4941
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 59.81%
# Target Domain Accuracy: 82.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3979, Domain Loss: 0.4980
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 59.93%
# Target Domain Accuracy: 83.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3970, Domain Loss: 0.4907
# Source Label Accuracy: 81.74%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 59.63%
# Target Domain Accuracy: 83.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3958, Domain Loss: 0.4956
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 59.55%
# Target Domain Accuracy: 83.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3947, Domain Loss: 0.4981
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 59.68%
# Target Domain Accuracy: 83.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3935, Domain Loss: 0.4949
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 59.65%
# Target Domain Accuracy: 84.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3925, Domain Loss: 0.5009
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 59.71%
# Target Domain Accuracy: 84.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3917, Domain Loss: 0.5063
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 59.92%
# Target Domain Accuracy: 84.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3911, Domain Loss: 0.5058
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.01%
# Target Domain Accuracy: 84.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3907, Domain Loss: 0.5087
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.08%
# Target Domain Accuracy: 84.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3899, Domain Loss: 0.5121
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 60.06%
# Target Domain Accuracy: 84.07%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.23865390552639
# Overall: 85.12642030914117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.398162327718225
# Target (Black): 81.47576412472985
# Overall: 67.3866311802641
#
# False Positive Rate (Test Data)
# Source (White): 9.112814895947427
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.21330067017328383
# Overall: 6.338973945742681
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.23865390552639
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 84.06915714726767
# Overall: 68.17483877571911
#
# False Positive Rate (Test Data)
# Source (White): 9.156626506024097
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22365224063282121
# Overall: 6.4061240934730055
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5087, Domain Loss: 0.5017
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 62.22%
# Target Domain Accuracy: 85.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4562, Domain Loss: 0.4766
# Source Label Accuracy: 76.20%
# Target Label Accuracy: 90.80%
# Source Domain Accuracy: 59.39%
# Target Domain Accuracy: 86.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4321, Domain Loss: 0.5082
# Source Label Accuracy: 80.40%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 59.08%
# Target Domain Accuracy: 83.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4220, Domain Loss: 0.5401
# Source Label Accuracy: 80.87%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 58.01%
# Target Domain Accuracy: 81.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4159, Domain Loss: 0.5494
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 58.26%
# Target Domain Accuracy: 81.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4112, Domain Loss: 0.5065
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 58.92%
# Target Domain Accuracy: 81.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4080, Domain Loss: 0.4926
# Source Label Accuracy: 81.54%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 59.82%
# Target Domain Accuracy: 82.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4056, Domain Loss: 0.5153
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 60.17%
# Target Domain Accuracy: 82.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4038, Domain Loss: 0.5198
# Source Label Accuracy: 81.61%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.22%
# Target Domain Accuracy: 82.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4020, Domain Loss: 0.5114
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 59.97%
# Target Domain Accuracy: 83.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4011, Domain Loss: 0.5157
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.23%
# Target Domain Accuracy: 84.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3999, Domain Loss: 0.5094
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.25%
# Target Domain Accuracy: 84.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3992, Domain Loss: 0.5182
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 60.60%
# Target Domain Accuracy: 84.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3983, Domain Loss: 0.5163
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 60.29%
# Target Domain Accuracy: 84.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3978, Domain Loss: 0.5219
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.59%
# Target Domain Accuracy: 84.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3970, Domain Loss: 0.5224
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.55%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3967, Domain Loss: 0.5303
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.46%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3957, Domain Loss: 0.5264
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.47%
# Target Domain Accuracy: 84.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3953, Domain Loss: 0.5288
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.47%
# Target Domain Accuracy: 83.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3948, Domain Loss: 0.5311
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.25%
# Target Domain Accuracy: 84.10%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.23865390552639
# Overall: 85.12642030914117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.398162327718225
# Target (Black): 81.47576412472985
# Overall: 67.3866311802641
#
# False Positive Rate (Test Data)
# Source (White): 9.112814895947427
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.21330067017328383
# Overall: 6.338973945742681
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.23865390552639
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 84.06915714726767
# Overall: 68.17483877571911
#
# False Positive Rate (Test Data)
# Source (White): 9.156626506024097
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22365224063282121
# Overall: 6.4061240934730055
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.99540581929556
# Target (Black): 93.20778017906761
# Overall: 85.04452861091207
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.382848392036756
# Target (Black): 84.10003087372645
# Overall: 68.24649401166957
#
# False Positive Rate (Test Data)
# Source (White): 9.222343921139101
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.21453111177251893
# Overall: 6.41955412301907
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5164, Domain Loss: 0.5620
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.12%
# Target Domain Accuracy: 78.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4643, Domain Loss: 0.5408
# Source Label Accuracy: 71.30%
# Target Label Accuracy: 89.10%
# Source Domain Accuracy: 62.58%
# Target Domain Accuracy: 82.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4313, Domain Loss: 0.5214
# Source Label Accuracy: 80.32%
# Target Label Accuracy: 92.00%
# Source Domain Accuracy: 61.87%
# Target Domain Accuracy: 83.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4214, Domain Loss: 0.5278
# Source Label Accuracy: 80.87%
# Target Label Accuracy: 92.41%
# Source Domain Accuracy: 61.68%
# Target Domain Accuracy: 83.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4158, Domain Loss: 0.5344
# Source Label Accuracy: 81.19%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 61.43%
# Target Domain Accuracy: 82.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4124, Domain Loss: 0.5361
# Source Label Accuracy: 81.40%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 61.44%
# Target Domain Accuracy: 80.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4101, Domain Loss: 0.5347
# Source Label Accuracy: 81.55%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.50%
# Target Domain Accuracy: 80.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4082, Domain Loss: 0.5302
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.89%
# Target Domain Accuracy: 80.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4070, Domain Loss: 0.5226
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.62%
# Target Domain Accuracy: 81.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4057, Domain Loss: 0.5184
# Source Label Accuracy: 81.69%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.66%
# Target Domain Accuracy: 81.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4051, Domain Loss: 0.5221
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.49%
# Target Domain Accuracy: 82.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4043, Domain Loss: 0.5174
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.22%
# Target Domain Accuracy: 82.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4038, Domain Loss: 0.5193
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.05%
# Source Domain Accuracy: 61.26%
# Target Domain Accuracy: 82.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4032, Domain Loss: 0.5196
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.12%
# Source Domain Accuracy: 61.19%
# Target Domain Accuracy: 82.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4028, Domain Loss: 0.5152
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.85%
# Target Domain Accuracy: 82.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4021, Domain Loss: 0.5149
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 60.91%
# Target Domain Accuracy: 82.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4018, Domain Loss: 0.5238
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 61.06%
# Target Domain Accuracy: 82.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4012, Domain Loss: 0.5122
# Source Label Accuracy: 81.86%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.62%
# Target Domain Accuracy: 83.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4007, Domain Loss: 0.5102
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.61%
# Target Domain Accuracy: 83.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4003, Domain Loss: 0.5220
# Source Label Accuracy: 81.90%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 60.75%
# Target Domain Accuracy: 82.99%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.23865390552639
# Overall: 85.12642030914117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.398162327718225
# Target (Black): 81.47576412472985
# Overall: 67.3866311802641
#
# False Positive Rate (Test Data)
# Source (White): 9.112814895947427
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.21330067017328383
# Overall: 6.338973945742681
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.23865390552639
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 84.06915714726767
# Overall: 68.17483877571911
#
# False Positive Rate (Test Data)
# Source (White): 9.156626506024097
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22365224063282121
# Overall: 6.4061240934730055
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.99540581929556
# Target (Black): 93.20778017906761
# Overall: 85.04452861091207
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.382848392036756
# Target (Black): 84.10003087372645
# Overall: 68.24649401166957
#
# False Positive Rate (Test Data)
# Source (White): 9.222343921139101
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.21453111177251893
# Overall: 6.41955412301907
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.16385911179174
# Target (Black): 93.20778017906761
# Overall: 85.15712969597708
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.98009188361409
# Target (Black): 82.98857672121025
# Overall: 68.27720339850548
#
# False Positive Rate (Test Data)
# Source (White): 9.134720700985762
# Target (Black): 2.013189864630337
# (Black FPR) / (White FPR): 0.22038877055245773
# Overall: 6.379264034380876
#
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.26952763198518
# Overall: 85.09571092230526
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.12863705972435
# Target (Black): 83.48255634455079
# Overall: 69.2087214658614
#
# False Positive Rate (Test Data)
# Source (White): 9.68236582694414
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.20075357192779655
# Overall: 6.688154713940371
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.10260336906585
# Target (Black): 93.23865390552639
# Overall: 85.12642030914117
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.398162327718225
# Target (Black): 81.47576412472985
# Overall: 67.3866311802641
#
# False Positive Rate (Test Data)
# Source (White): 9.112814895947427
# Target (Black): 1.9437695244706699
# (Black FPR) / (White FPR): 0.21330067017328383
# Overall: 6.338973945742681
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.04134762633997
# Target (Black): 93.23865390552639
# Overall: 85.08547446002662
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 84.06915714726767
# Overall: 68.17483877571911
#
# False Positive Rate (Test Data)
# Source (White): 9.156626506024097
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22365224063282121
# Overall: 6.4061240934730055
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.99540581929556
# Target (Black): 93.20778017906761
# Overall: 85.04452861091207
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.382848392036756
# Target (Black): 84.10003087372645
# Overall: 68.24649401166957
#
# False Positive Rate (Test Data)
# Source (White): 9.222343921139101
# Target (Black): 1.9784796945505032
# (Black FPR) / (White FPR): 0.21453111177251893
# Overall: 6.41955412301907
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.16385911179174
# Target (Black): 93.20778017906761
# Overall: 85.15712969597708
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.98009188361409
# Target (Black): 82.98857672121025
# Overall: 68.27720339850548
#
# False Positive Rate (Test Data)
# Source (White): 9.134720700985762
# Target (Black): 2.013189864630337
# (Black FPR) / (White FPR): 0.22038877055245773
# Overall: 6.379264034380876
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5059, Domain Loss: 0.4761
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 61.37%
# Target Domain Accuracy: 83.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4420, Domain Loss: 0.4034
# Source Label Accuracy: 79.68%
# Target Label Accuracy: 91.66%
# Source Domain Accuracy: 58.06%
# Target Domain Accuracy: 86.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4208, Domain Loss: 0.3854
# Source Label Accuracy: 80.62%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 56.74%
# Target Domain Accuracy: 86.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4164, Domain Loss: 0.4563
# Source Label Accuracy: 81.12%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 59.00%
# Target Domain Accuracy: 83.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4126, Domain Loss: 0.4613
# Source Label Accuracy: 81.34%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 59.75%
# Target Domain Accuracy: 82.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4096, Domain Loss: 0.4502
# Source Label Accuracy: 81.51%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 59.70%
# Target Domain Accuracy: 81.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4070, Domain Loss: 0.4609
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.72%
# Target Domain Accuracy: 80.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4052, Domain Loss: 0.4810
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 92.90%
# Source Domain Accuracy: 61.35%
# Target Domain Accuracy: 81.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4032, Domain Loss: 0.4593
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 61.36%
# Target Domain Accuracy: 83.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4022, Domain Loss: 0.4556
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 61.16%
# Target Domain Accuracy: 84.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4013, Domain Loss: 0.4596
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 61.31%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4001, Domain Loss: 0.4626
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.40%
# Target Domain Accuracy: 84.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3988, Domain Loss: 0.4591
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.21%
# Source Domain Accuracy: 61.45%
# Target Domain Accuracy: 84.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3982, Domain Loss: 0.4649
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.27%
# Target Domain Accuracy: 84.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3965, Domain Loss: 0.4620
# Source Label Accuracy: 81.82%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.29%
# Target Domain Accuracy: 84.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3954, Domain Loss: 0.4616
# Source Label Accuracy: 81.84%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.29%
# Target Domain Accuracy: 84.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3946, Domain Loss: 0.4612
# Source Label Accuracy: 81.85%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.39%
# Target Domain Accuracy: 84.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3943, Domain Loss: 0.4599
# Source Label Accuracy: 81.87%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 61.27%
# Target Domain Accuracy: 84.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3926, Domain Loss: 0.4622
# Source Label Accuracy: 81.89%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.11%
# Target Domain Accuracy: 84.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3920, Domain Loss: 0.4613
# Source Label Accuracy: 81.88%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 61.10%
# Target Domain Accuracy: 84.53%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.90352220520674
# Target (Black): 93.26952763198518
# Overall: 85.00358276179752
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.40888208269525
# Target (Black): 84.53226304414943
# Overall: 69.07564745623912
#
# False Positive Rate (Test Data)
# Source (White): 9.04709748083242
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22635989487777064
# Overall: 6.338973945742681
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5171, Domain Loss: 0.4886
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 63.92%
# Target Domain Accuracy: 78.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4760, Domain Loss: 0.4789
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 60.71%
# Target Domain Accuracy: 82.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4367, Domain Loss: 0.4754
# Source Label Accuracy: 80.33%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 60.58%
# Target Domain Accuracy: 82.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4224, Domain Loss: 0.4318
# Source Label Accuracy: 80.90%
# Target Label Accuracy: 92.53%
# Source Domain Accuracy: 60.37%
# Target Domain Accuracy: 82.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4161, Domain Loss: 0.4241
# Source Label Accuracy: 81.17%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 59.58%
# Target Domain Accuracy: 82.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4121, Domain Loss: 0.4422
# Source Label Accuracy: 81.39%
# Target Label Accuracy: 92.71%
# Source Domain Accuracy: 59.00%
# Target Domain Accuracy: 81.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4092, Domain Loss: 0.4488
# Source Label Accuracy: 81.48%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 59.49%
# Target Domain Accuracy: 81.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4069, Domain Loss: 0.4477
# Source Label Accuracy: 81.46%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 59.41%
# Target Domain Accuracy: 82.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4050, Domain Loss: 0.4479
# Source Label Accuracy: 81.53%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 59.61%
# Target Domain Accuracy: 82.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4026, Domain Loss: 0.4303
# Source Label Accuracy: 81.56%
# Target Label Accuracy: 93.08%
# Source Domain Accuracy: 59.07%
# Target Domain Accuracy: 83.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4009, Domain Loss: 0.4325
# Source Label Accuracy: 81.59%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 59.43%
# Target Domain Accuracy: 84.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4002, Domain Loss: 0.4317
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 59.61%
# Target Domain Accuracy: 84.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3990, Domain Loss: 0.4362
# Source Label Accuracy: 81.64%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 59.75%
# Target Domain Accuracy: 83.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3975, Domain Loss: 0.4356
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 59.28%
# Target Domain Accuracy: 84.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3973, Domain Loss: 0.4379
# Source Label Accuracy: 81.68%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 59.15%
# Target Domain Accuracy: 83.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3958, Domain Loss: 0.4405
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.27%
# Source Domain Accuracy: 59.09%
# Target Domain Accuracy: 83.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3953, Domain Loss: 0.4373
# Source Label Accuracy: 81.72%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 58.85%
# Target Domain Accuracy: 83.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3954, Domain Loss: 0.4367
# Source Label Accuracy: 81.76%
# Target Label Accuracy: 93.30%
# Source Domain Accuracy: 58.77%
# Target Domain Accuracy: 84.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3940, Domain Loss: 0.4355
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.30%
# Source Domain Accuracy: 58.26%
# Target Domain Accuracy: 84.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3929, Domain Loss: 0.4455
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.33%
# Source Domain Accuracy: 58.91%
# Target Domain Accuracy: 84.10%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.90352220520674
# Target (Black): 93.26952763198518
# Overall: 85.00358276179752
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.40888208269525
# Target (Black): 84.53226304414943
# Overall: 69.07564745623912
#
# False Positive Rate (Test Data)
# Source (White): 9.04709748083242
# Target (Black): 2.04790003471017
# (Black FPR) / (White FPR): 0.22635989487777064
# Overall: 6.338973945742681
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.93415007656968
# Target (Black): 93.33127508490274
# Overall: 85.04452861091207
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.26493108728943
# Target (Black): 84.10003087372645
# Overall: 67.4992322653291
#
# False Positive Rate (Test Data)
# Source (White): 8.28039430449069
# Target (Black): 2.013189864630337
# (Black FPR) / (White FPR): 0.24312729449834625
# Overall: 5.855492882084341
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5198, Domain Loss: 0.5282
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 64.99%
# Target Domain Accuracy: 75.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4809, Domain Loss: 0.4201
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 55.73%
# Target Domain Accuracy: 85.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4418, Domain Loss: 0.5091
# Source Label Accuracy: 80.12%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 56.53%
# Target Domain Accuracy: 80.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4263, Domain Loss: 0.5397
# Source Label Accuracy: 80.70%
# Target Label Accuracy: 92.22%
# Source Domain Accuracy: 59.95%
# Target Domain Accuracy: 79.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4180, Domain Loss: 0.5100
# Source Label Accuracy: 81.03%
# Target Label Accuracy: 92.56%
# Source Domain Accuracy: 60.91%
# Target Domain Accuracy: 78.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4135, Domain Loss: 0.4757
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 60.86%
# Target Domain Accuracy: 80.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4102, Domain Loss: 0.4977
# Source Label Accuracy: 81.34%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 60.91%
# Target Domain Accuracy: 79.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4074, Domain Loss: 0.4897
# Source Label Accuracy: 81.45%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 61.25%
# Target Domain Accuracy: 80.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4056, Domain Loss: 0.4869
# Source Label Accuracy: 81.54%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 61.08%
# Target Domain Accuracy: 81.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4045, Domain Loss: 0.4955
# Source Label Accuracy: 81.58%
# Target Label Accuracy: 92.99%
# Source Domain Accuracy: 60.67%
# Target Domain Accuracy: 82.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4035, Domain Loss: 0.4751
# Source Label Accuracy: 81.62%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.37%
# Target Domain Accuracy: 82.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4023, Domain Loss: 0.4700
# Source Label Accuracy: 81.65%
# Target Label Accuracy: 93.02%
# Source Domain Accuracy: 60.26%
# Target Domain Accuracy: 82.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4016, Domain Loss: 0.4793
# Source Label Accuracy: 81.70%
# Target Label Accuracy: 93.15%
# Source Domain Accuracy: 60.19%
# Target Domain Accuracy: 82.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4008, Domain Loss: 0.4733
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 59.53%
# Target Domain Accuracy: 83.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3998, Domain Loss: 0.4688
# Source Label Accuracy: 81.73%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 58.82%
# Target Domain Accuracy: 83.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3993, Domain Loss: 0.4685
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.18%
# Source Domain Accuracy: 58.60%
# Target Domain Accuracy: 83.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3986, Domain Loss: 0.4674
# Source Label Accuracy: 81.75%
# Target Label Accuracy: 93.24%
# Source Domain Accuracy: 58.32%
# Target Domain Accuracy: 83.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3970, Domain Loss: 0.4758
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.30%
# Source Domain Accuracy: 57.68%
# Target Domain Accuracy: 83.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3959, Domain Loss: 0.4744
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 93.30%
# Source Domain Accuracy: 57.36%
# Target Domain Accuracy: 83.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3951, Domain Loss: 0.4706
# Source Label Accuracy: 81.78%
# Target Label Accuracy: 93.30%
# Source Domain Accuracy: 58.30%
# Target Domain Accuracy: 84.19%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.90352220520674
# Target (Black): 93.26952763198518
# Overall: 85.00358276179752
#
# ...
# Target (Black): 82.09323865390553
# Overall: 67.51970518988638
#
# False Positive Rate (Test Data)
# Source (White): 6.615553121577218
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.42498695495263555
# Overall: 5.143701316142896
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5024, Domain Loss: 0.3780
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 61.87%
# Target Domain Accuracy: 96.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4616, Domain Loss: 0.3231
# Source Label Accuracy: 79.16%
# Target Label Accuracy: 90.86%
# Source Domain Accuracy: 52.28%
# Target Domain Accuracy: 95.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4462, Domain Loss: 0.3532
# Source Label Accuracy: 79.98%
# Target Label Accuracy: 91.73%
# Source Domain Accuracy: 42.02%
# Target Domain Accuracy: 94.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4384, Domain Loss: 0.3551
# Source Label Accuracy: 80.09%
# Target Label Accuracy: 91.85%
# Source Domain Accuracy: 39.60%
# Target Domain Accuracy: 93.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4325, Domain Loss: 0.3585
# Source Label Accuracy: 80.36%
# Target Label Accuracy: 91.82%
# Source Domain Accuracy: 42.02%
# Target Domain Accuracy: 91.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4284, Domain Loss: 0.4005
# Source Label Accuracy: 80.54%
# Target Label Accuracy: 91.94%
# Source Domain Accuracy: 59.45%
# Target Domain Accuracy: 81.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4248, Domain Loss: 0.4323
# Source Label Accuracy: 80.72%
# Target Label Accuracy: 91.91%
# Source Domain Accuracy: 60.57%
# Target Domain Accuracy: 80.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4208, Domain Loss: 0.3774
# Source Label Accuracy: 80.85%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 60.06%
# Target Domain Accuracy: 79.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4185, Domain Loss: 0.4123
# Source Label Accuracy: 81.04%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 62.13%
# Target Domain Accuracy: 78.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4157, Domain Loss: 0.4021
# Source Label Accuracy: 81.14%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 63.23%
# Target Domain Accuracy: 76.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4142, Domain Loss: 0.4042
# Source Label Accuracy: 81.13%
# Target Label Accuracy: 92.65%
# Source Domain Accuracy: 62.98%
# Target Domain Accuracy: 78.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4118, Domain Loss: 0.4080
# Source Label Accuracy: 81.30%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 62.74%
# Target Domain Accuracy: 78.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4106, Domain Loss: 0.4106
# Source Label Accuracy: 81.36%
# Target Label Accuracy: 92.78%
# Source Domain Accuracy: 62.56%
# Target Domain Accuracy: 78.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4083, Domain Loss: 0.4112
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.56%
# Target Domain Accuracy: 78.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4076, Domain Loss: 0.4145
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 62.55%
# Target Domain Accuracy: 78.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4056, Domain Loss: 0.4134
# Source Label Accuracy: 81.32%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 62.05%
# Target Domain Accuracy: 79.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4062, Domain Loss: 0.4154
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 62.08%
# Target Domain Accuracy: 79.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4049, Domain Loss: 0.4354
# Source Label Accuracy: 81.48%
# Target Label Accuracy: 92.87%
# Source Domain Accuracy: 61.74%
# Target Domain Accuracy: 79.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4036, Domain Loss: 0.4169
# Source Label Accuracy: 81.52%
# Target Label Accuracy: 92.93%
# Source Domain Accuracy: 61.74%
# Target Domain Accuracy: 78.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4008, Domain Loss: 0.4246
# Source Label Accuracy: 81.42%
# Target Label Accuracy: 92.96%
# Source Domain Accuracy: 61.41%
# Target Domain Accuracy: 79.04%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.84226646248086
# Target (Black): 92.6520531028095
# Overall: 84.75790766711025
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.32771822358346
# Target (Black): 81.63013275702377
# Overall: 62.043197870815845
#
# False Positive Rate (Test Data)
# Source (White): 6.681270536692224
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.4208067553957244
# Overall: 5.18399140478109
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.55130168453293
# Target (Black): 92.59030564989195
# Overall: 84.54294195925888
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.06738131699847
# Target (Black): 84.13090460018525
# Overall: 69.38274132459821
#
# False Positive Rate (Test Data)
# Source (White): 6.659364731653889
# Target (Black): 2.950364456785838
# (Black FPR) / (White FPR): 0.443039925829847
# Overall: 5.224281493419285
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.6125574272588
# Target (Black): 92.6520531028095
# Overall: 84.6043607329307
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 82.09323865390553
# Overall: 67.51970518988638
#
# False Positive Rate (Test Data)
# Source (White): 6.615553121577218
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.42498695495263555
# Overall: 5.143701316142896
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.64318529862175
# Target (Black): 92.96079036739735
# Overall: 84.72719828027434
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.822358346094944
# Target (Black): 79.03673973448595
# Overall: 67.52994165216501
#
# False Positive Rate (Test Data)
# Source (White): 8.762322015334064
# Target (Black): 2.1867407150295035
# (Black FPR) / (White FPR): 0.24956178410274207
# Overall: 6.218103679828095
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5102, Domain Loss: 0.4569
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 62.98%
# Target Domain Accuracy: 85.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4761, Domain Loss: 0.3710
# Source Label Accuracy: 69.62%
# Target Label Accuracy: 88.95%
# Source Domain Accuracy: 54.34%
# Target Domain Accuracy: 94.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4571, Domain Loss: 0.3609
# Source Label Accuracy: 77.17%
# Target Label Accuracy: 90.71%
# Source Domain Accuracy: 47.50%
# Target Domain Accuracy: 94.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4433, Domain Loss: 0.3581
# Source Label Accuracy: 79.89%
# Target Label Accuracy: 91.79%
# Source Domain Accuracy: 43.59%
# Target Domain Accuracy: 93.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4348, Domain Loss: 0.3577
# Source Label Accuracy: 80.24%
# Target Label Accuracy: 92.03%
# Source Domain Accuracy: 47.91%
# Target Domain Accuracy: 91.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4289, Domain Loss: 0.4769
# Source Label Accuracy: 80.46%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 53.67%
# Target Domain Accuracy: 85.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4242, Domain Loss: 0.5165
# Source Label Accuracy: 80.77%
# Target Label Accuracy: 92.25%
# Source Domain Accuracy: 58.48%
# Target Domain Accuracy: 82.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4197, Domain Loss: 0.4497
# Source Label Accuracy: 80.90%
# Target Label Accuracy: 92.44%
# Source Domain Accuracy: 56.66%
# Target Domain Accuracy: 81.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4170, Domain Loss: 0.5180
# Source Label Accuracy: 80.92%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 54.74%
# Target Domain Accuracy: 80.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4152, Domain Loss: 0.4725
# Source Label Accuracy: 81.02%
# Target Label Accuracy: 92.50%
# Source Domain Accuracy: 56.13%
# Target Domain Accuracy: 79.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4131, Domain Loss: 0.4321
# Source Label Accuracy: 81.19%
# Target Label Accuracy: 92.62%
# Source Domain Accuracy: 56.18%
# Target Domain Accuracy: 79.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4110, Domain Loss: 0.4455
# Source Label Accuracy: 81.41%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 55.42%
# Target Domain Accuracy: 81.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4084, Domain Loss: 0.4143
# Source Label Accuracy: 81.34%
# Target Label Accuracy: 92.68%
# Source Domain Accuracy: 57.75%
# Target Domain Accuracy: 79.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4051, Domain Loss: 0.4183
# Source Label Accuracy: 81.26%
# Target Label Accuracy: 92.84%
# Source Domain Accuracy: 59.18%
# Target Domain Accuracy: 78.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4043, Domain Loss: 0.4201
# Source Label Accuracy: 81.26%
# Target Label Accuracy: 92.81%
# Source Domain Accuracy: 57.89%
# Target Domain Accuracy: 80.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4018, Domain Loss: 0.4215
# Source Label Accuracy: 81.25%
# Target Label Accuracy: 92.74%
# Source Domain Accuracy: 57.76%
# Target Domain Accuracy: 80.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3946, Domain Loss: 0.4198
# Source Label Accuracy: 81.10%
# Target Label Accuracy: 92.59%
# Source Domain Accuracy: 56.61%
# Target Domain Accuracy: 81.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3878, Domain Loss: 0.4196
# Source Label Accuracy: 81.01%
# Target Label Accuracy: 92.47%
# Source Domain Accuracy: 58.07%
# Target Domain Accuracy: 80.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3817, Domain Loss: 0.4206
# Source Label Accuracy: 80.81%
# Target Label Accuracy: 92.34%
# Source Domain Accuracy: 58.23%
# Target Domain Accuracy: 80.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3791, Domain Loss: 0.4205
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 92.16%
# Source Domain Accuracy: 59.29%
# Target Domain Accuracy: 80.70%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.84226646248086
# Target (Black): 92.6520531028095
# Overall: 84.75790766711025
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.32771822358346
# Target (Black): 81.63013275702377
# Overall: 62.043197870815845
#
# False Positive Rate (Test Data)
# Source (White): 6.681270536692224
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.4208067553957244
# Overall: 5.18399140478109
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.55130168453293
# Target (Black): 92.59030564989195
# Overall: 84.54294195925888
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.06738131699847
# Target (Black): 84.13090460018525
# Overall: 69.38274132459821
#
# False Positive Rate (Test Data)
# Source (White): 6.659364731653889
# Target (Black): 2.950364456785838
# (Black FPR) / (White FPR): 0.443039925829847
# Overall: 5.224281493419285
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.6125574272588
# Target (Black): 92.6520531028095
# Overall: 84.6043607329307
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 82.09323865390553
# Overall: 67.51970518988638
#
# False Positive Rate (Test Data)
# Source (White): 6.615553121577218
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.42498695495263555
# Overall: 5.143701316142896
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.64318529862175
# Target (Black): 92.96079036739735
# Overall: 84.72719828027434
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.822358346094944
# Target (Black): 79.03673973448595
# Overall: 67.52994165216501
#
# False Positive Rate (Test Data)
# Source (White): 8.762322015334064
# Target (Black): 2.1867407150295035
# (Black FPR) / (White FPR): 0.24956178410274207
# Overall: 6.218103679828095
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.12251148545177
# Target (Black): 92.15807347946897
# Overall: 84.11301054355614
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.5405819295559
# Target (Black): 80.70392096326026
# Overall: 66.55747773569455
#
# False Positive Rate (Test Data)
# Source (White): 5.6297918948521355
# Target (Black): 3.575147518222839
# (Black FPR) / (White FPR): 0.6350407945792709
# Overall: 4.8348106365834
#
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.84226646248086
# Target (Black): 92.6520531028095
# Overall: 84.75790766711025
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.32771822358346
# Target (Black): 81.63013275702377
# Overall: 62.043197870815845
#
# False Positive Rate (Test Data)
# Source (White): 6.681270536692224
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.4208067553957244
# Overall: 5.18399140478109
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.55130168453293
# Target (Black): 92.59030564989195
# Overall: 84.54294195925888
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.06738131699847
# Target (Black): 84.13090460018525
# Overall: 69.38274132459821
#
# False Positive Rate (Test Data)
# Source (White): 6.659364731653889
# Target (Black): 2.950364456785838
# (Black FPR) / (White FPR): 0.443039925829847
# Overall: 5.224281493419285
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.6125574272588
# Target (Black): 92.6520531028095
# Overall: 84.6043607329307
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.290964777947934
# Target (Black): 82.09323865390553
# Overall: 67.51970518988638
#
# False Positive Rate (Test Data)
# Source (White): 6.615553121577218
# Target (Black): 2.8115237764665046
# (Black FPR) / (White FPR): 0.42498695495263555
# Overall: 5.143701316142896
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.64318529862175
# Target (Black): 92.96079036739735
# Overall: 84.72719828027434
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.822358346094944
# Target (Black): 79.03673973448595
# Overall: 67.52994165216501
#
# False Positive Rate (Test Data)
# Source (White): 8.762322015334064
# Target (Black): 2.1867407150295035
# (Black FPR) / (White FPR): 0.24956178410274207
# Overall: 6.218103679828095
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 80.12251148545177
# Target (Black): 92.15807347946897
# Overall: 84.11301054355614
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.5405819295559
# Target (Black): 80.70392096326026
# Overall: 66.55747773569455
#
# False Positive Rate (Test Data)
# Source (White): 5.6297918948521355
# Target (Black): 3.575147518222839
# (Black FPR) / (White FPR): 0.6350407945792709
# Overall: 4.8348106365834

# %% [markdown]
# # Lambda vs Domain Accuracy Adult Sex

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb Cell 24 line 3
#       <a href='vscode-notebook-cell:/Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> dataset = 'Adult'
#       <a href='vscode-notebook-cell:/Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> sensitive = 'Sex'
# ----> <a href='vscode-notebook-cell:/Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> my_stats = DANN_Stats[dataset][sensitive]
#       <a href='vscode-notebook-cell:/Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> # plot results
#       <a href='vscode-notebook-cell:/Users/sarahbock/Desktop/thesis/DANN/DANN_Adult/DANN_Adult_Unweight.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a> white_means = [stats['domain_source'][0] for stats in my_stats]
#
# NameError: name 'DANN_Stats' is not defined
