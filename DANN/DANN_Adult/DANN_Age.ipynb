# %% [markdown]
# # NEWEST

# %%
# IW CODE: https://github.com/sarahmbock/COS-IW-BOCK/blob/main/DANN%20CODE.ipynb

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import time
import os
import torch.nn as nn
from torch.autograd import Function
import torchvision
import torch.utils.data as data
from PIL import Image
import os
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
import numpy as np 
import torch.nn.functional as F
import torch.nn.init as init
import pandas as pd
import sklearn.preprocessing as preprocessing

# %%
# Gradient reversal layer
class GRL(Function):
    @staticmethod
    def forward(ctx, x, constant):
        ctx.constant = constant
        return x.view_as(x) * constant
    @staticmethod
    def backward(ctx, grad_output):
        return grad_output.neg() * ctx.constant, None

# %%
import torch.nn.functional as F
from torch.autograd import Function

class GradReverse(Function):
    
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)
    
    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None

def grad_reverse(x, lambda_=1.0):
    return GradReverse.apply(x, lambda_)

# %%
# Can adjust NN Sizes
class Dann(nn.Module):
    def __init__(self):
        super(Dann, self).__init__()
        self.f = nn.Sequential(
                nn.Linear(86, 64),
            nn.ReLU(),
        )
        # Label classifier
        self.lc = nn.Sequential(
    nn.Linear(64, 32),
    nn.Sigmoid(),
    nn.Linear(32, 32),
    nn.Sigmoid(),
    nn.Linear(32, 2),
    nn.Sigmoid()
)
        
        # Domain classifier
        self.dc = nn.Sequential(nn.Linear(64, 36),
    nn.Sigmoid(),
    nn.Linear(36, 36), nn.Sigmoid(),              
    nn.Linear(36, 2),
    nn.Sigmoid()
                                
)
    def forward(self, x,alpha):
        x = self.f(x)
        x = x.view(-1, 64) # must be same dimension as output size from init()
        y = GRL.apply(x, alpha)
        x = self.lc(x)
        y = self.dc(y)
        x=x.view(x.shape[0],-1)
        y=y.view(y.shape[0],-1)
        return x, y

# %% [markdown]
# # DATA

# %%
# Adult data code
# Change these to local file if available
train_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
test_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'

features = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"] 


# This will download 3.8M
original_train = pd.read_csv(train_url, names=features, sep=r'\s*,\s*', 
                             engine='python', na_values="?")
# This will download 1.9M
original_test = pd.read_csv(test_url, names=features, sep=r'\s*,\s*', 
                            engine='python', na_values="?", skiprows=1)



num_train = len(original_train)
original = pd.concat([original_train, original_test])
roc_original = original
labels = original['Target']
labels = labels.replace('<=50K', 0).replace('>50K', 1)
labels = labels.replace('<=50K.', 0).replace('>50K.', 1)


# Preprocess
# Redundant column
del original["Education"]
# Remove target variable
del original["Target"]


def data_transform(df):
    """Normalize features."""
    binary_data = pd.get_dummies(df)
    feature_cols = binary_data[binary_data.columns[:-2]]
    scaler = preprocessing.StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(feature_cols), columns=feature_cols.columns)
    return data

data = data_transform(original)

# %%
# Adult code, seperate sensitive and non sensitive
# get array of sensitive characteristics
sensitive = (original['Age'] > 37)
y = np.array(labels).flatten()
print(data.columns)
data = data.drop(['Age'], axis=1) # Drop sensitive info from data
data_np = np.array(data)
# Out:
# Index(['Age', 'fnlwgt', 'Education-Num', 'Capital Gain', 'Capital Loss',
#        'Hours per week', 'Workclass_Federal-gov', 'Workclass_Local-gov',
#        'Workclass_Never-worked', 'Workclass_Private', 'Workclass_Self-emp-inc',
#        'Workclass_Self-emp-not-inc', 'Workclass_State-gov',
#        'Workclass_Without-pay', 'Martial Status_Divorced',
#        'Martial Status_Married-AF-spouse', 'Martial Status_Married-civ-spouse',
#        'Martial Status_Married-spouse-absent', 'Martial Status_Never-married',
#        'Martial Status_Separated', 'Martial Status_Widowed',
#        'Occupation_Adm-clerical', 'Occupation_Armed-Forces',
#        'Occupation_Craft-repair', 'Occupation_Exec-managerial',
#        'Occupation_Farming-fishing', 'Occupation_Handlers-cleaners',
#        'Occupation_Machine-op-inspct', 'Occupation_Other-service',
#        'Occupation_Priv-house-serv', 'Occupation_Prof-specialty',
#        'Occupation_Protective-serv', 'Occupation_Sales',
#        'Occupation_Tech-support', 'Occupation_Transport-moving',
#        'Relationship_Husband', 'Relationship_Not-in-family',
#        'Relationship_Other-relative', 'Relationship_Own-child',
#        'Relationship_Unmarried', 'Relationship_Wife',
#        'Race_Amer-Indian-Eskimo', 'Race_Asian-Pac-Islander', 'Race_Black',
#        'Race_Other', 'Race_White', 'Sex_Female', 'Sex_Male',
#        'Country_Cambodia', 'Country_Canada', 'Country_China',
#        'Country_Columbia', 'Country_Cuba', 'Country_Dominican-Republic',
#        'Country_Ecuador', 'Country_El-Salvador', 'Country_England',
#        'Country_France', 'Country_Germany', 'Country_Greece',
#        'Country_Guatemala', 'Country_Haiti', 'Country_Holand-Netherlands',
#        'Country_Honduras', 'Country_Hong', 'Country_Hungary', 'Country_India',
#        'Country_Iran', 'Country_Ireland', 'Country_Italy', 'Country_Jamaica',
#        'Country_Japan', 'Country_Laos', 'Country_Mexico', 'Country_Nicaragua',
#        'Country_Outlying-US(Guam-USVI-etc)', 'Country_Peru',
#        'Country_Philippines', 'Country_Poland', 'Country_Portugal',
#        'Country_Puerto-Rico', 'Country_Scotland', 'Country_South',
#        'Country_Taiwan', 'Country_Thailand', 'Country_Trinadad&Tobago',
#        'Country_United-States'],
#       dtype='object')

# %%
# split to source (non-sensitive) and target (sensitive)
sensitive_idx = np.array(np.where(sensitive==1))[0].flatten()
nonsensitive_idx = np.array(np.where(sensitive!=1))[0].flatten()
data_sensitive = data_np[sensitive_idx,:]
data_nonsensitive = data_np[nonsensitive_idx,:]
y_sensitive = y[sensitive_idx]
y_nonsensitive = y[nonsensitive_idx]

# %%
# # ORIGINAL CODE -- need to replace with adult code


# import pandas as pd
# import numpy as np
# #import rowgenerators as rg ****commented out for thesis****

# from sklearn.feature_selection import VarianceThreshold

# scfp = pd.read_stata('p19i6.dta')



# # SELECT only rows where there is debt and where white and black
# delinquency = 'x3005'
# loan_schedule ='x3004'# 1 on time, 5 sometimes late, 0 inapp.
# race = 'x6809'
# additional_race = 'x6810'
# hispanic = 'x7004'

# scfp = scfp[(scfp[race] == 1) | (scfp[race] == 2)]
# scfp =  scfp[(scfp[loan_schedule] == 1) | (scfp[loan_schedule] == 5)]
# scfp.shape

# # Remove revealing columns
# race_revealing = [additional_race, 'x7004']
# race_revealing += [col.replace('x', 'j') for col in race_revealing]
# sched_revealing = ['x7571', 'x7570', 'x7569', 'x7556', 'x7564', 'x7554','x7553',
#                    'x7534', 'x7533', 'x7532', 'x7166', 'x7529', 'x7821', 'x7844',
#                    'x7867', 'x7921', 'x7569', 'x7944', 'x7521', 'x7520', 'x7518',
#                    'x7517', delinquency, 'j3005', 'j3004']
# sched_revealing += [col.replace('x', 'j') for col in sched_revealing]

# exclude = sched_revealing+ race_revealing
# X = scfp.copy()
# # Eliminate bad columns
# X = scfp.loc[:, [col for col in scfp.columns if col not in exclude]]
# X = X.fillna(-1)

# # Remove columns with all -1

# # instantiate the VarianceThreshold object with a threshold of 0
# selector = VarianceThreshold(threshold=0)

# # fit the selector on the DataFrame
# selector.fit(X)

# # get the indices of the non-constant columns
# non_constant_cols = selector.get_support(indices=True)

# # select the non-constant columns from the original DataFrame
# X = X.iloc[:, non_constant_cols]

# # print the filtered DataFrame
# print(X.shape)

# %%
# from sklearn.model_selection import train_test_split
# from torch.utils.data import TensorDataset, DataLoader

# # split to source (white) and target (black)
# # First, create a new column in X that indicates whether each person is white or black
# print(len(X))
# # Use groupby to split X and y into two separate dataframes, one with only white data and the other with only black data
# X_white = X[X[race] == 1]
# y_white = X_white[loan_schedule].replace({1: 0, 5: 1})
# X_white = X_white.drop([race, loan_schedule], axis =1)
# #print(y_white)
# print(len(y_white))
# print(len(X_white))

# X_black = X[X[race]==2]
# y_black = X_black[loan_schedule].replace({1: 0, 5: 1})
# X_black = X_black.drop([race, loan_schedule], axis =1)
# #print(y_black)
# print(len(y_black))
# print(len(X_black))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

X_tensor_source =  torch.from_numpy(data_nonsensitive).type(torch.float32)
X_tensor_target =  torch.from_numpy(data_sensitive).type(torch.float32)
y_tensor_source =torch.tensor(y_nonsensitive).type(torch.LongTensor)
y_tensor_target =torch.tensor(y_sensitive).type(torch.LongTensor)


# Split the source (race) dataset into training and test sets
X_train_source, X_test_source, y_train_source, y_test_source = train_test_split(X_tensor_source, y_tensor_source, test_size=0.2, random_state=42)


# Split the target (loan sched) into training and test sets
X_train_target, X_test_target, y_train_target, y_test_target = train_test_split(X_tensor_target, y_tensor_target, test_size=0.2, random_state=42)

# Create TensorDatasets from the training and test sets
target_train = TensorDataset(X_train_target, y_train_target)
target_test = TensorDataset(X_test_target, y_test_target)

source_train = TensorDataset(X_train_source, y_train_source)
source_test = TensorDataset(X_test_source, y_test_source)

# WEIGHTS
num_samples = len(target_train)
num_positives = sum(target_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_target])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))




# Create DataLoaders from the datasets
batch_size = 64
target_train = DataLoader(target_train, batch_size=batch_size, sampler=sampler)
target_test= DataLoader(target_test, batch_size=len(target_test), shuffle=False)



num_samples = len(source_train)
num_positives = sum(source_train[i][1] for i in range(num_samples))
num_negatives = num_samples - num_positives
class_sample_count = np.array([num_negatives, num_positives])

weight = 1/class_sample_count
print('positive weight (under represented):', weight[1])
print('negative weight (over represented):', weight[0])

samples_weight = np.array([weight[t] for t in y_train_source])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))


source_train = DataLoader(source_train, batch_size=batch_size, sampler = sampler)
source_test = DataLoader(source_test, batch_size=len(source_test), shuffle=False)

print(X_train_source.shape)
print(X_train_target.shape)
# Out:
# positive weight (under represented): 0.00014903129657228018
# negative weight (over represented): 8.074935400516796e-05
# positive weight (under represented): 0.00037650602409638556
# negative weight (over represented): 5.7726721699474687e-05
# torch.Size([19979, 86])
# torch.Size([19094, 86])

# %%
combined_tensor = torch.cat((X_train_source, X_train_target), dim=0)

y_domain = torch.zeros(len(combined_tensor), dtype=torch.long)
y_domain[len(X_train_source):] = 1
print(sum(y_domain).item())
print(y_domain)
combined_set =  TensorDataset(combined_tensor, y_domain)
class_sample_count = np.array([len(X_train_source), len(X_train_target)])
print(class_sample_count)
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_domain])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

combined_loader =  DataLoader(combined_set, batch_size=batch_size, sampler=sampler)



# Combine white and black to train credit predictor
y_label_combined = torch.cat((y_train_source,y_train_target), dim=0)
X_label_combined = torch.cat((X_train_source,X_train_target), dim=0)
num_samples = len(X_label_combined)
num_positives = sum(y_label_combined[i] for i in range(num_samples))
num_negatives = num_samples - num_positives
print(num_positives.item())
print(num_negatives.item())
class_sample_count = np.array([num_negatives.item(), num_positives.item()])
weight = 1/class_sample_count
print(weight)
samples_weight = np.array([weight[t] for t in y_label_combined])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))
combined_label_set = TensorDataset(X_label_combined, y_label_combined)
combined_label_loader = DataLoader(combined_label_set, batch_size=batch_size, sampler=sampler)
# Out:
# 19094
# tensor([0, 0, 0,  ..., 1, 1, 1])
# [19979 19094]
# [5.00525552e-05 5.23724730e-05]
# 9366
# 29707
# [3.36620998e-05 1.06769165e-04]

# %%
def test(model, source_train_loader, source_test_loader, target_test_loader, lambda_):
    # Set model to evaluation mode
    model.eval()
    model.lc.eval()
    model.dc.eval()
    model.f.eval()

    # Define variables for tracking accuracy
    source_label_correct = 0
    source_domain_correct = 0
    target_domain_correct = 0

    # Evaluate on source train set
    for i, (data, labels) in enumerate(source_train_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        #print(domain_preds)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    #num_ones_predicted =0
    # Evaluate on source test set
    for i, (data, labels) in enumerate(source_test_loader):
        # Set domain label to 0 (i.e., source domain)
        domain_labels = torch.zeros(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))

        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        source_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)

        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        source_domain_correct += (domain_preds == domain_labels).sum().item()
    
    # Evaluate on target test set
    target_label_correct =0
    for i, (data, labels) in enumerate(target_test_loader):
        # Set domain label to 1 (i.e., target domain)
        domain_labels = torch.ones(data.shape[0]).long()

        # Forward pass through the model
        label_preds, domain_preds = model(data, alpha=lambda_)
        domain_preds = model.dc(grad_reverse(model.f(data), lambda_))
        
        # Calculate accuracy of label classifier
        _, label_preds = torch.max(label_preds, 1)
        target_label_correct += (label_preds == labels).sum().item()
        #num_ones_predicted += list(label_preds.numpy()).count(1)
        
        # Calculate accuracy of domain classifier
        _, domain_preds = torch.max(domain_preds, 1)
        target_domain_correct += (domain_preds == domain_labels).sum().item()
        

    # Calculate and print accuracy
    source_label_accuracy = 100. * source_label_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    source_domain_accuracy = 100. * source_domain_correct / (len(source_train_loader.dataset) + len(source_test_loader.dataset))
    target_label_accuracy = 100. * target_label_correct / (len(target_test_loader.dataset))
    target_domain_accuracy = 100. * target_domain_correct / len(target_test_loader.dataset)
    print('Source Label Accuracy: {:.2f}%'.format(source_label_accuracy))
    print('Target Label Accuracy: {:.2f}%'.format(target_label_accuracy))
    print('Source Domain Accuracy: {:.2f}%'.format(source_domain_accuracy))
    print('Target Domain Accuracy: {:.2f}%'.format(target_domain_accuracy))
    #print('Number of loan defaults predicted: ', num_ones_predicted / (len(target_test_loader.dataset)+ len(source_test_loader.dataset)))

# %%
from sklearn.metrics import confusion_matrix
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score
def test_fairness(model, lambda_):
    with torch.no_grad():
        predicted_labels_white = []
        true_labels_white = []
        predicted_domain = []
        source_label_correct =0
        source_domain_correct =0
        for i, (data, labels) in enumerate(source_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.zeros(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            source_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            source_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels_white += label_preds
            true_labels_white += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels_white, predicted_labels_white)
        print('Credit Confusion Matrix White: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive white: ', fpr)
        
        predicted_labels = []
        true_labels = []
        predicted_domain = []
        target_label_correct =0
        target_domain_correct =0
        for i, (data, labels) in enumerate(target_test):
            # Set domain label to 0 (i.e., source domain)
            domain_labels = torch.ones(data.shape[0]).long()

            # Forward pass through the model
            label_preds, domain_preds = model(data, alpha=lambda_)
            domain_preds = model.dc(grad_reverse(model.f(data), lambda_=lambda_))

            # Calculate accuracy of label classifier
            _, label_preds = torch.max(label_preds, 1)
            target_label_correct += (label_preds == labels).sum().item()
            #num_ones_predicted += list(label_preds.numpy()).count(1)

            # Calculate accuracy of domain classifier
            _, domain_preds = torch.max(domain_preds, 1)
            target_domain_correct += (domain_preds == domain_labels).sum().item()
            predicted_labels += label_preds
            true_labels += labels
            predicted_domain += domain_preds
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        print('Credit Confusion Matrix Black: ')
        print(conf_matrix)
        fpr = conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0]) 
        print('False positive black: ', fpr)
        
        # predictive Parity
        metric_frame = MetricFrame(metrics=accuracy_score, y_true=true_labels_white + true_labels,
                           y_pred=predicted_labels_white + predicted_labels,
                           sensitive_features=[1]*len(true_labels_white) + [0]*len(true_labels)) #are white and black mixed up here?

        predictive_parity = metric_frame.difference(method='between_groups')

        print("Predictive parity: ", predictive_parity)

# %%
def test_lc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    correct = 0
    ones = 0
    for data, labels in source_test:
        embedding = model.f(data)
        label_preds = model.lc(embedding)
        print(label_preds)
        label_preds = torch.max(label_preds, 1)
        print(label_preds)
        # Get number of correct predictions
        source_label_correct += (label_preds == labels).sum().item()
        ones += list(label_preds.numpy()).count(1)
        
        # get number of ones
    source_test_label_acc = source_label_correct / len(source_test_loader.dataset)
    print('Accuracy of label classifier on source test: ', source_test_label_acc )
    print('Late loans predicted on source test: ', ones/ len(source_test_loader.dataset))

# %%
def test_dc(model, lambda_):
    model.eval()
    model.lc.eval()
    model.f.eval()
    model.dc.eval()
    correct = 0
    black = 0
    actually_black = 0
    for data, labels in combined_loader:
        combined_data, domain_labels = data, labels
        embedded = grad_reverse(model.f(combined_data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        #print(domain_preds)
        _, domain_preds = torch.max(domain_preds, 1)
        #domain_loss = domain_criterion(domain_preds, domain_labels)
        #print(domain_preds)
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
        actually_black += list(labels.numpy()).count(1)
    accuracy = correct / len(combined_loader.dataset)
    print('domain accuracy on train data: ', accuracy)
    print('black predicted: ', black/(len(combined_loader.dataset)))
    print('num actually black: ', actually_black/(len(combined_loader.dataset)))
    black = 0
    correct = 0
    actually_black = 0
    for data, labels in source_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.zeros(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    for data, labels in target_test:
        embedded = grad_reverse(model.f(data), lambda_=lambda_)
        domain_preds = model.dc(embedded)
        _, domain_preds = torch.max(domain_preds, 1)
        labels = torch.ones(data.shape[0]).long()
        correct += (domain_preds == labels).sum().item()
        black += list(domain_preds.numpy()).count(1)
    test_accuracy = correct / (len(target_test.dataset)+ len(source_test.dataset))
    print('domain test accuracy: ', test_accuracy)
    print('black pred test: ', black/(len(target_test.dataset)+ len(source_test.dataset)))
    print('actual black = ', len(target_test.dataset)/(len(target_test.dataset)+ len(source_test.dataset)))

# %%
def train(dann, num_epochs, feature_optimizer, label_epochs, domain_epochs, source_loader, target_loader, label_criterion, domain_criterion,
         label_optimizer, domain_optimizer, lambda_):
    for epoch in range(num_epochs):
    # Set the DANN model to training mode
        dann.train()
        # Set the number of batches for each epoch

            
        # Train the label classifier for label_epochs epochs
        for j in range(label_epochs):
            dann.lc.train()
            for data, labels in combined_label_loader:
                source_data, source_labels = data, labels
                label_optimizer.zero_grad()
                feature_embed = dann.f(source_data)
                label_preds = dann.lc(feature_embed)
                label_loss = label_criterion(label_preds, source_labels)
                label_loss.backward()
                label_optimizer.step()
        print('label trained')
        dann.lc.eval()

        # Train the domain classifier for domain_epochs epochs
        for j in range(domain_epochs):
            dann.dc.train()
            for data, labels in combined_loader:
                combined_data, domain_labels = data, labels
                domain_optimizer.zero_grad()
                embedded = grad_reverse(dann.f(combined_data), lambda_=lambda_)
                domain_preds = dann.dc(embedded)
                domain_loss = domain_criterion(domain_preds, domain_labels)
                domain_loss.backward()
                domain_optimizer.step()
        print('domain trained')
        dann.dc.eval()


        dann.f.train()
        dann.dc.train()
        dann.lc.train()
        dann.train()
        
        for data, labels in source_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed_label, feature_embed_domain = dann(data, lambda_)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #label_preds = dann.lc(feature_embed_label)
            #domain_preds = dann.dc(feature_embed_domain)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.zeros(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss* lambda_)
            total_loss.backward()
            feature_optimizer.step()
            
        for data, labels in target_loader:
            feature_optimizer.zero_grad()
            #dann.zero_grad()
            #feature_embed = dann.f(data)
            #label_preds = dann.lc(feature_embed)
            #feature_embed_domain = grad_reverse(dann.f(data), lambda_=lambda_)
            #domain_preds=dann.dc(feature_embed_domain)
            #print(domain_preds)
            label_preds, domain_preds = dann(data, lambda_)
            label_loss = label_criterion(label_preds, labels)
            domain_labels = torch.ones(len(data), dtype=torch.long)
            domain_loss = domain_criterion(domain_preds, domain_labels)
            total_loss = label_loss + (domain_loss*lambda_)
            total_loss.backward()
            feature_optimizer.step()
        print('feature extractor trained')
        dann.f.eval()
        dann.dc.eval()
        dann.lc.eval()
        dann.eval()
        print('Epoch [{}/{}], Label Loss: {:.4f}, Domain Loss: {:.4f}'.format(epoch+1, num_epochs, label_loss.item(), domain_loss.item()))
        test(dann, source_train, source_test, target_test, lambda_)
        #test_dc(dann, lambda_)
        #test_fairness(dann, lambda_)
        print()

# Print the loss for this epoch

# %%
def train_for_lambda(lambda_):
    model = Dann()

    # initialize weights
    for m in model.f.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.lc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
    for m in model.dc.modules():
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)

    # Define optimizer for the feature extractor and label classifier
    optimizer_lc = torch.optim.Adam(list(model.f.parameters()) + list(model.lc.parameters()), lr=0.00001, weight_decay=1e-3)
    criterion_lc = nn.CrossEntropyLoss()

    # Define optimizer for the domain classifier
    optimizer_dc = torch.optim.Adam(model.dc.parameters(), lr=0.0001, weight_decay=1e-3)
    criterion_dc = nn.CrossEntropyLoss()

    f_optimizer = torch.optim.Adam(model.f.parameters(), lr=0.0001, weight_decay=1e-3)
    # Define number of epochs to train the label and domain classifiers
    n_lc_epochs = 10
    n_dc_epochs = 10

    _lambda = lambda_
    lambda_ = _lambda
    # Training loop
    num_epochs = 32
    train(model, num_epochs, optimizer_lc, 20, domain_epochs =30, 
          source_loader=source_train, target_loader= target_train, 
          label_criterion =criterion_lc, domain_criterion=criterion_dc,
         label_optimizer = optimizer_lc, domain_optimizer = optimizer_dc, lambda_ = lambda_)
    return model

# %%
'''lambda = 0
label trained
domain trained
feature extractor trained
Epoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133
Source Label Accuracy: 96.33%
Target Label Accuracy: 97.27%
Source Domain Accuracy: 89.32%
Target Domain Accuracy: 84.73%
domain accuracy on train data:  0.901286677105317
black predicted:  0.4585063653073729
num actually black:  0.48519300156579753
domain test accuracy:  0.906071331336782
black pred test:  0.19793084671930303
actual black =  0.14974135583991288
Credit Confusion Matrix White: 
[[2673   64]
 [  40  346]]
False positive white:  0.023383266350018268
Credit Confusion Matrix Black: 
[[376   7]
 [  8 159]]
False positive black:  0.018276762402088774

'''
# Out:
# 'lambda = 0\nlabel trained\ndomain trained\nfeature extractor trained\nEpoch [30/30], Label Loss: 0.3613, Domain Loss: 0.3133\nSource Label Accuracy: 96.33%\nTarget Label Accuracy: 97.27%\nSource Domain Accuracy: 89.32%\nTarget Domain Accuracy: 84.73%\ndomain accuracy on train data:  0.901286677105317\nblack predicted:  0.4585063653073729\nnum actually black:  0.48519300156579753\ndomain test accuracy:  0.906071331336782\nblack pred test:  0.19793084671930303\nactual black =  0.14974135583991288\nCredit Confusion Matrix White: \n[[2673   64]\n [  40  346]]\nFalse positive white:  0.023383266350018268\nCredit Confusion Matrix Black: \n[[376   7]\n [  8 159]]\nFalse positive black:  0.018276762402088774\n\n'

# %%
def write_results(lam, model, test_src, test_targ):
    file_name = 'results_mult_age'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    results = get_results(model, test_src, test_targ, lam)
    # test accuracy-- source, target, and overall
    my_str += 'Label Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
    # domain test accuracy-- source, target, and overall
    my_str += 'Domain Classifier Accuracy (Test Data) \n'
    my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
    my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
    my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
    # false positives-- source, target, and overall
    my_str += 'False Positive Rate (Test Data) \n'
    my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
    my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
    my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
    my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
    
    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)
    
    # parity

# %%
def get_results(model, test_src, test_targ, lam):
    #print('get results model')
    #print(model)
    with torch.no_grad():
        # Label predictor metrics
        source_correct = 0
        source_label_predictions = []
        source_label_true = []
        
        # Domain predictor metrics
        source_dom_correct = 0
        source_dom_predictions = []
        source_dom_true = []
        for data, labels in test_src:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            source_correct += (label_preds == labels).sum().item()
            source_label_predictions += label_preds
            source_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.zeros(data.shape[0]).long()
            source_dom_correct += (domain_preds == domain_true).sum().item()
            source_dom_predictions += domain_preds
            source_dom_true += domain_true
        source_label_accuracy = 100.* source_correct / len(test_src.dataset)
        source_domain_accuracy = 100 * source_dom_correct / len(test_src.dataset)
        source_label_positive_rate = (sum(source_label_predictions)/len(source_label_predictions)).item()

        
        
        
        # FOR TARGET DATA
        # Label predictor metrics
        target_correct = 0
        target_label_predictions = []
        target_label_true = []
        
        # Domain predictor metrics
        target_dom_correct = 0
        target_dom_predictions = []
        target_dom_true = []
        for data, labels in test_targ:
            # Make label predictions
            embedded = model.f(data)
            label_preds = model.lc(embedded)
            _, label_preds = torch.max(label_preds, 1)
            target_correct += (label_preds == labels).sum().item()
            target_label_predictions += label_preds
            target_label_true+= labels
            
            # Make domain predictions
            domain_embedded = grad_reverse(model.f(data), lam)
            domain_preds = model.dc(domain_embedded)
            _, domain_preds = torch.max(domain_preds, 1)
            domain_true = torch.ones(data.shape[0]).long()
            target_dom_correct += (domain_preds == domain_true).sum().item()
            target_dom_predictions += domain_preds
            target_dom_true += domain_true
        target_label_accuracy = 100.* target_correct / len(test_targ.dataset)
        target_domain_accuracy = 100 * target_dom_correct / len(test_targ.dataset)
        target_label_positive_rate = (sum(target_label_predictions)/len(target_label_predictions)).item()

        
        # OVERALL
        overall_label_accuracy = 100.*(target_correct + source_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_domain_accuracy = 100.*(target_dom_correct + source_dom_correct)/(len(test_src.dataset)+len(test_targ.dataset))
        overall_label_positive_rate = ((sum(source_label_predictions) + sum(target_label_predictions))/(len(target_label_predictions)+len(source_label_predictions))).item()

        
        # False positive rates
        conf_matrix = confusion_matrix(source_label_true, source_label_predictions)
        fpr_white = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true, target_label_predictions)
        fpr_black = 100.* conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        conf_matrix = confusion_matrix(target_label_true+source_label_true, target_label_predictions+source_label_predictions)
        fpr_overall = 100. *conf_matrix[0, 1] / (conf_matrix[0, 1] + conf_matrix[0, 0])
        
        
        
        
        
        
        
        
        results = {'source_label_accuracy': source_label_accuracy, 'source_domain_accuracy':source_domain_accuracy,
                  'target_label_accuracy': target_label_accuracy, 'target_domain_accuracy':target_domain_accuracy,
                   'overall_label_accuracy': overall_label_accuracy, 'overall_domain_accuracy': overall_domain_accuracy,
                   'fpr_white': fpr_white, 'fpr_black': fpr_black, 'fpr_overall': fpr_overall, 'source_label_positive_rate': source_label_positive_rate, 'target_label_positive_rate': target_label_positive_rate,
                   'overall_label_positive_rate': overall_label_positive_rate}
        return results

# %%
# For adult only, fine tune the model to be more accurate
lam = 0
model = train_for_lambda(lam)
write_results(lam, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/32], Label Loss: 0.4758, Domain Loss: 0.8557
# Source Label Accuracy: 81.79%
# Target Label Accuracy: 70.21%
# Source Domain Accuracy: 43.80%
# Target Domain Accuracy: 84.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/32], Label Loss: 0.5383, Domain Loss: 0.6776
# Source Label Accuracy: 83.70%
# Target Label Accuracy: 72.60%
# Source Domain Accuracy: 42.65%
# Target Domain Accuracy: 85.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/32], Label Loss: 0.3981, Domain Loss: 0.6395
# Source Label Accuracy: 83.80%
# Target Label Accuracy: 73.94%
# Source Domain Accuracy: 42.86%
# Target Domain Accuracy: 86.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/32], Label Loss: 0.5859, Domain Loss: 0.6290
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 74.24%
# Source Domain Accuracy: 43.12%
# Target Domain Accuracy: 85.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/32], Label Loss: 0.4555, Domain Loss: 0.6177
# Source Label Accuracy: 84.42%
# Target Label Accuracy: 74.42%
# Source Domain Accuracy: 42.94%
# Target Domain Accuracy: 85.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/32], Label Loss: 0.4528, Domain Loss: 0.6100
# Source Label Accuracy: 84.58%
# Target Label Accuracy: 74.44%
# Source Domain Accuracy: 42.43%
# Target Domain Accuracy: 85.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/32], Label Loss: 0.4924, Domain Loss: 0.6178
# Source Label Accuracy: 84.53%
# Target Label Accuracy: 74.53%
# Source Domain Accuracy: 42.47%
# Target Domain Accuracy: 84.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/32], Label Loss: 0.4943, Domain Loss: 0.6074
# Source Label Accuracy: 84.56%
# Target Label Accuracy: 74.68%
# Source Domain Accuracy: 42.48%
# Target Domain Accuracy: 84.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/32], Label Loss: 0.4559, Domain Loss: 0.5793
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 74.82%
# Source Domain Accuracy: 41.62%
# Target Domain Accuracy: 85.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/32], Label Loss: 0.4181, Domain Loss: 0.6005
# Source Label Accuracy: 84.71%
# Target Label Accuracy: 74.93%
# Source Domain Accuracy: 43.12%
# Target Domain Accuracy: 83.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/32], Label Loss: 0.5015, Domain Loss: 0.5773
# Source Label Accuracy: 84.94%
# Target Label Accuracy: 75.01%
# Source Domain Accuracy: 42.13%
# Target Domain Accuracy: 85.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/32], Label Loss: 0.5903, Domain Loss: 0.5713
# Source Label Accuracy: 84.94%
# Target Label Accuracy: 74.86%
# Source Domain Accuracy: 42.67%
# Target Domain Accuracy: 84.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/32], Label Loss: 0.4475, Domain Loss: 0.5789
# Source Label Accuracy: 84.54%
# Target Label Accuracy: 74.93%
# Source Domain Accuracy: 42.18%
# Target Domain Accuracy: 84.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/32], Label Loss: 0.5211, Domain Loss: 0.5589
# Source Label Accuracy: 85.02%
# Target Label Accuracy: 75.12%
# Source Domain Accuracy: 41.21%
# Target Domain Accuracy: 84.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/32], Label Loss: 0.4121, Domain Loss: 0.5751
# Source Label Accuracy: 84.96%
# Target Label Accuracy: 74.88%
# Source Domain Accuracy: 42.79%
# Target Domain Accuracy: 82.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/32], Label Loss: 0.4464, Domain Loss: 0.5581
# Source Label Accuracy: 85.10%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 41.59%
# Target Domain Accuracy: 85.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/32], Label Loss: 0.5939, Domain Loss: 0.5753
# Source Label Accuracy: 84.82%
# Target Label Accuracy: 74.76%
# Source Domain Accuracy: 42.78%
# Target Domain Accuracy: 83.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/32], Label Loss: 0.6480, Domain Loss: 0.5817
# Source Label Accuracy: 84.90%
# Target Label Accuracy: 74.99%
# Source Domain Accuracy: 42.81%
# Target Domain Accuracy: 82.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/32], Label Loss: 0.4277, Domain Loss: 0.5663
# Source Label Accuracy: 85.18%
# Target Label Accuracy: 75.12%
# Source Domain Accuracy: 42.35%
# Target Domain Accuracy: 83.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/32], Label Loss: 0.6344, Domain Loss: 0.5700
# Source Label Accuracy: 84.90%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 43.14%
# Target Domain Accuracy: 82.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [21/32], Label Loss: 0.4603, Domain Loss: 0.5656
# Source Label Accuracy: 84.68%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 42.83%
# Target Domain Accuracy: 83.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [22/32], Label Loss: 0.4926, Domain Loss: 0.5552
# Source Label Accuracy: 84.59%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 42.08%
# Target Domain Accuracy: 83.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [23/32], Label Loss: 0.5209, Domain Loss: 0.5630
# Source Label Accuracy: 85.09%
# Target Label Accuracy: 75.18%
# Source Domain Accuracy: 43.16%
# Target Domain Accuracy: 82.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [24/32], Label Loss: 0.4162, Domain Loss: 0.5505
# Source Label Accuracy: 85.00%
# Target Label Accuracy: 75.01%
# Source Domain Accuracy: 42.48%
# Target Domain Accuracy: 83.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [25/32], Label Loss: 0.5312, Domain Loss: 0.5493
# Source Label Accuracy: 85.28%
# Target Label Accuracy: 75.37%
# Source Domain Accuracy: 42.31%
# Target Domain Accuracy: 83.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [26/32], Label Loss: 0.5339, Domain Loss: 0.5693
# Source Label Accuracy: 84.97%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 43.42%
# Target Domain Accuracy: 82.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [27/32], Label Loss: 0.5311, Domain Loss: 0.5550
# Source Label Accuracy: 84.90%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 43.15%
# Target Domain Accuracy: 82.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [28/32], Label Loss: 0.4679, Domain Loss: 0.5486
# Source Label Accuracy: 84.75%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 43.03%
# Target Domain Accuracy: 83.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [29/32], Label Loss: 0.5527, Domain Loss: 0.5411
# Source Label Accuracy: 84.44%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 42.51%
# Target Domain Accuracy: 82.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [30/32], Label Loss: 0.5081, Domain Loss: 0.5405
# Source Label Accuracy: 84.92%
# Target Label Accuracy: 75.18%
# Source Domain Accuracy: 42.51%
# Target Domain Accuracy: 82.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [31/32], Label Loss: 0.5830, Domain Loss: 0.5329
# Source Label Accuracy: 85.04%
# Target Label Accuracy: 75.41%
# Source Domain Accuracy: 42.38%
# Target Domain Accuracy: 83.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [32/32], Label Loss: 0.5415, Domain Loss: 0.5317
# Source Label Accuracy: 84.75%
# Target Label Accuracy: 75.03%
# Source Domain Accuracy: 42.44%
# Target Domain Accuracy: 82.20%
#
# Lambda: 0
#
# Label Classifier Accuracy (Test Data)
# Source (White): 83.58358358358359
# Target (Black): 75.03142019271051
# Overall: 79.40423789538336
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.8988988988989
# Target (Black): 82.195224130708
# Overall: 70.28355000511823
#
# False Positive Rate (Test Data)
# Source (White): 16.468114926419062
# Target (Black): 29.365329965266813
# (Black FPR) / (White FPR): 1.7831628025717337
# Overall: 21.95220193340494

# %%
#write_results(0.8, model, source_test, target_test)

# %%
models = {}
for lam in range(10):
    lam = 0.1*lam
    model = train_for_lambda(lam)
    models[lam] = model
    write_results(lam, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4232, Domain Loss: 0.9995
# Source Label Accuracy: 78.22%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 79.01%
# Target Domain Accuracy: 87.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4238, Domain Loss: 1.0814
# Source Label Accuracy: 78.43%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 76.13%
# Target Domain Accuracy: 89.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4207, Domain Loss: 1.1666
# Source Label Accuracy: 78.86%
# Target Label Accuracy: 86.60%
# Source Domain Accuracy: 76.44%
# Target Domain Accuracy: 88.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3666, Domain Loss: 1.1788
# Source Label Accuracy: 78.65%
# Target Label Accuracy: 87.22%
# Source Domain Accuracy: 74.29%
# Target Domain Accuracy: 92.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4550, Domain Loss: 1.2183
# Source Label Accuracy: 79.09%
# Target Label Accuracy: 86.63%
# Source Domain Accuracy: 76.36%
# Target Domain Accuracy: 89.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4533, Domain Loss: 1.2019
# Source Label Accuracy: 78.93%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 76.44%
# Target Domain Accuracy: 91.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4189, Domain Loss: 1.2043
# Source Label Accuracy: 79.02%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 78.51%
# Target Domain Accuracy: 89.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4038, Domain Loss: 1.2022
# Source Label Accuracy: 79.19%
# Target Label Accuracy: 87.28%
# Source Domain Accuracy: 78.05%
# Target Domain Accuracy: 90.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4458, Domain Loss: 1.1957
# Source Label Accuracy: 79.00%
# Target Label Accuracy: 86.97%
# Source Domain Accuracy: 77.50%
# Target Domain Accuracy: 90.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4404, Domain Loss: 1.1984
# Source Label Accuracy: 79.39%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 77.44%
# Target Domain Accuracy: 91.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4493, Domain Loss: 1.2212
# Source Label Accuracy: 78.88%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 80.02%
# Target Domain Accuracy: 88.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4244, Domain Loss: 1.2107
# Source Label Accuracy: 78.91%
# Target Label Accuracy: 86.63%
# Source Domain Accuracy: 77.59%
# Target Domain Accuracy: 91.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4836, Domain Loss: 1.2078
# Source Label Accuracy: 79.26%
# Target Label Accuracy: 87.06%
# Source Domain Accuracy: 78.80%
# Target Domain Accuracy: 89.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3983, Domain Loss: 1.2012
# Source Label Accuracy: 79.34%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 76.41%
# Target Domain Accuracy: 91.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4161, Domain Loss: 1.2065
# Source Label Accuracy: 79.02%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 75.83%
# Target Domain Accuracy: 92.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3864, Domain Loss: 1.1998
# Source Label Accuracy: 78.76%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 75.89%
# Target Domain Accuracy: 92.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3908, Domain Loss: 1.1982
# Source Label Accuracy: 78.71%
# Target Label Accuracy: 86.60%
# Source Domain Accuracy: 78.12%
# Target Domain Accuracy: 90.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4609, Domain Loss: 1.2049
# Source Label Accuracy: 79.26%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 78.19%
# Target Domain Accuracy: 90.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5365, Domain Loss: 1.1995
# Source Label Accuracy: 78.78%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 78.26%
# Target Domain Accuracy: 90.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3611, Domain Loss: 1.2196
# Source Label Accuracy: 78.55%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 78.82%
# Target Domain Accuracy: 89.75%
#
# Lambda: 0.0
#
# Label Classifier Accuracy (Test Data)
# Source (White): 74.04287901990811
# Target (Black): 87.09478234022846
# Overall: 78.37035520524107
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 74.90045941807044
# Target (Black): 89.74992281568386
# Overall: 79.82393284880746
#
# False Positive Rate (Test Data)
# Source (White): 32.8368017524644
# Target (Black): 12.59979173897952
# (Black FPR) / (White FPR): 0.38370946823510016
# Overall: 25.006715014773032
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.3812, Domain Loss: 0.9457
# Source Label Accuracy: 77.72%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 76.72%
# Target Domain Accuracy: 77.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4407, Domain Loss: 0.9120
# Source Label Accuracy: 78.82%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 73.07%
# Target Domain Accuracy: 74.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4919, Domain Loss: 1.0675
# Source Label Accuracy: 78.85%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 75.84%
# Target Domain Accuracy: 75.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3508, Domain Loss: 1.0939
# Source Label Accuracy: 78.79%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 74.57%
# Target Domain Accuracy: 78.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4069, Domain Loss: 1.1046
# Source Label Accuracy: 79.20%
# Target Label Accuracy: 86.11%
# Source Domain Accuracy: 74.80%
# Target Domain Accuracy: 79.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4168, Domain Loss: 1.1050
# Source Label Accuracy: 78.85%
# Target Label Accuracy: 86.51%
# Source Domain Accuracy: 74.87%
# Target Domain Accuracy: 77.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.3632, Domain Loss: 1.1047
# Source Label Accuracy: 78.81%
# Target Label Accuracy: 87.68%
# Source Domain Accuracy: 74.32%
# Target Domain Accuracy: 79.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.3319, Domain Loss: 1.1185
# Source Label Accuracy: 79.20%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 74.47%
# Target Domain Accuracy: 80.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3834, Domain Loss: 1.1205
# Source Label Accuracy: 78.84%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 75.62%
# Target Domain Accuracy: 78.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4639, Domain Loss: 1.1718
# Source Label Accuracy: 78.98%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 75.09%
# Target Domain Accuracy: 80.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4236, Domain Loss: 1.1479
# Source Label Accuracy: 79.18%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 74.49%
# Target Domain Accuracy: 82.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.3515, Domain Loss: 1.1697
# Source Label Accuracy: 79.25%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 77.44%
# Target Domain Accuracy: 78.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4674, Domain Loss: 1.1622
# Source Label Accuracy: 79.41%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 75.36%
# Target Domain Accuracy: 78.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4291, Domain Loss: 1.1801
# Source Label Accuracy: 78.81%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 73.66%
# Target Domain Accuracy: 80.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3802, Domain Loss: 1.1615
# Source Label Accuracy: 79.42%
# Target Label Accuracy: 87.40%
# Source Domain Accuracy: 72.52%
# Target Domain Accuracy: 81.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4576, Domain Loss: 1.1829
# Source Label Accuracy: 78.89%
# Target Label Accuracy: 87.40%
# Source Domain Accuracy: 74.21%
# Target Domain Accuracy: 83.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3746, Domain Loss: 1.1656
# Source Label Accuracy: 78.62%
# Target Label Accuracy: 86.63%
# Source Domain Accuracy: 72.70%
# Target Domain Accuracy: 83.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3784, Domain Loss: 1.1615
# Source Label Accuracy: 78.64%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 74.68%
# Target Domain Accuracy: 77.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3513, Domain Loss: 1.1617
# Source Label Accuracy: 79.35%
# Target Label Accuracy: 87.43%
# Source Domain Accuracy: 74.12%
# Target Domain Accuracy: 79.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5206, Domain Loss: 1.1706
# Source Label Accuracy: 79.55%
# Target Label Accuracy: 87.16%
# Source Domain Accuracy: 74.04%
# Target Domain Accuracy: 81.94%
#
# Lambda: 0.1
#
# Label Classifier Accuracy (Test Data)
# Source (White): 74.57886676875957
# Target (Black): 87.15652979314603
# Overall: 78.74910430955062
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 68.68300153139357
# Target (Black): 81.9388700216116
# Overall: 73.078104207186
#
# False Positive Rate (Test Data)
# Source (White): 31.741511500547645
# Target (Black): 12.49566122874002
# (Black FPR) / (White FPR): 0.3936693823961228
# Overall: 24.294923448831586
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4543, Domain Loss: 0.9342
# Source Label Accuracy: 77.92%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 16.47%
# Target Domain Accuracy: 49.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.3855, Domain Loss: 1.0946
# Source Label Accuracy: 78.23%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 10.31%
# Target Domain Accuracy: 44.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4969, Domain Loss: 1.1062
# Source Label Accuracy: 78.45%
# Target Label Accuracy: 86.51%
# Source Domain Accuracy: 14.11%
# Target Domain Accuracy: 31.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5009, Domain Loss: 1.0295
# Source Label Accuracy: 78.75%
# Target Label Accuracy: 87.16%
# Source Domain Accuracy: 8.61%
# Target Domain Accuracy: 43.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4038, Domain Loss: 1.0228
# Source Label Accuracy: 78.50%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 13.40%
# Target Domain Accuracy: 29.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4017, Domain Loss: 1.0082
# Source Label Accuracy: 78.59%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 7.81%
# Target Domain Accuracy: 46.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4058, Domain Loss: 0.9866
# Source Label Accuracy: 78.78%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 8.37%
# Target Domain Accuracy: 38.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4923, Domain Loss: 1.0183
# Source Label Accuracy: 78.32%
# Target Label Accuracy: 86.05%
# Source Domain Accuracy: 7.73%
# Target Domain Accuracy: 44.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.3811, Domain Loss: 1.0159
# Source Label Accuracy: 78.78%
# Target Label Accuracy: 87.22%
# Source Domain Accuracy: 4.93%
# Target Domain Accuracy: 51.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5940, Domain Loss: 1.0603
# Source Label Accuracy: 78.77%
# Target Label Accuracy: 86.51%
# Source Domain Accuracy: 8.66%
# Target Domain Accuracy: 43.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4722, Domain Loss: 1.0450
# Source Label Accuracy: 78.76%
# Target Label Accuracy: 87.06%
# Source Domain Accuracy: 11.44%
# Target Domain Accuracy: 33.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5655, Domain Loss: 1.0491
# Source Label Accuracy: 78.50%
# Target Label Accuracy: 87.25%
# Source Domain Accuracy: 8.02%
# Target Domain Accuracy: 46.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4559, Domain Loss: 1.0663
# Source Label Accuracy: 78.64%
# Target Label Accuracy: 87.37%
# Source Domain Accuracy: 8.98%
# Target Domain Accuracy: 40.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4151, Domain Loss: 1.0035
# Source Label Accuracy: 78.81%
# Target Label Accuracy: 87.50%
# Source Domain Accuracy: 6.92%
# Target Domain Accuracy: 51.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3786, Domain Loss: 1.0938
# Source Label Accuracy: 79.15%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 12.44%
# Target Domain Accuracy: 32.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.3257, Domain Loss: 0.9194
# Source Label Accuracy: 78.46%
# Target Label Accuracy: 87.13%
# Source Domain Accuracy: 7.65%
# Target Domain Accuracy: 47.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4963, Domain Loss: 1.0532
# Source Label Accuracy: 78.87%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 15.32%
# Target Domain Accuracy: 29.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3682, Domain Loss: 0.9564
# Source Label Accuracy: 79.07%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 7.73%
# Target Domain Accuracy: 49.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4783, Domain Loss: 1.1261
# Source Label Accuracy: 79.18%
# Target Label Accuracy: 86.97%
# Source Domain Accuracy: 15.24%
# Target Domain Accuracy: 27.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5006, Domain Loss: 0.9885
# Source Label Accuracy: 78.64%
# Target Label Accuracy: 87.40%
# Source Domain Accuracy: 7.03%
# Target Domain Accuracy: 45.82%
#
# Lambda: 0.2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.15467075038285
# Target (Black): 87.4035196048163
# Overall: 77.87900501586651
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 8.514548238897397
# Target (Black): 45.816610064834826
# Overall: 20.88238304841847
#
# False Positive Rate (Test Data)
# Source (White): 34.52354874041621
# Target (Black): 12.217979868101354
# (Black FPR) / (White FPR): 0.3539027798089003
# Overall: 25.893096964813324
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4713, Domain Loss: 0.8822
# Source Label Accuracy: 77.32%
# Target Label Accuracy: 87.28%
# Source Domain Accuracy: 6.33%
# Target Domain Accuracy: 55.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5421, Domain Loss: 0.9577
# Source Label Accuracy: 77.34%
# Target Label Accuracy: 86.42%
# Source Domain Accuracy: 4.69%
# Target Domain Accuracy: 55.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4125, Domain Loss: 0.9162
# Source Label Accuracy: 78.54%
# Target Label Accuracy: 87.34%
# Source Domain Accuracy: 7.21%
# Target Domain Accuracy: 44.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5534, Domain Loss: 0.9619
# Source Label Accuracy: 78.25%
# Target Label Accuracy: 86.94%
# Source Domain Accuracy: 4.69%
# Target Domain Accuracy: 51.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5051, Domain Loss: 0.9820
# Source Label Accuracy: 78.61%
# Target Label Accuracy: 87.25%
# Source Domain Accuracy: 5.14%
# Target Domain Accuracy: 49.00%
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4750, Domain Loss: 0.9959
# Source Label Accuracy: 78.32%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 4.53%
# Target Domain Accuracy: 53.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4118, Domain Loss: 0.9333
# Source Label Accuracy: 77.71%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 6.69%
# Target Domain Accuracy: 44.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5774, Domain Loss: 0.9871
# Source Label Accuracy: 78.23%
# Target Label Accuracy: 86.63%
# Source Domain Accuracy: 6.65%
# Target Domain Accuracy: 44.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4923, Domain Loss: 0.9718
# Source Label Accuracy: 79.24%
# Target Label Accuracy: 87.25%
# Source Domain Accuracy: 6.28%
# Target Domain Accuracy: 47.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4717, Domain Loss: 0.9805
# Source Label Accuracy: 78.83%
# Target Label Accuracy: 86.94%
# Source Domain Accuracy: 4.04%
# Target Domain Accuracy: 57.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4041, Domain Loss: 0.9891
# Source Label Accuracy: 78.38%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 5.90%
# Target Domain Accuracy: 49.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5237, Domain Loss: 0.9461
# Source Label Accuracy: 78.96%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 6.02%
# Target Domain Accuracy: 53.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3854, Domain Loss: 1.1042
# Source Label Accuracy: 78.28%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 9.56%
# Target Domain Accuracy: 41.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.3925, Domain Loss: 0.9795
# Source Label Accuracy: 78.78%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 5.36%
# Target Domain Accuracy: 51.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4272, Domain Loss: 1.0595
# Source Label Accuracy: 78.64%
# Target Label Accuracy: 86.97%
# Source Domain Accuracy: 6.32%
# Target Domain Accuracy: 49.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4077, Domain Loss: 0.9651
# Source Label Accuracy: 78.80%
# Target Label Accuracy: 87.09%
# Source Domain Accuracy: 3.47%
# Target Domain Accuracy: 60.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4408, Domain Loss: 1.1180
# Source Label Accuracy: 79.08%
# Target Label Accuracy: 86.32%
# Source Domain Accuracy: 9.45%
# Target Domain Accuracy: 40.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4341, Domain Loss: 0.9106
# Source Label Accuracy: 78.56%
# Target Label Accuracy: 87.00%
# Source Domain Accuracy: 3.31%
# Target Domain Accuracy: 61.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4435, Domain Loss: 1.0930
# Source Label Accuracy: 78.82%
# Target Label Accuracy: 87.16%
# Source Domain Accuracy: 6.43%
# Target Domain Accuracy: 50.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5125, Domain Loss: 1.0539
# Source Label Accuracy: 78.79%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 4.73%
# Target Domain Accuracy: 59.22%
#
# Lambda: 0.30000000000000004
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.58346094946401
# Target (Black): 86.26119172584131
# Overall: 77.78687685535878
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 5.114854517611026
# Target (Black): 59.2158073479469
# Overall: 23.052513051489406
#
# False Positive Rate (Test Data)
# Source (White): 33.84446878422782
# Target (Black): 13.71051718153419
# (Black FPR) / (White FPR): 0.40510363063885807
# Overall: 26.0542573193661
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4618, Domain Loss: 0.9679
# Source Label Accuracy: 77.51%
# Target Label Accuracy: 86.54%
# Source Domain Accuracy: 7.37%
# Target Domain Accuracy: 49.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4282, Domain Loss: 0.8179
# Source Label Accuracy: 77.62%
# Target Label Accuracy: 86.45%
# Source Domain Accuracy: 6.16%
# Target Domain Accuracy: 48.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5094, Domain Loss: 0.8792
# Source Label Accuracy: 78.67%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 7.00%
# Target Domain Accuracy: 46.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3944, Domain Loss: 0.9832
# Source Label Accuracy: 78.35%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 5.57%
# Target Domain Accuracy: 50.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.3658, Domain Loss: 1.0252
# Source Label Accuracy: 77.71%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 6.85%
# Target Domain Accuracy: 46.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4724, Domain Loss: 0.9685
# Source Label Accuracy: 78.12%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 4.80%
# Target Domain Accuracy: 52.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.3736, Domain Loss: 0.8609
# Source Label Accuracy: 78.12%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 5.38%
# Target Domain Accuracy: 51.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4446, Domain Loss: 0.8974
# Source Label Accuracy: 78.61%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 6.07%
# Target Domain Accuracy: 49.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4669, Domain Loss: 0.9060
# Source Label Accuracy: 78.42%
# Target Label Accuracy: 86.32%
# Source Domain Accuracy: 5.96%
# Target Domain Accuracy: 49.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4564, Domain Loss: 0.9971
# Source Label Accuracy: 78.77%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 4.32%
# Target Domain Accuracy: 54.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3861, Domain Loss: 0.9979
# Source Label Accuracy: 78.36%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 6.79%
# Target Domain Accuracy: 46.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4341, Domain Loss: 0.9448
# Source Label Accuracy: 78.49%
# Target Label Accuracy: 87.13%
# Source Domain Accuracy: 5.09%
# Target Domain Accuracy: 52.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4269, Domain Loss: 0.9078
# Source Label Accuracy: 78.73%
# Target Label Accuracy: 87.16%
# Source Domain Accuracy: 5.41%
# Target Domain Accuracy: 51.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4089, Domain Loss: 0.9147
# Source Label Accuracy: 79.05%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 5.76%
# Target Domain Accuracy: 51.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4689, Domain Loss: 0.9584
# Source Label Accuracy: 78.80%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 6.00%
# Target Domain Accuracy: 50.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4298, Domain Loss: 1.0175
# Source Label Accuracy: 79.11%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 5.33%
# Target Domain Accuracy: 53.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4362, Domain Loss: 0.9443
# Source Label Accuracy: 78.56%
# Target Label Accuracy: 87.28%
# Source Domain Accuracy: 5.00%
# Target Domain Accuracy: 52.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4757, Domain Loss: 1.0057
# Source Label Accuracy: 78.94%
# Target Label Accuracy: 86.54%
# Source Domain Accuracy: 8.68%
# Target Domain Accuracy: 41.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4920, Domain Loss: 0.9975
# Source Label Accuracy: 78.79%
# Target Label Accuracy: 87.71%
# Source Domain Accuracy: 6.77%
# Target Domain Accuracy: 47.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4638, Domain Loss: 1.0726
# Source Label Accuracy: 78.97%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 8.90%
# Target Domain Accuracy: 39.58%
#
# Lambda: 0.4
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.62940275650843
# Target (Black): 85.98332818771226
# Overall: 77.72545808168697
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 9.846860643185298
# Target (Black): 39.58011732016055
# Overall: 19.70518988637527
#
# False Positive Rate (Test Data)
# Source (White): 33.559693318729465
# Target (Black): 14.02290871225269
# (Black FPR) / (White FPR): 0.4178497276203233
# Overall: 26.000537201181842
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5659, Domain Loss: 1.0575
# Source Label Accuracy: 75.52%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 6.83%
# Target Domain Accuracy: 49.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.3770, Domain Loss: 0.9877
# Source Label Accuracy: 77.80%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 6.74%
# Target Domain Accuracy: 45.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4165, Domain Loss: 0.9281
# Source Label Accuracy: 77.87%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 6.76%
# Target Domain Accuracy: 47.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3830, Domain Loss: 0.9477
# Source Label Accuracy: 77.83%
# Target Label Accuracy: 86.42%
# Source Domain Accuracy: 6.58%
# Target Domain Accuracy: 47.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4296, Domain Loss: 0.9125
# Source Label Accuracy: 78.85%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 5.97%
# Target Domain Accuracy: 50.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4238, Domain Loss: 0.9707
# Source Label Accuracy: 78.17%
# Target Label Accuracy: 85.86%
# Source Domain Accuracy: 7.19%
# Target Domain Accuracy: 46.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5037, Domain Loss: 0.9836
# Source Label Accuracy: 77.95%
# Target Label Accuracy: 86.20%
# Source Domain Accuracy: 5.24%
# Target Domain Accuracy: 49.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4919, Domain Loss: 0.9909
# Source Label Accuracy: 79.01%
# Target Label Accuracy: 86.60%
# Source Domain Accuracy: 6.78%
# Target Domain Accuracy: 47.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4866, Domain Loss: 1.0970
# Source Label Accuracy: 78.11%
# Target Label Accuracy: 86.85%
# Source Domain Accuracy: 7.66%
# Target Domain Accuracy: 45.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4334, Domain Loss: 0.9969
# Source Label Accuracy: 79.15%
# Target Label Accuracy: 87.13%
# Source Domain Accuracy: 6.81%
# Target Domain Accuracy: 49.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3773, Domain Loss: 0.9807
# Source Label Accuracy: 78.36%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 8.51%
# Target Domain Accuracy: 43.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4101, Domain Loss: 0.9293
# Source Label Accuracy: 78.47%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 6.80%
# Target Domain Accuracy: 49.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4075, Domain Loss: 1.0070
# Source Label Accuracy: 78.85%
# Target Label Accuracy: 86.20%
# Source Domain Accuracy: 6.78%
# Target Domain Accuracy: 48.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4468, Domain Loss: 0.9029
# Source Label Accuracy: 78.64%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 7.11%
# Target Domain Accuracy: 51.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4046, Domain Loss: 0.9994
# Source Label Accuracy: 77.95%
# Target Label Accuracy: 85.15%
# Source Domain Accuracy: 9.88%
# Target Domain Accuracy: 39.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4374, Domain Loss: 0.9195
# Source Label Accuracy: 79.00%
# Target Label Accuracy: 86.45%
# Source Domain Accuracy: 6.04%
# Target Domain Accuracy: 54.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4170, Domain Loss: 0.9462
# Source Label Accuracy: 78.55%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 10.06%
# Target Domain Accuracy: 38.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5274, Domain Loss: 1.0624
# Source Label Accuracy: 78.66%
# Target Label Accuracy: 86.14%
# Source Domain Accuracy: 7.38%
# Target Domain Accuracy: 45.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4446, Domain Loss: 1.1201
# Source Label Accuracy: 78.61%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 10.75%
# Target Domain Accuracy: 36.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4025, Domain Loss: 1.1523
# Source Label Accuracy: 78.58%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 6.96%
# Target Domain Accuracy: 46.68%
#
# Lambda: 0.5
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.29249617151608
# Target (Black): 86.26119172584131
# Overall: 77.59238407206469
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 7.320061255742726
# Target (Black): 46.68107440568077
# Overall: 20.370559934486643
#
# False Positive Rate (Test Data)
# Source (White): 34.12924424972618
# Target (Black): 13.641096841374523
# (Black FPR) / (White FPR): 0.3996893907629955
# Overall: 26.201987644372817
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4863, Domain Loss: 1.0738
# Source Label Accuracy: 76.55%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 7.83%
# Target Domain Accuracy: 45.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4600, Domain Loss: 0.9389
# Source Label Accuracy: 77.09%
# Target Label Accuracy: 86.91%
# Source Domain Accuracy: 7.40%
# Target Domain Accuracy: 43.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5013, Domain Loss: 0.9923
# Source Label Accuracy: 77.80%
# Target Label Accuracy: 86.57%
# Source Domain Accuracy: 7.79%
# Target Domain Accuracy: 45.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4485, Domain Loss: 1.0117
# Source Label Accuracy: 78.12%
# Target Label Accuracy: 86.51%
# Source Domain Accuracy: 8.22%
# Target Domain Accuracy: 43.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4743, Domain Loss: 1.0170
# Source Label Accuracy: 78.58%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 7.94%
# Target Domain Accuracy: 46.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4420, Domain Loss: 1.0908
# Source Label Accuracy: 78.25%
# Target Label Accuracy: 86.23%
# Source Domain Accuracy: 7.05%
# Target Domain Accuracy: 44.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4270, Domain Loss: 1.0857
# Source Label Accuracy: 78.26%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 7.72%
# Target Domain Accuracy: 47.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4008, Domain Loss: 0.9623
# Source Label Accuracy: 78.37%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 7.13%
# Target Domain Accuracy: 46.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4236, Domain Loss: 0.9324
# Source Label Accuracy: 78.14%
# Target Label Accuracy: 86.29%
# Source Domain Accuracy: 8.14%
# Target Domain Accuracy: 46.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4852, Domain Loss: 1.0644
# Source Label Accuracy: 78.82%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 9.04%
# Target Domain Accuracy: 42.24%
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4660, Domain Loss: 0.9363
# Source Label Accuracy: 78.36%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 8.36%
# Target Domain Accuracy: 46.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4382, Domain Loss: 1.0771
# Source Label Accuracy: 78.06%
# Target Label Accuracy: 86.54%
# Source Domain Accuracy: 9.74%
# Target Domain Accuracy: 41.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4173, Domain Loss: 0.8855
# Source Label Accuracy: 78.95%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 7.59%
# Target Domain Accuracy: 48.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4093, Domain Loss: 1.1577
# Source Label Accuracy: 78.89%
# Target Label Accuracy: 87.43%
# Source Domain Accuracy: 11.83%
# Target Domain Accuracy: 32.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.3802, Domain Loss: 0.9126
# Source Label Accuracy: 78.77%
# Target Label Accuracy: 86.54%
# Source Domain Accuracy: 8.66%
# Target Domain Accuracy: 45.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4239, Domain Loss: 1.1355
# Source Label Accuracy: 79.08%
# Target Label Accuracy: 86.94%
# Source Domain Accuracy: 10.12%
# Target Domain Accuracy: 39.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4470, Domain Loss: 0.9727
# Source Label Accuracy: 78.27%
# Target Label Accuracy: 85.49%
# Source Domain Accuracy: 7.55%
# Target Domain Accuracy: 47.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3738, Domain Loss: 0.9688
# Source Label Accuracy: 78.36%
# Target Label Accuracy: 86.45%
# Source Domain Accuracy: 7.18%
# Target Domain Accuracy: 48.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.3981, Domain Loss: 1.1045
# Source Label Accuracy: 78.82%
# Target Label Accuracy: 86.32%
# Source Domain Accuracy: 8.16%
# Target Domain Accuracy: 47.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4539, Domain Loss: 1.0990
# Source Label Accuracy: 78.89%
# Target Label Accuracy: 86.42%
# Source Domain Accuracy: 8.12%
# Target Domain Accuracy: 46.77%
#
# Lambda: 0.6000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.9509954058193
# Target (Black): 86.41556035813522
# Overall: 78.08373426143925
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 8.453292496171516
# Target (Black): 46.77369558505712
# Overall: 21.158767529941652
#
# False Positive Rate (Test Data)
# Source (White): 32.968236582694416
# Target (Black): 13.432835820895523
# (Black FPR) / (White FPR): 0.4074478107799871
# Overall: 25.409615901154982
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4268, Domain Loss: 0.9700
# Source Label Accuracy: 76.88%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 8.73%
# Target Domain Accuracy: 43.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4550, Domain Loss: 0.9928
# Source Label Accuracy: 77.72%
# Target Label Accuracy: 87.13%
# Source Domain Accuracy: 7.88%
# Target Domain Accuracy: 44.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4994, Domain Loss: 1.0222
# Source Label Accuracy: 77.63%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 9.71%
# Target Domain Accuracy: 41.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5066, Domain Loss: 1.1196
# Source Label Accuracy: 78.02%
# Target Label Accuracy: 86.79%
# Source Domain Accuracy: 7.90%
# Target Domain Accuracy: 44.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4364, Domain Loss: 1.1230
# Source Label Accuracy: 78.43%
# Target Label Accuracy: 86.20%
# Source Domain Accuracy: 8.57%
# Target Domain Accuracy: 43.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4361, Domain Loss: 0.9151
# Source Label Accuracy: 78.58%
# Target Label Accuracy: 87.00%
# Source Domain Accuracy: 6.83%
# Target Domain Accuracy: 45.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4850, Domain Loss: 1.0170
# Source Label Accuracy: 78.57%
# Target Label Accuracy: 87.19%
# Source Domain Accuracy: 6.71%
# Target Domain Accuracy: 48.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4107, Domain Loss: 1.0057
# Source Label Accuracy: 78.06%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 7.44%
# Target Domain Accuracy: 44.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4615, Domain Loss: 0.9848
# Source Label Accuracy: 79.20%
# Target Label Accuracy: 86.51%
# Source Domain Accuracy: 7.56%
# Target Domain Accuracy: 46.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5039, Domain Loss: 0.9931
# Source Label Accuracy: 79.14%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 9.06%
# Target Domain Accuracy: 41.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4405, Domain Loss: 1.0730
# Source Label Accuracy: 79.29%
# Target Label Accuracy: 87.16%
# Source Domain Accuracy: 7.60%
# Target Domain Accuracy: 46.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5041, Domain Loss: 1.0481
# Source Label Accuracy: 78.61%
# Target Label Accuracy: 85.83%
# Source Domain Accuracy: 7.67%
# Target Domain Accuracy: 46.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4278, Domain Loss: 1.0952
# Source Label Accuracy: 79.11%
# Target Label Accuracy: 86.42%
# Source Domain Accuracy: 8.74%
# Target Domain Accuracy: 42.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4766, Domain Loss: 1.0039
# Source Label Accuracy: 79.36%
# Target Label Accuracy: 86.72%
# Source Domain Accuracy: 9.04%
# Target Domain Accuracy: 43.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4625, Domain Loss: 1.1681
# Source Label Accuracy: 79.06%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 10.89%
# Target Domain Accuracy: 35.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4076, Domain Loss: 0.9551
# Source Label Accuracy: 79.02%
# Target Label Accuracy: 86.20%
# Source Domain Accuracy: 9.83%
# Target Domain Accuracy: 41.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4436, Domain Loss: 1.0597
# Source Label Accuracy: 78.40%
# Target Label Accuracy: 85.83%
# Source Domain Accuracy: 8.52%
# Target Domain Accuracy: 45.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4602, Domain Loss: 1.1093
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 87.28%
# Source Domain Accuracy: 10.53%
# Target Domain Accuracy: 39.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5037, Domain Loss: 0.8889
# Source Label Accuracy: 78.88%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 6.69%
# Target Domain Accuracy: 49.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3337, Domain Loss: 1.2063
# Source Label Accuracy: 78.48%
# Target Label Accuracy: 86.11%
# Source Domain Accuracy: 10.97%
# Target Domain Accuracy: 37.20%
#
# Lambda: 0.7000000000000001
#
# Label Classifier Accuracy (Test Data)
# Source (White): 73.76722817764166
# Target (Black): 86.10682309354739
# Overall: 77.85853209130924
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 11.791730474732006
# Target (Black): 37.20284038283421
# Overall: 20.217013000307094
#
# False Positive Rate (Test Data)
# Source (White): 33.231106243154436
# Target (Black): 13.745227351614023
# (Black FPR) / (White FPR): 0.4136253319717733
# Overall: 25.69164652162235
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.4951, Domain Loss: 0.9938
# Source Label Accuracy: 77.42%
# Target Label Accuracy: 86.29%
# Source Domain Accuracy: 9.05%
# Target Domain Accuracy: 43.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.3752, Domain Loss: 0.9571
# Source Label Accuracy: 77.77%
# Target Label Accuracy: 87.00%
# Source Domain Accuracy: 6.64%
# Target Domain Accuracy: 45.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5106, Domain Loss: 0.9427
# Source Label Accuracy: 78.75%
# Target Label Accuracy: 86.38%
# Source Domain Accuracy: 8.85%
# Target Domain Accuracy: 42.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3293, Domain Loss: 1.1072
# Source Label Accuracy: 77.91%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 8.98%
# Target Domain Accuracy: 42.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4636, Domain Loss: 1.1302
# Source Label Accuracy: 78.84%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 9.79%
# Target Domain Accuracy: 39.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.3755, Domain Loss: 1.0563
# Source Label Accuracy: 78.31%
# Target Label Accuracy: 85.74%
# Source Domain Accuracy: 7.74%
# Target Domain Accuracy: 43.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4937, Domain Loss: 1.0574
# Source Label Accuracy: 79.34%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 9.67%
# Target Domain Accuracy: 40.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4534, Domain Loss: 1.0125
# Source Label Accuracy: 78.68%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 8.22%
# Target Domain Accuracy: 43.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4374, Domain Loss: 1.1023
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 8.17%
# Target Domain Accuracy: 44.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4530, Domain Loss: 1.1034
# Source Label Accuracy: 78.98%
# Target Label Accuracy: 86.26%
# Source Domain Accuracy: 6.70%
# Target Domain Accuracy: 48.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4430, Domain Loss: 1.0432
# Source Label Accuracy: 78.43%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 8.35%
# Target Domain Accuracy: 42.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4740, Domain Loss: 1.0643
# Source Label Accuracy: 78.56%
# Target Label Accuracy: 85.24%
# Source Domain Accuracy: 6.87%
# Target Domain Accuracy: 47.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4493, Domain Loss: 1.0001
# Source Label Accuracy: 78.55%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 8.08%
# Target Domain Accuracy: 43.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4941, Domain Loss: 0.9724
# Source Label Accuracy: 78.79%
# Target Label Accuracy: 86.88%
# Source Domain Accuracy: 6.09%
# Target Domain Accuracy: 49.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5121, Domain Loss: 1.1860
# Source Label Accuracy: 78.76%
# Target Label Accuracy: 86.48%
# Source Domain Accuracy: 10.20%
# Target Domain Accuracy: 38.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4284, Domain Loss: 0.9837
# Source Label Accuracy: 79.76%
# Target Label Accuracy: 87.37%
# Source Domain Accuracy: 7.84%
# Target Domain Accuracy: 45.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4749, Domain Loss: 1.0276
# Source Label Accuracy: 78.93%
# Target Label Accuracy: 86.66%
# Source Domain Accuracy: 9.84%
# Target Domain Accuracy: 40.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4189, Domain Loss: 0.9610
# Source Label Accuracy: 79.25%
# Target Label Accuracy: 86.85%
# Source Domain Accuracy: 7.50%
# Target Domain Accuracy: 47.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4306, Domain Loss: 0.9565
# Source Label Accuracy: 78.94%
# Target Label Accuracy: 86.17%
# Source Domain Accuracy: 10.03%
# Target Domain Accuracy: 37.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.3584, Domain Loss: 1.0719
# Source Label Accuracy: 79.06%
# Target Label Accuracy: 85.61%
# Source Domain Accuracy: 11.62%
# Target Domain Accuracy: 34.92%
#
# Lambda: 0.8
#
# Label Classifier Accuracy (Test Data)
# Source (White): 74.64012251148546
# Target (Black): 85.61284347020685
# Overall: 78.27822704473334
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 12.404287901990811
# Target (Black): 34.918184624884226
# Overall: 19.86897328283345
#
# False Positive Rate (Test Data)
# Source (White): 31.259583789704273
# Target (Black): 14.404720583130857
# (Black FPR) / (White FPR): 0.46080973694458555
# Overall: 24.738114423851734
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5578, Domain Loss: 1.0459
# Source Label Accuracy: 77.50%
# Target Label Accuracy: 85.98%
# Source Domain Accuracy: 10.81%
# Target Domain Accuracy: 39.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5739, Domain Loss: 0.9744
# Source Label Accuracy: 78.26%
# Target Label Accuracy: 87.00%
# Source Domain Accuracy: 8.96%
# Target Domain Accuracy: 42.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5329, Domain Loss: 1.0104
# Source Label Accuracy: 78.30%
# Target Label Accuracy: 86.60%
# Source Domain Accuracy: 10.07%
# Target Domain Accuracy: 38.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.3866, Domain Loss: 0.9604
# Source Label Accuracy: 78.78%
# Target Label Accuracy: 86.11%
# Source Domain Accuracy: 9.99%
# Target Domain Accuracy: 40.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4046, Domain Loss: 0.9545
# Source Label Accuracy: 78.51%
# Target Label Accuracy: 86.38%
# Source Domain Accuracy: 11.22%
# Target Domain Accuracy: 37.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.3906, Domain Loss: 1.0902
# Source Label Accuracy: 79.12%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 9.70%
# Target Domain Accuracy: 39.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4964, Domain Loss: 1.0738
# Source Label Accuracy: 79.21%
# Target Label Accuracy: 86.05%
# Source Domain Accuracy: 10.21%
# Target Domain Accuracy: 39.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4360, Domain Loss: 1.0205
# Source Label Accuracy: 78.77%
# Target Label Accuracy: 86.76%
# Source Domain Accuracy: 10.01%
# Target Domain Accuracy: 39.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4332, Domain Loss: 1.0330
# Source Label Accuracy: 78.82%
# Target Label Accuracy: 86.20%
# Source Domain Accuracy: 9.35%
# Target Domain Accuracy: 42.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4982, Domain Loss: 1.0353
# Source Label Accuracy: 79.06%
# Target Label Accuracy: 87.06%
# Source Domain Accuracy: 9.23%
# Target Domain Accuracy: 39.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4522, Domain Loss: 1.0766
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 86.38%
# Source Domain Accuracy: 10.07%
# Target Domain Accuracy: 42.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4210, Domain Loss: 1.0394
# Source Label Accuracy: 79.18%
# Target Label Accuracy: 86.82%
# Source Domain Accuracy: 9.99%
# Target Domain Accuracy: 39.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3937, Domain Loss: 1.0651
# Source Label Accuracy: 79.38%
# Target Label Accuracy: 86.42%
# Source Domain Accuracy: 10.83%
# Target Domain Accuracy: 39.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4604, Domain Loss: 0.8571
# Source Label Accuracy: 78.94%
# Target Label Accuracy: 86.35%
# Source Domain Accuracy: 10.19%
# Target Domain Accuracy: 38.25%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4774, Domain Loss: 1.0211
# Source Label Accuracy: 78.73%
# Target Label Accuracy: 85.55%
# Source Domain Accuracy: 10.51%
# Target Domain Accuracy: 39.77%
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4257, Domain Loss: 0.9080
# Source Label Accuracy: 78.99%
# Target Label Accuracy: 87.03%
# Source Domain Accuracy: 10.28%
# Target Domain Accuracy: 39.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4489, Domain Loss: 1.1633
# Source Label Accuracy: 79.39%
# Target Label Accuracy: 86.45%
# Source Domain Accuracy: 10.06%
# Target Domain Accuracy: 39.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.3768, Domain Loss: 0.9731
# Source Label Accuracy: 79.37%
# Target Label Accuracy: 85.92%
# Source Domain Accuracy: 10.64%
# Target Domain Accuracy: 35.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4287, Domain Loss: 1.0659
# Source Label Accuracy: 78.33%
# Target Label Accuracy: 85.27%
# Source Domain Accuracy: 7.89%
# Target Domain Accuracy: 45.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4269, Domain Loss: 1.0128
# Source Label Accuracy: 79.29%
# Target Label Accuracy: 86.69%
# Source Domain Accuracy: 6.82%
# Target Domain Accuracy: 47.05%
#
# Lambda: 0.9
#
# Label Classifier Accuracy (Test Data)
# Source (White): 75.17611026033691
# Target (Black): 86.69342389626428
# Overall: 78.99477940423789
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 7.304747320061256
# Target (Black): 47.051559123186166
# Overall: 20.483161019551645
#
# False Positive Rate (Test Data)
# Source (White): 30.36144578313253
# Target (Black): 13.155154460256854
# (Black FPR) / (White FPR): 0.43328484928623767
# Overall: 23.704002148804726

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'final_results/results_conf_age_37_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(10):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        model_file = 'model_results/adult_age_37_'+str(lam)+'_'+str(i)+'.pt'
        torch.save(model.state_dict(), model_file)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        my_str += 'Source Label Positive Rate: ' + str(results['source_label_positive_rate']) + '\n'
        my_str += 'Target Label Positive Rate: ' + str(results['target_label_positive_rate']) + '\n'
        my_str += 'Overall Label Positive Rate: ' + str(results['overall_label_positive_rate']) + '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
for l in range(10):
    l = l * .1
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6574, Domain Loss: 0.7973
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 69.04%
# Source Domain Accuracy: 45.13%
# Target Domain Accuracy: 83.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.3868, Domain Loss: 0.7085
# Source Label Accuracy: 83.68%
# Target Label Accuracy: 72.25%
# Source Domain Accuracy: 43.37%
# Target Domain Accuracy: 85.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5391, Domain Loss: 0.7075
# Source Label Accuracy: 83.76%
# Target Label Accuracy: 74.19%
# Source Domain Accuracy: 42.85%
# Target Domain Accuracy: 84.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4372, Domain Loss: 0.7253
# Source Label Accuracy: 83.64%
# Target Label Accuracy: 74.34%
# Source Domain Accuracy: 43.37%
# Target Domain Accuracy: 84.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4454, Domain Loss: 0.7125
# Source Label Accuracy: 84.11%
# Target Label Accuracy: 74.55%
# Source Domain Accuracy: 43.26%
# Target Domain Accuracy: 84.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5480, Domain Loss: 0.7359
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 74.30%
# Source Domain Accuracy: 43.34%
# Target Domain Accuracy: 83.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5300, Domain Loss: 0.6947
# Source Label Accuracy: 84.44%
# Target Label Accuracy: 74.68%
# Source Domain Accuracy: 42.62%
# Target Domain Accuracy: 84.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5062, Domain Loss: 0.6991
# Source Label Accuracy: 84.47%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 42.55%
# Target Domain Accuracy: 84.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5314, Domain Loss: 0.6911
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 74.74%
# Source Domain Accuracy: 43.41%
# Target Domain Accuracy: 83.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4898, Domain Loss: 0.6532
# Source Label Accuracy: 84.66%
# Target Label Accuracy: 74.86%
# Source Domain Accuracy: 43.23%
# Target Domain Accuracy: 84.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4439, Domain Loss: 0.6510
# Source Label Accuracy: 84.56%
# Target Label Accuracy: 74.88%
# Source Domain Accuracy: 42.68%
# Target Domain Accuracy: 84.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5353, Domain Loss: 0.6488
# Source Label Accuracy: 84.55%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 44.11%
# Target Domain Accuracy: 83.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4714, Domain Loss: 0.6574
# Source Label Accuracy: 84.89%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 43.42%
# Target Domain Accuracy: 83.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5343, Domain Loss: 0.6508
# Source Label Accuracy: 84.81%
# Target Label Accuracy: 75.32%
# Source Domain Accuracy: 43.31%
# Target Domain Accuracy: 83.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5511, Domain Loss: 0.6378
# Source Label Accuracy: 84.55%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 43.17%
# Target Domain Accuracy: 84.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4843, Domain Loss: 0.6326
# Source Label Accuracy: 84.86%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 42.92%
# Target Domain Accuracy: 84.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.6923, Domain Loss: 0.6313
# Source Label Accuracy: 84.51%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 43.33%
# Target Domain Accuracy: 83.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5216, Domain Loss: 0.6208
# Source Label Accuracy: 84.54%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 42.61%
# Target Domain Accuracy: 84.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5718, Domain Loss: 0.6201
# Source Label Accuracy: 84.89%
# Target Label Accuracy: 75.37%
# Source Domain Accuracy: 43.26%
# Target Domain Accuracy: 83.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4977, Domain Loss: 0.6078
# Source Label Accuracy: 85.00%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 43.41%
# Target Domain Accuracy: 83.45%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5662, Domain Loss: 0.5618
# Source Label Accuracy: 81.91%
# Target Label Accuracy: 69.19%
# Source Domain Accuracy: 42.95%
# Target Domain Accuracy: 85.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5625, Domain Loss: 0.5564
# Source Label Accuracy: 83.09%
# Target Label Accuracy: 73.00%
# Source Domain Accuracy: 41.31%
# Target Domain Accuracy: 86.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.6667, Domain Loss: 0.5630
# Source Label Accuracy: 83.74%
# Target Label Accuracy: 73.82%
# Source Domain Accuracy: 41.71%
# Target Domain Accuracy: 87.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5118, Domain Loss: 0.6324
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 74.40%
# Source Domain Accuracy: 43.06%
# Target Domain Accuracy: 85.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4875, Domain Loss: 0.6445
# Source Label Accuracy: 84.41%
# Target Label Accuracy: 74.80%
# Source Domain Accuracy: 42.50%
# Target Domain Accuracy: 85.74%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5988, Domain Loss: 0.6340
# Source Label Accuracy: 84.60%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 42.76%
# Target Domain Accuracy: 86.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4697, Domain Loss: 0.6524
# Source Label Accuracy: 84.31%
# Target Label Accuracy: 74.84%
# Source Domain Accuracy: 42.70%
# Target Domain Accuracy: 85.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5404, Domain Loss: 0.6346
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 74.99%
# Source Domain Accuracy: 41.64%
# Target Domain Accuracy: 86.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5135, Domain Loss: 0.6543
# Source Label Accuracy: 84.50%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 42.55%
# Target Domain Accuracy: 85.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4906, Domain Loss: 0.6514
# Source Label Accuracy: 84.22%
# Target Label Accuracy: 75.03%
# Source Domain Accuracy: 42.43%
# Target Domain Accuracy: 85.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4887, Domain Loss: 0.6429
# Source Label Accuracy: 84.61%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 42.04%
# Target Domain Accuracy: 85.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5265, Domain Loss: 0.6107
# Source Label Accuracy: 84.51%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 42.22%
# Target Domain Accuracy: 85.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.6467, Domain Loss: 0.6139
# Source Label Accuracy: 84.62%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 42.06%
# Target Domain Accuracy: 85.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4622, Domain Loss: 0.6226
# Source Label Accuracy: 84.76%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 41.99%
# Target Domain Accuracy: 84.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4686, Domain Loss: 0.6337
# Source Label Accuracy: 84.74%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 41.93%
# Target Domain Accuracy: 84.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5789, Domain Loss: 0.6703
# Source Label Accuracy: 85.04%
# Target Label Accuracy: 75.30%
# Source Domain Accuracy: 44.24%
# Target Domain Accuracy: 82.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5251, Domain Loss: 0.6250
# Source Label Accuracy: 84.58%
# Target Label Accuracy: 75.39%
# Source Domain Accuracy: 41.89%
# Target Domain Accuracy: 85.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4877, Domain Loss: 0.6246
# Source Label Accuracy: 84.58%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 42.41%
# Target Domain Accuracy: 84.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4302, Domain Loss: 0.6225
# Source Label Accuracy: 84.80%
# Target Label Accuracy: 75.20%
# Source Domain Accuracy: 43.78%
# Target Domain Accuracy: 83.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5190, Domain Loss: 0.6458
# Source Label Accuracy: 85.10%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 44.51%
# Target Domain Accuracy: 82.43%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5916, Domain Loss: 0.7199
# Source Label Accuracy: 81.63%
# Target Label Accuracy: 69.08%
# Source Domain Accuracy: 42.18%
# Target Domain Accuracy: 86.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4990, Domain Loss: 0.7328
# Source Label Accuracy: 83.39%
# Target Label Accuracy: 72.85%
# Source Domain Accuracy: 43.01%
# Target Domain Accuracy: 86.11%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4603, Domain Loss: 0.6943
# Source Label Accuracy: 83.75%
# Target Label Accuracy: 73.88%
# Source Domain Accuracy: 41.74%
# Target Domain Accuracy: 87.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4838, Domain Loss: 0.7361
# Source Label Accuracy: 84.28%
# Target Label Accuracy: 74.30%
# Source Domain Accuracy: 41.65%
# Target Domain Accuracy: 86.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4137, Domain Loss: 0.7288
# Source Label Accuracy: 84.34%
# Target Label Accuracy: 74.65%
# Source Domain Accuracy: 41.80%
# Target Domain Accuracy: 86.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5128, Domain Loss: 0.7594
# Source Label Accuracy: 84.34%
# Target Label Accuracy: 74.86%
# Source Domain Accuracy: 43.30%
# Target Domain Accuracy: 85.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4919, Domain Loss: 0.7186
# Source Label Accuracy: 84.36%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 41.87%
# Target Domain Accuracy: 86.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4863, Domain Loss: 0.7247
# Source Label Accuracy: 84.32%
# Target Label Accuracy: 74.65%
# Source Domain Accuracy: 41.92%
# Target Domain Accuracy: 86.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5388, Domain Loss: 0.7450
# Source Label Accuracy: 84.60%
# Target Label Accuracy: 75.03%
# Source Domain Accuracy: 43.23%
# Target Domain Accuracy: 84.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4103, Domain Loss: 0.7333
# Source Label Accuracy: 84.48%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 42.40%
# Target Domain Accuracy: 85.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4882, Domain Loss: 0.7223
# Source Label Accuracy: 84.97%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 43.02%
# Target Domain Accuracy: 84.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4388, Domain Loss: 0.7149
# Source Label Accuracy: 84.82%
# Target Label Accuracy: 75.32%
# Source Domain Accuracy: 42.89%
# Target Domain Accuracy: 84.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5635, Domain Loss: 0.6877
# Source Label Accuracy: 84.94%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 42.70%
# Target Domain Accuracy: 84.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4996, Domain Loss: 0.7096
# Source Label Accuracy: 84.83%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 43.16%
# Target Domain Accuracy: 83.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4761, Domain Loss: 0.6691
# Source Label Accuracy: 84.70%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 42.44%
# Target Domain Accuracy: 83.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4629, Domain Loss: 0.6476
# Source Label Accuracy: 84.79%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 43.04%
# Target Domain Accuracy: 83.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5480, Domain Loss: 0.6501
# Source Label Accuracy: 84.86%
# Target Label Accuracy: 75.28%
# Source Domain Accuracy: 43.80%
# Target Domain Accuracy: 82.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5788, Domain Loss: 0.6068
# Source Label Accuracy: 84.71%
# Target Label Accuracy: 75.41%
# Source Domain Accuracy: 42.10%
# Target Domain Accuracy: 84.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5180, Domain Loss: 0.6159
# Source Label Accuracy: 84.82%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 42.47%
# Target Domain Accuracy: 83.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5455, Domain Loss: 0.5995
# Source Label Accuracy: 85.12%
# Target Label Accuracy: 75.56%
# Source Domain Accuracy: 42.51%
# Target Domain Accuracy: 83.64%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.72372372372372
# Target (Black): 75.5550900712191
# Overall: 79.73180468829972
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.2982982982983
# Target (Black): 83.6405529953917
# Overall: 70.68277203398506
#
# False Positive Rate (Test Data)
# Source (White): 16.327960756832514
# Target (Black): 28.512788127565518
# (Black FPR) / (White FPR): 1.7462553072118454
# Overall: 21.509129967776584
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4704650044441223
# Overall Label Positive Rate: 0.3628825843334198
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6112, Domain Loss: 0.6513
# Source Label Accuracy: 81.83%
# Target Label Accuracy: 68.83%
# Source Domain Accuracy: 43.80%
# Target Domain Accuracy: 84.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5242, Domain Loss: 0.5798
# Source Label Accuracy: 83.71%
# Target Label Accuracy: 72.79%
# Source Domain Accuracy: 42.79%
# Target Domain Accuracy: 85.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5217, Domain Loss: 0.5892
# Source Label Accuracy: 83.65%
# Target Label Accuracy: 73.84%
# Source Domain Accuracy: 42.76%
# Target Domain Accuracy: 84.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.6250, Domain Loss: 0.6111
# Source Label Accuracy: 84.25%
# Target Label Accuracy: 74.05%
# Source Domain Accuracy: 43.51%
# Target Domain Accuracy: 84.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4958, Domain Loss: 0.5898
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 74.51%
# Source Domain Accuracy: 42.79%
# Target Domain Accuracy: 85.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5264, Domain Loss: 0.6016
# Source Label Accuracy: 84.56%
# Target Label Accuracy: 74.82%
# Source Domain Accuracy: 42.93%
# Target Domain Accuracy: 84.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4732, Domain Loss: 0.6139
# Source Label Accuracy: 84.28%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 43.26%
# Target Domain Accuracy: 83.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5694, Domain Loss: 0.5848
# Source Label Accuracy: 84.66%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 42.51%
# Target Domain Accuracy: 84.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4778, Domain Loss: 0.5858
# Source Label Accuracy: 84.54%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 42.96%
# Target Domain Accuracy: 84.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5593, Domain Loss: 0.5774
# Source Label Accuracy: 84.42%
# Target Label Accuracy: 75.09%
# Source Domain Accuracy: 41.93%
# Target Domain Accuracy: 84.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4782, Domain Loss: 0.5896
# Source Label Accuracy: 84.44%
# Target Label Accuracy: 75.09%
# Source Domain Accuracy: 43.30%
# Target Domain Accuracy: 84.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4625, Domain Loss: 0.6000
# Source Label Accuracy: 84.56%
# Target Label Accuracy: 74.93%
# Source Domain Accuracy: 44.02%
# Target Domain Accuracy: 82.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4753, Domain Loss: 0.5736
# Source Label Accuracy: 84.84%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 42.89%
# Target Domain Accuracy: 84.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5288, Domain Loss: 0.5714
# Source Label Accuracy: 84.70%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 43.37%
# Target Domain Accuracy: 83.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4567, Domain Loss: 0.5468
# Source Label Accuracy: 84.77%
# Target Label Accuracy: 75.20%
# Source Domain Accuracy: 42.12%
# Target Domain Accuracy: 84.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5017, Domain Loss: 0.5737
# Source Label Accuracy: 84.73%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 44.01%
# Target Domain Accuracy: 82.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4246, Domain Loss: 0.5470
# Source Label Accuracy: 84.68%
# Target Label Accuracy: 75.30%
# Source Domain Accuracy: 43.51%
# Target Domain Accuracy: 83.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5534, Domain Loss: 0.5304
# Source Label Accuracy: 84.80%
# Target Label Accuracy: 75.45%
# Source Domain Accuracy: 43.65%
# Target Domain Accuracy: 83.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4823, Domain Loss: 0.5232
# Source Label Accuracy: 85.09%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 42.74%
# Target Domain Accuracy: 83.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4755, Domain Loss: 0.5270
# Source Label Accuracy: 84.98%
# Target Label Accuracy: 75.32%
# Source Domain Accuracy: 43.48%
# Target Domain Accuracy: 82.40%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.72372372372372
# Target (Black): 75.5550900712191
# Overall: 79.73180468829972
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.2982982982983
# Target (Black): 83.6405529953917
# Overall: 70.68277203398506
#
# False Positive Rate (Test Data)
# Source (White): 16.327960756832514
# Target (Black): 28.512788127565518
# (Black FPR) / (White FPR): 1.7462553072118454
# Overall: 21.509129967776584
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4704650044441223
# Overall Label Positive Rate: 0.3628825843334198
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.64364364364364
# Target (Black): 75.32467532467533
# Overall: 79.57825775412017
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.31931931931932
# Target (Black): 82.40469208211144
# Overall: 70.60088033575596
#
# False Positive Rate (Test Data)
# Source (White): 16.39803784162579
# Target (Black): 28.95484685822545
# (Black FPR) / (White FPR): 1.7657507037046032
# Overall: 21.737379162191193
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3648275136947632
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6036, Domain Loss: 0.6422
# Source Label Accuracy: 81.71%
# Target Label Accuracy: 68.94%
# Source Domain Accuracy: 43.82%
# Target Domain Accuracy: 85.69%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5116, Domain Loss: 0.6075
# Source Label Accuracy: 83.41%
# Target Label Accuracy: 73.02%
# Source Domain Accuracy: 42.96%
# Target Domain Accuracy: 85.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5606, Domain Loss: 0.6032
# Source Label Accuracy: 83.89%
# Target Label Accuracy: 73.65%
# Source Domain Accuracy: 42.89%
# Target Domain Accuracy: 86.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5727, Domain Loss: 0.6189
# Source Label Accuracy: 83.90%
# Target Label Accuracy: 74.21%
# Source Domain Accuracy: 42.32%
# Target Domain Accuracy: 86.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4466, Domain Loss: 0.6193
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 74.49%
# Source Domain Accuracy: 42.56%
# Target Domain Accuracy: 85.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5699, Domain Loss: 0.6201
# Source Label Accuracy: 84.14%
# Target Label Accuracy: 74.63%
# Source Domain Accuracy: 42.48%
# Target Domain Accuracy: 85.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5125, Domain Loss: 0.6190
# Source Label Accuracy: 84.48%
# Target Label Accuracy: 74.82%
# Source Domain Accuracy: 43.13%
# Target Domain Accuracy: 85.27%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.6760, Domain Loss: 0.6049
# Source Label Accuracy: 84.54%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 42.37%
# Target Domain Accuracy: 85.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5126, Domain Loss: 0.5864
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 40.91%
# Target Domain Accuracy: 86.99%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5075, Domain Loss: 0.6282
# Source Label Accuracy: 84.88%
# Target Label Accuracy: 74.84%
# Source Domain Accuracy: 42.41%
# Target Domain Accuracy: 84.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.6089, Domain Loss: 0.5938
# Source Label Accuracy: 84.79%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 40.95%
# Target Domain Accuracy: 86.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5059, Domain Loss: 0.5908
# Source Label Accuracy: 84.82%
# Target Label Accuracy: 74.95%
# Source Domain Accuracy: 41.89%
# Target Domain Accuracy: 85.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5683, Domain Loss: 0.5728
# Source Label Accuracy: 84.70%
# Target Label Accuracy: 74.76%
# Source Domain Accuracy: 42.54%
# Target Domain Accuracy: 85.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5113, Domain Loss: 0.5675
# Source Label Accuracy: 84.88%
# Target Label Accuracy: 74.91%
# Source Domain Accuracy: 42.28%
# Target Domain Accuracy: 84.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4720, Domain Loss: 0.5503
# Source Label Accuracy: 84.80%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 42.56%
# Target Domain Accuracy: 85.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4093, Domain Loss: 0.5764
# Source Label Accuracy: 84.66%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 43.01%
# Target Domain Accuracy: 83.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5621, Domain Loss: 0.5575
# Source Label Accuracy: 84.77%
# Target Label Accuracy: 75.32%
# Source Domain Accuracy: 43.16%
# Target Domain Accuracy: 82.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4926, Domain Loss: 0.5279
# Source Label Accuracy: 84.95%
# Target Label Accuracy: 75.39%
# Source Domain Accuracy: 42.80%
# Target Domain Accuracy: 84.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5207, Domain Loss: 0.5318
# Source Label Accuracy: 84.38%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 42.92%
# Target Domain Accuracy: 82.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5206, Domain Loss: 0.5270
# Source Label Accuracy: 84.97%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 42.93%
# Target Domain Accuracy: 83.24%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.72372372372372
# Target (Black): 75.5550900712191
# Overall: 79.73180468829972
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.2982982982983
# Target (Black): 83.6405529953917
# Overall: 70.68277203398506
#
# False Positive Rate (Test Data)
# Source (White): 16.327960756832514
# Target (Black): 28.512788127565518
# (Black FPR) / (White FPR): 1.7462553072118454
# Overall: 21.509129967776584
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4704650044441223
# Overall Label Positive Rate: 0.3628825843334198
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.64364364364364
# Target (Black): 75.32467532467533
# Overall: 79.57825775412017
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.31931931931932
# Target (Black): 82.40469208211144
# Overall: 70.60088033575596
#
# False Positive Rate (Test Data)
# Source (White): 16.39803784162579
# Target (Black): 28.95484685822545
# (Black FPR) / (White FPR): 1.7657507037046032
# Overall: 21.737379162191193
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.8038038038038
# Target (Black): 75.24088814411395
# Overall: 79.61920360323472
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.47847847847848
# Target (Black): 83.24256388772518
# Overall: 70.58040741119869
#
# False Positive Rate (Test Data)
# Source (White): 16.281242700303668
# Target (Black): 29.01799810546258
# (Black FPR) / (White FPR): 1.7822962681418264
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3646227717399597
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6274, Domain Loss: 0.6243
# Source Label Accuracy: 81.13%
# Target Label Accuracy: 68.29%
# Source Domain Accuracy: 43.56%
# Target Domain Accuracy: 85.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4563, Domain Loss: 0.6321
# Source Label Accuracy: 83.04%
# Target Label Accuracy: 72.45%
# Source Domain Accuracy: 42.69%
# Target Domain Accuracy: 86.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4769, Domain Loss: 0.6840
# Source Label Accuracy: 83.88%
# Target Label Accuracy: 73.77%
# Source Domain Accuracy: 43.71%
# Target Domain Accuracy: 85.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4290, Domain Loss: 0.7112
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 74.30%
# Source Domain Accuracy: 43.86%
# Target Domain Accuracy: 85.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4384, Domain Loss: 0.6951
# Source Label Accuracy: 84.62%
# Target Label Accuracy: 74.65%
# Source Domain Accuracy: 43.34%
# Target Domain Accuracy: 86.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5843, Domain Loss: 0.6751
# Source Label Accuracy: 84.58%
# Target Label Accuracy: 74.70%
# Source Domain Accuracy: 42.89%
# Target Domain Accuracy: 86.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4796, Domain Loss: 0.6958
# Source Label Accuracy: 84.89%
# Target Label Accuracy: 74.63%
# Source Domain Accuracy: 43.57%
# Target Domain Accuracy: 85.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5386, Domain Loss: 0.6940
# Source Label Accuracy: 84.70%
# Target Label Accuracy: 74.70%
# Source Domain Accuracy: 43.39%
# Target Domain Accuracy: 85.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4593, Domain Loss: 0.6757
# Source Label Accuracy: 84.84%
# Target Label Accuracy: 74.55%
# Source Domain Accuracy: 43.16%
# Target Domain Accuracy: 85.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5254, Domain Loss: 0.6699
# Source Label Accuracy: 84.48%
# Target Label Accuracy: 75.01%
# Source Domain Accuracy: 43.00%
# Target Domain Accuracy: 85.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.3935, Domain Loss: 0.6869
# Source Label Accuracy: 84.66%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 43.51%
# Target Domain Accuracy: 84.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.6837, Domain Loss: 0.6698
# Source Label Accuracy: 84.59%
# Target Label Accuracy: 74.63%
# Source Domain Accuracy: 43.20%
# Target Domain Accuracy: 84.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4227, Domain Loss: 0.6329
# Source Label Accuracy: 84.40%
# Target Label Accuracy: 74.80%
# Source Domain Accuracy: 43.42%
# Target Domain Accuracy: 84.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5561, Domain Loss: 0.6337
# Source Label Accuracy: 84.90%
# Target Label Accuracy: 75.03%
# Source Domain Accuracy: 43.90%
# Target Domain Accuracy: 84.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5780, Domain Loss: 0.5949
# Source Label Accuracy: 84.59%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 43.22%
# Target Domain Accuracy: 84.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4595, Domain Loss: 0.6004
# Source Label Accuracy: 85.32%
# Target Label Accuracy: 75.05%
# Source Domain Accuracy: 43.85%
# Target Domain Accuracy: 82.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5274, Domain Loss: 0.5711
# Source Label Accuracy: 84.67%
# Target Label Accuracy: 74.99%
# Source Domain Accuracy: 44.03%
# Target Domain Accuracy: 82.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5621, Domain Loss: 0.5810
# Source Label Accuracy: 84.62%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 44.02%
# Target Domain Accuracy: 81.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.7146, Domain Loss: 0.5704
# Source Label Accuracy: 84.73%
# Target Label Accuracy: 75.20%
# Source Domain Accuracy: 45.11%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4898, Domain Loss: 0.5691
# Source Label Accuracy: 84.92%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 44.68%
# Target Domain Accuracy: 80.62%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.72372372372372
# Target (Black): 75.5550900712191
# Overall: 79.73180468829972
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.2982982982983
# Target (Black): 83.6405529953917
# Overall: 70.68277203398506
#
# False Positive Rate (Test Data)
# Source (White): 16.327960756832514
# Target (Black): 28.512788127565518
# (Black FPR) / (White FPR): 1.7462553072118454
# Overall: 21.509129967776584
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4704650044441223
# Overall Label Positive Rate: 0.3628825843334198
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.64364364364364
# Target (Black): 75.32467532467533
# Overall: 79.57825775412017
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.31931931931932
# Target (Black): 82.40469208211144
# Overall: 70.60088033575596
#
# False Positive Rate (Test Data)
# Source (White): 16.39803784162579
# Target (Black): 28.95484685822545
# (Black FPR) / (White FPR): 1.7657507037046032
# Overall: 21.737379162191193
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.8038038038038
# Target (Black): 75.24088814411395
# Overall: 79.61920360323472
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.47847847847848
# Target (Black): 83.24256388772518
# Overall: 70.58040741119869
#
# False Positive Rate (Test Data)
# Source (White): 16.281242700303668
# Target (Black): 29.01799810546258
# (Black FPR) / (White FPR): 1.7822962681418264
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3646227717399597
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.6036036036036
# Target (Black): 74.96857980728949
# Overall: 79.38376497082608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.77977977977978
# Target (Black): 80.62421449518224
# Overall: 69.9662196744805
#
# False Positive Rate (Test Data)
# Source (White): 16.514832982947908
# Target (Black): 29.365329965266813
# (Black FPR) / (White FPR): 1.7781184947851094
# Overall: 21.97905477980666
#
# Source Label Positive Rate: 0.26206207275390625
# Target Label Positive Rate: 0.4759112000465393
# Overall Label Positive Rate: 0.3665677011013031
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5734, Domain Loss: 0.7056
# Source Label Accuracy: 81.80%
# Target Label Accuracy: 68.31%
# Source Domain Accuracy: 44.16%
# Target Domain Accuracy: 82.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4364, Domain Loss: 0.6473
# Source Label Accuracy: 83.42%
# Target Label Accuracy: 72.56%
# Source Domain Accuracy: 44.06%
# Target Domain Accuracy: 83.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4808, Domain Loss: 0.6638
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 73.65%
# Source Domain Accuracy: 43.48%
# Target Domain Accuracy: 83.75%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5281, Domain Loss: 0.6469
# Source Label Accuracy: 84.29%
# Target Label Accuracy: 74.17%
# Source Domain Accuracy: 42.88%
# Target Domain Accuracy: 84.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4370, Domain Loss: 0.6592
# Source Label Accuracy: 84.33%
# Target Label Accuracy: 74.55%
# Source Domain Accuracy: 43.44%
# Target Domain Accuracy: 83.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4314, Domain Loss: 0.6504
# Source Label Accuracy: 84.27%
# Target Label Accuracy: 74.63%
# Source Domain Accuracy: 43.50%
# Target Domain Accuracy: 83.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5572, Domain Loss: 0.6392
# Source Label Accuracy: 84.30%
# Target Label Accuracy: 74.76%
# Source Domain Accuracy: 43.20%
# Target Domain Accuracy: 83.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4587, Domain Loss: 0.6429
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 74.74%
# Source Domain Accuracy: 42.16%
# Target Domain Accuracy: 83.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4520, Domain Loss: 0.6348
# Source Label Accuracy: 84.50%
# Target Label Accuracy: 74.88%
# Source Domain Accuracy: 41.99%
# Target Domain Accuracy: 84.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5145, Domain Loss: 0.6197
# Source Label Accuracy: 84.84%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 42.99%
# Target Domain Accuracy: 83.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4629, Domain Loss: 0.5739
# Source Label Accuracy: 85.40%
# Target Label Accuracy: 74.99%
# Source Domain Accuracy: 41.63%
# Target Domain Accuracy: 84.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5458, Domain Loss: 0.5999
# Source Label Accuracy: 84.57%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 42.42%
# Target Domain Accuracy: 82.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4206, Domain Loss: 0.5732
# Source Label Accuracy: 84.71%
# Target Label Accuracy: 75.14%
# Source Domain Accuracy: 42.36%
# Target Domain Accuracy: 84.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5490, Domain Loss: 0.5581
# Source Label Accuracy: 84.89%
# Target Label Accuracy: 75.09%
# Source Domain Accuracy: 42.31%
# Target Domain Accuracy: 84.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4099, Domain Loss: 0.5697
# Source Label Accuracy: 84.69%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 43.28%
# Target Domain Accuracy: 82.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4962, Domain Loss: 0.5696
# Source Label Accuracy: 84.88%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 43.43%
# Target Domain Accuracy: 82.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5478, Domain Loss: 0.5373
# Source Label Accuracy: 84.78%
# Target Label Accuracy: 75.20%
# Source Domain Accuracy: 42.53%
# Target Domain Accuracy: 84.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4504, Domain Loss: 0.5432
# Source Label Accuracy: 84.54%
# Target Label Accuracy: 75.28%
# Source Domain Accuracy: 43.39%
# Target Domain Accuracy: 82.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5704, Domain Loss: 0.5406
# Source Label Accuracy: 84.79%
# Target Label Accuracy: 75.20%
# Source Domain Accuracy: 42.19%
# Target Domain Accuracy: 84.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4874, Domain Loss: 0.5335
# Source Label Accuracy: 84.78%
# Target Label Accuracy: 75.26%
# Source Domain Accuracy: 41.84%
# Target Domain Accuracy: 84.39%
#
# Lambda: 0.0
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.54354354354355
# Target (Black): 75.13615416841223
# Overall: 79.43494728221927
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.27927927927928
# Target (Black): 83.45203183912861
# Overall: 71.09223052513052
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.752695969558958
# Overall: 21.831364124597208
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47255969047546387
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.68368368368368
# Target (Black): 75.34562211981567
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 60.38038038038038
# Target (Black): 82.42563887725179
# Overall: 71.15364929880234
#
# False Positive Rate (Test Data)
# Source (White): 16.374678813361363
# Target (Black): 28.891695610988318
# (Black FPR) / (White FPR): 1.7644129659149927
# Overall: 21.697099892588614
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36452043056488037
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.72372372372372
# Target (Black): 75.5550900712191
# Overall: 79.73180468829972
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.2982982982983
# Target (Black): 83.6405529953917
# Overall: 70.68277203398506
#
# False Positive Rate (Test Data)
# Source (White): 16.327960756832514
# Target (Black): 28.512788127565518
# (Black FPR) / (White FPR): 1.7462553072118454
# Overall: 21.509129967776584
#
# Source Label Positive Rate: 0.26006007194519043
# Target Label Positive Rate: 0.4704650044441223
# Overall Label Positive Rate: 0.3628825843334198
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.64364364364364
# Target (Black): 75.32467532467533
# Overall: 79.57825775412017
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.31931931931932
# Target (Black): 82.40469208211144
# Overall: 70.60088033575596
#
# False Positive Rate (Test Data)
# Source (White): 16.39803784162579
# Target (Black): 28.95484685822545
# (Black FPR) / (White FPR): 1.7657507037046032
# Overall: 21.737379162191193
#
# Source Label Positive Rate: 0.2604604661464691
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.3648275136947632
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.8038038038038
# Target (Black): 75.24088814411395
# Overall: 79.61920360323472
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.47847847847848
# Target (Black): 83.24256388772518
# Overall: 70.58040741119869
#
# ...
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5917, Domain Loss: 0.5149
# Source Label Accuracy: 84.22%
# Target Label Accuracy: 74.38%
# Source Domain Accuracy: 40.07%
# Target Domain Accuracy: 81.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4451, Domain Loss: 0.5681
# Source Label Accuracy: 84.63%
# Target Label Accuracy: 74.65%
# Source Domain Accuracy: 40.59%
# Target Domain Accuracy: 77.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5758, Domain Loss: 0.5657
# Source Label Accuracy: 84.65%
# Target Label Accuracy: 74.78%
# Source Domain Accuracy: 40.69%
# Target Domain Accuracy: 74.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5135, Domain Loss: 0.5418
# Source Label Accuracy: 84.74%
# Target Label Accuracy: 74.99%
# Source Domain Accuracy: 43.06%
# Target Domain Accuracy: 68.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4710, Domain Loss: 0.4812
# Source Label Accuracy: 84.45%
# Target Label Accuracy: 75.01%
# Source Domain Accuracy: 42.04%
# Target Domain Accuracy: 68.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5388, Domain Loss: 0.5911
# Source Label Accuracy: 84.56%
# Target Label Accuracy: 74.97%
# Source Domain Accuracy: 44.58%
# Target Domain Accuracy: 65.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5257, Domain Loss: 0.5197
# Source Label Accuracy: 84.53%
# Target Label Accuracy: 75.24%
# Source Domain Accuracy: 43.97%
# Target Domain Accuracy: 65.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5365, Domain Loss: 0.5761
# Source Label Accuracy: 84.89%
# Target Label Accuracy: 75.16%
# Source Domain Accuracy: 43.10%
# Target Domain Accuracy: 66.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4579, Domain Loss: 0.5424
# Source Label Accuracy: 85.10%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 43.67%
# Target Domain Accuracy: 65.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4632, Domain Loss: 0.5593
# Source Label Accuracy: 84.94%
# Target Label Accuracy: 75.43%
# Source Domain Accuracy: 44.18%
# Target Domain Accuracy: 64.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5328, Domain Loss: 0.6685
# Source Label Accuracy: 84.93%
# Target Label Accuracy: 75.37%
# Source Domain Accuracy: 45.19%
# Target Domain Accuracy: 62.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4808, Domain Loss: 0.5705
# Source Label Accuracy: 84.42%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 43.99%
# Target Domain Accuracy: 63.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4991, Domain Loss: 0.5349
# Source Label Accuracy: 85.00%
# Target Label Accuracy: 75.30%
# Source Domain Accuracy: 44.44%
# Target Domain Accuracy: 64.20%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4741, Domain Loss: 0.6765
# Source Label Accuracy: 84.74%
# Target Label Accuracy: 75.51%
# Source Domain Accuracy: 44.50%
# Target Domain Accuracy: 63.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5663, Domain Loss: 0.5668
# Source Label Accuracy: 84.79%
# Target Label Accuracy: 75.32%
# Source Domain Accuracy: 42.55%
# Target Domain Accuracy: 65.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.6730, Domain Loss: 0.5289
# Source Label Accuracy: 85.11%
# Target Label Accuracy: 75.37%
# Source Domain Accuracy: 44.01%
# Target Domain Accuracy: 64.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4543, Domain Loss: 0.5640
# Source Label Accuracy: 84.69%
# Target Label Accuracy: 75.35%
# Source Domain Accuracy: 43.92%
# Target Domain Accuracy: 63.22%
#
# Lambda: 0.9
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.50350350350351
# Target (Black): 75.15710096355258
# Overall: 79.42471081994063
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.04204204204204
# Target (Black): 64.43234185169669
# Overall: 63.21015457058041
#
# False Positive Rate (Test Data)
# Source (White): 16.654987152534453
# Target (Black): 29.081149352699715
# (Black FPR) / (White FPR): 1.7460925719341864
# Overall: 21.93877551020408
#
# Source Label Positive Rate: 0.26346346735954285
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.366362988948822
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.66366366366367
# Target (Black): 75.51319648093842
# Overall: 79.68062237690654
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.48248248248248
# Target (Black): 63.67825722664433
# Overall: 63.066844098679496
#
# False Positive Rate (Test Data)
# Source (White): 16.444755898154636
# Target (Black): 28.449636880328388
# (Black FPR) / (White FPR): 1.7300127199529238
# Overall: 21.549409237379162
#
# Source Label Positive Rate: 0.261461466550827
# Target Label Positive Rate: 0.4692082107067108
# Overall Label Positive Rate: 0.36298495531082153
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.24324324324324
# Target (Black): 75.13615416841223
# Overall: 79.28140034803971
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.06206206206206
# Target (Black): 64.0971931294512
# Overall: 63.05660763640086
#
# False Positive Rate (Test Data)
# Source (White): 16.91193646344312
# Target (Black): 29.460056836122515
# (Black FPR) / (White FPR): 1.741968277837576
# Overall: 22.247583243823847
#
# Source Label Positive Rate: 0.26526525616645813
# Target Label Positive Rate: 0.4788437485694885
# Overall Label Positive Rate: 0.3696386516094208
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.24324324324324
# Target (Black): 75.32467532467533
# Overall: 79.37352850854745
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.14214214214214
# Target (Black): 64.0552995391705
# Overall: 63.07708056095813
#
# False Positive Rate (Test Data)
# Source (White): 16.98201354823639
# Target (Black): 29.01799810546258
# (Black FPR) / (White FPR): 1.7087489668429894
# Overall: 22.09989258861439
#
# Source Label Positive Rate: 0.2664664685726166
# Target Label Positive Rate: 0.47486385703086853
# Overall Label Positive Rate: 0.3683079183101654
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.6036036036036
# Target (Black): 75.34562211981567
# Overall: 79.56802129184155
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.02302302302302
# Target (Black): 63.510682865521574
# Overall: 63.26133688197359
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.796968740132616
# (Black FPR) / (White FPR): 1.7412404403461543
# Overall: 21.75080558539205
#
# Source Label Positive Rate: 0.26246246695518494
# Target Label Positive Rate: 0.47214075922966003
# Overall Label Positive Rate: 0.3649298846721649
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.48348348348348
# Target (Black): 75.42940930037705
# Overall: 79.54754836728426
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.6036036036036
# Target (Black): 62.48428990364474
# Overall: 63.05660763640086
#
# False Positive Rate (Test Data)
# Source (White): 16.608269096005607
# Target (Black): 28.828544363751185
# (Black FPR) / (White FPR): 1.7357946332098286
# Overall: 21.804511278195488
#
# Source Label Positive Rate: 0.26246246695518494
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36554408073425293
#
# run: 7/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.52352352352352
# Target (Black): 75.32467532467533
# Overall: 79.51683898044836
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.58358358358358
# Target (Black): 62.903225806451616
# Overall: 63.25110041969495
#
# False Positive Rate (Test Data)
# Source (White): 16.63162812427003
# Target (Black): 28.76539311651405
# (Black FPR) / (White FPR): 1.7295596619634361
# Overall: 21.79108485499463
#
# Source Label Positive Rate: 0.2632632553577423
# Target Label Positive Rate: 0.4715123474597931
# Overall Label Positive Rate: 0.36503225564956665
#
# run: 8/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.58358358358359
# Target (Black): 75.45035609551739
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.38338338338338
# Target (Black): 62.88227901131127
# Overall: 63.138499334629955
#
# False Positive Rate (Test Data)
# Source (White): 16.514832982947908
# Target (Black): 28.733817492895486
# (Black FPR) / (White FPR): 1.739879387370376
# Overall: 21.710526315789473
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47235023975372314
# Overall Label Positive Rate: 0.36472514271736145
#
# run: 9/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.56356356356356
# Target (Black): 75.2199413489736
# Overall: 79.48612959361245
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.24224224224224
# Target (Black): 63.86677838290741
# Overall: 63.03613471184359
#
# False Positive Rate (Test Data)
# Source (White): 16.63162812427003
# Target (Black): 29.239027470792546
# (Black FPR) / (White FPR): 1.7580375927312204
# Overall: 21.992481203007518
#
# Source Label Positive Rate: 0.263663649559021
# Target Label Positive Rate: 0.476749062538147
# Overall Label Positive Rate: 0.3677960932254791
#
# run: 10/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.50350350350351
# Target (Black): 75.34562211981567
# Overall: 79.51683898044836
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.34334334334334
# Target (Black): 63.21742773355677
# Overall: 63.281809806530866
#
# False Positive Rate (Test Data)
# Source (White): 16.608269096005607
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.7453006279152494
# Overall: 21.871643394199786
#
# Source Label Positive Rate: 0.2626626491546631
# Target Label Positive Rate: 0.4746543765068054
# Overall Label Positive Rate: 0.3662606179714203
#
#
# Lambda: 0.9
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.50350350350351
# Target (Black): 75.15710096355258
# Overall: 79.42471081994063
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.04204204204204
# Target (Black): 64.43234185169669
# Overall: 63.21015457058041
#
# False Positive Rate (Test Data)
# Source (White): 16.654987152534453
# Target (Black): 29.081149352699715
# (Black FPR) / (White FPR): 1.7460925719341864
# Overall: 21.93877551020408
#
# Source Label Positive Rate: 0.26346346735954285
# Target Label Positive Rate: 0.4740259647369385
# Overall Label Positive Rate: 0.366362988948822
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.66366366366367
# Target (Black): 75.51319648093842
# Overall: 79.68062237690654
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.48248248248248
# Target (Black): 63.67825722664433
# Overall: 63.066844098679496
#
# False Positive Rate (Test Data)
# Source (White): 16.444755898154636
# Target (Black): 28.449636880328388
# (Black FPR) / (White FPR): 1.7300127199529238
# Overall: 21.549409237379162
#
# Source Label Positive Rate: 0.261461466550827
# Target Label Positive Rate: 0.4692082107067108
# Overall Label Positive Rate: 0.36298495531082153
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.24324324324324
# Target (Black): 75.13615416841223
# Overall: 79.28140034803971
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.06206206206206
# Target (Black): 64.0971931294512
# Overall: 63.05660763640086
#
# False Positive Rate (Test Data)
# Source (White): 16.91193646344312
# Target (Black): 29.460056836122515
# (Black FPR) / (White FPR): 1.741968277837576
# Overall: 22.247583243823847
#
# Source Label Positive Rate: 0.26526525616645813
# Target Label Positive Rate: 0.4788437485694885
# Overall Label Positive Rate: 0.3696386516094208
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.24324324324324
# Target (Black): 75.32467532467533
# Overall: 79.37352850854745
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.14214214214214
# Target (Black): 64.0552995391705
# Overall: 63.07708056095813
#
# False Positive Rate (Test Data)
# Source (White): 16.98201354823639
# Target (Black): 29.01799810546258
# (Black FPR) / (White FPR): 1.7087489668429894
# Overall: 22.09989258861439
#
# Source Label Positive Rate: 0.2664664685726166
# Target Label Positive Rate: 0.47486385703086853
# Overall Label Positive Rate: 0.3683079183101654
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.6036036036036
# Target (Black): 75.34562211981567
# Overall: 79.56802129184155
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.02302302302302
# Target (Black): 63.510682865521574
# Overall: 63.26133688197359
#
# False Positive Rate (Test Data)
# Source (White): 16.538192011212335
# Target (Black): 28.796968740132616
# (Black FPR) / (White FPR): 1.7412404403461543
# Overall: 21.75080558539205
#
# Source Label Positive Rate: 0.26246246695518494
# Target Label Positive Rate: 0.47214075922966003
# Overall Label Positive Rate: 0.3649298846721649
#
# run: 6/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.48348348348348
# Target (Black): 75.42940930037705
# Overall: 79.54754836728426
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.6036036036036
# Target (Black): 62.48428990364474
# Overall: 63.05660763640086
#
# False Positive Rate (Test Data)
# Source (White): 16.608269096005607
# Target (Black): 28.828544363751185
# (Black FPR) / (White FPR): 1.7357946332098286
# Overall: 21.804511278195488
#
# Source Label Positive Rate: 0.26246246695518494
# Target Label Positive Rate: 0.4733975827693939
# Overall Label Positive Rate: 0.36554408073425293
#
# run: 7/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.52352352352352
# Target (Black): 75.32467532467533
# Overall: 79.51683898044836
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.58358358358358
# Target (Black): 62.903225806451616
# Overall: 63.25110041969495
#
# False Positive Rate (Test Data)
# Source (White): 16.63162812427003
# Target (Black): 28.76539311651405
# (Black FPR) / (White FPR): 1.7295596619634361
# Overall: 21.79108485499463
#
# Source Label Positive Rate: 0.2632632553577423
# Target Label Positive Rate: 0.4715123474597931
# Overall Label Positive Rate: 0.36503225564956665
#
# run: 8/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.58358358358359
# Target (Black): 75.45035609551739
# Overall: 79.60896714095608
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.38338338338338
# Target (Black): 62.88227901131127
# Overall: 63.138499334629955
#
# False Positive Rate (Test Data)
# Source (White): 16.514832982947908
# Target (Black): 28.733817492895486
# (Black FPR) / (White FPR): 1.739879387370376
# Overall: 21.710526315789473
#
# Source Label Positive Rate: 0.2618618607521057
# Target Label Positive Rate: 0.47235023975372314
# Overall Label Positive Rate: 0.36472514271736145
#
# run: 9/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.56356356356356
# Target (Black): 75.2199413489736
# Overall: 79.48612959361245
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 62.24224224224224
# Target (Black): 63.86677838290741
# Overall: 63.03613471184359
#
# False Positive Rate (Test Data)
# Source (White): 16.63162812427003
# Target (Black): 29.239027470792546
# (Black FPR) / (White FPR): 1.7580375927312204
# Overall: 21.992481203007518
#
# Source Label Positive Rate: 0.263663649559021
# Target Label Positive Rate: 0.476749062538147
# Overall Label Positive Rate: 0.3677960932254791
#
# run: 10/15
# Label Classifier Accuracy (Test Data)
# Source (White): 83.50350350350351
# Target (Black): 75.34562211981567
# Overall: 79.51683898044836
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 63.34334334334334
# Target (Black): 63.21742773355677
# Overall: 63.281809806530866
#
# False Positive Rate (Test Data)
# Source (White): 16.608269096005607
# Target (Black): 28.986422481844016
# (Black FPR) / (White FPR): 1.7453006279152494
# Overall: 21.871643394199786
#
# Source Label Positive Rate: 0.2626626491546631
# Target Label Positive Rate: 0.4746543765068054
# Overall Label Positive Rate: 0.3662606179714203

# %%
# Get true positive and negative rates for test data !!!!!

# %%
true_pos_black = sum(y_test_target)
print('1s in y_test_target', true_pos_black)
true_pos_white = sum(y_test_source)
print('1s in y_test_source', true_pos_white)

length_white = len(y_test_source)
length_black = len(y_test_target)

true_neg_black = len(y_test_target) - true_pos_black
print('zeros in test black ', true_neg_black)
true_neg_white = len(y_test_source) - true_pos_white
print('zeros in test white ', true_neg_white)

# %%
l = 1
write_conf_results(l, source_test, target_test)

# %%
lams = [1.5, 2, 3]
for l in lams:
    model = train_for_lambda(l)
    write_results(l, model, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5974, Domain Loss: 0.4243
# Source Label Accuracy: 80.74%
# Target Label Accuracy: 70.81%
# Source Domain Accuracy: 39.09%
# Target Domain Accuracy: 87.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6253, Domain Loss: 0.4419
# Source Label Accuracy: 82.90%
# Target Label Accuracy: 74.65%
# Source Domain Accuracy: 39.21%
# Target Domain Accuracy: 85.65%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5350, Domain Loss: 0.3981
# Source Label Accuracy: 82.78%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 38.84%
# Target Domain Accuracy: 85.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5063, Domain Loss: 0.4164
# Source Label Accuracy: 83.10%
# Target Label Accuracy: 75.76%
# Source Domain Accuracy: 39.24%
# Target Domain Accuracy: 82.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4848, Domain Loss: 0.5861
# Source Label Accuracy: 83.43%
# Target Label Accuracy: 75.91%
# Source Domain Accuracy: 38.82%
# Target Domain Accuracy: 80.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4762, Domain Loss: 0.5851
# Source Label Accuracy: 83.58%
# Target Label Accuracy: 76.21%
# Source Domain Accuracy: 38.13%
# Target Domain Accuracy: 79.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5383, Domain Loss: 0.6622
# Source Label Accuracy: 83.59%
# Target Label Accuracy: 75.98%
# Source Domain Accuracy: 39.35%
# Target Domain Accuracy: 77.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4882, Domain Loss: 0.6011
# Source Label Accuracy: 83.44%
# Target Label Accuracy: 76.26%
# Source Domain Accuracy: 41.99%
# Target Domain Accuracy: 72.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5306, Domain Loss: 0.6794
# Source Label Accuracy: 83.96%
# Target Label Accuracy: 76.23%
# Source Domain Accuracy: 43.22%
# Target Domain Accuracy: 68.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4197, Domain Loss: 0.6023
# Source Label Accuracy: 83.98%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 42.32%
# Target Domain Accuracy: 68.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5619, Domain Loss: 0.5566
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 42.35%
# Target Domain Accuracy: 67.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5337, Domain Loss: 0.5954
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 42.64%
# Target Domain Accuracy: 66.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5396, Domain Loss: 0.6288
# Source Label Accuracy: 84.16%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 44.04%
# Target Domain Accuracy: 64.48%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4704, Domain Loss: 0.5740
# Source Label Accuracy: 83.76%
# Target Label Accuracy: 76.70%
# Source Domain Accuracy: 43.81%
# Target Domain Accuracy: 63.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5090, Domain Loss: 0.5898
# Source Label Accuracy: 83.68%
# Target Label Accuracy: 76.60%
# Source Domain Accuracy: 43.71%
# Target Domain Accuracy: 63.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5064, Domain Loss: 0.6352
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 42.88%
# Target Domain Accuracy: 64.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.3785, Domain Loss: 0.6500
# Source Label Accuracy: 83.56%
# Target Label Accuracy: 76.92%
# Source Domain Accuracy: 43.49%
# Target Domain Accuracy: 62.70%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5023, Domain Loss: 0.6328
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 43.77%
# Target Domain Accuracy: 62.16%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5046, Domain Loss: 0.6421
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 43.79%
# Target Domain Accuracy: 62.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4541, Domain Loss: 0.6360
# Source Label Accuracy: 83.69%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 43.56%
# Target Domain Accuracy: 62.26%
#
# Lambda: 1.5
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9975554391479
# Target (Black): 76.77467227306455
# Overall: 79.83623336745138
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.48070543041732
# Target (Black): 62.25575068018798
# Overall: 61.8014329580348
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.718631178707223
# (Black FPR) / (White FPR): 1.4829777732411258
# Overall: 21.89397005261028
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5540, Domain Loss: 0.4011
# Source Label Accuracy: 81.27%
# Target Label Accuracy: 70.94%
# Source Domain Accuracy: 38.21%
# Target Domain Accuracy: 90.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5365, Domain Loss: 0.4921
# Source Label Accuracy: 82.69%
# Target Label Accuracy: 74.80%
# Source Domain Accuracy: 38.33%
# Target Domain Accuracy: 89.12%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5103, Domain Loss: 0.4357
# Source Label Accuracy: 83.57%
# Target Label Accuracy: 75.29%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 88.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5450, Domain Loss: 0.4271
# Source Label Accuracy: 83.40%
# Target Label Accuracy: 75.76%
# Source Domain Accuracy: 37.06%
# Target Domain Accuracy: 89.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4904, Domain Loss: 0.4892
# Source Label Accuracy: 83.39%
# Target Label Accuracy: 75.96%
# Source Domain Accuracy: 36.06%
# Target Domain Accuracy: 88.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4623, Domain Loss: 0.3729
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 75.96%
# Source Domain Accuracy: 34.22%
# Target Domain Accuracy: 87.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5254, Domain Loss: 0.4644
# Source Label Accuracy: 83.94%
# Target Label Accuracy: 76.21%
# Source Domain Accuracy: 34.55%
# Target Domain Accuracy: 83.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5229, Domain Loss: 0.4436
# Source Label Accuracy: 83.92%
# Target Label Accuracy: 76.35%
# Source Domain Accuracy: 35.05%
# Target Domain Accuracy: 82.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4968, Domain Loss: 0.4730
# Source Label Accuracy: 83.96%
# Target Label Accuracy: 76.35%
# Source Domain Accuracy: 38.85%
# Target Domain Accuracy: 73.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4789, Domain Loss: 0.6208
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 38.66%
# Target Domain Accuracy: 73.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4491, Domain Loss: 0.5149
# Source Label Accuracy: 83.75%
# Target Label Accuracy: 76.65%
# Source Domain Accuracy: 38.83%
# Target Domain Accuracy: 71.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4882, Domain Loss: 0.5629
# Source Label Accuracy: 84.01%
# Target Label Accuracy: 76.60%
# Source Domain Accuracy: 40.91%
# Target Domain Accuracy: 68.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5166, Domain Loss: 0.5527
# Source Label Accuracy: 84.04%
# Target Label Accuracy: 76.70%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 67.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5695, Domain Loss: 0.5455
# Source Label Accuracy: 83.95%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 40.89%
# Target Domain Accuracy: 67.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4696, Domain Loss: 0.6522
# Source Label Accuracy: 83.97%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 42.25%
# Target Domain Accuracy: 65.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5160, Domain Loss: 0.6922
# Source Label Accuracy: 84.21%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 40.48%
# Target Domain Accuracy: 67.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4745, Domain Loss: 0.5291
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 41.38%
# Target Domain Accuracy: 66.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4255, Domain Loss: 0.6277
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 76.85%
# Source Domain Accuracy: 42.51%
# Target Domain Accuracy: 63.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4876, Domain Loss: 0.6346
# Source Label Accuracy: 84.21%
# Target Label Accuracy: 77.00%
# Source Domain Accuracy: 42.17%
# Target Domain Accuracy: 63.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5095, Domain Loss: 0.6136
# Source Label Accuracy: 84.23%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 42.89%
# Target Domain Accuracy: 63.72%
#
# Lambda: 2
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.73563820499389
# Target (Black): 76.74993816472916
# Overall: 79.67246673490277
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.437751004016064
# Target (Black): 63.71506307197625
# Overall: 61.207778915046056
#
# False Positive Rate (Test Data)
# Source (White): 19.234789880827933
# Target (Black): 28.098859315589355
# (Black FPR) / (White FPR): 1.4608352620267813
# Overall: 22.379603399433428
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5915, Domain Loss: 0.3751
# Source Label Accuracy: 80.80%
# Target Label Accuracy: 69.70%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 86.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5931, Domain Loss: 0.3786
# Source Label Accuracy: 82.49%
# Target Label Accuracy: 73.98%
# Source Domain Accuracy: 36.51%
# Target Domain Accuracy: 87.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5023, Domain Loss: 0.3923
# Source Label Accuracy: 82.81%
# Target Label Accuracy: 74.92%
# Source Domain Accuracy: 34.66%
# Target Domain Accuracy: 86.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5147, Domain Loss: 0.4611
# Source Label Accuracy: 83.43%
# Target Label Accuracy: 75.49%
# Source Domain Accuracy: 34.47%
# Target Domain Accuracy: 85.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5292, Domain Loss: 0.4205
# Source Label Accuracy: 83.65%
# Target Label Accuracy: 76.01%
# Source Domain Accuracy: 35.60%
# Target Domain Accuracy: 81.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4788, Domain Loss: 0.4684
# Source Label Accuracy: 83.55%
# Target Label Accuracy: 76.11%
# Source Domain Accuracy: 35.65%
# Target Domain Accuracy: 79.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5506, Domain Loss: 0.4489
# Source Label Accuracy: 83.90%
# Target Label Accuracy: 76.28%
# Source Domain Accuracy: 35.67%
# Target Domain Accuracy: 78.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4465, Domain Loss: 0.4902
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.35%
# Source Domain Accuracy: 35.87%
# Target Domain Accuracy: 76.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5047, Domain Loss: 0.5650
# Source Label Accuracy: 83.70%
# Target Label Accuracy: 76.40%
# Source Domain Accuracy: 36.08%
# Target Domain Accuracy: 75.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4511, Domain Loss: 0.6148
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.35%
# Source Domain Accuracy: 37.70%
# Target Domain Accuracy: 71.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5286, Domain Loss: 0.5188
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 76.28%
# Source Domain Accuracy: 38.37%
# Target Domain Accuracy: 71.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5050, Domain Loss: 0.5356
# Source Label Accuracy: 83.85%
# Target Label Accuracy: 76.26%
# Source Domain Accuracy: 38.77%
# Target Domain Accuracy: 69.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5404, Domain Loss: 0.6176
# Source Label Accuracy: 84.15%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 40.57%
# Target Domain Accuracy: 66.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4960, Domain Loss: 0.6139
# Source Label Accuracy: 84.01%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 40.52%
# Target Domain Accuracy: 66.66%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4599, Domain Loss: 0.6803
# Source Label Accuracy: 83.90%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 40.96%
# Target Domain Accuracy: 65.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4385, Domain Loss: 0.6283
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 40.98%
# Target Domain Accuracy: 65.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5024, Domain Loss: 0.6068
# Source Label Accuracy: 83.72%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 40.62%
# Target Domain Accuracy: 65.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4790, Domain Loss: 0.6931
# Source Label Accuracy: 83.88%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 41.39%
# Target Domain Accuracy: 65.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5692, Domain Loss: 0.7051
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 42.10%
# Target Domain Accuracy: 63.72%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5210, Domain Loss: 0.5733
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.65%
# Source Domain Accuracy: 40.82%
# Target Domain Accuracy: 65.77%
#
# Lambda: 3
#
# Label Classifier Accuracy (Test Data)
# Source (White): 81.7181770560503
# Target (Black): 76.65100173138758
# Overall: 79.62128966223132
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.32495198184041
# Target (Black): 65.767994063814
# Overall: 60.81883316274309
#
# False Positive Rate (Test Data)
# Source (White): 19.0884382186912
# Target (Black): 27.79467680608365
# (Black FPR) / (White FPR): 1.4561001003669014
# Overall: 22.17725617159045

# %%
def write_conf_results(lam, test_src, test_targ):
    file_name = 'results_conf_age_'+str(lam)+'.txt'
    my_str = 'Lambda: ' +str(lam) + '\n\n'
    for i in range(5):
        my_str += 'run: ' + str(i+1)+'/15\n'
        model = train_for_lambda(lam)
        results = get_results(model, test_src, test_targ, lam)
        # test accuracy-- source, target, and overall
        my_str += 'Label Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_label_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_label_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_label_accuracy'])+ '\n\n'
        # domain test accuracy-- source, target, and overall
        my_str += 'Domain Classifier Accuracy (Test Data) \n'
        my_str += 'Source (White): ' + str(results['source_domain_accuracy']) + '\n'
        my_str += 'Target (Black): ' + str(results['target_domain_accuracy'])+ '\n'
        my_str += 'Overall: ' + str(results['overall_domain_accuracy'])+ '\n\n'
        # false positives-- source, target, and overall
        my_str += 'False Positive Rate (Test Data) \n'
        my_str += 'Source (White): ' + str(results['fpr_white']) + '\n'
        my_str += 'Target (Black): ' + str(results['fpr_black'])+ '\n'
        my_str += '(Black FPR) / (White FPR): ' +  str(results['fpr_black']/results['fpr_white'])+ '\n'
        my_str += 'Overall: ' + str(results['fpr_overall'])+ '\n\n'
        print(my_str)

    print(my_str)
    with open(file_name, "w") as file:
        file.write(my_str)

# %%
# More lambdas
lams = [2, 3, 5, 10, 15, 100]
for l in lams:
    write_conf_results(l, source_test, target_test)
# Out:
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5242, Domain Loss: 0.4723
# Source Label Accuracy: 81.07%
# Target Label Accuracy: 70.22%
# Source Domain Accuracy: 40.33%
# Target Domain Accuracy: 87.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5886, Domain Loss: 0.4287
# Source Label Accuracy: 82.64%
# Target Label Accuracy: 74.33%
# Source Domain Accuracy: 40.03%
# Target Domain Accuracy: 87.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4812, Domain Loss: 0.3784
# Source Label Accuracy: 82.95%
# Target Label Accuracy: 75.12%
# Source Domain Accuracy: 38.72%
# Target Domain Accuracy: 88.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4779, Domain Loss: 0.4600
# Source Label Accuracy: 83.74%
# Target Label Accuracy: 75.69%
# Source Domain Accuracy: 38.94%
# Target Domain Accuracy: 86.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5479, Domain Loss: 0.4069
# Source Label Accuracy: 83.68%
# Target Label Accuracy: 75.93%
# Source Domain Accuracy: 38.79%
# Target Domain Accuracy: 86.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4609, Domain Loss: 0.4129
# Source Label Accuracy: 83.57%
# Target Label Accuracy: 76.06%
# Source Domain Accuracy: 38.25%
# Target Domain Accuracy: 85.90%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5614, Domain Loss: 0.4871
# Source Label Accuracy: 83.59%
# Target Label Accuracy: 76.18%
# Source Domain Accuracy: 37.59%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5176, Domain Loss: 0.4352
# Source Label Accuracy: 83.60%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 36.73%
# Target Domain Accuracy: 83.43%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4607, Domain Loss: 0.4559
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 36.57%
# Target Domain Accuracy: 81.50%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.6324, Domain Loss: 0.4741
# Source Label Accuracy: 83.88%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 35.50%
# Target Domain Accuracy: 80.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5007, Domain Loss: 0.5409
# Source Label Accuracy: 84.16%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 35.80%
# Target Domain Accuracy: 79.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5622, Domain Loss: 0.4517
# Source Label Accuracy: 83.85%
# Target Label Accuracy: 76.33%
# Source Domain Accuracy: 38.15%
# Target Domain Accuracy: 75.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4614, Domain Loss: 0.5908
# Source Label Accuracy: 84.35%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 37.92%
# Target Domain Accuracy: 75.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5065, Domain Loss: 0.6798
# Source Label Accuracy: 84.10%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 40.20%
# Target Domain Accuracy: 72.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4069, Domain Loss: 0.5446
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 39.74%
# Target Domain Accuracy: 71.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4193, Domain Loss: 0.5817
# Source Label Accuracy: 83.87%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 39.02%
# Target Domain Accuracy: 71.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5154, Domain Loss: 0.6460
# Source Label Accuracy: 83.62%
# Target Label Accuracy: 76.30%
# Source Domain Accuracy: 38.81%
# Target Domain Accuracy: 70.54%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4812, Domain Loss: 0.5801
# Source Label Accuracy: 84.23%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 38.89%
# Target Domain Accuracy: 71.06%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5630, Domain Loss: 0.5066
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 41.27%
# Target Domain Accuracy: 67.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5975, Domain Loss: 0.5553
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 39.66%
# Target Domain Accuracy: 67.67%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6242, Domain Loss: 0.4704
# Source Label Accuracy: 80.96%
# Target Label Accuracy: 70.44%
# Source Domain Accuracy: 39.57%
# Target Domain Accuracy: 88.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5486, Domain Loss: 0.3565
# Source Label Accuracy: 82.58%
# Target Label Accuracy: 74.57%
# Source Domain Accuracy: 39.97%
# Target Domain Accuracy: 87.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4719, Domain Loss: 0.4806
# Source Label Accuracy: 82.97%
# Target Label Accuracy: 75.34%
# Source Domain Accuracy: 40.25%
# Target Domain Accuracy: 86.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5234, Domain Loss: 0.4506
# Source Label Accuracy: 83.45%
# Target Label Accuracy: 75.74%
# Source Domain Accuracy: 39.39%
# Target Domain Accuracy: 87.01%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4412, Domain Loss: 0.5453
# Source Label Accuracy: 83.77%
# Target Label Accuracy: 76.03%
# Source Domain Accuracy: 39.31%
# Target Domain Accuracy: 86.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5413, Domain Loss: 0.4981
# Source Label Accuracy: 83.80%
# Target Label Accuracy: 76.16%
# Source Domain Accuracy: 38.88%
# Target Domain Accuracy: 86.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4932, Domain Loss: 0.4694
# Source Label Accuracy: 83.98%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 39.04%
# Target Domain Accuracy: 85.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.6067, Domain Loss: 0.4293
# Source Label Accuracy: 83.80%
# Target Label Accuracy: 76.40%
# Source Domain Accuracy: 38.08%
# Target Domain Accuracy: 84.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4933, Domain Loss: 0.4479
# Source Label Accuracy: 83.71%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 38.06%
# Target Domain Accuracy: 82.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4810, Domain Loss: 0.5327
# Source Label Accuracy: 84.32%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 38.25%
# Target Domain Accuracy: 79.40%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.6740, Domain Loss: 0.5037
# Source Label Accuracy: 83.87%
# Target Label Accuracy: 76.87%
# Source Domain Accuracy: 37.70%
# Target Domain Accuracy: 78.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4275, Domain Loss: 0.5471
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 37.86%
# Target Domain Accuracy: 76.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5383, Domain Loss: 0.5784
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 37.80%
# Target Domain Accuracy: 74.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5402, Domain Loss: 0.5604
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 39.57%
# Target Domain Accuracy: 70.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5471, Domain Loss: 0.5516
# Source Label Accuracy: 84.08%
# Target Label Accuracy: 76.85%
# Source Domain Accuracy: 39.15%
# Target Domain Accuracy: 70.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5029, Domain Loss: 0.5554
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 40.31%
# Target Domain Accuracy: 68.04%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4937, Domain Loss: 0.5613
# Source Label Accuracy: 84.08%
# Target Label Accuracy: 76.90%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 67.38%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5103, Domain Loss: 0.4944
# Source Label Accuracy: 84.17%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 41.93%
# Target Domain Accuracy: 64.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5054, Domain Loss: 0.5977
# Source Label Accuracy: 83.65%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 40.19%
# Target Domain Accuracy: 66.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4659, Domain Loss: 0.6113
# Source Label Accuracy: 84.40%
# Target Label Accuracy: 76.87%
# Source Domain Accuracy: 41.65%
# Target Domain Accuracy: 64.14%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.87899423782085
# Target (Black): 64.13554291367797
# Overall: 61.05424769703173
#
# False Positive Rate (Test Data)
# Source (White): 18.87936441563872
# Target (Black): 27.680608365019012
# (Black FPR) / (White FPR): 1.4661832758569873
# Overall: 22.001888574126536
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6218, Domain Loss: 0.4641
# Source Label Accuracy: 80.63%
# Target Label Accuracy: 69.38%
# Source Domain Accuracy: 39.23%
# Target Domain Accuracy: 88.08%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6211, Domain Loss: 0.4559
# Source Label Accuracy: 82.53%
# Target Label Accuracy: 73.86%
# Source Domain Accuracy: 38.40%
# Target Domain Accuracy: 88.05%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5558, Domain Loss: 0.3982
# Source Label Accuracy: 83.14%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 37.97%
# Target Domain Accuracy: 87.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5685, Domain Loss: 0.4277
# Source Label Accuracy: 83.61%
# Target Label Accuracy: 75.64%
# Source Domain Accuracy: 37.72%
# Target Domain Accuracy: 88.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.6073, Domain Loss: 0.4142
# Source Label Accuracy: 83.57%
# Target Label Accuracy: 75.69%
# Source Domain Accuracy: 37.72%
# Target Domain Accuracy: 85.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5300, Domain Loss: 0.4611
# Source Label Accuracy: 83.80%
# Target Label Accuracy: 75.83%
# Source Domain Accuracy: 38.11%
# Target Domain Accuracy: 82.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5843, Domain Loss: 0.4632
# Source Label Accuracy: 83.59%
# Target Label Accuracy: 76.13%
# Source Domain Accuracy: 36.20%
# Target Domain Accuracy: 83.30%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5090, Domain Loss: 0.4803
# Source Label Accuracy: 84.18%
# Target Label Accuracy: 76.33%
# Source Domain Accuracy: 37.85%
# Target Domain Accuracy: 79.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5403, Domain Loss: 0.5494
# Source Label Accuracy: 83.77%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 38.11%
# Target Domain Accuracy: 77.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4974, Domain Loss: 0.4693
# Source Label Accuracy: 83.55%
# Target Label Accuracy: 76.65%
# Source Domain Accuracy: 38.06%
# Target Domain Accuracy: 76.82%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5000, Domain Loss: 0.5578
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.35%
# Source Domain Accuracy: 38.37%
# Target Domain Accuracy: 75.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5088, Domain Loss: 0.6193
# Source Label Accuracy: 83.68%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 39.37%
# Target Domain Accuracy: 72.32%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4889, Domain Loss: 0.7005
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 76.65%
# Source Domain Accuracy: 40.15%
# Target Domain Accuracy: 70.17%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5423, Domain Loss: 0.6612
# Source Label Accuracy: 83.87%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 40.80%
# Target Domain Accuracy: 68.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4528, Domain Loss: 0.5107
# Source Label Accuracy: 84.41%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 39.49%
# Target Domain Accuracy: 69.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4456, Domain Loss: 0.5895
# Source Label Accuracy: 83.89%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 42.16%
# Target Domain Accuracy: 65.92%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4784, Domain Loss: 0.5728
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 40.51%
# Target Domain Accuracy: 66.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5452, Domain Loss: 0.6835
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 41.34%
# Target Domain Accuracy: 65.47%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4607, Domain Loss: 0.7357
# Source Label Accuracy: 84.05%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 42.65%
# Target Domain Accuracy: 63.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5380, Domain Loss: 0.5800
# Source Label Accuracy: 84.06%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 42.42%
# Target Domain Accuracy: 63.72%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.87899423782085
# Target (Black): 64.13554291367797
# Overall: 61.05424769703173
#
# False Positive Rate (Test Data)
# Source (White): 18.87936441563872
# Target (Black): 27.680608365019012
# (Black FPR) / (White FPR): 1.4661832758569873
# Overall: 22.001888574126536
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.87532739654269
# Target (Black): 76.74993816472916
# Overall: 79.75435005117707
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.96158547232408
# Target (Black): 63.71506307197625
# Overall: 61.51484135107472
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.79467680608365
# (Black FPR) / (White FPR): 1.46411827272575
# Overall: 22.10980709564279
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5759, Domain Loss: 0.4469
# Source Label Accuracy: 81.13%
# Target Label Accuracy: 69.68%
# Source Domain Accuracy: 40.82%
# Target Domain Accuracy: 86.07%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.4810, Domain Loss: 0.4838
# Source Label Accuracy: 82.44%
# Target Label Accuracy: 73.98%
# Source Domain Accuracy: 39.69%
# Target Domain Accuracy: 85.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5534, Domain Loss: 0.4891
# Source Label Accuracy: 83.01%
# Target Label Accuracy: 75.19%
# Source Domain Accuracy: 40.39%
# Target Domain Accuracy: 85.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4787, Domain Loss: 0.4381
# Source Label Accuracy: 83.07%
# Target Label Accuracy: 75.66%
# Source Domain Accuracy: 37.74%
# Target Domain Accuracy: 85.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5298, Domain Loss: 0.4182
# Source Label Accuracy: 83.40%
# Target Label Accuracy: 75.81%
# Source Domain Accuracy: 36.91%
# Target Domain Accuracy: 84.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4925, Domain Loss: 0.5332
# Source Label Accuracy: 83.73%
# Target Label Accuracy: 75.93%
# Source Domain Accuracy: 37.41%
# Target Domain Accuracy: 82.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5453, Domain Loss: 0.4821
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 76.08%
# Source Domain Accuracy: 37.09%
# Target Domain Accuracy: 80.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4750, Domain Loss: 0.5599
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 76.11%
# Source Domain Accuracy: 37.54%
# Target Domain Accuracy: 78.78%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4483, Domain Loss: 0.5228
# Source Label Accuracy: 84.11%
# Target Label Accuracy: 76.28%
# Source Domain Accuracy: 37.02%
# Target Domain Accuracy: 76.80%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5374, Domain Loss: 0.5136
# Source Label Accuracy: 83.70%
# Target Label Accuracy: 76.33%
# Source Domain Accuracy: 37.78%
# Target Domain Accuracy: 74.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5024, Domain Loss: 0.6560
# Source Label Accuracy: 83.89%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 39.86%
# Target Domain Accuracy: 70.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5088, Domain Loss: 0.5654
# Source Label Accuracy: 84.15%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 40.27%
# Target Domain Accuracy: 68.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4986, Domain Loss: 0.5905
# Source Label Accuracy: 83.93%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 38.16%
# Target Domain Accuracy: 70.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5335, Domain Loss: 0.5819
# Source Label Accuracy: 83.94%
# Target Label Accuracy: 76.70%
# Source Domain Accuracy: 39.53%
# Target Domain Accuracy: 68.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4710, Domain Loss: 0.5900
# Source Label Accuracy: 84.40%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 40.15%
# Target Domain Accuracy: 67.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5995, Domain Loss: 0.5804
# Source Label Accuracy: 84.04%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 40.26%
# Target Domain Accuracy: 66.29%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5464, Domain Loss: 0.5656
# Source Label Accuracy: 84.34%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 39.81%
# Target Domain Accuracy: 66.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4612, Domain Loss: 0.6601
# Source Label Accuracy: 84.28%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 42.16%
# Target Domain Accuracy: 63.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5659, Domain Loss: 0.5871
# Source Label Accuracy: 84.03%
# Target Label Accuracy: 76.70%
# Source Domain Accuracy: 42.90%
# Target Domain Accuracy: 62.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5033, Domain Loss: 0.5851
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.85%
# Source Domain Accuracy: 42.06%
# Target Domain Accuracy: 63.57%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.87899423782085
# Target (Black): 64.13554291367797
# Overall: 61.05424769703173
#
# False Positive Rate (Test Data)
# Source (White): 18.87936441563872
# Target (Black): 27.680608365019012
# (Black FPR) / (White FPR): 1.4661832758569873
# Overall: 22.001888574126536
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.87532739654269
# Target (Black): 76.74993816472916
# Overall: 79.75435005117707
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.96158547232408
# Target (Black): 63.71506307197625
# Overall: 61.51484135107472
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.79467680608365
# (Black FPR) / (White FPR): 1.46411827272575
# Overall: 22.10980709564279
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.8404050986555
# Target (Black): 76.84887459807074
# Overall: 79.77482088024566
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.98376113148245
# Target (Black): 63.566658421963886
# Overall: 60.880245649948826
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.870722433460077
# (Black FPR) / (White FPR): 1.4681240682735632
# Overall: 22.136786726021853
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5810, Domain Loss: 0.4946
# Source Label Accuracy: 80.33%
# Target Label Accuracy: 70.47%
# Source Domain Accuracy: 40.49%
# Target Domain Accuracy: 87.95%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.6387, Domain Loss: 0.4262
# Source Label Accuracy: 82.52%
# Target Label Accuracy: 74.05%
# Source Domain Accuracy: 39.17%
# Target Domain Accuracy: 88.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5498, Domain Loss: 0.4236
# Source Label Accuracy: 82.97%
# Target Label Accuracy: 75.19%
# Source Domain Accuracy: 38.57%
# Target Domain Accuracy: 88.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5495, Domain Loss: 0.4180
# Source Label Accuracy: 83.06%
# Target Label Accuracy: 75.49%
# Source Domain Accuracy: 37.46%
# Target Domain Accuracy: 87.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5606, Domain Loss: 0.5159
# Source Label Accuracy: 83.36%
# Target Label Accuracy: 75.81%
# Source Domain Accuracy: 36.15%
# Target Domain Accuracy: 88.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5106, Domain Loss: 0.4434
# Source Label Accuracy: 83.52%
# Target Label Accuracy: 75.98%
# Source Domain Accuracy: 38.06%
# Target Domain Accuracy: 81.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5015, Domain Loss: 0.4999
# Source Label Accuracy: 83.86%
# Target Label Accuracy: 76.03%
# Source Domain Accuracy: 35.77%
# Target Domain Accuracy: 80.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.4265, Domain Loss: 0.6092
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.40%
# Source Domain Accuracy: 39.44%
# Target Domain Accuracy: 73.88%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5554, Domain Loss: 0.5238
# Source Label Accuracy: 83.71%
# Target Label Accuracy: 76.18%
# Source Domain Accuracy: 39.92%
# Target Domain Accuracy: 72.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.5186, Domain Loss: 0.6139
# Source Label Accuracy: 84.05%
# Target Label Accuracy: 76.38%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 71.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4475, Domain Loss: 0.6069
# Source Label Accuracy: 84.06%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 40.52%
# Target Domain Accuracy: 69.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4994, Domain Loss: 0.5601
# Source Label Accuracy: 83.58%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 41.10%
# Target Domain Accuracy: 67.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5126, Domain Loss: 0.5436
# Source Label Accuracy: 83.80%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 40.37%
# Target Domain Accuracy: 68.22%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4663, Domain Loss: 0.6034
# Source Label Accuracy: 83.95%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 41.62%
# Target Domain Accuracy: 65.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5251, Domain Loss: 0.5890
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 42.09%
# Target Domain Accuracy: 64.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5539, Domain Loss: 0.5779
# Source Label Accuracy: 84.22%
# Target Label Accuracy: 76.80%
# Source Domain Accuracy: 41.06%
# Target Domain Accuracy: 65.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5199, Domain Loss: 0.5828
# Source Label Accuracy: 84.12%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 43.74%
# Target Domain Accuracy: 62.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5852, Domain Loss: 0.5729
# Source Label Accuracy: 83.79%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 40.63%
# Target Domain Accuracy: 66.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4327, Domain Loss: 0.6174
# Source Label Accuracy: 84.04%
# Target Label Accuracy: 76.73%
# Source Domain Accuracy: 41.68%
# Target Domain Accuracy: 64.19%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5784, Domain Loss: 0.5393
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.87%
# Source Domain Accuracy: 41.58%
# Target Domain Accuracy: 63.96%
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.87899423782085
# Target (Black): 64.13554291367797
# Overall: 61.05424769703173
#
# False Positive Rate (Test Data)
# Source (White): 18.87936441563872
# Target (Black): 27.680608365019012
# (Black FPR) / (White FPR): 1.4661832758569873
# Overall: 22.001888574126536
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.87532739654269
# Target (Black): 76.74993816472916
# Overall: 79.75435005117707
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.96158547232408
# Target (Black): 63.71506307197625
# Overall: 61.51484135107472
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.79467680608365
# (Black FPR) / (White FPR): 1.46411827272575
# Overall: 22.10980709564279
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.8404050986555
# Target (Black): 76.84887459807074
# Overall: 79.77482088024566
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.98376113148245
# Target (Black): 63.566658421963886
# Overall: 60.880245649948826
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.870722433460077
# (Black FPR) / (White FPR): 1.4681240682735632
# Overall: 22.136786726021853
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.10232233280949
# Target (Black): 76.87360870640613
# Overall: 79.93858751279427
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.193294918805655
# Target (Black): 63.9624041553302
# Overall: 61.166837256908906
#
# False Positive Rate (Test Data)
# Source (White): 18.58666109136525
# Target (Black): 27.490494296577946
# (Black FPR) / (White FPR): 1.4790442544491824
# Overall: 21.745582085525427
#
#
# Lambda: 2
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.1197834817531
# Target (Black): 76.74993816472916
# Overall: 79.89764585465711
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.626506024096386
# Target (Black): 67.67252040563937
# Overall: 61.19754350051177
#
# False Positive Rate (Test Data)
# Source (White): 18.691197992891492
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.4890805624314183
# Overall: 21.934439498178875
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.87899423782085
# Target (Black): 64.13554291367797
# Overall: 61.05424769703173
#
# False Positive Rate (Test Data)
# Source (White): 18.87936441563872
# Target (Black): 27.680608365019012
# (Black FPR) / (White FPR): 1.4661832758569873
# Overall: 22.001888574126536
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.87532739654269
# Target (Black): 76.74993816472916
# Overall: 79.75435005117707
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.96158547232408
# Target (Black): 63.71506307197625
# Overall: 61.51484135107472
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.79467680608365
# (Black FPR) / (White FPR): 1.46411827272575
# Overall: 22.10980709564279
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.8404050986555
# Target (Black): 76.84887459807074
# Overall: 79.77482088024566
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.98376113148245
# Target (Black): 63.566658421963886
# Overall: 60.880245649948826
#
# False Positive Rate (Test Data)
# Source (White): 18.98390131716496
# Target (Black): 27.870722433460077
# (Black FPR) / (White FPR): 1.4681240682735632
# Overall: 22.136786726021853
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.10232233280949
# Target (Black): 76.87360870640613
# Overall: 79.93858751279427
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.193294918805655
# Target (Black): 63.9624041553302
# Overall: 61.166837256908906
#
# False Positive Rate (Test Data)
# Source (White): 18.58666109136525
# Target (Black): 27.490494296577946
# (Black FPR) / (White FPR): 1.4790442544491824
# Overall: 21.745582085525427
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5948, Domain Loss: 0.4513
# Source Label Accuracy: 80.59%
# Target Label Accuracy: 68.93%
# Source Domain Accuracy: 38.61%
# Target Domain Accuracy: 89.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5164, Domain Loss: 0.4134
# Source Label Accuracy: 82.68%
# Target Label Accuracy: 73.81%
# Source Domain Accuracy: 36.47%
# Target Domain Accuracy: 89.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5071, Domain Loss: 0.5244
# Source Label Accuracy: 83.15%
# Target Label Accuracy: 75.36%
# Source Domain Accuracy: 35.53%
# Target Domain Accuracy: 88.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5441, Domain Loss: 0.3330
# Source Label Accuracy: 83.17%
# Target Label Accuracy: 75.71%
# Source Domain Accuracy: 34.14%
# Target Domain Accuracy: 86.37%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4533, Domain Loss: 0.5278
# Source Label Accuracy: 83.46%
# Target Label Accuracy: 76.08%
# Source Domain Accuracy: 34.70%
# Target Domain Accuracy: 83.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.6101, Domain Loss: 0.3899
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.13%
# Source Domain Accuracy: 35.40%
# Target Domain Accuracy: 81.94%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4200, Domain Loss: 0.4461
# Source Label Accuracy: 83.71%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 36.54%
# Target Domain Accuracy: 78.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5094, Domain Loss: 0.5546
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 38.34%
# Target Domain Accuracy: 77.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5146, Domain Loss: 0.5217
# Source Label Accuracy: 84.27%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 36.57%
# Target Domain Accuracy: 77.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4902, Domain Loss: 0.5168
# Source Label Accuracy: 83.83%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 38.05%
# Target Domain Accuracy: 74.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5641, Domain Loss: 0.4988
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 38.96%
# Target Domain Accuracy: 72.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.4926, Domain Loss: 0.6517
# Source Label Accuracy: 84.13%
# Target Label Accuracy: 76.63%
# Source Domain Accuracy: 39.95%
# Target Domain Accuracy: 70.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4316, Domain Loss: 0.6087
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 76.77%
# Source Domain Accuracy: 39.72%
# Target Domain Accuracy: 71.14%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4849, Domain Loss: 0.6079
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 40.99%
# Target Domain Accuracy: 68.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5375, Domain Loss: 0.6376
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 39.71%
# Target Domain Accuracy: 69.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5865, Domain Loss: 0.6455
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 76.82%
# Source Domain Accuracy: 39.93%
# Target Domain Accuracy: 69.73%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4651, Domain Loss: 0.5099
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 41.93%
# Target Domain Accuracy: 65.62%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5121, Domain Loss: 0.5247
# Source Label Accuracy: 83.98%
# Target Label Accuracy: 76.75%
# Source Domain Accuracy: 39.53%
# Target Domain Accuracy: 69.28%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5086, Domain Loss: 0.5698
# Source Label Accuracy: 83.95%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 40.06%
# Target Domain Accuracy: 67.60%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5135, Domain Loss: 0.5881
# Source Label Accuracy: 84.29%
# Target Label Accuracy: 76.87%
# Source Domain Accuracy: 41.29%
# Target Domain Accuracy: 66.29%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.81386415226122
# Target (Black): 66.28741033885728
# Overall: 61.320368474923235
#
# False Positive Rate (Test Data)
# Source (White): 18.942086556554464
# Target (Black): 27.90874524714829
# (Black FPR) / (White FPR): 1.473372279438303
# Overall: 22.123296910832323
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6055, Domain Loss: 0.4347
# Source Label Accuracy: 81.23%
# Target Label Accuracy: 70.76%
# Source Domain Accuracy: 38.79%
# Target Domain Accuracy: 87.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5259, Domain Loss: 0.4623
# Source Label Accuracy: 82.96%
# Target Label Accuracy: 73.91%
# Source Domain Accuracy: 37.68%
# Target Domain Accuracy: 88.87%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5214, Domain Loss: 0.3580
# Source Label Accuracy: 83.14%
# Target Label Accuracy: 74.94%
# Source Domain Accuracy: 37.68%
# Target Domain Accuracy: 88.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5384, Domain Loss: 0.5236
# Source Label Accuracy: 83.29%
# Target Label Accuracy: 75.19%
# Source Domain Accuracy: 37.17%
# Target Domain Accuracy: 87.24%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5001, Domain Loss: 0.4238
# Source Label Accuracy: 83.76%
# Target Label Accuracy: 75.61%
# Source Domain Accuracy: 36.17%
# Target Domain Accuracy: 85.31%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.4524, Domain Loss: 0.4276
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 75.91%
# Source Domain Accuracy: 37.21%
# Target Domain Accuracy: 82.44%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5425, Domain Loss: 0.4778
# Source Label Accuracy: 83.91%
# Target Label Accuracy: 76.18%
# Source Domain Accuracy: 35.71%
# Target Domain Accuracy: 80.81%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5090, Domain Loss: 0.5295
# Source Label Accuracy: 83.40%
# Target Label Accuracy: 76.06%
# Source Domain Accuracy: 35.61%
# Target Domain Accuracy: 78.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5769, Domain Loss: 0.5782
# Source Label Accuracy: 83.48%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 35.92%
# Target Domain Accuracy: 75.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4528, Domain Loss: 0.5892
# Source Label Accuracy: 83.72%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 36.50%
# Target Domain Accuracy: 74.33%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4956, Domain Loss: 0.6820
# Source Label Accuracy: 83.84%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 38.24%
# Target Domain Accuracy: 70.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5202, Domain Loss: 0.5166
# Source Label Accuracy: 83.82%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 37.78%
# Target Domain Accuracy: 70.79%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.4642, Domain Loss: 0.6609
# Source Label Accuracy: 83.75%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 39.41%
# Target Domain Accuracy: 68.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5058, Domain Loss: 0.6687
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 76.45%
# Source Domain Accuracy: 39.49%
# Target Domain Accuracy: 67.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5185, Domain Loss: 0.5742
# Source Label Accuracy: 83.87%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 40.05%
# Target Domain Accuracy: 67.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5312, Domain Loss: 0.6948
# Source Label Accuracy: 83.69%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 39.54%
# Target Domain Accuracy: 66.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4842, Domain Loss: 0.6112
# Source Label Accuracy: 83.98%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 39.53%
# Target Domain Accuracy: 67.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5446, Domain Loss: 0.5714
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 76.48%
# Source Domain Accuracy: 40.44%
# Target Domain Accuracy: 65.52%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5465, Domain Loss: 0.6852
# Source Label Accuracy: 83.94%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 40.10%
# Target Domain Accuracy: 66.46%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5326, Domain Loss: 0.7090
# Source Label Accuracy: 83.77%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 42.06%
# Target Domain Accuracy: 63.57%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 57.81386415226122
# Target (Black): 66.28741033885728
# Overall: 61.320368474923235
#
# False Positive Rate (Test Data)
# Source (White): 18.942086556554464
# Target (Black): 27.90874524714829
# (Black FPR) / (White FPR): 1.473372279438303
# Overall: 22.123296910832323
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.68325475816309
# Target (Black): 76.552065298046
# Overall: 79.55987717502559
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 59.35044525929806
# Target (Black): 63.566658421963886
# Overall: 61.095189355168884
#
# False Positive Rate (Test Data)
# Source (White): 19.27660464143843
# Target (Black): 28.288973384030417
# (Black FPR) / (White FPR): 1.46752884702622
# Overall: 22.474032105760152
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5866, Domain Loss: 0.3797
# Source Label Accuracy: 80.73%
# Target Label Accuracy: 70.02%
# Source Domain Accuracy: 38.16%
# Target Domain Accuracy: 88.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5598, Domain Loss: 0.4402
# Source Label Accuracy: 82.48%
# Target Label Accuracy: 73.95%
# Source Domain Accuracy: 38.99%
# Target Domain Accuracy: 87.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4655, Domain Loss: 0.3985
# Source Label Accuracy: 83.01%
# Target Label Accuracy: 74.94%
# Source Domain Accuracy: 38.21%
# Target Domain Accuracy: 88.13%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4368, Domain Loss: 0.4282
# Source Label Accuracy: 83.36%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 37.06%
# Target Domain Accuracy: 87.83%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5738, Domain Loss: 0.4301
# Source Label Accuracy: 83.62%
# Target Label Accuracy: 75.69%
# Source Domain Accuracy: 35.31%
# Target Domain Accuracy: 87.51%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5947, Domain Loss: 0.4506
# Source Label Accuracy: 83.54%
# Target Label Accuracy: 75.74%
# Source Domain Accuracy: 33.86%
# Target Domain Accuracy: 86.45%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.4834, Domain Loss: 0.3648
# Source Label Accuracy: 83.61%
# Target Label Accuracy: 75.81%
# Source Domain Accuracy: 34.19%
# Target Domain Accuracy: 83.35%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.6208, Domain Loss: 0.4664
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 75.93%
# Source Domain Accuracy: 34.87%
# Target Domain Accuracy: 80.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4641, Domain Loss: 0.5422
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 75.98%
# Source Domain Accuracy: 35.74%
# Target Domain Accuracy: 78.26%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4512, Domain Loss: 0.5359
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 76.28%
# Source Domain Accuracy: 36.18%
# Target Domain Accuracy: 77.02%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.5539, Domain Loss: 0.5000
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.30%
# Source Domain Accuracy: 34.96%
# Target Domain Accuracy: 76.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5697, Domain Loss: 0.5673
# Source Label Accuracy: 83.71%
# Target Label Accuracy: 76.28%
# Source Domain Accuracy: 36.61%
# Target Domain Accuracy: 73.53%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5413, Domain Loss: 0.5495
# Source Label Accuracy: 84.24%
# Target Label Accuracy: 76.33%
# Source Domain Accuracy: 35.80%
# Target Domain Accuracy: 73.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5275, Domain Loss: 0.5682
# Source Label Accuracy: 84.08%
# Target Label Accuracy: 76.55%
# Source Domain Accuracy: 38.03%
# Target Domain Accuracy: 70.64%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5405, Domain Loss: 0.4860
# Source Label Accuracy: 84.00%
# Target Label Accuracy: 76.58%
# Source Domain Accuracy: 38.95%
# Target Domain Accuracy: 68.76%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4584, Domain Loss: 0.6192
# Source Label Accuracy: 83.73%
# Target Label Accuracy: 76.40%
# Source Domain Accuracy: 39.03%
# Target Domain Accuracy: 67.55%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4941, Domain Loss: 0.6342
# Source Label Accuracy: 83.67%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 39.09%
# Target Domain Accuracy: 66.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.4537, Domain Loss: 0.6983
# Source Label Accuracy: 83.85%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 39.38%
# Target Domain Accuracy: 66.96%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4723, Domain Loss: 0.6876
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.68%
# Source Domain Accuracy: 40.81%
# Target Domain Accuracy: 64.23%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.4621, Domain Loss: 0.5865
# Source Label Accuracy: 84.07%
# Target Label Accuracy: 76.70%
# Source Domain Accuracy: 40.35%
# Target Domain Accuracy: 65.15%
#
# Lambda: 3
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9102496944299
# Target (Black): 76.87360870640613
# Overall: 79.82599795291709
#
# ...
# Source (White): 56.52173913043478
# Target (Black): 78.90180558990848
# Overall: 65.78300921187308
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 27.984790874524716
# (Black FPR) / (White FPR): 1.5039466826163113
# Overall: 21.934439498178875
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.5297, Domain Loss: 0.5176
# Source Label Accuracy: 80.44%
# Target Label Accuracy: 70.59%
# Source Domain Accuracy: 41.30%
# Target Domain Accuracy: 86.84%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5348, Domain Loss: 0.3169
# Source Label Accuracy: 81.77%
# Target Label Accuracy: 72.74%
# Source Domain Accuracy: 41.29%
# Target Domain Accuracy: 86.57%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.5839, Domain Loss: 0.4145
# Source Label Accuracy: 82.46%
# Target Label Accuracy: 74.15%
# Source Domain Accuracy: 41.61%
# Target Domain Accuracy: 85.36%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.5604, Domain Loss: 0.4399
# Source Label Accuracy: 82.51%
# Target Label Accuracy: 74.45%
# Source Domain Accuracy: 42.48%
# Target Domain Accuracy: 84.59%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.4877, Domain Loss: 0.3899
# Source Label Accuracy: 82.98%
# Target Label Accuracy: 74.92%
# Source Domain Accuracy: 41.87%
# Target Domain Accuracy: 85.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5435, Domain Loss: 0.3650
# Source Label Accuracy: 83.02%
# Target Label Accuracy: 75.07%
# Source Domain Accuracy: 42.73%
# Target Domain Accuracy: 82.98%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5187, Domain Loss: 0.3401
# Source Label Accuracy: 83.24%
# Target Label Accuracy: 75.22%
# Source Domain Accuracy: 40.00%
# Target Domain Accuracy: 84.39%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5093, Domain Loss: 0.3402
# Source Label Accuracy: 83.25%
# Target Label Accuracy: 75.39%
# Source Domain Accuracy: 41.44%
# Target Domain Accuracy: 82.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.4479, Domain Loss: 0.4205
# Source Label Accuracy: 83.16%
# Target Label Accuracy: 75.61%
# Source Domain Accuracy: 41.20%
# Target Domain Accuracy: 80.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4115, Domain Loss: 0.4413
# Source Label Accuracy: 83.19%
# Target Label Accuracy: 75.66%
# Source Domain Accuracy: 40.92%
# Target Domain Accuracy: 79.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4947, Domain Loss: 0.3927
# Source Label Accuracy: 83.64%
# Target Label Accuracy: 76.01%
# Source Domain Accuracy: 39.85%
# Target Domain Accuracy: 78.58%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5009, Domain Loss: 0.4681
# Source Label Accuracy: 83.18%
# Target Label Accuracy: 76.16%
# Source Domain Accuracy: 39.57%
# Target Domain Accuracy: 76.77%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.3957, Domain Loss: 0.4451
# Source Label Accuracy: 83.55%
# Target Label Accuracy: 76.03%
# Source Domain Accuracy: 38.41%
# Target Domain Accuracy: 75.93%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.5454, Domain Loss: 0.5853
# Source Label Accuracy: 83.42%
# Target Label Accuracy: 75.93%
# Source Domain Accuracy: 39.47%
# Target Domain Accuracy: 71.56%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.4673, Domain Loss: 0.5392
# Source Label Accuracy: 83.56%
# Target Label Accuracy: 76.08%
# Source Domain Accuracy: 41.51%
# Target Domain Accuracy: 66.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.4934, Domain Loss: 0.6310
# Source Label Accuracy: 83.13%
# Target Label Accuracy: 76.06%
# Source Domain Accuracy: 43.18%
# Target Domain Accuracy: 63.67%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.4373, Domain Loss: 0.6920
# Source Label Accuracy: 83.67%
# Target Label Accuracy: 76.03%
# Source Domain Accuracy: 41.78%
# Target Domain Accuracy: 65.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5352, Domain Loss: 0.5724
# Source Label Accuracy: 84.02%
# Target Label Accuracy: 76.06%
# Source Domain Accuracy: 42.65%
# Target Domain Accuracy: 64.68%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.5095, Domain Loss: 0.6646
# Source Label Accuracy: 83.66%
# Target Label Accuracy: 76.06%
# Source Domain Accuracy: 44.04%
# Target Domain Accuracy: 61.41%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5830, Domain Loss: 0.6675
# Source Label Accuracy: 83.79%
# Target Label Accuracy: 75.91%
# Source Domain Accuracy: 43.67%
# Target Domain Accuracy: 61.74%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9626331412607
# Target (Black): 76.45312886470442
# Overall: 79.68270214943705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.610441767068274
# Target (Black): 77.31882265644323
# Overall: 62.83520982599795
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 28.250950570342205
# (Black FPR) / (White FPR): 1.5182505233477164
# Overall: 22.0288682045056
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0674000349223
# Target (Black): 76.67573583972298
# Overall: 79.83623336745138
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.03282696001397
# Target (Black): 71.58050952263171
# Overall: 62.46673490276356
#
# False Positive Rate (Test Data)
# Source (White): 18.52393895044951
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.5025259851170296
# Overall: 21.82652097666262
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0324777370351
# Target (Black): 76.50259708137521
# Overall: 79.74411463664278
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.52173913043478
# Target (Black): 78.90180558990848
# Overall: 65.78300921187308
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 27.984790874524716
# (Black FPR) / (White FPR): 1.5039466826163113
# Overall: 21.934439498178875
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.49118211978349
# Target (Black): 75.90897848132575
# Overall: 79.18116683725691
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.07909900471451
# Target (Black): 61.736334405144696
# Overall: 61.3510747185261
#
# False Positive Rate (Test Data)
# Source (White): 19.192975120217437
# Target (Black): 28.8212927756654
# (Black FPR) / (White FPR): 1.5016584242484488
# Overall: 22.60893025765547
#
#
# label trained
# domain trained
# feature extractor trained
# Epoch [1/20], Label Loss: 0.6199, Domain Loss: 0.4346
# Source Label Accuracy: 80.99%
# Target Label Accuracy: 70.02%
# Source Domain Accuracy: 41.11%
# Target Domain Accuracy: 84.91%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [2/20], Label Loss: 0.5703, Domain Loss: 0.4919
# Source Label Accuracy: 82.12%
# Target Label Accuracy: 72.62%
# Source Domain Accuracy: 41.81%
# Target Domain Accuracy: 84.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [3/20], Label Loss: 0.4752, Domain Loss: 0.4896
# Source Label Accuracy: 82.70%
# Target Label Accuracy: 74.00%
# Source Domain Accuracy: 41.80%
# Target Domain Accuracy: 84.00%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [4/20], Label Loss: 0.4599, Domain Loss: 0.4403
# Source Label Accuracy: 82.67%
# Target Label Accuracy: 74.55%
# Source Domain Accuracy: 41.56%
# Target Domain Accuracy: 83.18%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [5/20], Label Loss: 0.5440, Domain Loss: 0.4672
# Source Label Accuracy: 83.12%
# Target Label Accuracy: 74.80%
# Source Domain Accuracy: 42.71%
# Target Domain Accuracy: 81.03%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [6/20], Label Loss: 0.5501, Domain Loss: 0.4146
# Source Label Accuracy: 83.22%
# Target Label Accuracy: 75.02%
# Source Domain Accuracy: 40.77%
# Target Domain Accuracy: 83.21%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [7/20], Label Loss: 0.5714, Domain Loss: 0.4650
# Source Label Accuracy: 83.42%
# Target Label Accuracy: 75.41%
# Source Domain Accuracy: 41.59%
# Target Domain Accuracy: 80.86%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [8/20], Label Loss: 0.5532, Domain Loss: 0.4652
# Source Label Accuracy: 83.35%
# Target Label Accuracy: 75.49%
# Source Domain Accuracy: 38.98%
# Target Domain Accuracy: 81.89%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [9/20], Label Loss: 0.5632, Domain Loss: 0.3913
# Source Label Accuracy: 83.28%
# Target Label Accuracy: 75.59%
# Source Domain Accuracy: 39.22%
# Target Domain Accuracy: 80.61%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [10/20], Label Loss: 0.4949, Domain Loss: 0.5404
# Source Label Accuracy: 83.68%
# Target Label Accuracy: 75.66%
# Source Domain Accuracy: 39.76%
# Target Domain Accuracy: 78.09%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [11/20], Label Loss: 0.4636, Domain Loss: 0.5416
# Source Label Accuracy: 83.54%
# Target Label Accuracy: 75.76%
# Source Domain Accuracy: 40.28%
# Target Domain Accuracy: 75.49%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [12/20], Label Loss: 0.5195, Domain Loss: 0.4190
# Source Label Accuracy: 83.76%
# Target Label Accuracy: 75.91%
# Source Domain Accuracy: 38.15%
# Target Domain Accuracy: 76.97%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [13/20], Label Loss: 0.5203, Domain Loss: 0.4213
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.13%
# Source Domain Accuracy: 39.30%
# Target Domain Accuracy: 74.15%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [14/20], Label Loss: 0.4412, Domain Loss: 0.4239
# Source Label Accuracy: 83.93%
# Target Label Accuracy: 76.26%
# Source Domain Accuracy: 41.44%
# Target Domain Accuracy: 70.10%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [15/20], Label Loss: 0.5246, Domain Loss: 0.4511
# Source Label Accuracy: 83.54%
# Target Label Accuracy: 76.18%
# Source Domain Accuracy: 40.22%
# Target Domain Accuracy: 70.34%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [16/20], Label Loss: 0.5513, Domain Loss: 0.4147
# Source Label Accuracy: 83.44%
# Target Label Accuracy: 76.23%
# Source Domain Accuracy: 40.08%
# Target Domain Accuracy: 69.63%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [17/20], Label Loss: 0.5100, Domain Loss: 0.4788
# Source Label Accuracy: 83.78%
# Target Label Accuracy: 76.40%
# Source Domain Accuracy: 39.47%
# Target Domain Accuracy: 69.85%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [18/20], Label Loss: 0.5383, Domain Loss: 0.5045
# Source Label Accuracy: 83.76%
# Target Label Accuracy: 76.43%
# Source Domain Accuracy: 41.78%
# Target Domain Accuracy: 65.42%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [19/20], Label Loss: 0.4913, Domain Loss: 0.4648
# Source Label Accuracy: 83.99%
# Target Label Accuracy: 76.53%
# Source Domain Accuracy: 43.78%
# Target Domain Accuracy: 61.71%
#
# label trained
# domain trained
# feature extractor trained
# Epoch [20/20], Label Loss: 0.5030, Domain Loss: 0.5988
# Source Label Accuracy: 83.81%
# Target Label Accuracy: 76.50%
# Source Domain Accuracy: 42.05%
# Target Domain Accuracy: 62.73%
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9626331412607
# Target (Black): 76.45312886470442
# Overall: 79.68270214943705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.610441767068274
# Target (Black): 77.31882265644323
# Overall: 62.83520982599795
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 28.250950570342205
# (Black FPR) / (White FPR): 1.5182505233477164
# Overall: 22.0288682045056
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0674000349223
# Target (Black): 76.67573583972298
# Overall: 79.83623336745138
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.03282696001397
# Target (Black): 71.58050952263171
# Overall: 62.46673490276356
#
# False Positive Rate (Test Data)
# Source (White): 18.52393895044951
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.5025259851170296
# Overall: 21.82652097666262
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0324777370351
# Target (Black): 76.50259708137521
# Overall: 79.74411463664278
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.52173913043478
# Target (Black): 78.90180558990848
# Overall: 65.78300921187308
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 27.984790874524716
# (Black FPR) / (White FPR): 1.5039466826163113
# Overall: 21.934439498178875
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.49118211978349
# Target (Black): 75.90897848132575
# Overall: 79.18116683725691
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.07909900471451
# Target (Black): 61.736334405144696
# Overall: 61.3510747185261
#
# False Positive Rate (Test Data)
# Source (White): 19.192975120217437
# Target (Black): 28.8212927756654
# (Black FPR) / (White FPR): 1.5016584242484488
# Overall: 22.60893025765547
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9626331412607
# Target (Black): 76.50259708137521
# Overall: 79.70317297850563
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.25039287585123
# Target (Black): 62.725698738560475
# Overall: 60.102354145342886
#
# False Positive Rate (Test Data)
# Source (White): 18.58666109136525
# Target (Black): 27.30038022813688
# (Black FPR) / (White FPR): 1.468815732634181
# Overall: 21.67813300957777
#
#
# Lambda: 100
#
# run: 1/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9626331412607
# Target (Black): 76.45312886470442
# Overall: 79.68270214943705
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 52.610441767068274
# Target (Black): 77.31882265644323
# Overall: 62.83520982599795
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 28.250950570342205
# (Black FPR) / (White FPR): 1.5182505233477164
# Overall: 22.0288682045056
#
# run: 2/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0674000349223
# Target (Black): 76.67573583972298
# Overall: 79.83623336745138
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.03282696001397
# Target (Black): 71.58050952263171
# Overall: 62.46673490276356
#
# False Positive Rate (Test Data)
# Source (White): 18.52393895044951
# Target (Black): 27.832699619771862
# (Black FPR) / (White FPR): 1.5025259851170296
# Overall: 21.82652097666262
#
# run: 3/15
# Label Classifier Accuracy (Test Data)
# Source (White): 82.0324777370351
# Target (Black): 76.50259708137521
# Overall: 79.74411463664278
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 56.52173913043478
# Target (Black): 78.90180558990848
# Overall: 65.78300921187308
#
# False Positive Rate (Test Data)
# Source (White): 18.6075684716705
# Target (Black): 27.984790874524716
# (Black FPR) / (White FPR): 1.5039466826163113
# Overall: 21.934439498178875
#
# run: 4/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.49118211978349
# Target (Black): 75.90897848132575
# Overall: 79.18116683725691
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 61.07909900471451
# Target (Black): 61.736334405144696
# Overall: 61.3510747185261
#
# False Positive Rate (Test Data)
# Source (White): 19.192975120217437
# Target (Black): 28.8212927756654
# (Black FPR) / (White FPR): 1.5016584242484488
# Overall: 22.60893025765547
#
# run: 5/15
# Label Classifier Accuracy (Test Data)
# Source (White): 81.9626331412607
# Target (Black): 76.50259708137521
# Overall: 79.70317297850563
#
# Domain Classifier Accuracy (Test Data)
# Source (White): 58.25039287585123
# Target (Black): 62.725698738560475
# Overall: 60.102354145342886
#
# False Positive Rate (Test Data)
# Source (White): 18.58666109136525
# Target (Black): 27.30038022813688
# (Black FPR) / (White FPR): 1.468815732634181
# Overall: 21.67813300957777
